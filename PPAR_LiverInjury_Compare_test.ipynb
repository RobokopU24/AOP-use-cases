# %%
# Parameter inputs
aragorn_submit_url = "https://aragorn-u24.apps.renci.org/robokop/query"
# trapi_submit_url = "http://automat-u24.apps.renci.org/robokopkg/1.3/query"
trapi_submit_url = "http://automat-u24.apps.renci.org/robokopkg/1.4/query"

automat_cypher_submit_url = "https://automat-u24.apps.renci.org/robokopkg/cypher"
robokopkg_bolt_url = "bolt://robokopkg.renci.org:7687"

input_search_string = 'ppara'
output_search_string = 'liver fibrosis'

# %%
import requests
import os
import json
import time
import pandas as pd
import pprint
pp = pprint.PrettyPrinter(indent=5)

from datetime import datetime
from pathlib import Path
from collections import Counter

# %%
# Initializing directory to write
now = datetime.now()
dt_string = now.strftime("%Y-%m-%d_%H%M%S")
write_dir_trapi_automat = Path("output/compare/"+str(dt_string)+"/trapi/automat")
write_dir_trapi_automat.mkdir(parents=True, exist_ok=True)

write_dir_trapi_ara = Path("output/compare/"+str(dt_string)+"/trapi/ara")
write_dir_trapi_ara.mkdir(parents=True, exist_ok=True)

write_dir_cypher_automat = Path("output/compare/"+str(dt_string)+"/cypher/automat")
write_dir_cypher_automat.mkdir(parents=True, exist_ok=True)

write_dir_cypher_robokopkg = Path("output/compare/"+str(dt_string)+"/cypher/robokopkg")
write_dir_cypher_robokopkg.mkdir(parents=True, exist_ok=True)

# %%
# Pathway results to load
write_dir_cypher_automat = "output/compare/"+str(dt_string)+"/cypher/automat"
write_dir_cypher_robokopkg = "output/compare/"+str(dt_string)+"/cypher/robokopkg"
ARA_results_file = "output/compare/"+str(dt_string)+"/trapi/ara/results_ARA.csv"
TRAPI_results_file = "output/compare/"+str(dt_string)+"/trapi/automat/results_TRAPI.csv"
Cypher_ROBOKOPKG_results_file = "output/compare/"+str(dt_string)+"/cypher/robokopkg/results.csv"
Cypher_ROBOKOPKG_single_results_file = "output/compare/"+str(dt_string)+"/cypher/robokopkg_single/results.csv"
Cypher_Automat_results_file = "output/compare/"+str(dt_string)+"/cypher/automat/results.csv"
write_dir_compare = "output/compare/"+str(dt_string)+""
exemplar_results_file = "output/compare/"+str(dt_string)+"/exemplar_data.csv"
qbuilder_bio_entity_results_file = "output/compare/"+str(dt_string)+"/qbuilder_bio_entity_data.csv"
qbuilder_blank_results_file = "output/compare/"+str(dt_string)+"/qbuilder_blank_data.csv"
ARA_PPARA_Fibrosis_results_file = "output/compare/"+str(dt_string)+"/results_ARA_PPARA_Fibrosis.csv"

# %%
results_date = "2023-07-07_153233" # report out 2023-07-10, 2023-07-24
results_date = "2023-08-03_112930" # report out 2023-08-07
results_date = "2023-08-18_125007" # report out 2023-08-21 (with additional IDs)
results_date = "2023-08-18_133624" # report out 2023-08-21 (without additional IDs)

# %%
# Pathway results to load and write directory to specify (on David's work computer from previous run)
write_dir_cypher_automat = "output/compare/"+results_date+"/cypher/automat"
write_dir_cypher_robokopkg = "output/compare/"+results_date+"/cypher/robokopkg"
ARA_results_file = "output/compare/"+results_date+"/trapi/ara/results_ARA.csv"
TRAPI_results_file = "output/compare/"+results_date+"/trapi/automat/results_TRAPI.csv"
Cypher_ROBOKOPKG_results_file = "output/compare/"+results_date+"/cypher/robokopkg/results.csv"
Cypher_ROBOKOPKG_single_results_file = "output/compare/"+results_date+"/cypher/robokopkg_single/results.csv"
Cypher_Automat_results_file = "output/compare/"+results_date+"/cypher/automat/results.csv"
write_dir_compare = "output/compare/"+results_date+""
exemplar_results_file = "output/compare/"+results_date+"/exemplar_data.csv"
qbuilder_bio_entity_results_file = "output/compare/"+results_date+"/qbuilder_bio_entity_data.csv"
qbuilder_blank_results_file = "output/compare/"+results_date+"/qbuilder_blank_data.csv"
ARA_PPARA_Fibrosis_results_file = "output/compare/"+results_date+"/results_ARA_PPARA_Fibrosis.csv"

# %%
# Initializing Neo4j connection class
user = 'neo4j'
pw = ''

from neo4j import GraphDatabase
class Neo4jConnection:
    
    def __init__(self, uri, user, pwd):
        self.__uri = uri
        self.__user = user
        self.__pwd = pwd
        self.__driver = None
        try:
            self.__driver = GraphDatabase.driver(self.__uri, auth=(self.__user, self.__pwd))
        except Exception as e:
            print("Failed to create the driver:", e)
        
    def close(self):
        if self.__driver is not None:
            self.__driver.close()
        
    def query(self, query, db=None):
        assert self.__driver is not None, "Driver not initialized!"
        session = None
        response = None
        try: 
            session = self.__driver.session(database=db) if db is not None else self.__driver.session()
            response = list(session.run(query))
        except Exception as e:
            print("Query failed:", e)
        finally: 
            if session is not None:
                session.close()
        return response

# %% [markdown]
# ## Generating data for comparison

# %% [markdown]
# ### Getting "Input/Output" CURIES

# %%
results = requests.post(f'https://name-resolution-sri.renci.org/lookup?string={input_search_string}&offset=0&limit=100')
results_json = results.json()
#print(json.dumps(results_json,indent=4))
input_node_id_list = list(results_json.keys())
print(input_node_id_list)
print(f"Number of 'input' IDs: {len(input_node_id_list)}")
# Out:
# ['UniProtKB:P37230', 'UniProtKB:Q07869', 'UniProtKB:Q95N78', 'PR:000013056', 'UniProtKB:P23204', 'NCBIGene:19013', 'NCBIGene:25747', 'NCBIGene:5465', 'NCBIGene:557714', 'NCBIGene:30755', 'NCBIGene:563298', 'UMLS:C0166415', 'NCBIGene:10891', 'NCBIGene:133522', 'UMLS:C2984537', 'NCBIGene:400931', 'PR:000040325', 'UMLS:C1868415', 'MESH:C000630914', 'MESH:C000634429', 'UMLS:C5226508', 'UMLS:C5197094', 'UMLS:C5417797', 'REACT:R-SSC-400204', 'REACT:R-BTA-400204', 'UMLS:C1518805', 'REACT:R-DRE-400204', 'REACT:R-HSA-400204', 'REACT:R-MMU-400204', 'REACT:R-BTA-9734475', 'REACT:R-SSC-9734475', 'REACT:R-HSA-879724', 'REACT:R-DRE-9734475', 'REACT:R-HSA-9734475', 'REACT:R-CFA-400204', 'REACT:R-MMU-9734475', 'REACT:R-RNO-400204', 'REACT:R-XTR-400204', 'REACT:R-CFA-9734475', 'REACT:R-RNO-9734475', 'REACT:R-XTR-9734475', 'REACT:R-DME-400204', 'REACT:R-HSA-1989781', 'REACT:R-BTA-4341070', 'REACT:R-DME-9734475', 'REACT:R-BTA-400143', 'REACT:R-DRE-400143', 'REACT:R-DRE-4341070', 'REACT:R-MMU-400143', 'REACT:R-HSA-400143', 'REACT:R-MMU-4341070', 'REACT:R-HSA-4341070', 'REACT:R-GGA-4341070', 'REACT:R-GGA-400143', 'REACT:R-SSC-400183', 'REACT:R-BTA-400183', 'NCBIGene:80205', 'REACT:R-CFA-400143', 'REACT:R-DRE-400183', 'REACT:R-MMU-400183', 'REACT:R-HSA-5663156', 'REACT:R-RNO-400143', 'REACT:R-HSA-400183', 'REACT:R-RNO-4341070', 'REACT:R-XTR-4341070', 'REACT:R-BTA-400206', 'REACT:R-SSC-400206', 'REACT:R-DRE-400206', 'REACT:R-CFA-400183', 'UMLS:C5575466', 'REACT:R-MMU-400206', 'REACT:R-HSA-400206', 'REACT:R-CEL-4341070', 'REACT:R-RNO-400183', 'REACT:R-DME-400143', 'REACT:R-CFA-400206', 'REACT:R-RNO-400206', 'REACT:R-XTR-400206', 'REACT:R-DME-400183', 'REACT:R-DME-400206']
# Number of 'input' IDs: 80

# %%
# TO-DO- sanity check and get the preferred labels for each of these - output as table
for id, name_list in results_json.items():
    print(f"{id}: {name_list}")
# Out:
# UniProtKB:P37230: ['Ppara', 'Ppar', 'Nr1c1', 'rPPARA', 'PPAR-alpha (rat)', 'nuclear receptor subfamily 1 group C member 1 (rat)', 'peroxisome proliferator-activated receptor alpha (rat)']
# UniProtKB:Q07869: ['PPARA', 'PPARA', 'PPAR', 'NR1C1', 'hPPARA', 'PPAR-Alpha', 'PPAR-alpha (human)', 'Nuclear Receptor Subfamily 1 Group C Member 1', 'Peroxisome Proliferator-Activated Receptor Alpha', 'nuclear receptor subfamily 1 group C member 1 (human)', 'Peroxisome Proliferator-Activated Receptor Alpha, human', 'peroxisome proliferator-activated receptor alpha (human)']
# UniProtKB:Q95N78: ['PPARA', 'dog-PPARA', 'NR1C1', 'PPAR-alpha (dog)', 'nuclear receptor subfamily 1 group C member 1 (dog)', 'peroxisome proliferator-activated receptor alpha (dog)']
# PR:000013056: ['PPARA', 'PPAR', 'NR1C1', 'PPAR-alpha', 'nuclear receptor subfamily 1 group C member 1', 'peroxisome proliferator-activated receptor alpha']
# UniProtKB:P23204: ['Ppara', 'Ppar', 'Nr1c1', 'mPPARA', 'PPAR-alpha (mouse)', 'nuclear receptor subfamily 1 group C member 1 (mouse)', 'peroxisome proliferator-activated receptor alpha (mouse)']
# NCBIGene:19013: ['Ppara', 'Ppara (Mmus)']
# NCBIGene:25747: ['Ppara']
# NCBIGene:5465: ['PPARA', 'PPARA gene', 'PPARA Gene', 'PPAR', 'NR1C1', 'hPPAR', 'hPPAR', 'NR1C1', 'PEROXISOME PROLIFERATOR-ACTIVATED RECEPTOR', 'peroxisome proliferator-activated receptor alpha', 'PEROXISOME PROLIFERATOR-ACTIVATED RECEPTOR-ALPHA', 'peroxisome proliferator activated receptor alpha', 'peroxisome proliferative activated receptor, alpha', 'Peroxisome Proliferator-Activated Receptor Alpha Gene']
# NCBIGene:557714: ['pparab']
# NCBIGene:30755: ['ppara2']
# NCBIGene:563298: ['pparaa']
# UMLS:C0166415: ['PPARalpha', 'PPAR alpha', 'Peroxisome Proliferator-Activated Receptor alpha', 'Peroxisome Proliferator Activated Receptor alpha']
# NCBIGene:10891: ['PPARAGCIα', 'PGC1', 'PGC1', 'PGC1A', 'PGC1A', 'PPARGC1', 'PPARGC1A', 'PGC-1alpha', 'PGC1-ALPHA', 'PGC-1alpha', 'PPARGC1A Gene', 'PPARGC1A gene', 'PPAR-GAMMA COACTIVATOR 1', 'PPARG coactivator 1 alpha', 'PPARgamma coactivator 1alpha', 'PPARgamma coactivator 1alpha', 'PPAR-GAMMA COACTIVATOR 1-ALPHA', 'PEROXISOME PROLIFERATOR-ACTIVATED RECEPTOR-GAMMA, COACTIVATOR 1', 'peroxisome proliferative activated receptor, gamma, coactivator 1', 'peroxisome proliferator-activated receptor gamma, coactivator 1 alpha', 'PEROXISOME PROLIFERATOR-ACTIVATED RECEPTOR-GAMMA, COACTIVATOR 1, ALPHA', 'peroxisome proliferative activated receptor, gamma, coactivator 1, alpha', 'Peroxisome Proliferator-Activated Receptor Gamma, Coactivator 1 Alpha Gene']
# NCBIGene:133522: ['PPARAGCIβ', 'PERC', 'PERC', 'PGC1B', 'ERRL1', 'PGC1B', 'PPARGC1B', 'PGC1-BETA', 'PPARGC1B Gene', 'PPARGC1B gene', 'PPARG coactivator 1 beta', 'PPARgamma coactivator 1 beta', 'PPARgamma coactivator 1 beta', 'PPAR-GAMMA COACTIVATOR 1-BETA', 'PGC1-RELATED ESTROGEN RECEPTOR COACTIVATOR', 'ESTROGEN RECEPTOR-RELATED RECEPTOR LIGAND 1', 'peroxisome proliferator-activated receptor gamma, coactivator 1 beta', 'PEROXISOME PROLIFERATOR-ACTIVATED RECEPTOR-GAMMA, COACTIVATOR 1, BETA', 'peroxisome proliferative activated receptor, gamma, coactivator 1, beta', 'Peroxisome Proliferator-Activated Receptor Gamma, Coactivator 1 Beta Gene']
# UMLS:C2984537: ['PPARalpha', 'PPARA wt Allele', 'PPAR', 'NR1C1', 'MGC2452', 'MGC2237', 'Peroxisome Proliferator-Activated Receptor Alpha wt Allele']
# NCBIGene:400931: ['linc-Ppara', 'LINC-PPARA', 'linc-Ppara', 'LONG INTERGENIC NONCODING RNA PPARA', 'MIRLET7BHG', 'MIRLET7BHG gene', 'MIRLET7B host gene', 'lincRNA MIRLET7BHG', 'MIRLET7B HOST GENE, NONCODING', 'MIRLET7B host gene (non-protein coding)', 'LONG INTERGENIC NONCODING RNA MIRLET7BHG']
# PR:000040325: ['PPARA/iso:1', 'peroxisome proliferator-activated receptor alpha isoform 1']
# UMLS:C1868415: ['PPARA, LEU162VAL']
# MESH:C000630914: ['Ppara protein, mouse']
# MESH:C000634429: ['PPARA protein, human']
# UMLS:C5226508: ['PPARA protein, human', 'PPARalpha protein, human', 'peroxisome proliferator activated receptor alpha protein, human']
# UMLS:C5197094: ['Ppara protein, mouse', 'peroxisome proliferator activated receptor alpha protein, mouse']
# UMLS:C5417797: ['PPARA Antagonist TPST-1120', 'PPARalpha Antagonist TPST-1120', 'TPST1120', 'TPST 1120', 'TPST-1120', 'PPAR Alpha Antagonist TPST-1120', 'Peroxisome Proliferator Activated Receptor Alpha Antagonist TPST-1120']
# REACT:R-SSC-400204: ['PPARA binds RXRA (Sus scrofa)']
# REACT:R-BTA-400204: ['PPARA binds RXRA (Bos taurus)']
# UMLS:C1518805: ['PPARA Gene Regulation Pathway', 'PPAR-alpha Gene Regulation Pathway']
# REACT:R-DRE-400204: ['PPARA binds RXRA (Danio rerio)']
# REACT:R-HSA-400204: ['PPARA binds RXRA (Homo sapiens)']
# REACT:R-MMU-400204: ['PPARA binds RXRA (Mus musculus)']
# REACT:R-BTA-9734475: ['PPARA binds fibrates (Bos taurus)']
# REACT:R-SSC-9734475: ['PPARA binds fibrates (Sus scrofa)']
# REACT:R-HSA-879724: ['Expression of PPARA (Homo sapiens)']
# REACT:R-DRE-9734475: ['PPARA binds fibrates (Danio rerio)']
# REACT:R-HSA-9734475: ['PPARA binds fibrates (Homo sapiens)']
# REACT:R-CFA-400204: ['PPARA binds RXRA (Canis familiaris)']
# REACT:R-MMU-9734475: ['PPARA binds fibrates (Mus musculus)']
# REACT:R-RNO-400204: ['PPARA binds RXRA (Rattus norvegicus)']
# REACT:R-XTR-400204: ['PPARA binds RXRA (Xenopus tropicalis)']
# REACT:R-CFA-9734475: ['PPARA binds fibrates (Canis familiaris)']
# REACT:R-RNO-9734475: ['PPARA binds fibrates (Rattus norvegicus)']
# REACT:R-XTR-9734475: ['PPARA binds fibrates (Xenopus tropicalis)']
# REACT:R-DME-400204: ['PPARA binds RXRA (Drosophila melanogaster)']
# REACT:R-HSA-1989781: ['PPARA activates gene expression (Homo sapiens)']
# REACT:R-BTA-4341070: ['PIAS4 SUMOylates PPARA with SUMO1 (Bos taurus)']
# REACT:R-DME-9734475: ['PPARA binds fibrates (Drosophila melanogaster)']
# REACT:R-BTA-400143: ['Fatty acid ligands activate PPARA (Bos taurus)']
# REACT:R-DRE-400143: ['Fatty acid ligands activate PPARA (Danio rerio)']
# REACT:R-DRE-4341070: ['PIAS4 SUMOylates PPARA with SUMO1 (Danio rerio)']
# REACT:R-MMU-400143: ['Fatty acid ligands activate PPARA (Mus musculus)']
# REACT:R-HSA-400143: ['Fatty acid ligands activate PPARA (Homo sapiens)']
# REACT:R-MMU-4341070: ['PIAS4 SUMOylates PPARA with SUMO1 (Mus musculus)']
# REACT:R-HSA-4341070: ['PIAS4 SUMOylates PPARA with SUMO1 (Homo sapiens)']
# REACT:R-GGA-4341070: ['PIAS4 SUMOylates PPARA with SUMO1 (Gallus gallus)']
# REACT:R-GGA-400143: ['Fatty acid ligands activate PPARA (Gallus gallus)']
# REACT:R-SSC-400183: ['PPARA:RXRA binds Corepressors of PPARA (Sus scrofa)']
# REACT:R-BTA-400183: ['PPARA:RXRA binds Corepressors of PPARA (Bos taurus)']
# NCBIGene:80205: ['PPARA-INTERACTING COFACTOR COMPLEX COMPONENT, 320-KD', 'CHD9', 'CREMM', 'PRIC320', 'FLJ12178', 'KIAA0308', 'FLJ12178', 'BC022889', 'KIAA0308', 'BC022889', 'CHD9 gene', 'CHD9 Gene', 'PRIC COMPLEX, 320-KD COMPONENT', 'CHROMATIN-RELATED MESENCHYMAL MODULATOR', 'CHROMODOMAIN HELICASE DNA-BINDING PROTEIN 9', 'chromodomain helicase DNA binding protein 9', 'Chromodomain Helicase DNA Binding Protein 9 Gene']
# REACT:R-CFA-400143: ['Fatty acid ligands activate PPARA (Canis familiaris)']
# REACT:R-DRE-400183: ['PPARA:RXRA binds Corepressors of PPARA (Danio rerio)']
# REACT:R-MMU-400183: ['PPARA:RXRA binds Corepressors of PPARA (Mus musculus)']
# REACT:R-HSA-5663156: ['p-BMAL1:p-CLOCK,NPAS2 binds PPARA gene (Homo sapiens)']
# REACT:R-RNO-400143: ['Fatty acid ligands activate PPARA (Rattus norvegicus)']
# REACT:R-HSA-400183: ['PPARA:RXRA binds Corepressors of PPARA (Homo sapiens)']
# REACT:R-RNO-4341070: ['PIAS4 SUMOylates PPARA with SUMO1 (Rattus norvegicus)']
# REACT:R-XTR-4341070: ['PIAS4 SUMOylates PPARA with SUMO1 (Xenopus tropicalis)']
# REACT:R-BTA-400206: ['Regulation of lipid metabolism by PPARalpha (Bos taurus)']
# REACT:R-SSC-400206: ['Regulation of lipid metabolism by PPARalpha (Sus scrofa)']
# REACT:R-DRE-400206: ['Regulation of lipid metabolism by PPARalpha (Danio rerio)']
# REACT:R-CFA-400183: ['PPARA:RXRA binds Corepressors of PPARA (Canis familiaris)']
# UMLS:C5575466: ['PPARA-Interacting Cofactor Complex Component, 320-kD Gene', 'KISH2', 'AD013', 'CReMM', 'CHD-9', 'PRIC320', 'BC022889', 'KIAA0308', 'FLJ12178', 'CHD9 wt Allele', 'PRIC Complex, 320-kD Component Gene', 'PPAR{Gamma}-Interacting Cofactor 320 kDa Gene', 'Chromodomain Helicase DNA Binding Protein 9 wt Allele']
# REACT:R-MMU-400206: ['Regulation of lipid metabolism by PPARalpha (Mus musculus)']
# REACT:R-HSA-400206: ['Regulation of lipid metabolism by PPARalpha (Homo sapiens)']
# REACT:R-CEL-4341070: ['PIAS4 SUMOylates PPARA with SUMO1 (Caenorhabditis elegans)']
# REACT:R-RNO-400183: ['PPARA:RXRA binds Corepressors of PPARA (Rattus norvegicus)']
# REACT:R-DME-400143: ['Fatty acid ligands activate PPARA (Drosophila melanogaster)']
# REACT:R-CFA-400206: ['Regulation of lipid metabolism by PPARalpha (Canis familiaris)']
# REACT:R-RNO-400206: ['Regulation of lipid metabolism by PPARalpha (Rattus norvegicus)']
# REACT:R-XTR-400206: ['Regulation of lipid metabolism by PPARalpha (Xenopus tropicalis)']
# REACT:R-DME-400183: ['PPARA:RXRA binds Corepressors of PPARA (Drosophila melanogaster)']
# REACT:R-DME-400206: ['Regulation of lipid metabolism by PPARalpha (Drosophila melanogaster)']

# %%
results = requests.post(f'https://name-resolution-sri.renci.org/lookup?string={output_search_string}&offset=0&limit=100')
results_json = results.json()
#print(json.dumps(results_json,indent=4))
output_node_id_list = list(results_json.keys())
print(output_node_id_list)
print(f"Number of 'output' IDs: {len(output_node_id_list)}")
# Out:
# ['HP:0001395', 'UMLS:C4227681', 'UMLS:C4034373', 'UMLS:C5189427', 'UMLS:C0544816', 'MONDO:0100430', 'MONDO:0018840', 'UMLS:C1397317', 'UMLS:C4068302', 'UMLS:C4481250', 'UMLS:C2827436', 'UMLS:C4321337', 'UMLS:C4695229', 'UMLS:C0494791', 'UMLS:C0400961', 'UMLS:C3864238', 'UMLS:C1960658', 'UMLS:C4695228', 'UMLS:C5563662', 'UMLS:C1407032', 'UMLS:C0400925', 'UMLS:C4749320', 'UMLS:C5548949', 'UMLS:C4533463', 'UMLS:C5689517', 'UMLS:C5689516', 'UMLS:C4722044', 'UMLS:C1856310', 'UMLS:C5439238', 'UMLS:C4722043', 'UMLS:C5548946', 'UMLS:C4533767', 'UMLS:C3277942', 'UMLS:C1385044', 'UMLS:C4070891', 'UMLS:C3873179', 'UMLS:C4070890', 'UMLS:C1954436', 'UMLS:C4070622', 'UMLS:C4036765', 'UMLS:C5215514', 'UMLS:C0451713', 'UMLS:C5686432', 'UMLS:C3275636', 'UMLS:C4750548', 'UMLS:C5549445', 'UMLS:C5549441', 'UMLS:C2184113', 'UMLS:C5190480', 'UMLS:C5171263', 'UMLS:C5171261', 'UMLS:C5171262', 'UMLS:C2751577', 'UMLS:C1869017', 'UMLS:C4030819', 'UMLS:C2749679', 'UMLS:C5697513', 'UMLS:C4732266', 'UMLS:C3869480', 'UMLS:C3869479', 'UMLS:C5413287', 'UMLS:C5416725', 'UMLS:C5414544', 'UMLS:C5414546']
# Number of 'output' IDs: 64

# %%
# TO-DO- sanity check and get the preferred labels for each of these - output as table
for id, name_list in results_json.items():
    print(f"{id}: {name_list[0]}")
# Out:
# HP:0001395: Fibrosis liver
# UMLS:C4227681: Liver fibrosis, mild
# UMLS:C4034373: liver fibrosis score
# UMLS:C5189427: liver fibrosis stage
# UMLS:C0544816: Fibrosis, septal, liver
# MONDO:0100430: liver fibrosis (disease)
# MONDO:0018840: congenital liver fibrosis
# UMLS:C1397317: fibrosis; liver, alcoholic
# UMLS:C4068302: Liver fibrosis score panel
# UMLS:C4481250: biopsy liver portal fibrosis
# UMLS:C2827436: Cystic Fibrosis Liver Disease
# UMLS:C4321337: Enhanced Liver Fibrosis Score
# UMLS:C4695229: Liver fibrosis interpretation
# UMLS:C0494791: Fibrosis and cirrhosis of liver
# UMLS:C0400961: fibrosis; liver, with sclerosis
# UMLS:C3864238: abdominal ultrasound liver fibrosis
# UMLS:C1960658: Liver disease due to cystic fibrosis
# UMLS:C4695228: Liver fibrosis interpretation Ser-Imp
# UMLS:C5563662: Periportal fibrosis seen on liver biopsy
# UMLS:C1407032: toxic; disorders of liver, with fibrosis
# UMLS:C0400925: alcoholic sclerosis and fibrosis of liver
# UMLS:C4749320: Liver transient elastography fibrosis score
# UMLS:C5548949: Liver fibrosis score panel Calculated by FIB4
# UMLS:C4533463: Liver fibrosis score Calculated by ELF [Score]
# UMLS:C5689517: Liver fibrosis score Calculated.Agile4 [Score]
# UMLS:C5689516: Liver fibrosis score Calculated.Agile3+ [Score]
# UMLS:C4722044: Non-Alcoholic Fatty Liver Disease fibrosis score
# UMLS:C1856310: Liver biopsy shows diffuse interstitial fibrosis
# UMLS:C5439238: Liver cirrhosis due to classical cystic fibrosis
# UMLS:C4722043: Non-Alcoholic Fatty Liver Disease Fibrosis Score
# UMLS:C5548946: Liver fibrosis score in Serum Calculated by FIB4
# UMLS:C4533767: Calculated by Enhanced Liver Fibrosis Score (ELF)
# UMLS:C3277942: Liver biopsy shows portal and/or bridging fibrosis
# UMLS:C1385044: disease (or disorder); liver, toxic, with fibrosis
# UMLS:C4070891: Liver fibrosis score panel Calculated by HepaScore
# UMLS:C3873179: Elevated liver enzymes level due to cystic fibrosis
# UMLS:C4070890: Liver fibrosis score panel Calculated by FibroMeter
# UMLS:C1954436: Liver fibrosis score Calculated by FibroSure [Score]
# UMLS:C4070622: Liver fibrosis score Calculated by HepaScore [Score]
# UMLS:C4036765: Liver fibrosis score Calculated by FibroMeter [Score]
# UMLS:C5215514: Liver fibrosis score&#x7C;Score&#x7C;Pt&#x7C;ANYBldSerPl
# UMLS:C0451713: Toxic liver disease with fibrosis and cirrhosis of liver
# UMLS:C5686432: Hepatic fibrosis due to non-alcoholic fatty liver disease
# UMLS:C3275636: Abnormal liver enzymes in those with hepatic cysts or fibrosis
# UMLS:C4750548: Assessment using Non-Alcoholic Fatty Liver Disease fibrosis score
# UMLS:C5549445: Liver fibrosis score panel &#x7C; Patient &#x7C; Chemistry Panels
# UMLS:C5549441: Liver fibrosis score &#x7C; Serum &#x7C; Chemistry - non-challenge
# UMLS:C2184113: Hodgkin's disease, lymphocytic depletion, diffuse fibrosis of liver
# UMLS:C5190480: hepatitis C FibroSURE(TM) panel in serum or plasma liver fibrosis score
# UMLS:C5171263: Liver fibrosis score panel &#x7C; Serum or Plasma &#x7C; Chemistry Panels
# UMLS:C5171261: Liver fibrosis interpretation &#x7C; Serum &#x7C; Chemistry - non-challenge
# UMLS:C5171262: Liver fibrosis score &#x7C; Serum or Plasma &#x7C; Chemistry - non-challenge
# UMLS:C2751577: Liver biopsy during acute episode shows variable portal and sinusoidal fibrosis
# UMLS:C1869017: Hepatic failure, fibrosis and cirrhosis and other liver damage-related conditions (SMQ)
# UMLS:C4030819: biopsy of liver showed Hodgkin's lymphoma with lymphocytic depletion with diffuse fibrosis
# UMLS:C2749679: Liver fibrosis with nodular regeneration, cholestasis, ductular proliferation, and iron deposition
# UMLS:C5697513: Molecular pathology test for risk of serious liver disease within 5 years (Enhanced Liver Fibrosis (ELF) Test)
# UMLS:C4732266: Infectious disease, chronic hepatitis C virus (HCV) infection, six biochemical assays (ALT, A2-macroglobulin, apolipoprotein A-1, total bilirubin, GGT, and haptoglobin) utilizing serum, prognostic algorithm reported as scores for fibrosis and necroinflammatory activity in liver
# UMLS:C3869480: Liver disease, ten biochemical assays (alt, a2-macroglobulin, apolipoprotein a-1, total bilirubin, ggt, haptoglobin, ast, glucose, total cholesterol and triglycerides) utilizing serum, prognostic algorithm reported as quantitative scores for fibrosis, steatosis and alcoholic steatohepatitis (ash)
# UMLS:C3869479: Liver disease, ten biochemical assays (alt, a2-macroglobulin, apolipoprotein a-1, total bilirubin, ggt, haptoglobin, ast, glucose, total cholesterol and triglycerides) utilizing serum, prognostic algorithm reported as quantitative scores for fibrosis, steatosis and nonalcoholic steatohepatitis (nash)
# UMLS:C5413287: Measurement of alanine aminotransferase, A2-macroglobulin, apolipoprotein A-1, total bilirubin, gamma-glutamyl transferase (GGT), and haptoglobin in serum for assessment of chronic hepatitis C virus infection, prognostic algorithm reported as scores for fibrosis, and necroinflammatory activity in liver
# UMLS:C5416725: Liver disease, analysis of 3 biomarkers (hyaluronic acid [ha], procollagen iii amino terminal peptide [piiinp], tissue inhibitor of metalloproteinase 1 [timp-1]), using immunoassays, utilizing serum, prognostic algorithm reported as a risk score and risk of liver fibrosis and liver-related clinical events within 5 years
# UMLS:C5414544: Liver disease, 10 biochemical assays (α2-macroglobulin, haptoglobin, apolipoprotein A1, bilirubin, GGT, ALT, AST, triglycerides, cholesterol, fasting glucose) and biometric and demographic data, utilizing serum, algorithm reported as scores for fibrosis, necroinflammatory activity, and steatosis with a summary interpretation
# UMLS:C5414546: Biochemical assay for 10 markers of liver disease (α2-macroglobulin, haptoglobin, apolipoprotein A1, bilirubin, gamma-glutamyl transferase [GGT], alanine aminotransferase [ALT], aspartate aminotransferase [AST], triglycerides, cholesterol, and fasting glucose) in serum specimen, algorithm reported as scores for fibrosis, necroinflammatory activity, and steatosis with summary interpretation

# %%
# List of input/output IDs in case the name resolver isn't working
input_node_id_list = ['NCBIGene:5465', 'MESH:C000630914', 'MESH:C000634429', 'NCBIGene:10891', 'NCBIGene:133522', 'NCBIGene:19013',
                      'NCBIGene:25747', 'NCBIGene:30755', 'NCBIGene:400931', 'NCBIGene:557714', 'NCBIGene:563298', 'NCBIGene:80205',
                      'PR:000013056', 'PR:000040325', 'REACT:R-BTA-400143', 'REACT:R-BTA-400183', 'REACT:R-BTA-400204',
                      'REACT:R-BTA-400206', 'REACT:R-BTA-4341070', 'REACT:R-BTA-9734475', 'REACT:R-CEL-4341070', 'REACT:R-CFA-400143',
                      'REACT:R-CFA-400183', 'REACT:R-CFA-400204', 'REACT:R-CFA-400206', 'REACT:R-CFA-9734475', 'REACT:R-DME-400143',
                      'REACT:R-DME-400183', 'REACT:R-DME-400204', 'REACT:R-DME-400206', 'REACT:R-DME-9734475', 'REACT:R-DRE-400143',
                      'REACT:R-DRE-400183', 'REACT:R-DRE-400204', 'REACT:R-DRE-400206', 'REACT:R-DRE-4341070', 'REACT:R-DRE-9734475',
                      'REACT:R-GGA-400143', 'REACT:R-GGA-4341070', 'REACT:R-HSA-1989781', 'REACT:R-HSA-400143', 'REACT:R-HSA-400183',
                      'REACT:R-HSA-400204', 'REACT:R-HSA-400206', 'REACT:R-HSA-4341070', 'REACT:R-HSA-5663156', 'REACT:R-HSA-879724',
                      'REACT:R-HSA-9734475', 'REACT:R-MMU-400143', 'REACT:R-MMU-400183', 'REACT:R-MMU-400204', 'REACT:R-MMU-400206',
                      'REACT:R-MMU-4341070', 'REACT:R-MMU-9734475', 'REACT:R-RNO-400143', 'REACT:R-RNO-400183', 'REACT:R-RNO-400204',
                      'REACT:R-RNO-400206', 'REACT:R-RNO-4341070', 'REACT:R-RNO-9734475', 'REACT:R-SSC-400183', 'REACT:R-SSC-400204',
                      'REACT:R-SSC-400206', 'REACT:R-SSC-9734475', 'REACT:R-XTR-400204', 'REACT:R-XTR-400206', 'REACT:R-XTR-4341070',
                      'REACT:R-XTR-9734475', 'UMLS:C0166415', 'UMLS:C1518805', 'UMLS:C1868415', 'UMLS:C2984537', 'UMLS:C5197094', 'UMLS:C5226508',
                      'UMLS:C5417797', 'UMLS:C5575466', 'UniProtKB:P23204', 'UniProtKB:P37230', 'UniProtKB:Q07869', 'UniProtKB:Q95N78']
output_node_id_list = ['HP:0001395', 'UMLS:C4227681', 'UMLS:C4034373', 'UMLS:C5189427', 'UMLS:C0544816', 'MONDO:0100430', 'MONDO:0018840',
                       'UMLS:C1397317', 'UMLS:C4068302', 'UMLS:C4481250', 'UMLS:C2827436', 'UMLS:C4321337', 'UMLS:C4695229', 'UMLS:C0494791',
                       'UMLS:C0400961', 'UMLS:C3864238', 'UMLS:C1960658', 'UMLS:C4695228', 'UMLS:C5563662', 'UMLS:C1407032', 'UMLS:C0400925',
                       'UMLS:C4749320', 'UMLS:C5548949', 'UMLS:C4533463', 'UMLS:C5689517', 'UMLS:C5689516', 'UMLS:C4722044', 'UMLS:C1856310',
                       'UMLS:C5439238', 'UMLS:C4722043', 'UMLS:C5548946', 'UMLS:C4533767', 'UMLS:C3277942', 'UMLS:C1385044', 'UMLS:C4070891',
                       'UMLS:C3873179', 'UMLS:C4070890', 'UMLS:C1954436', 'UMLS:C4070622', 'UMLS:C4036765', 'UMLS:C5215514', 'UMLS:C0451713',
                       'UMLS:C5686432', 'UMLS:C3275636', 'UMLS:C4750548', 'UMLS:C5549445', 'UMLS:C5549441', 'UMLS:C2184113', 'UMLS:C5190480',
                       'UMLS:C5171263', 'UMLS:C5171261', 'UMLS:C5171262', 'UMLS:C2751577', 'UMLS:C1869017', 'UMLS:C4030819', 'UMLS:C2749679',
                       'UMLS:C5697513', 'UMLS:C4732266', 'UMLS:C3869480', 'UMLS:C3869479', 'UMLS:C5413287', 'UMLS:C5416725', 'UMLS:C5414544', 'UMLS:C5414546']

# %% [markdown]
# ### TRAPI methods

# %%
# Initializing TRAPI query and extracting results for ARA and Automat
query={
    "message": {
      "query_graph": {
        "edges": {
          "e00": {
            "subject": "n00",
              "object": "n01",
          "predicates":["biolink:GenotypeToGeneAssociation"]
          }
        },
        "nodes": {
          "n00": {
            "ids": input_node_id_list, #['NCBIGene:5465'], #
            "categories": ["biolink:GeneOrGeneProduct"]
          },
          "n01": {
              # "categories": ["biolink:BiologicalEntity"]
          }
        }
      }
    }
  }

# %%
response_trapi = requests.post(trapi_submit_url,json=query)
print(response_trapi.status_code)
number_pathway_results_trapi = len(response_trapi.json()['message']['results'])
print(len(response_trapi.json()['message']['results']))
# Out:
# 404
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [13], line 3
#       1 response_trapi = requests.post(trapi_submit_url,json=query)
#       2 print(response_trapi.status_code)
# ----> 3 number_pathway_results_trapi = len(response_trapi.json()['message']['results'])
#       4 print(len(response_trapi.json()['message']['results']))
#
# KeyError: 'message'

# %%
kg_trapi = response_trapi.json()['message']['knowledge_graph']
results_trapi = response_trapi.json()['message']['results']

# %%
import pandas as pd
import os

cols = []
for node in sorted(results_trapi[0]['node_bindings'].keys()):
    cols.append(node)
    cols.append(node + '_name')
results_trapi_df = pd.DataFrame(columns = cols)

results_trapi_list = []
for result in results_trapi:
    result_dict = {}
    for node in sorted(result['node_bindings'].keys()):
        node_id = result['node_bindings'][node][0]['id']
        result_dict[node] = node_id
        result_dict[node + '_name'] = kg_trapi['nodes'][node_id]['name']

    results_trapi_list.append(pd.DataFrame([result_dict]))
results_trapi_df = pd.concat(results_trapi_list)
display(results_trapi_df)
# results_trapi_df.to_csv(os.path.join(write_dir_trapi_automat,'results_TRAPI.csv'), index=False)
results_trapi_df.to_csv(TRAPI_results_file, index=False)

combined_node_list = ["_".join([row[1].replace(" ", "_"), row[3].replace(" ", "_"), row[5].replace(" ", "_")]) for row in results_trapi_df[cols].to_numpy()]
pp.pprint(combined_node_list)
# Out:
#                    n00                                           n00_name  \
# 0        NCBIGene:5465                                              PPARA
# 0   UniProtKB:Q07869-1  peroxisome proliferator-activated receptor alp...
# 0        NCBIGene:5465                                              PPARA
# 0       NCBIGene:10891                                           PPARGC1A
# 0        NCBIGene:5465                                              PPARA
# ..                 ...                                                ...
# 0      NCBIGene:133522                                           PPARGC1B
# 0   UniProtKB:Q07869-1  peroxisome proliferator-activated receptor alp...
# 0        NCBIGene:5465                                              PPARA
# 0        NCBIGene:5465                                              PPARA
# 0        NCBIGene:5465                                              PPARA
#
#               n01        n01_name            n02  \
# 0   NCBIGene:9104             RGN     HP:0001395
# 0    NCBIGene:183             AGT     HP:0001395
# 0   MONDO:0005154  liver disorder  MONDO:0100430
# 0    NCBIGene:183             AGT     HP:0001395
# 0   MONDO:0005154  liver disorder     HP:0012852
# ..            ...             ...            ...
# 0   NCBIGene:7422           VEGFA     HP:0001395
# 0   NCBIGene:2147              F2     HP:0001395
# 0   NCBIGene:7057           THBS1  MONDO:0018840
# 0   NCBIGene:4313            MMP2     HP:0001395
# 0   NCBIGene:1490            CCN2     HP:0001395
#
#                                 n02_name
# 0                       Hepatic fibrosis
# 0                       Hepatic fibrosis
# 0                 fibrotic liver disease
# 0                       Hepatic fibrosis
# 0              Hepatic bridging fibrosis
# ..                                   ...
# 0                       Hepatic fibrosis
# 0                       Hepatic fibrosis
# 0   isolated congenital hepatic fibrosis
# 0                       Hepatic fibrosis
# 0                       Hepatic fibrosis
#
# [201 rows x 6 columns]
# [    'PPARA_RGN_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_Hepatic_fibrosis',
#      'PPARA_liver_disorder_fibrotic_liver_disease',
#      'PPARGC1A_AGT_Hepatic_fibrosis',
#      'PPARA_liver_disorder_Hepatic_bridging_fibrosis',
#      'peroxisome_proliferator-activated_receptor_gamma_coactivator_1-alpha_isoform_h1_(human)_AGT_Hepatic_fibrosis',
#      'PPARGC1A_SPP1_Hepatic_fibrosis',
#      'PPARA_PKHD1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_COL1A1_Hepatic_fibrosis',
#      'PPARGC1B_CCL2_Hepatic_fibrosis',
#      'PPARA_LGALS1_Hepatic_fibrosis',
#      'PPARGC1B_IL6_Hepatic_fibrosis',
#      'PPARA_SPP1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_IGFBP1_Hepatic_fibrosis',
#      'PPARA_F2_Hepatic_fibrosis',
#      'PPARGC1B_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARA_VIM_Hepatic_fibrosis',
#      'PPARA_liver_disorder_isolated_congenital_hepatic_fibrosis',
#      'PPARA_HGF_Hepatic_fibrosis',
#      'PPARGC1A_FLT1_Hepatic_fibrosis',
#      'PPARA_NF1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_CTNNB1_Hepatic_fibrosis',
#      'PPARGC1A_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1A_AGT_isolated_congenital_hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CNR2_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_SERPINA6_Hepatic_fibrosis',
#      'PPARA_HNF1A_isolated_congenital_hepatic_fibrosis',
#      'PPARA_FGF2_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARA_cirrhosis_of_liver_isolated_congenital_hepatic_fibrosis',
#      'PPARA_THBS1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_TGFB1_Hepatic_fibrosis',
#      'PPARA_cirrhosis_of_liver_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1B_ARNT_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_isolated_congenital_hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_LOX_Hepatic_fibrosis',
#      'PPARGC1A_REN_isolated_congenital_hepatic_fibrosis',
#      'PPARA_HGF_Hepatic_fibrosis',
#      'PPARA_ARNT_Hepatic_fibrosis',
#      'PPARA_NF1_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1B_MMP2_Hepatic_fibrosis',
#      'PPARA_CTNNB1_Hepatic_fibrosis',
#      'PPARGC1A_NFE2L2_Hepatic_fibrosis',
#      'PPARA_SPP1_Hepatic_fibrosis',
#      'PPARA_liver_disorder_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARA_NPC1_Hepatic_fibrosis',
#      'PPARA_THBS1_isolated_congenital_hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CP_Hepatic_fibrosis',
#      'PPARGC1B_FLT1_Hepatic_fibrosis',
#      'chromodomain-helicase-DNA-binding_protein_9_isoform_h2_(human)_CTNNB1_Hepatic_fibrosis',
#      'PPARA_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARA_F2R_Hepatic_fibrosis',
#      'PPARA_CCL2_Hepatic_fibrosis',
#      'PPARA_SMAD3_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CP_Hepatic_fibrosis',
#      'PPARA_AGT_Hepatic_fibrosis',
#      'PPARGC1A_ARNT_Hepatic_fibrosis',
#      'PPARA_F2_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_LOX_Hepatic_fibrosis',
#      'PPARA_CCN2_Hepatic_fibrosis',
#      'PPARGC1B_AGT_Hepatic_fibrosis',
#      'PPARA_NF1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_ABCB4_Hepatic_fibrosis',
#      'PPARA_RGN_Hepatic_fibrosis',
#      'PPARA_TGFB1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_COL1A2_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_gamma_coactivator_1-alpha_isoform_h1_(human)_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1A_FBN1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_THBS1_Hepatic_fibrosis',
#      'PPARA_MMP2_Hepatic_fibrosis',
#      'PPARA_REN_isolated_congenital_hepatic_fibrosis',
#      'PPARA_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARA_TGFBR1_Hepatic_fibrosis',
#      'PPARA_VEGFA_Hepatic_fibrosis',
#      'PPARA_PKHD1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_HNF1A_isolated_congenital_hepatic_fibrosis',
#      'PPARA_CNR2_Hepatic_fibrosis',
#      'PPARA_SMAD3_Hepatic_fibrosis',
#      'PPARA_cirrhosis_of_liver_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1A_HNF1A_isolated_congenital_hepatic_fibrosis',
#      'PPARA_VEGFA_Hepatic_fibrosis',
#      'PPARA_HNF1A_isolated_congenital_hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARA_PKHD1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_IL6_Hepatic_fibrosis',
#      'PPARA_TGFB1_Hepatic_fibrosis',
#      'PPARA_TGFB1_isolated_congenital_hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_gamma_coactivator_1-alpha_isoform_h1_(human)_CYP27A1_Hepatic_fibrosis',
#      'PPARA_F2R_Hepatic_fibrosis',
#      'PPARGC1B_ALB_Hepatic_fibrosis',
#      'PPARA_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARA_NPC1_Hepatic_fibrosis',
#      'PPARA_PLAU_Hepatic_fibrosis',
#      'PPARA_REN_isolated_congenital_hepatic_fibrosis',
#      'PPARA_TGFB1_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1A_IL6_Hepatic_fibrosis',
#      'PPARA_CCL2_Hepatic_fibrosis',
#      'PPARGC1A_MMP2_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_isolated_congenital_hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_IGFBP1_Hepatic_fibrosis',
#      'PPARA_HNF1A_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1B_HNF1A_isolated_congenital_hepatic_fibrosis',
#      'PPARA_cirrhosis_of_liver_isolated_congenital_hepatic_fibrosis',
#      'PPARA_FLT1_Hepatic_fibrosis',
#      'PPARA_ARRB1_Hepatic_fibrosis',
#      'PPARA_REN_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1B_SPP1_Hepatic_fibrosis',
#      'PPARA_NFE2L2_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CP_Hepatic_fibrosis',
#      'PPARGC1A_STAT1_Hepatic_fibrosis',
#      'PPARA_NF1_isolated_congenital_hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_KRT18_Hepatic_fibrosis',
#      'PPARA_liver_disorder_Hepatic_fibrosis',
#      'PPARA_COL1A1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP2R1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_Hepatic_fibrosis',
#      'PPARA_liver_disorder_Liver_Disease_Associated_with_Cystic_Fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_LOX_Hepatic_fibrosis',
#      'PPARA_TGFBR1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP27A1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CNR2_Hepatic_fibrosis',
#      'PPARA_CP_Hepatic_fibrosis',
#      'PPARA_ARRB1_Hepatic_fibrosis',
#      'CHD9_AGT_isolated_congenital_hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_SERPINA6_Hepatic_fibrosis',
#      'PPARGC1B_STAT1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CNR2_Hepatic_fibrosis',
#      'PPARA_liver_disorder_Hepatic_bridging_fibrosis',
#      'PPARGC1B_HNF1A_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1A_ALB_Hepatic_fibrosis',
#      'PPARA_ALB_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CCL2_Hepatic_fibrosis',
#      'PPARA_LGALS1_Hepatic_fibrosis',
#      'PPARA_liver_disorder_fibrotic_liver_disease',
#      'peroxisome_proliferator-activated_receptor_gamma_coactivator_1-alpha_isoform_h1_(human)_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARA_liver_disorder_Periportal_fibrosis',
#      'CHD9_AGT_Hepatic_fibrosis',
#      'PPARA_ALB_Hepatic_fibrosis',
#      'PPARA_REN_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_gamma_coactivator_1-alpha_isoform_h1_(human)_VIM_Hepatic_fibrosis',
#      'PPARA_liver_disorder_Liver_Disease_Associated_with_Cystic_Fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP2R1_Hepatic_fibrosis',
#      'PPARGC1A_FBN1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_AGT_Hepatic_fibrosis',
#      'PPARA_liver_disorder_isolated_congenital_hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1A_VEGFA_Hepatic_fibrosis',
#      'PPARA_STAT1_Hepatic_fibrosis',
#      'PPARA_REN_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1A_CCL2_Hepatic_fibrosis',
#      'PPARA_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1B_NFE2L2_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_KRT18_Hepatic_fibrosis',
#      'PPARA_liver_disorder_isolated_congenital_hepatic_fibrosis',
#      'PPARA_liver_disorder_isolated_congenital_hepatic_fibrosis',
#      'CHD9_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARA_THBS1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP27A1_Hepatic_fibrosis',
#      'PPARGC1B_REN_Hepatic_fibrosis',
#      'PPARA_FLT1_Hepatic_fibrosis',
#      'PPARA_ABCB4_Hepatic_fibrosis',
#      'PPARGC1B_REN_isolated_congenital_hepatic_fibrosis',
#      'PPARA_PLAU_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CCL2_Hepatic_fibrosis',
#      'PPARA_IL6_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP27A1_Hepatic_fibrosis',
#      'PPARA_COL1A2_Hepatic_fibrosis',
#      'PPARA_FGF2_Hepatic_fibrosis',
#      'PPARA_PKHD1_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1A_REN_Hepatic_fibrosis',
#      'CHD9_ABCB4_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_KRT18_Hepatic_fibrosis',
#      'PPARGC1B_REN_isolated_congenital_hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_F2_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_Hepatic_fibrosis',
#      'PPARA_THBS1_isolated_congenital_hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CCL2_Hepatic_fibrosis',
#      'PPARA_CP_Hepatic_fibrosis',
#      'PPARA_liver_disorder_Periportal_fibrosis',
#      'PPARA_ARNT_Hepatic_fibrosis',
#      'PPARGC1A_REN_isolated_congenital_hepatic_fibrosis',
#      'PPARA_VIM_Hepatic_fibrosis',
#      'PPARA_NFE2L2_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_SERPINA6_Hepatic_fibrosis',
#      'PPARGC1A_FBN1_Hepatic_fibrosis',
#      'PPARA_STAT1_Hepatic_fibrosis',
#      'PPARA_REN_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP2R1_Hepatic_fibrosis',
#      'PPARGC1A_HDAC2_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_IGFBP1_Hepatic_fibrosis',
#      'PPARA_CNR2_Hepatic_fibrosis',
#      'PPARGC1B_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARA_TGFB1_isolated_congenital_hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_F2_Hepatic_fibrosis',
#      'PPARGC1A_HNF1A_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1B_VEGFA_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_F2_Hepatic_fibrosis',
#      'PPARA_THBS1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_MMP2_Hepatic_fibrosis',
#      'PPARA_CCN2_Hepatic_fibrosis']

# %%
from collections import Counter
import json
import pprint
pp = pprint.PrettyPrinter(indent=5)

for i in range(number_pathway_results_trapi):
    # print(f"Pathway result: {combined_node_list[i]}")
    edge_bindings = results_trapi[i]['edge_bindings']

    edge_ids = []
    for edge_name, edge_list in edge_bindings.items():
        edge_ids.append({edge_name: [x['id'] for x in edge_list]})

    string_out_list = []
    for edge_dict in edge_ids:
        for edge_name, edge_list in edge_dict.items():
            for edge_id in edge_list:
                source_list_raw = [ sub['attribute_source'] for sub in kg_trapi['edges'][edge_id]['attributes'] ]
                source_list = []
                for value in source_list_raw:
                    if value != None:
                        source_list.append(value)
                source_list = set(source_list)
                subject_id = kg_trapi['edges'][edge_id]['subject']
                subject = kg_trapi['nodes'][subject_id]['name']
                predicate = kg_trapi['edges'][edge_id]['predicate']
                object_id = kg_trapi['edges'][edge_id]['object']
                object = kg_trapi['nodes'][object_id]['name']
                string_out = f"{subject} -> {predicate} -> {object}|{source_list}"
                string_out_list.append(string_out)
    string_out_dict = dict(Counter(string_out_list).items())
    pp.pprint(string_out_dict)
    print("")
    
    with open(os.path.join(write_dir_trapi_automat,combined_node_list[i]+".txt"), 'a') as convert_file:
        convert_file.write(json.dumps(string_out_dict))
# Out:
# {    "PPARA -> biolink:regulates -> RGN|{'infores:automat-robokop'}": 1,
#      "RGN -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "AGT -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:contributes_to -> liver disorder|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:genetic_association -> liver disorder|{'infores:automat-robokop'}": 1,
#      "fibrotic liver disease -> biolink:subclass_of -> liver disorder|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARGC1A -> biolink:regulates -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "Hepatic bridging fibrosis -> biolink:subclass_of -> liver disorder|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:contributes_to -> liver disorder|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:genetic_association -> liver disorder|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human)|{'infores:automat-robokop'}": 1,
#      "AGT -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human) -> biolink:coexpressed_with -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "PPARGC1A -> biolink:regulates -> SPP1|{'infores:automat-robokop'}": 1,
#      "SPP1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "SPP1 -> biolink:regulates -> PPARGC1A|{'infores:automat-robokop'}": 1}
#
# {    "PKHD1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PKHD1 -> biolink:genetic_association -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PKHD1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "COL1A1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> COL1A1|{'infores:automat-robokop'}": 1}
#
# {    "CCL2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "CCL2 -> biolink:regulates -> PPARGC1B|{'infores:automat-robokop'}": 1,
#      "PPARGC1B -> biolink:regulates -> CCL2|{'infores:automat-robokop'}": 1}
#
# {    "LGALS1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "LGALS1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "IL6 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "IL6 -> biolink:regulates -> PPARGC1B|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> SPP1|{'infores:automat-robokop'}": 2,
#      "SPP1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "SPP1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "IGFBP1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "IGFBP1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> IGFBP1|{'infores:automat-robokop'}": 1}
#
# {    "F2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:interacts_with -> F2|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> F2|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARGC1B -> biolink:regulates -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> VIM|{'infores:automat-robokop'}": 1,
#      "VIM -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:contributes_to -> liver disorder|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:genetic_association -> liver disorder|{'infores:automat-robokop'}": 1,
#      "isolated congenital hepatic fibrosis -> biolink:subclass_of -> liver disorder|{'infores:automat-robokop'}": 1}
#
# {    "HGF -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "HGF -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> HGF|{'infores:automat-robokop'}": 1}
#
# {    "FLT1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "FLT1 -> biolink:regulates -> PPARGC1A|{'infores:automat-robokop'}": 1,
#      "PPARGC1A -> biolink:regulates -> FLT1|{'infores:automat-robokop'}": 1}
#
# {    "NF1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> NF1|{'infores:automat-robokop'}": 1}
#
# {    "CTNNB1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "CTNNB1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> CTNNB1|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARGC1A -> biolink:regulates -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARGC1A -> biolink:regulates -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "CNR2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "CNR2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CNR2|{'infores:automat-robokop'}": 1}
#
# {    "SERPINA6 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "SERPINA6 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> SERPINA6|{'infores:automat-robokop'}": 1}
#
# {    "HNF1A -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> HNF1A|{'infores:automat-robokop'}": 1}
#
# {    "FGF2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> FGF2|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:contributes_to -> cirrhosis of liver|{'infores:automat-robokop'}": 1,
#      "isolated congenital hepatic fibrosis -> biolink:subclass_of -> cirrhosis of liver|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> THBS1|{'infores:automat-robokop'}": 1,
#      "THBS1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "THBS1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> TGFB1|{'infores:automat-robokop'}": 1,
#      "TGFB1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "TGFB1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:contributes_to -> cirrhosis of liver|{'infores:automat-robokop'}": 1,
#      "isolated congenital hepatic fibrosis -> biolink:subclass_of -> cirrhosis of liver|{'infores:automat-robokop'}": 1}
#
# {    "ARNT -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARGC1B -> biolink:regulates -> ARNT|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "LOX -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "LOX -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> LOX|{'infores:automat-robokop'}": 1}
#
# {    "PPARGC1A -> biolink:regulates -> REN|{'infores:automat-robokop'}": 1,
#      "REN -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1}
#
# {    "HGF -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "HGF -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> HGF|{'infores:automat-robokop'}": 1}
#
# {    "ARNT -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "ARNT -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "NF1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> NF1|{'infores:automat-robokop'}": 1}
#
# {    "MMP2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARGC1B -> biolink:regulates -> MMP2|{'infores:automat-robokop'}": 1}
#
# {    "CTNNB1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "CTNNB1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> CTNNB1|{'infores:automat-robokop'}": 1}
#
# {    "NFE2L2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "NFE2L2 -> biolink:regulates -> PPARGC1A|{'infores:automat-robokop'}": 1,
#      "PPARGC1A -> biolink:regulates -> NFE2L2|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> SPP1|{'infores:automat-robokop'}": 2,
#      "SPP1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "SPP1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "Hepatic fibrosis -> biolink:subclass_of -> liver disorder|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:contributes_to -> liver disorder|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:genetic_association -> liver disorder|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "NPC1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "NPC1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> THBS1|{'infores:automat-robokop'}": 1,
#      "THBS1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "THBS1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "CP -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "CP -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CP|{'infores:automat-robokop'}": 1}
#
# {    "FLT1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "FLT1 -> biolink:regulates -> PPARGC1B|{'infores:automat-robokop'}": 1,
#      "PPARGC1B -> biolink:regulates -> FLT1|{'infores:automat-robokop'}": 1}
#
# {    "CTNNB1 -> biolink:coexpressed_with -> chromodomain-helicase-DNA-binding protein 9 isoform h2 (human)|{'infores:automat-robokop'}": 1,
#      "CTNNB1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "chromodomain-helicase-DNA-binding protein 9 isoform h2 (human) -> biolink:coexpressed_with -> CTNNB1|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "AGT -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:interacts_with -> AGT|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "F2R -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "F2R -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> F2R|{'infores:automat-robokop'}": 1}
#
# {    "CCL2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "CCL2 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> CCL2|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> SMAD3|{'infores:automat-robokop'}": 1,
#      "SMAD3 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "SMAD3 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "CP -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "CP -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CP|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "AGT -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:interacts_with -> AGT|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "ARNT -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARGC1A -> biolink:regulates -> ARNT|{'infores:automat-robokop'}": 1}
#
# {    "F2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:interacts_with -> F2|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> F2|{'infores:automat-robokop'}": 1}
#
# {    "LOX -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "LOX -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> LOX|{'infores:automat-robokop'}": 1}
#
# {    "CCN2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "CCN2 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> CCN2|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARGC1B -> biolink:regulates -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "NF1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> NF1|{'infores:automat-robokop'}": 1}
#
# {    "ABCB4 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:interacts_with -> ABCB4|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> ABCB4|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> RGN|{'infores:automat-robokop'}": 1,
#      "RGN -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> TGFB1|{'infores:automat-robokop'}": 1,
#      "TGFB1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "TGFB1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "COL1A2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> COL1A2|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human)|{'infores:automat-robokop'}": 1,
#      "AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human) -> biolink:coexpressed_with -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "FBN1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "FBN1 -> biolink:regulates -> PPARGC1A|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> THBS1|{'infores:automat-robokop'}": 1,
#      "THBS1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "THBS1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "MMP2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "MMP2 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> MMP2|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> REN|{'infores:automat-robokop'}": 1,
#      "REN -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "REN -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "AGT -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:interacts_with -> AGT|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> TGFBR1|{'infores:automat-robokop'}": 1,
#      "TGFBR1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "TGFBR1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> VEGFA|{'infores:automat-robokop'}": 1,
#      "VEGFA -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "VEGFA -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "PKHD1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PKHD1 -> biolink:genetic_association -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PKHD1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "HNF1A -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> HNF1A|{'infores:automat-robokop'}": 1}
#
# {    "CNR2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "CNR2 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> SMAD3|{'infores:automat-robokop'}": 1,
#      "SMAD3 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "SMAD3 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:contributes_to -> cirrhosis of liver|{'infores:automat-robokop'}": 1,
#      "isolated congenital hepatic fibrosis -> biolink:subclass_of -> cirrhosis of liver|{'infores:automat-robokop'}": 1}
#
# {    "HNF1A -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARGC1A -> biolink:regulates -> HNF1A|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> VEGFA|{'infores:automat-robokop'}": 1,
#      "VEGFA -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "VEGFA -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "HNF1A -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> HNF1A|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "PKHD1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PKHD1 -> biolink:genetic_association -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PKHD1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "IL6 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "IL6 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> IL6|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> TGFB1|{'infores:automat-robokop'}": 1,
#      "TGFB1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "TGFB1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> TGFB1|{'infores:automat-robokop'}": 1,
#      "TGFB1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "TGFB1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "CYP27A1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human)|{'infores:automat-robokop'}": 1,
#      "CYP27A1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human) -> biolink:coexpressed_with -> CYP27A1|{'infores:automat-robokop'}": 1}
#
# {    "F2R -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "F2R -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> F2R|{'infores:automat-robokop'}": 1}
#
# {    "ALB -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "ALB -> biolink:regulates -> PPARGC1B|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "AGT -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:interacts_with -> AGT|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "NPC1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "NPC1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "PLAU -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PLAU -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> PLAU|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> REN|{'infores:automat-robokop'}": 1,
#      "REN -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "REN -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> TGFB1|{'infores:automat-robokop'}": 1,
#      "TGFB1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "TGFB1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "IL6 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "IL6 -> biolink:regulates -> PPARGC1A|{'infores:automat-robokop'}": 1}
#
# {    "CCL2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "CCL2 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> CCL2|{'infores:automat-robokop'}": 1}
#
# {    "MMP2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARGC1A -> biolink:regulates -> MMP2|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "IGFBP1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "IGFBP1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> IGFBP1|{'infores:automat-robokop'}": 1}
#
# {    "HNF1A -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> HNF1A|{'infores:automat-robokop'}": 1}
#
# {    "HNF1A -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARGC1B -> biolink:regulates -> HNF1A|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:contributes_to -> cirrhosis of liver|{'infores:automat-robokop'}": 1,
#      "isolated congenital hepatic fibrosis -> biolink:subclass_of -> cirrhosis of liver|{'infores:automat-robokop'}": 1}
#
# {    "FLT1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> FLT1|{'infores:automat-robokop'}": 1}
#
# {    "ARRB1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "ARRB1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> REN|{'infores:automat-robokop'}": 1,
#      "REN -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "REN -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "PPARGC1B -> biolink:regulates -> SPP1|{'infores:automat-robokop'}": 2,
#      "SPP1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "SPP1 -> biolink:regulates -> PPARGC1B|{'infores:automat-robokop'}": 1}
#
# {    "NFE2L2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "NFE2L2 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> NFE2L2|{'infores:automat-robokop'}": 1}
#
# {    "CP -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "CP -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CP|{'infores:automat-robokop'}": 1}
#
# {    "STAT1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "STAT1 -> biolink:interacts_with -> PPARGC1A|{'infores:automat-robokop'}": 1}
#
# {    "NF1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> NF1|{'infores:automat-robokop'}": 1}
#
# {    "KRT18 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "KRT18 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> KRT18|{'infores:automat-robokop'}": 1}
#
# {    "Hepatic fibrosis -> biolink:subclass_of -> liver disorder|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:contributes_to -> liver disorder|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:genetic_association -> liver disorder|{'infores:automat-robokop'}": 1}
#
# {    "COL1A1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> COL1A1|{'infores:automat-robokop'}": 1}
#
# {    "CYP2R1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "CYP2R1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CYP2R1|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "AGT -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "Liver Disease Associated with Cystic Fibrosis -> biolink:subclass_of -> liver disorder|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:contributes_to -> liver disorder|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:genetic_association -> liver disorder|{'infores:automat-robokop'}": 1}
#
# {    "LOX -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "LOX -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> LOX|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> TGFBR1|{'infores:automat-robokop'}": 1,
#      "TGFBR1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "TGFBR1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "CYP27A1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "CYP27A1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CYP27A1|{'infores:automat-robokop'}": 1}
#
# {    "CNR2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "CNR2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CNR2|{'infores:automat-robokop'}": 1}
#
# {    "CP -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "CP -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> CP|{'infores:automat-robokop'}": 1}
#
# {    "ARRB1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "ARRB1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "CHD9 -> biolink:interacts_with -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "SERPINA6 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "SERPINA6 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> SERPINA6|{'infores:automat-robokop'}": 1}
#
# {    "STAT1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "STAT1 -> biolink:interacts_with -> PPARGC1B|{'infores:automat-robokop'}": 1}
#
# {    "CNR2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "CNR2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CNR2|{'infores:automat-robokop'}": 1}
#
# {    "Hepatic bridging fibrosis -> biolink:subclass_of -> liver disorder|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:contributes_to -> liver disorder|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:genetic_association -> liver disorder|{'infores:automat-robokop'}": 1}
#
# {    "HNF1A -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARGC1B -> biolink:regulates -> HNF1A|{'infores:automat-robokop'}": 1}
#
# {    "ALB -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "ALB -> biolink:regulates -> PPARGC1A|{'infores:automat-robokop'}": 1}
#
# {    "ALB -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "ALB -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:directly_physically_interacts_with -> ALB|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> ALB|{'infores:automat-robokop'}": 1}
#
# {    "CCL2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "CCL2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CCL2|{'infores:automat-robokop'}": 1}
#
# {    "LGALS1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "LGALS1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:contributes_to -> liver disorder|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:genetic_association -> liver disorder|{'infores:automat-robokop'}": 1,
#      "fibrotic liver disease -> biolink:subclass_of -> liver disorder|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human)|{'infores:automat-robokop'}": 1,
#      "AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human) -> biolink:coexpressed_with -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:contributes_to -> liver disorder|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:genetic_association -> liver disorder|{'infores:automat-robokop'}": 1,
#      "Periportal fibrosis -> biolink:subclass_of -> liver disorder|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "CHD9 -> biolink:interacts_with -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "ALB -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "ALB -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:directly_physically_interacts_with -> ALB|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> ALB|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> REN|{'infores:automat-robokop'}": 1,
#      "REN -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "REN -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "VIM -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human)|{'infores:automat-robokop'}": 1,
#      "VIM -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human) -> biolink:coexpressed_with -> VIM|{'infores:automat-robokop'}": 1}
#
# {    "Liver Disease Associated with Cystic Fibrosis -> biolink:subclass_of -> liver disorder|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:contributes_to -> liver disorder|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:genetic_association -> liver disorder|{'infores:automat-robokop'}": 1}
#
# {    "CYP2R1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "CYP2R1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CYP2R1|{'infores:automat-robokop'}": 1}
#
# {    "FBN1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "FBN1 -> biolink:regulates -> PPARGC1A|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "AGT -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:interacts_with -> AGT|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:contributes_to -> liver disorder|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:genetic_association -> liver disorder|{'infores:automat-robokop'}": 1,
#      "isolated congenital hepatic fibrosis -> biolink:subclass_of -> liver disorder|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "PPARGC1A -> biolink:regulates -> VEGFA|{'infores:automat-robokop'}": 1,
#      "VEGFA -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "VEGFA -> biolink:regulates -> PPARGC1A|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> STAT1|{'infores:automat-robokop'}": 1,
#      "STAT1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "STAT1 -> biolink:interacts_with -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> REN|{'infores:automat-robokop'}": 1,
#      "REN -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "REN -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "CCL2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "CCL2 -> biolink:regulates -> PPARGC1A|{'infores:automat-robokop'}": 1,
#      "PPARGC1A -> biolink:regulates -> CCL2|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "AGT -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:interacts_with -> AGT|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "NFE2L2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "NFE2L2 -> biolink:regulates -> PPARGC1B|{'infores:automat-robokop'}": 1,
#      "PPARGC1B -> biolink:regulates -> NFE2L2|{'infores:automat-robokop'}": 1}
#
# {    "KRT18 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "KRT18 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> KRT18|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:contributes_to -> liver disorder|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:genetic_association -> liver disorder|{'infores:automat-robokop'}": 1,
#      "isolated congenital hepatic fibrosis -> biolink:subclass_of -> liver disorder|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:contributes_to -> liver disorder|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:genetic_association -> liver disorder|{'infores:automat-robokop'}": 1,
#      "isolated congenital hepatic fibrosis -> biolink:subclass_of -> liver disorder|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "CHD9 -> biolink:interacts_with -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> THBS1|{'infores:automat-robokop'}": 1,
#      "THBS1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "THBS1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "CYP27A1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "CYP27A1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CYP27A1|{'infores:automat-robokop'}": 1}
#
# {    "PPARGC1B -> biolink:regulates -> REN|{'infores:automat-robokop'}": 1,
#      "REN -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1}
#
# {    "FLT1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> FLT1|{'infores:automat-robokop'}": 1}
#
# {    "ABCB4 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:interacts_with -> ABCB4|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> ABCB4|{'infores:automat-robokop'}": 1}
#
# {    "PPARGC1B -> biolink:regulates -> REN|{'infores:automat-robokop'}": 1,
#      "REN -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1}
#
# {    "PLAU -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PLAU -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> PLAU|{'infores:automat-robokop'}": 1}
#
# {    "CCL2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "CCL2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CCL2|{'infores:automat-robokop'}": 1}
#
# {    "IL6 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "IL6 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> IL6|{'infores:automat-robokop'}": 1}
#
# {    "CYP27A1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "CYP27A1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CYP27A1|{'infores:automat-robokop'}": 1}
#
# {    "COL1A2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> COL1A2|{'infores:automat-robokop'}": 1}
#
# {    "FGF2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> FGF2|{'infores:automat-robokop'}": 1}
#
# {    "PKHD1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PKHD1 -> biolink:genetic_association -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PKHD1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "PPARGC1A -> biolink:regulates -> REN|{'infores:automat-robokop'}": 1,
#      "REN -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1}
#
# {    "ABCB4 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "CHD9 -> biolink:interacts_with -> ABCB4|{'infores:automat-robokop'}": 1}
#
# {    "KRT18 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "KRT18 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> KRT18|{'infores:automat-robokop'}": 1}
#
# {    "PPARGC1B -> biolink:regulates -> REN|{'infores:automat-robokop'}": 1,
#      "REN -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1}
#
# {    "F2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "F2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> F2|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "AGT -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> THBS1|{'infores:automat-robokop'}": 1,
#      "THBS1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "THBS1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "CCL2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "CCL2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CCL2|{'infores:automat-robokop'}": 1}
#
# {    "CP -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "CP -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> CP|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:contributes_to -> liver disorder|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:genetic_association -> liver disorder|{'infores:automat-robokop'}": 1,
#      "Periportal fibrosis -> biolink:subclass_of -> liver disorder|{'infores:automat-robokop'}": 1}
#
# {    "ARNT -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "ARNT -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "PPARGC1A -> biolink:regulates -> REN|{'infores:automat-robokop'}": 1,
#      "REN -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> VIM|{'infores:automat-robokop'}": 1,
#      "VIM -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1}
#
# {    "NFE2L2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "NFE2L2 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> NFE2L2|{'infores:automat-robokop'}": 1}
#
# {    "SERPINA6 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "SERPINA6 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> SERPINA6|{'infores:automat-robokop'}": 1}
#
# {    "FBN1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "FBN1 -> biolink:regulates -> PPARGC1A|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> STAT1|{'infores:automat-robokop'}": 1,
#      "STAT1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "STAT1 -> biolink:interacts_with -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> REN|{'infores:automat-robokop'}": 1,
#      "REN -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "REN -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "CYP2R1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "CYP2R1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CYP2R1|{'infores:automat-robokop'}": 1}
#
# {    "HDAC2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARGC1A -> biolink:regulates -> HDAC2|{'infores:automat-robokop'}": 1}
#
# {    "IGFBP1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "IGFBP1 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> IGFBP1|{'infores:automat-robokop'}": 1}
#
# {    "CNR2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "CNR2 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARGC1B -> biolink:regulates -> AGT|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> TGFB1|{'infores:automat-robokop'}": 1,
#      "TGFB1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "TGFB1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "F2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "F2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> F2|{'infores:automat-robokop'}": 1}
#
# {    "HNF1A -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "PPARGC1A -> biolink:regulates -> HNF1A|{'infores:automat-robokop'}": 1}
#
# {    "PPARGC1B -> biolink:regulates -> VEGFA|{'infores:automat-robokop'}": 1,
#      "VEGFA -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "VEGFA -> biolink:regulates -> PPARGC1B|{'infores:automat-robokop'}": 1}
#
# {    "F2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)|{'infores:automat-robokop'}": 1,
#      "F2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> F2|{'infores:automat-robokop'}": 1}
#
# {    "PPARA -> biolink:regulates -> THBS1|{'infores:automat-robokop'}": 1,
#      "THBS1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "THBS1 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1}
#
# {    "MMP2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "MMP2 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> MMP2|{'infores:automat-robokop'}": 1}
#
# {    "CCN2 -> biolink:genetic_association -> Hepatic fibrosis|{'infores:automat-robokop'}": 1,
#      "CCN2 -> biolink:regulates -> PPARA|{'infores:automat-robokop'}": 1,
#      "PPARA -> biolink:regulates -> CCN2|{'infores:automat-robokop'}": 1}

# %%
response_ara = requests.post(aragorn_submit_url,json=query)
print(response_ara.status_code)
number_pathway_results_ara = len(response_ara.json()['message']['results'])
print(len(response_ara.json()['message']['results']))
# Out:
# 200
# 201

# %%
kg_ara = response_ara.json()['message']['knowledge_graph']
results_ara = response_ara.json()['message']['results']

# %%
import pandas as pd
import os

cols = []
for node in sorted(results_ara[0]['node_bindings'].keys()):
    cols.append(node)
    cols.append(node + '_name')
results_ara_df = pd.DataFrame(columns = cols)

results_ara_list = []
for result in results_ara:
    result_dict = {}
    for node in sorted(result['node_bindings'].keys()):
        node_id = result['node_bindings'][node][0]['id']
        result_dict[node] = node_id
        result_dict[node + '_name'] = kg_ara['nodes'][node_id]['name']

    results_ara_list.append(pd.DataFrame([result_dict]))
results_ara_df = pd.concat(results_ara_list)
display(results_ara_df)
# results_ara_df.to_csv(os.path.join(write_dir_trapi_ara,'results_ARA.csv'), index=False)
results_ara_df.to_csv(ARA_results_file, index=False)

combined_node_list = ["_".join([row[1].replace(" ", "_"), row[3].replace(" ", "_"), row[5].replace(" ", "_")]) for row in results_ara_df[cols].to_numpy()]
pp.pprint(combined_node_list)
# Out:
#                n00  n00_name            n01 n01_name            n02  \
# 0    NCBIGene:5465     PPARA  NCBIGene:4088    SMAD3     HP:0001395
# 0    NCBIGene:5465     PPARA  NCBIGene:4088    SMAD3     HP:0001395
# 0    NCBIGene:5465     PPARA  NCBIGene:7040    TGFB1     HP:0001395
# 0    NCBIGene:5465     PPARA  NCBIGene:7040    TGFB1     HP:0001395
# 0    NCBIGene:5465     PPARA  NCBIGene:6347     CCL2     HP:0001395
# ..             ...       ...            ...      ...            ...
# 0   NCBIGene:10891  PPARGC1A  NCBIGene:3066    HDAC2     HP:0001395
# 0   NCBIGene:80205      CHD9   NCBIGene:183      AGT  MONDO:0018840
# 0   NCBIGene:80205      CHD9   NCBIGene:183      AGT  MONDO:0018840
# 0   NCBIGene:80205      CHD9  NCBIGene:5244    ABCB4     HP:0001395
# 0   NCBIGene:80205      CHD9   NCBIGene:183      AGT     HP:0001395
#
#                                 n02_name
# 0                       Hepatic fibrosis
# 0                       Hepatic fibrosis
# 0                       Hepatic fibrosis
# 0                       Hepatic fibrosis
# 0                       Hepatic fibrosis
# ..                                   ...
# 0                       Hepatic fibrosis
# 0   isolated congenital hepatic fibrosis
# 0   isolated congenital hepatic fibrosis
# 0                       Hepatic fibrosis
# 0                       Hepatic fibrosis
#
# [201 rows x 6 columns]
# [    'PPARA_SMAD3_Hepatic_fibrosis',
#      'PPARA_SMAD3_Hepatic_fibrosis',
#      'PPARA_TGFB1_Hepatic_fibrosis',
#      'PPARA_TGFB1_Hepatic_fibrosis',
#      'PPARA_CCL2_Hepatic_fibrosis',
#      'PPARA_CCL2_Hepatic_fibrosis',
#      'PPARA_ALB_Hepatic_fibrosis',
#      'PPARA_ALB_Hepatic_fibrosis',
#      'PPARA_HGF_Hepatic_fibrosis',
#      'PPARA_HGF_Hepatic_fibrosis',
#      'PPARA_liver_disorder_Hepatic_fibrosis',
#      'PPARA_liver_disorder_Hepatic_fibrosis',
#      'PPARA_MMP2_Hepatic_fibrosis',
#      'PPARA_MMP2_Hepatic_fibrosis',
#      'PPARA_IL6_Hepatic_fibrosis',
#      'PPARA_IL6_Hepatic_fibrosis',
#      'PPARGC1A_CCL2_Hepatic_fibrosis',
#      'PPARA_liver_disorder_isolated_congenital_hepatic_fibrosis',
#      'PPARA_liver_disorder_isolated_congenital_hepatic_fibrosis',
#      'PPARA_liver_disorder_isolated_congenital_hepatic_fibrosis',
#      'PPARA_liver_disorder_isolated_congenital_hepatic_fibrosis',
#      'PPARA_CCN2_Hepatic_fibrosis',
#      'PPARA_CCN2_Hepatic_fibrosis',
#      'PPARA_F2_Hepatic_fibrosis',
#      'PPARA_F2_Hepatic_fibrosis',
#      'PPARA_liver_disorder_Periportal_fibrosis',
#      'PPARA_liver_disorder_Periportal_fibrosis',
#      'PPARGC1B_CCL2_Hepatic_fibrosis',
#      'PPARA_STAT1_Hepatic_fibrosis',
#      'PPARA_STAT1_Hepatic_fibrosis',
#      'PPARA_NFE2L2_Hepatic_fibrosis',
#      'PPARA_NFE2L2_Hepatic_fibrosis',
#      'PPARA_cirrhosis_of_liver_isolated_congenital_hepatic_fibrosis',
#      'PPARA_cirrhosis_of_liver_isolated_congenital_hepatic_fibrosis',
#      'PPARA_cirrhosis_of_liver_isolated_congenital_hepatic_fibrosis',
#      'PPARA_cirrhosis_of_liver_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1A_NFE2L2_Hepatic_fibrosis',
#      'PPARGC1A_ALB_Hepatic_fibrosis',
#      'PPARA_CP_Hepatic_fibrosis',
#      'PPARA_CP_Hepatic_fibrosis',
#      'PPARGC1A_IL6_Hepatic_fibrosis',
#      'PPARGC1B_ALB_Hepatic_fibrosis',
#      'PPARA_REN_Hepatic_fibrosis',
#      'PPARA_REN_Hepatic_fibrosis',
#      'PPARGC1B_NFE2L2_Hepatic_fibrosis',
#      'PPARA_COL1A1_Hepatic_fibrosis',
#      'PPARA_COL1A1_Hepatic_fibrosis',
#      'PPARA_SPP1_Hepatic_fibrosis',
#      'PPARA_SPP1_Hepatic_fibrosis',
#      'PPARA_VEGFA_Hepatic_fibrosis',
#      'PPARA_VEGFA_Hepatic_fibrosis',
#      'PPARA_AGT_Hepatic_fibrosis',
#      'PPARA_AGT_Hepatic_fibrosis',
#      'PPARA_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARA_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARA_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARA_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1A_MMP2_Hepatic_fibrosis',
#      'PPARA_TGFB1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_TGFB1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_TGFB1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_TGFB1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_TGFBR1_Hepatic_fibrosis',
#      'PPARA_TGFBR1_Hepatic_fibrosis',
#      'PPARA_CTNNB1_Hepatic_fibrosis',
#      'PPARA_CTNNB1_Hepatic_fibrosis',
#      'PPARA_THBS1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_THBS1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_THBS1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_THBS1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_REN_isolated_congenital_hepatic_fibrosis',
#      'PPARA_REN_isolated_congenital_hepatic_fibrosis',
#      'PPARA_REN_isolated_congenital_hepatic_fibrosis',
#      'PPARA_REN_isolated_congenital_hepatic_fibrosis',
#      'PPARA_PKHD1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_PKHD1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_PKHD1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_PKHD1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_THBS1_Hepatic_fibrosis',
#      'PPARA_THBS1_Hepatic_fibrosis',
#      'PPARGC1A_VEGFA_Hepatic_fibrosis',
#      'PPARGC1A_FBN1_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1A_FBN1_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1B_IL6_Hepatic_fibrosis',
#      'PPARA_ABCB4_Hepatic_fibrosis',
#      'PPARA_ABCB4_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CCL2_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CCL2_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CCL2_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_F2_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_F2_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_F2_Hepatic_fibrosis',
#      'PPARA_COL1A2_Hepatic_fibrosis',
#      'PPARA_COL1A2_Hepatic_fibrosis',
#      'PPARGC1A_SPP1_Hepatic_fibrosis',
#      'PPARGC1B_VEGFA_Hepatic_fibrosis',
#      'PPARGC1A_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1A_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARA_PLAU_Hepatic_fibrosis',
#      'PPARA_PLAU_Hepatic_fibrosis',
#      'PPARGC1B_MMP2_Hepatic_fibrosis',
#      'PPARGC1B_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1B_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1B_SPP1_Hepatic_fibrosis',
#      'PPARA_F2R_Hepatic_fibrosis',
#      'PPARA_F2R_Hepatic_fibrosis',
#      'PPARA_ARRB1_Hepatic_fibrosis',
#      'PPARA_ARRB1_Hepatic_fibrosis',
#      'PPARA_FLT1_Hepatic_fibrosis',
#      'PPARA_FLT1_Hepatic_fibrosis',
#      'PPARA_FGF2_Hepatic_fibrosis',
#      'PPARA_FGF2_Hepatic_fibrosis',
#      'PPARGC1A_AGT_Hepatic_fibrosis',
#      'PPARA_ARNT_Hepatic_fibrosis',
#      'PPARA_ARNT_Hepatic_fibrosis',
#      'PPARA_LGALS1_Hepatic_fibrosis',
#      'PPARA_LGALS1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CP_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CP_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CP_Hepatic_fibrosis',
#      'PPARA_NPC1_Hepatic_fibrosis',
#      'PPARA_NPC1_Hepatic_fibrosis',
#      'PPARGC1B_AGT_Hepatic_fibrosis',
#      'PPARA_CNR2_Hepatic_fibrosis',
#      'PPARA_CNR2_Hepatic_fibrosis',
#      'PPARA_RGN_Hepatic_fibrosis',
#      'PPARA_RGN_Hepatic_fibrosis',
#      'PPARGC1A_REN_Hepatic_fibrosis',
#      'PPARA_HNF1A_isolated_congenital_hepatic_fibrosis',
#      'PPARA_HNF1A_isolated_congenital_hepatic_fibrosis',
#      'PPARA_HNF1A_isolated_congenital_hepatic_fibrosis',
#      'PPARA_HNF1A_isolated_congenital_hepatic_fibrosis',
#      'PPARA_NF1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_NF1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_NF1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_NF1_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1A_FLT1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_isolated_congenital_hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_isolated_congenital_hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_isolated_congenital_hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_gamma_coactivator_1-alpha_isoform_h1_(human)_AGT_isolated_congenital_hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_isolated_congenital_hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_gamma_coactivator_1-alpha_isoform_h1_(human)_AGT_isolated_congenital_hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_isolated_congenital_hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARA_VIM_Hepatic_fibrosis',
#      'PPARA_VIM_Hepatic_fibrosis',
#      'PPARGC1A_STAT1_Hepatic_fibrosis',
#      'PPARGC1A_REN_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1A_REN_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1B_REN_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1B_REN_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1A_HNF1A_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1A_HNF1A_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1B_HNF1A_isolated_congenital_hepatic_fibrosis',
#      'PPARGC1B_HNF1A_isolated_congenital_hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_LOX_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_LOX_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_LOX_Hepatic_fibrosis',
#      'PPARGC1B_REN_Hepatic_fibrosis',
#      'PPARGC1A_FBN1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_gamma_coactivator_1-alpha_isoform_h1_(human)_VIM_Hepatic_fibrosis',
#      'PPARA_liver_disorder_Hepatic_bridging_fibrosis',
#      'PPARA_liver_disorder_Hepatic_bridging_fibrosis',
#      'PPARGC1B_FLT1_Hepatic_fibrosis',
#      'chromodomain-helicase-DNA-binding_protein_9_isoform_h2_(human)_CTNNB1_Hepatic_fibrosis',
#      'PPARA_liver_disorder_Liver_Disease_Associated_with_Cystic_Fibrosis',
#      'PPARA_liver_disorder_Liver_Disease_Associated_with_Cystic_Fibrosis',
#      'PPARA_liver_disorder_fibrotic_liver_disease',
#      'PPARA_liver_disorder_fibrotic_liver_disease',
#      'peroxisome_proliferator-activated_receptor_gamma_coactivator_1-alpha_isoform_h1_(human)_AGT_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP27A1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP27A1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_gamma_coactivator_1-alpha_isoform_h1_(human)_CYP27A1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP27A1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP2R1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP2R1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP2R1_Hepatic_fibrosis',
#      'PPARGC1A_ARNT_Hepatic_fibrosis',
#      'PPARGC1B_STAT1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_KRT18_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_KRT18_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_KRT18_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_IGFBP1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_IGFBP1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_IGFBP1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CNR2_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CNR2_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CNR2_Hepatic_fibrosis',
#      'PPARGC1B_ARNT_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_SERPINA6_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_SERPINA6_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_SERPINA6_Hepatic_fibrosis',
#      'PPARGC1A_HDAC2_Hepatic_fibrosis',
#      'CHD9_AGT_isolated_congenital_hepatic_fibrosis',
#      'CHD9_AGT_isolated_congenital_hepatic_fibrosis',
#      'CHD9_ABCB4_Hepatic_fibrosis',
#      'CHD9_AGT_Hepatic_fibrosis']

# %%
from collections import Counter
import json
import pprint
pp = pprint.PrettyPrinter(indent=5)

for i in range(number_pathway_results_ara):
    print(f"Pathway result: {combined_node_list[i]}")
    edge_bindings = results_ara[i]['edge_bindings']

    edge_ids = []
    for edge_name, edge_list in edge_bindings.items():
        edge_ids.append({edge_name: [x['id'] for x in edge_list]})

    string_out_list = []
    for edge_dict in edge_ids:
        for edge_name, edge_list in edge_dict.items():
            for edge_id in edge_list:
                subject_id = kg_ara['edges'][edge_id]['subject']
                subject = kg_ara['nodes'][subject_id]['name']
                predicate = kg_ara['edges'][edge_id]['predicate']
                object_id = kg_ara['edges'][edge_id]['object']
                object = kg_ara['nodes'][object_id]['name']
                string_out = f"{subject} -> {predicate} -> {object}"
                string_out_list.append(string_out)
    string_out_dict = dict(Counter(string_out_list).items())
    pp.pprint(string_out_dict)
    print("")
    
    with open(os.path.join(write_dir_trapi_ara,combined_node_list[i]+".txt"), 'a') as convert_file:
        convert_file.write(json.dumps(string_out_dict))
# Out:
# Pathway result: PPARA_SMAD3_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> SMAD3': 1,
#      'PPARA -> biolink:regulates -> SMAD3': 1,
#      'SMAD3 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'SMAD3 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'SMAD3 -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_SMAD3_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> SMAD3': 1,
#      'PPARA -> biolink:regulates -> SMAD3': 1,
#      'SMAD3 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'SMAD3 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'SMAD3 -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_TGFB1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> TGFB1': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> TGFB1': 1,
#      'PPARA -> biolink:regulates -> TGFB1': 1,
#      'TGFB1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'TGFB1 -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_TGFB1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> TGFB1': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> TGFB1': 1,
#      'PPARA -> biolink:regulates -> TGFB1': 1,
#      'TGFB1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'TGFB1 -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_CCL2_Hepatic_fibrosis
# {    'CCL2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CCL2 -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CCL2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> CCL2': 1,
#      'PPARA -> biolink:regulates -> CCL2': 1}
#
# Pathway result: PPARA_CCL2_Hepatic_fibrosis
# {    'CCL2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CCL2 -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CCL2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> CCL2': 1,
#      'PPARA -> biolink:regulates -> CCL2': 1}
#
# Pathway result: PPARA_ALB_Hepatic_fibrosis
# {    'ALB -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'ALB -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'ALB -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> ALB': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:directly_physically_interacts_with -> ALB': 1,
#      'PPARA -> biolink:regulates -> ALB': 1}
#
# Pathway result: PPARA_ALB_Hepatic_fibrosis
# {    'ALB -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'ALB -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'ALB -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> ALB': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:directly_physically_interacts_with -> ALB': 1,
#      'PPARA -> biolink:regulates -> ALB': 1}
#
# Pathway result: PPARA_HGF_Hepatic_fibrosis
# {    'HGF -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'HGF -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'HGF -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> HGF': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> HGF': 1}
#
# Pathway result: PPARA_HGF_Hepatic_fibrosis
# {    'HGF -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'HGF -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'HGF -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> HGF': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> HGF': 1}
#
# Pathway result: PPARA_liver_disorder_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> liver disorder': 1,
#      'Hepatic fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_liver_disorder_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> liver disorder': 1,
#      'Hepatic fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_MMP2_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> MMP2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'MMP2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'MMP2 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'MMP2 -> biolink:regulates -> PPARA': 1,
#      'PPARA -> biolink:regulates -> MMP2': 1}
#
# Pathway result: PPARA_MMP2_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> MMP2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'MMP2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'MMP2 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'MMP2 -> biolink:regulates -> PPARA': 1,
#      'PPARA -> biolink:regulates -> MMP2': 1}
#
# Pathway result: PPARA_IL6_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> IL6': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'IL6 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'IL6 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'IL6 -> biolink:regulates -> PPARA': 1,
#      'PPARA -> biolink:regulates -> IL6': 1}
#
# Pathway result: PPARA_IL6_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> IL6': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'IL6 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'IL6 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'IL6 -> biolink:regulates -> PPARA': 1,
#      'PPARA -> biolink:regulates -> IL6': 1}
#
# Pathway result: PPARGC1A_CCL2_Hepatic_fibrosis
# {    'CCL2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CCL2 -> biolink:regulates -> PPARGC1A': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CCL2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARGC1A': 1,
#      'PPARGC1A -> biolink:occurs_together_in_literature_with -> CCL2': 1,
#      'PPARGC1A -> biolink:regulates -> CCL2': 1}
#
# Pathway result: PPARA_liver_disorder_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> isolated congenital hepatic fibrosis': 1}
#
# Pathway result: PPARA_liver_disorder_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> isolated congenital hepatic fibrosis': 1}
#
# Pathway result: PPARA_liver_disorder_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> isolated congenital hepatic fibrosis': 1}
#
# Pathway result: PPARA_liver_disorder_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> isolated congenital hepatic fibrosis': 1}
#
# Pathway result: PPARA_CCN2_Hepatic_fibrosis
# {    'CCN2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CCN2 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'CCN2 -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CCN2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> CCN2': 1}
#
# Pathway result: PPARA_CCN2_Hepatic_fibrosis
# {    'CCN2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CCN2 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'CCN2 -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CCN2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> CCN2': 1}
#
# Pathway result: PPARA_F2_Hepatic_fibrosis
# {    'F2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'F2 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> F2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:interacts_with -> F2': 1,
#      'PPARA -> biolink:regulates -> F2': 1}
#
# Pathway result: PPARA_F2_Hepatic_fibrosis
# {    'F2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'F2 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> F2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:interacts_with -> F2': 1,
#      'PPARA -> biolink:regulates -> F2': 1}
#
# Pathway result: PPARA_liver_disorder_Periportal_fibrosis
# {    'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'Periportal fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Periportal fibrosis -> biolink:occurs_together_in_literature_with -> liver disorder': 1,
#      'Periportal fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_liver_disorder_Periportal_fibrosis
# {    'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'Periportal fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Periportal fibrosis -> biolink:occurs_together_in_literature_with -> liver disorder': 1,
#      'Periportal fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARGC1B_CCL2_Hepatic_fibrosis
# {    'CCL2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CCL2 -> biolink:regulates -> PPARGC1B': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CCL2': 1,
#      'PPARGC1B -> biolink:regulates -> CCL2': 1}
#
# Pathway result: PPARA_STAT1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> STAT1': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> STAT1': 1,
#      'PPARA -> biolink:regulates -> STAT1': 1,
#      'STAT1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'STAT1 -> biolink:interacts_with -> PPARA': 1}
#
# Pathway result: PPARA_STAT1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> STAT1': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> STAT1': 1,
#      'PPARA -> biolink:regulates -> STAT1': 1,
#      'STAT1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'STAT1 -> biolink:interacts_with -> PPARA': 1}
#
# Pathway result: PPARA_NFE2L2_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> NFE2L2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'NFE2L2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'NFE2L2 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'NFE2L2 -> biolink:regulates -> PPARA': 1,
#      'PPARA -> biolink:regulates -> NFE2L2': 1}
#
# Pathway result: PPARA_NFE2L2_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> NFE2L2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'NFE2L2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'NFE2L2 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'NFE2L2 -> biolink:regulates -> PPARA': 1,
#      'PPARA -> biolink:regulates -> NFE2L2': 1}
#
# Pathway result: PPARA_cirrhosis_of_liver_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:contributes_to -> cirrhosis of liver': 1,
#      'cirrhosis of liver -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'cirrhosis of liver -> biolink:occurs_together_in_literature_with -> isolated congenital hepatic fibrosis': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:subclass_of -> cirrhosis of liver': 1}
#
# Pathway result: PPARA_cirrhosis_of_liver_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:contributes_to -> cirrhosis of liver': 1,
#      'cirrhosis of liver -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'cirrhosis of liver -> biolink:occurs_together_in_literature_with -> isolated congenital hepatic fibrosis': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:subclass_of -> cirrhosis of liver': 1}
#
# Pathway result: PPARA_cirrhosis_of_liver_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:contributes_to -> cirrhosis of liver': 1,
#      'cirrhosis of liver -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'cirrhosis of liver -> biolink:occurs_together_in_literature_with -> isolated congenital hepatic fibrosis': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:subclass_of -> cirrhosis of liver': 1}
#
# Pathway result: PPARA_cirrhosis_of_liver_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:contributes_to -> cirrhosis of liver': 1,
#      'cirrhosis of liver -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'cirrhosis of liver -> biolink:occurs_together_in_literature_with -> isolated congenital hepatic fibrosis': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:subclass_of -> cirrhosis of liver': 1}
#
# Pathway result: PPARGC1A_NFE2L2_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> NFE2L2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARGC1A': 1,
#      'NFE2L2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'NFE2L2 -> biolink:regulates -> PPARGC1A': 1,
#      'PPARGC1A -> biolink:occurs_together_in_literature_with -> NFE2L2': 1,
#      'PPARGC1A -> biolink:regulates -> NFE2L2': 1}
#
# Pathway result: PPARGC1A_ALB_Hepatic_fibrosis
# {    'ALB -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'ALB -> biolink:regulates -> PPARGC1A': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> ALB': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARGC1A': 1}
#
# Pathway result: PPARA_CP_Hepatic_fibrosis
# {    'CP -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CP -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'CP -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CP': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> CP': 1}
#
# Pathway result: PPARA_CP_Hepatic_fibrosis
# {    'CP -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CP -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'CP -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CP': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> CP': 1}
#
# Pathway result: PPARGC1A_IL6_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> IL6': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARGC1A': 1,
#      'IL6 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'IL6 -> biolink:regulates -> PPARGC1A': 1,
#      'PPARGC1A -> biolink:occurs_together_in_literature_with -> IL6': 1}
#
# Pathway result: PPARGC1B_ALB_Hepatic_fibrosis
# {    'ALB -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'ALB -> biolink:regulates -> PPARGC1B': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> ALB': 1}
#
# Pathway result: PPARA_REN_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> REN': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> REN': 1,
#      'PPARA -> biolink:regulates -> REN': 1,
#      'REN -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'REN -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_REN_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> REN': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> REN': 1,
#      'PPARA -> biolink:regulates -> REN': 1,
#      'REN -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'REN -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARGC1B_NFE2L2_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> NFE2L2': 1,
#      'NFE2L2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'NFE2L2 -> biolink:regulates -> PPARGC1B': 1,
#      'PPARGC1B -> biolink:occurs_together_in_literature_with -> NFE2L2': 1,
#      'PPARGC1B -> biolink:regulates -> NFE2L2': 1}
#
# Pathway result: PPARA_COL1A1_Hepatic_fibrosis
# {    'COL1A1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'COL1A1 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> COL1A1': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> COL1A1': 1}
#
# Pathway result: PPARA_COL1A1_Hepatic_fibrosis
# {    'COL1A1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'COL1A1 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> COL1A1': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> COL1A1': 1}
#
# Pathway result: PPARA_SPP1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> SPP1': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> SPP1': 1,
#      'PPARA -> biolink:regulates -> SPP1': 2,
#      'SPP1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'SPP1 -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_SPP1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> SPP1': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> SPP1': 1,
#      'PPARA -> biolink:regulates -> SPP1': 2,
#      'SPP1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'SPP1 -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_VEGFA_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> VEGFA': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> VEGFA': 1,
#      'PPARA -> biolink:regulates -> VEGFA': 1,
#      'VEGFA -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'VEGFA -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_VEGFA_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> VEGFA': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> VEGFA': 1,
#      'PPARA -> biolink:regulates -> VEGFA': 1,
#      'VEGFA -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'VEGFA -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_AGT_Hepatic_fibrosis
# {    'AGT -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'AGT -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'AGT -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:interacts_with -> AGT': 1,
#      'PPARA -> biolink:regulates -> AGT': 1}
#
# Pathway result: PPARA_AGT_Hepatic_fibrosis
# {    'AGT -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'AGT -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'AGT -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:interacts_with -> AGT': 1,
#      'PPARA -> biolink:regulates -> AGT': 1}
#
# Pathway result: PPARA_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'AGT -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'AGT -> biolink:regulates -> PPARA': 1,
#      'PPARA -> biolink:interacts_with -> AGT': 1,
#      'PPARA -> biolink:regulates -> AGT': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'AGT -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'AGT -> biolink:regulates -> PPARA': 1,
#      'PPARA -> biolink:interacts_with -> AGT': 1,
#      'PPARA -> biolink:regulates -> AGT': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'AGT -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'AGT -> biolink:regulates -> PPARA': 1,
#      'PPARA -> biolink:interacts_with -> AGT': 1,
#      'PPARA -> biolink:regulates -> AGT': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'AGT -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'AGT -> biolink:regulates -> PPARA': 1,
#      'PPARA -> biolink:interacts_with -> AGT': 1,
#      'PPARA -> biolink:regulates -> AGT': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARGC1A_MMP2_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> MMP2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARGC1A': 1,
#      'MMP2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARGC1A -> biolink:occurs_together_in_literature_with -> MMP2': 1,
#      'PPARGC1A -> biolink:regulates -> MMP2': 1}
#
# Pathway result: PPARA_TGFB1_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:occurs_together_in_literature_with -> TGFB1': 1,
#      'PPARA -> biolink:regulates -> TGFB1': 1,
#      'TGFB1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'TGFB1 -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> TGFB1': 1}
#
# Pathway result: PPARA_TGFB1_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:occurs_together_in_literature_with -> TGFB1': 1,
#      'PPARA -> biolink:regulates -> TGFB1': 1,
#      'TGFB1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'TGFB1 -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> TGFB1': 1}
#
# Pathway result: PPARA_TGFB1_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:occurs_together_in_literature_with -> TGFB1': 1,
#      'PPARA -> biolink:regulates -> TGFB1': 1,
#      'TGFB1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'TGFB1 -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> TGFB1': 1}
#
# Pathway result: PPARA_TGFB1_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:occurs_together_in_literature_with -> TGFB1': 1,
#      'PPARA -> biolink:regulates -> TGFB1': 1,
#      'TGFB1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'TGFB1 -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> TGFB1': 1}
#
# Pathway result: PPARA_TGFBR1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> TGFBR1': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> TGFBR1': 1,
#      'PPARA -> biolink:regulates -> TGFBR1': 1,
#      'TGFBR1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'TGFBR1 -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_TGFBR1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> TGFBR1': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> TGFBR1': 1,
#      'PPARA -> biolink:regulates -> TGFBR1': 1,
#      'TGFBR1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'TGFBR1 -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_CTNNB1_Hepatic_fibrosis
# {    'CTNNB1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CTNNB1 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'CTNNB1 -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CTNNB1': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> CTNNB1': 1}
#
# Pathway result: PPARA_CTNNB1_Hepatic_fibrosis
# {    'CTNNB1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CTNNB1 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'CTNNB1 -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CTNNB1': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> CTNNB1': 1}
#
# Pathway result: PPARA_THBS1_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:occurs_together_in_literature_with -> THBS1': 1,
#      'PPARA -> biolink:regulates -> THBS1': 1,
#      'THBS1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'THBS1 -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> THBS1': 1}
#
# Pathway result: PPARA_THBS1_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:occurs_together_in_literature_with -> THBS1': 1,
#      'PPARA -> biolink:regulates -> THBS1': 1,
#      'THBS1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'THBS1 -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> THBS1': 1}
#
# Pathway result: PPARA_THBS1_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:occurs_together_in_literature_with -> THBS1': 1,
#      'PPARA -> biolink:regulates -> THBS1': 1,
#      'THBS1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'THBS1 -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> THBS1': 1}
#
# Pathway result: PPARA_THBS1_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:occurs_together_in_literature_with -> THBS1': 1,
#      'PPARA -> biolink:regulates -> THBS1': 1,
#      'THBS1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'THBS1 -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> THBS1': 1}
#
# Pathway result: PPARA_REN_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:occurs_together_in_literature_with -> REN': 1,
#      'PPARA -> biolink:regulates -> REN': 1,
#      'REN -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'REN -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> REN': 1}
#
# Pathway result: PPARA_REN_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:occurs_together_in_literature_with -> REN': 1,
#      'PPARA -> biolink:regulates -> REN': 1,
#      'REN -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'REN -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> REN': 1}
#
# Pathway result: PPARA_REN_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:occurs_together_in_literature_with -> REN': 1,
#      'PPARA -> biolink:regulates -> REN': 1,
#      'REN -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'REN -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> REN': 1}
#
# Pathway result: PPARA_REN_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:occurs_together_in_literature_with -> REN': 1,
#      'PPARA -> biolink:regulates -> REN': 1,
#      'REN -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'REN -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> REN': 1}
#
# Pathway result: PPARA_PKHD1_isolated_congenital_hepatic_fibrosis
# {    'PKHD1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PKHD1 -> biolink:genetic_association -> isolated congenital hepatic fibrosis': 1,
#      'PKHD1 -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PKHD1': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_PKHD1_isolated_congenital_hepatic_fibrosis
# {    'PKHD1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PKHD1 -> biolink:genetic_association -> isolated congenital hepatic fibrosis': 1,
#      'PKHD1 -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PKHD1': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_PKHD1_isolated_congenital_hepatic_fibrosis
# {    'PKHD1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PKHD1 -> biolink:genetic_association -> isolated congenital hepatic fibrosis': 1,
#      'PKHD1 -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PKHD1': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_PKHD1_isolated_congenital_hepatic_fibrosis
# {    'PKHD1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PKHD1 -> biolink:genetic_association -> isolated congenital hepatic fibrosis': 1,
#      'PKHD1 -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PKHD1': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_THBS1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> THBS1': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> THBS1': 1,
#      'PPARA -> biolink:regulates -> THBS1': 1,
#      'THBS1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'THBS1 -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_THBS1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> THBS1': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> THBS1': 1,
#      'PPARA -> biolink:regulates -> THBS1': 1,
#      'THBS1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'THBS1 -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARGC1A_VEGFA_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARGC1A': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> VEGFA': 1,
#      'PPARGC1A -> biolink:occurs_together_in_literature_with -> VEGFA': 1,
#      'PPARGC1A -> biolink:regulates -> VEGFA': 1,
#      'VEGFA -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'VEGFA -> biolink:regulates -> PPARGC1A': 1}
#
# Pathway result: PPARGC1A_FBN1_isolated_congenital_hepatic_fibrosis
# {    'FBN1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'FBN1 -> biolink:regulates -> PPARGC1A': 1,
#      'PPARGC1A -> biolink:occurs_together_in_literature_with -> FBN1': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> FBN1': 1}
#
# Pathway result: PPARGC1A_FBN1_isolated_congenital_hepatic_fibrosis
# {    'FBN1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'FBN1 -> biolink:regulates -> PPARGC1A': 1,
#      'PPARGC1A -> biolink:occurs_together_in_literature_with -> FBN1': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> FBN1': 1}
#
# Pathway result: PPARGC1B_IL6_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> IL6': 1,
#      'IL6 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'IL6 -> biolink:regulates -> PPARGC1B': 1,
#      'PPARGC1B -> biolink:occurs_together_in_literature_with -> IL6': 1}
#
# Pathway result: PPARA_ABCB4_Hepatic_fibrosis
# {    'ABCB4 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'ABCB4 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> ABCB4': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:interacts_with -> ABCB4': 1,
#      'PPARA -> biolink:regulates -> ABCB4': 1}
#
# Pathway result: PPARA_ABCB4_Hepatic_fibrosis
# {    'ABCB4 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'ABCB4 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> ABCB4': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:interacts_with -> ABCB4': 1,
#      'PPARA -> biolink:regulates -> ABCB4': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CCL2_Hepatic_fibrosis
# {    'CCL2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CCL2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CCL2': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CCL2': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CCL2_Hepatic_fibrosis
# {    'CCL2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CCL2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CCL2': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CCL2': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CCL2_Hepatic_fibrosis
# {    'CCL2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CCL2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CCL2': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CCL2': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_F2_Hepatic_fibrosis
# {    'F2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'F2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> F2': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> F2': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_F2_Hepatic_fibrosis
# {    'F2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'F2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> F2': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> F2': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_F2_Hepatic_fibrosis
# {    'F2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'F2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> F2': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> F2': 1}
#
# Pathway result: PPARA_COL1A2_Hepatic_fibrosis
# {    'COL1A2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'COL1A2 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> COL1A2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> COL1A2': 1}
#
# Pathway result: PPARA_COL1A2_Hepatic_fibrosis
# {    'COL1A2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'COL1A2 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> COL1A2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> COL1A2': 1}
#
# Pathway result: PPARGC1A_SPP1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARGC1A': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> SPP1': 1,
#      'PPARGC1A -> biolink:occurs_together_in_literature_with -> SPP1': 1,
#      'PPARGC1A -> biolink:regulates -> SPP1': 1,
#      'SPP1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'SPP1 -> biolink:regulates -> PPARGC1A': 1}
#
# Pathway result: PPARGC1B_VEGFA_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> VEGFA': 1,
#      'PPARGC1B -> biolink:occurs_together_in_literature_with -> VEGFA': 1,
#      'PPARGC1B -> biolink:regulates -> VEGFA': 1,
#      'VEGFA -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'VEGFA -> biolink:regulates -> PPARGC1B': 1}
#
# Pathway result: PPARGC1A_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PPARGC1A -> biolink:occurs_together_in_literature_with -> AGT': 1,
#      'PPARGC1A -> biolink:regulates -> AGT': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1}
#
# Pathway result: PPARGC1A_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PPARGC1A -> biolink:occurs_together_in_literature_with -> AGT': 1,
#      'PPARGC1A -> biolink:regulates -> AGT': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1}
#
# Pathway result: PPARA_PLAU_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PLAU': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PLAU -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PLAU -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PLAU -> biolink:regulates -> PPARA': 1,
#      'PPARA -> biolink:regulates -> PLAU': 1}
#
# Pathway result: PPARA_PLAU_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PLAU': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PLAU -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PLAU -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PLAU -> biolink:regulates -> PPARA': 1,
#      'PPARA -> biolink:regulates -> PLAU': 1}
#
# Pathway result: PPARGC1B_MMP2_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> MMP2': 1,
#      'MMP2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARGC1B -> biolink:occurs_together_in_literature_with -> MMP2': 1,
#      'PPARGC1B -> biolink:regulates -> MMP2': 1}
#
# Pathway result: PPARGC1B_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PPARGC1B -> biolink:regulates -> AGT': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1}
#
# Pathway result: PPARGC1B_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PPARGC1B -> biolink:regulates -> AGT': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1}
#
# Pathway result: PPARGC1B_SPP1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> SPP1': 1,
#      'PPARGC1B -> biolink:regulates -> SPP1': 2,
#      'SPP1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'SPP1 -> biolink:regulates -> PPARGC1B': 1}
#
# Pathway result: PPARA_F2R_Hepatic_fibrosis
# {    'F2R -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'F2R -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> F2R': 1}
#
# Pathway result: PPARA_F2R_Hepatic_fibrosis
# {    'F2R -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'F2R -> biolink:regulates -> PPARA': 1,
# ...
#      'liver disorder -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARGC1B_FLT1_Hepatic_fibrosis
# {    'FLT1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'FLT1 -> biolink:regulates -> PPARGC1B': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> FLT1': 1,
#      'PPARGC1B -> biolink:regulates -> FLT1': 1}
#
# Pathway result: chromodomain-helicase-DNA-binding_protein_9_isoform_h2_(human)_CTNNB1_Hepatic_fibrosis
# {    'CTNNB1 -> biolink:coexpressed_with -> chromodomain-helicase-DNA-binding protein 9 isoform h2 (human)': 1,
#      'CTNNB1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CTNNB1': 1,
#      'chromodomain-helicase-DNA-binding protein 9 isoform h2 (human) -> biolink:coexpressed_with -> CTNNB1': 1}
#
# Pathway result: PPARA_liver_disorder_Liver_Disease_Associated_with_Cystic_Fibrosis
# {    'Liver Disease Associated with Cystic Fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_liver_disorder_Liver_Disease_Associated_with_Cystic_Fibrosis
# {    'Liver Disease Associated with Cystic Fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_liver_disorder_fibrotic_liver_disease
# {    'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'fibrotic liver disease -> biolink:subclass_of -> liver disorder': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_liver_disorder_fibrotic_liver_disease
# {    'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'fibrotic liver disease -> biolink:subclass_of -> liver disorder': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_gamma_coactivator_1-alpha_isoform_h1_(human)_AGT_Hepatic_fibrosis
# {    'AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human)': 1,
#      'AGT -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1,
#      'peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human) -> biolink:coexpressed_with -> AGT': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_Hepatic_fibrosis
# {    'AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'AGT -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> AGT': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_Hepatic_fibrosis
# {    'AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'AGT -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> AGT': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_Hepatic_fibrosis
# {    'AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'AGT -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> AGT': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP27A1_Hepatic_fibrosis
# {    'CYP27A1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CYP27A1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CYP27A1': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CYP27A1': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP27A1_Hepatic_fibrosis
# {    'CYP27A1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CYP27A1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CYP27A1': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CYP27A1': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_gamma_coactivator_1-alpha_isoform_h1_(human)_CYP27A1_Hepatic_fibrosis
# {    'CYP27A1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human)': 1,
#      'CYP27A1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CYP27A1': 1,
#      'peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human) -> biolink:coexpressed_with -> CYP27A1': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP27A1_Hepatic_fibrosis
# {    'CYP27A1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CYP27A1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CYP27A1': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CYP27A1': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP2R1_Hepatic_fibrosis
# {    'CYP2R1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CYP2R1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CYP2R1': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CYP2R1': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP2R1_Hepatic_fibrosis
# {    'CYP2R1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CYP2R1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CYP2R1': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CYP2R1': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP2R1_Hepatic_fibrosis
# {    'CYP2R1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CYP2R1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CYP2R1': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CYP2R1': 1}
#
# Pathway result: PPARGC1A_ARNT_Hepatic_fibrosis
# {    'ARNT -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> ARNT': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARGC1A': 1,
#      'PPARGC1A -> biolink:occurs_together_in_literature_with -> ARNT': 1,
#      'PPARGC1A -> biolink:regulates -> ARNT': 1}
#
# Pathway result: PPARGC1B_STAT1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> STAT1': 1,
#      'PPARGC1B -> biolink:occurs_together_in_literature_with -> STAT1': 1,
#      'STAT1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'STAT1 -> biolink:interacts_with -> PPARGC1B': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_KRT18_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> KRT18': 1,
#      'KRT18 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'KRT18 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> KRT18': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_KRT18_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> KRT18': 1,
#      'KRT18 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'KRT18 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> KRT18': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_KRT18_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> KRT18': 1,
#      'KRT18 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'KRT18 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> KRT18': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_IGFBP1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> IGFBP1': 1,
#      'IGFBP1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'IGFBP1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> IGFBP1': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_IGFBP1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> IGFBP1': 1,
#      'IGFBP1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'IGFBP1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> IGFBP1': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_IGFBP1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> IGFBP1': 1,
#      'IGFBP1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'IGFBP1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> IGFBP1': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CNR2_Hepatic_fibrosis
# {    'CNR2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CNR2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CNR2': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CNR2': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CNR2_Hepatic_fibrosis
# {    'CNR2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CNR2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CNR2': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CNR2': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CNR2_Hepatic_fibrosis
# {    'CNR2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CNR2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CNR2': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CNR2': 1}
#
# Pathway result: PPARGC1B_ARNT_Hepatic_fibrosis
# {    'ARNT -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> ARNT': 1,
#      'PPARGC1B -> biolink:regulates -> ARNT': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_SERPINA6_Hepatic_fibrosis
# {    'SERPINA6 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'SERPINA6 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> SERPINA6': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_SERPINA6_Hepatic_fibrosis
# {    'SERPINA6 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'SERPINA6 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> SERPINA6': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_SERPINA6_Hepatic_fibrosis
# {    'SERPINA6 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'SERPINA6 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> SERPINA6': 1}
#
# Pathway result: PPARGC1A_HDAC2_Hepatic_fibrosis
# {    'HDAC2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> HDAC2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARGC1A': 1,
#      'PPARGC1A -> biolink:occurs_together_in_literature_with -> HDAC2': 1,
#      'PPARGC1A -> biolink:regulates -> HDAC2': 1}
#
# Pathway result: CHD9_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'CHD9 -> biolink:interacts_with -> AGT': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1}
#
# Pathway result: CHD9_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'CHD9 -> biolink:interacts_with -> AGT': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1}
#
# Pathway result: CHD9_ABCB4_Hepatic_fibrosis
# {    'ABCB4 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CHD9 -> biolink:interacts_with -> ABCB4': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> ABCB4': 1}
#
# Pathway result: CHD9_AGT_Hepatic_fibrosis
# {    'AGT -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CHD9 -> biolink:interacts_with -> AGT': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1}

# %% [markdown]
# ### Cypher methods

# %%
# Initializing Cypher query and extracting results from Automat using Cypher

nodes = ['n00','n01','n02']
relationships = ['r0','r1']
cols = []
for node in nodes:
    cols.append(node)
    cols.append(node+"_name")

results_df = pd.DataFrame(columns = cols)
results_dict_list = []

additional_input_node_ids = ['UniProtKB:Q07869-1', 'UniProtKB:Q3L8U1-2', 'UniProtKB:Q9UBK2-1']
additional_output_node_ids = ['HP:0001405', 'HP:0012852']

i = 0

# cypher = f"""MATCH
# ({nodes[0]}:`biolink:GeneOrGeneProduct`)-[{relationships[0]}]-({nodes[1]}:`biolink:BiologicalEntity`)-[{relationships[1]}]-({nodes[2]}:`biolink:DiseaseOrPhenotypicFeature`)
# WHERE {nodes[0]}.id IN {input_node_id_list} AND {nodes[2]}.id IN {output_node_id_list}
# RETURN [startNode({relationships[0]}),[type({relationships[0]}),properties({relationships[0]})],endNode({relationships[0]})] as edge_1, 
# [startNode({relationships[1]}),[type({relationships[1]}),properties({relationships[1]})],endNode({relationships[1]})] as edge_2, 
# [{nodes[0]}.name, {nodes[1]}.name, {nodes[2]}.name] as node_names,
# [{nodes[0]}.id, {nodes[1]}.id, {nodes[2]}.id] as node_ids LIMIT 100"""
# json_query = {'query': cypher}

cypher = f"""MATCH
({nodes[0]}:`biolink:GeneOrGeneProduct`)-[{relationships[0]}]-({nodes[1]}:`biolink:BiologicalEntity`)-[{relationships[1]}]-({nodes[2]}:`biolink:DiseaseOrPhenotypicFeature`)
WHERE {nodes[0]}.id IN {input_node_id_list+additional_input_node_ids} AND {nodes[2]}.id IN {output_node_id_list+additional_output_node_ids}
RETURN [startNode({relationships[0]}),[type({relationships[0]}),properties({relationships[0]})],endNode({relationships[0]})] as edge_1, 
[startNode({relationships[1]}),[type({relationships[1]}),properties({relationships[1]})],endNode({relationships[1]})] as edge_2, 
[{nodes[0]}.name, {nodes[1]}.name, {nodes[2]}.name] as node_names,
[{nodes[0]}.id, {nodes[1]}.id, {nodes[2]}.id] as node_ids LIMIT 300"""
json_query = {'query': cypher}

results = requests.post(automat_cypher_submit_url,json=json_query, timeout=(40,200))
results_json = results.json()

# pp.pprint(results_json)
for result in results_json['results'][0]['data']:
    string_out_list = []
    for item in result['row'][0:2]:
        string_out = f"{item[0]['name']} -> {item[1][0]} -> {item[2]['name']}||{item[1][1]}"
        string_out_ids = f"{item[0]['id']} -> {item[1][0]} -> {item[2]['id']}||{item[1][1]['biolink:primary_knowledge_source']}"
        print()
        print(string_out_ids)
        if string_out not in string_out_list:
            string_out_list.append(string_out)
    if len(results_json['results'][0]['data']) > 0:
        combined_node_list = "_".join(results_json['results'][0]['data'][0]['row'][2]).replace(" ", "_")
        # print(combined_node_list)

    # string_out_list = [i.split('||', 1)[0] for i in string_out_list]

    string_out_dict = dict(Counter(string_out_list).items())
    if len(string_out_dict.keys()) == 0:
        pass
        # print(f"None found for {input_node_id}-{output_node_id}")
    else:
        combined_node_list = "_".join(result['row'][2]).replace(" ", "_")
        print(combined_node_list)

        string_out_list = [i.split('||', 1)[0] for i in string_out_list]

        string_out_dict = dict(Counter(string_out_list).items())
        pp.pprint(string_out_dict)
        # i = i + 1

        with open(os.path.join(write_dir_cypher_automat,combined_node_list+".txt"), 'a') as convert_file:
            convert_file.write(json.dumps(string_out_dict))

    result_dict = {}
    for k in range(len(nodes)):
        node_id = result['row'][3][k]
        node_name = result['row'][2][k]
        result_dict[nodes[k]] = node_id
        result_dict[nodes[k]+"_name"] = node_name
    # pp.pprint(result_dict)

    results_dict_list.append(result_dict)

results_df = pd.concat([results_df,pd.DataFrame.from_records(results_dict_list)])
print(results_df.shape)
results_df.to_csv(os.path.join(write_dir_cypher_automat,'results.csv'))
results_df.to_csv(Cypher_Automat_results_file)
# Out:
# NCBIGene:7431 -> biolink:coexpressed_with -> UniProtKB:Q9UBK2-1||infores:STRING
#
# NCBIGene:7431 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_gamma_coactivator_1-alpha_isoform_h1_(human)_VIM_Hepatic_fibrosis
# {    'VIM -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human)': 1,
#      'VIM -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:183 -> biolink:coexpressed_with -> UniProtKB:Q9UBK2-1||infores:STRING
#
# NCBIGene:183 -> biolink:contributes_to -> MONDO:0018840||infores:textminingkp
# peroxisome_proliferator-activated_receptor_gamma_coactivator_1-alpha_isoform_h1_(human)_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human)': 1,
#      'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
#
# NCBIGene:183 -> biolink:coexpressed_with -> UniProtKB:Q9UBK2-1||infores:STRING
#
# NCBIGene:183 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_gamma_coactivator_1-alpha_isoform_h1_(human)_AGT_Hepatic_fibrosis
# {    'AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human)': 1,
#      'AGT -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:1593 -> biolink:coexpressed_with -> UniProtKB:Q9UBK2-1||infores:STRING
#
# NCBIGene:1593 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_gamma_coactivator_1-alpha_isoform_h1_(human)_CYP27A1_Hepatic_fibrosis
# {    'CYP27A1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human)': 1,
#      'CYP27A1 -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# UniProtKB:Q9UBK2-1 -> biolink:coexpressed_with -> NCBIGene:1593||infores:STRING
#
# NCBIGene:1593 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_gamma_coactivator_1-alpha_isoform_h1_(human)_CYP27A1_Hepatic_fibrosis
# {    'CYP27A1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human) -> biolink:coexpressed_with -> CYP27A1': 1}
#
# UniProtKB:Q9UBK2-1 -> biolink:coexpressed_with -> NCBIGene:183||infores:STRING
#
# NCBIGene:183 -> biolink:contributes_to -> MONDO:0018840||infores:textminingkp
# peroxisome_proliferator-activated_receptor_gamma_coactivator_1-alpha_isoform_h1_(human)_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human) -> biolink:coexpressed_with -> AGT': 1}
#
# UniProtKB:Q9UBK2-1 -> biolink:coexpressed_with -> NCBIGene:183||infores:STRING
#
# NCBIGene:183 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_gamma_coactivator_1-alpha_isoform_h1_(human)_AGT_Hepatic_fibrosis
# {    'AGT -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human) -> biolink:coexpressed_with -> AGT': 1}
#
# UniProtKB:Q9UBK2-1 -> biolink:coexpressed_with -> NCBIGene:7431||infores:STRING
#
# NCBIGene:7431 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_gamma_coactivator_1-alpha_isoform_h1_(human)_VIM_Hepatic_fibrosis
# {    'VIM -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human) -> biolink:coexpressed_with -> VIM': 1}
#
# NCBIGene:1499 -> biolink:coexpressed_with -> UniProtKB:Q3L8U1-2||infores:STRING
#
# NCBIGene:1499 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# chromodomain-helicase-DNA-binding_protein_9_isoform_h2_(human)_CTNNB1_Hepatic_fibrosis
# {    'CTNNB1 -> biolink:coexpressed_with -> chromodomain-helicase-DNA-binding protein 9 isoform h2 (human)': 1,
#      'CTNNB1 -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# UniProtKB:Q3L8U1-2 -> biolink:coexpressed_with -> NCBIGene:1499||infores:STRING
#
# NCBIGene:1499 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# chromodomain-helicase-DNA-binding_protein_9_isoform_h2_(human)_CTNNB1_Hepatic_fibrosis
# {    'CTNNB1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'chromodomain-helicase-DNA-binding protein 9 isoform h2 (human) -> biolink:coexpressed_with -> CTNNB1': 1}
#
# NCBIGene:6772 -> biolink:interacts_with -> NCBIGene:133522||infores:sri-reference-kg
#
# NCBIGene:6772 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1B_STAT1_Hepatic_fibrosis
# {    'STAT1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'STAT1 -> biolink:interacts_with -> PPARGC1B': 1}
#
# NCBIGene:4780 -> biolink:regulates -> NCBIGene:133522||infores:textminingkp
#
# NCBIGene:4780 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1B_NFE2L2_Hepatic_fibrosis
# {    'NFE2L2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'NFE2L2 -> biolink:regulates -> PPARGC1B': 1}
#
# NCBIGene:2321 -> biolink:regulates -> NCBIGene:133522||infores:textminingkp
#
# NCBIGene:2321 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1B_FLT1_Hepatic_fibrosis
# {    'FLT1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'FLT1 -> biolink:regulates -> PPARGC1B': 1}
#
# NCBIGene:6347 -> biolink:regulates -> NCBIGene:133522||infores:textminingkp
#
# NCBIGene:6347 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1B_CCL2_Hepatic_fibrosis
# {    'CCL2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CCL2 -> biolink:regulates -> PPARGC1B': 1}
#
# NCBIGene:7422 -> biolink:regulates -> NCBIGene:133522||infores:textminingkp
#
# NCBIGene:7422 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1B_VEGFA_Hepatic_fibrosis
# {    'VEGFA -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'VEGFA -> biolink:regulates -> PPARGC1B': 1}
#
# NCBIGene:213 -> biolink:regulates -> NCBIGene:133522||infores:textminingkp
#
# NCBIGene:213 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1B_ALB_Hepatic_fibrosis
# {    'ALB -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'ALB -> biolink:regulates -> PPARGC1B': 1}
#
# NCBIGene:3569 -> biolink:regulates -> NCBIGene:133522||infores:textminingkp
#
# NCBIGene:3569 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1B_IL6_Hepatic_fibrosis
# {    'IL6 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'IL6 -> biolink:regulates -> PPARGC1B': 1}
#
# NCBIGene:6696 -> biolink:regulates -> NCBIGene:133522||infores:textminingkp
#
# NCBIGene:6696 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1B_SPP1_Hepatic_fibrosis
# {    'SPP1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'SPP1 -> biolink:regulates -> PPARGC1B': 1}
#
# NCBIGene:133522 -> biolink:regulates -> NCBIGene:6347||infores:textminingkp
#
# NCBIGene:6347 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1B_CCL2_Hepatic_fibrosis
# {    'CCL2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARGC1B -> biolink:regulates -> CCL2': 1}
#
# NCBIGene:133522 -> biolink:regulates -> NCBIGene:183||infores:textminingkp
#
# NCBIGene:183 -> biolink:contributes_to -> MONDO:0018840||infores:textminingkp
# PPARGC1B_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PPARGC1B -> biolink:regulates -> AGT': 1}
#
# NCBIGene:133522 -> biolink:regulates -> NCBIGene:183||infores:textminingkp
#
# NCBIGene:183 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1B_AGT_Hepatic_fibrosis
# {    'AGT -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARGC1B -> biolink:regulates -> AGT': 1}
#
# NCBIGene:133522 -> biolink:regulates -> NCBIGene:4313||infores:textminingkp
#
# NCBIGene:4313 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1B_MMP2_Hepatic_fibrosis
# {    'MMP2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARGC1B -> biolink:regulates -> MMP2': 1}
#
# NCBIGene:133522 -> biolink:regulates -> NCBIGene:6927||infores:textminingkp
#
# NCBIGene:6927 -> biolink:contributes_to -> MONDO:0018840||infores:textminingkp
# PPARGC1B_HNF1A_isolated_congenital_hepatic_fibrosis
# {    'HNF1A -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PPARGC1B -> biolink:regulates -> HNF1A': 1}
#
# NCBIGene:133522 -> biolink:regulates -> NCBIGene:7422||infores:textminingkp
#
# NCBIGene:7422 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1B_VEGFA_Hepatic_fibrosis
# {    'PPARGC1B -> biolink:regulates -> VEGFA': 1,
#      'VEGFA -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:133522 -> biolink:regulates -> NCBIGene:5972||infores:textminingkp
#
# NCBIGene:5972 -> biolink:contributes_to -> MONDO:0018840||infores:textminingkp
# PPARGC1B_REN_isolated_congenital_hepatic_fibrosis
# {    'PPARGC1B -> biolink:regulates -> REN': 1,
#      'REN -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
#
# NCBIGene:133522 -> biolink:regulates -> NCBIGene:5972||infores:textminingkp
#
# NCBIGene:5972 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1B_REN_Hepatic_fibrosis
# {    'PPARGC1B -> biolink:regulates -> REN': 1,
#      'REN -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:133522 -> biolink:regulates -> NCBIGene:6696||infores:lincs
#
# NCBIGene:6696 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1B_SPP1_Hepatic_fibrosis
# {    'PPARGC1B -> biolink:regulates -> SPP1': 1,
#      'SPP1 -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:133522 -> biolink:regulates -> NCBIGene:6696||infores:textminingkp
#
# NCBIGene:6696 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1B_SPP1_Hepatic_fibrosis
# {    'PPARGC1B -> biolink:regulates -> SPP1': 1,
#      'SPP1 -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:133522 -> biolink:regulates -> NCBIGene:4780||infores:textminingkp
#
# NCBIGene:4780 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1B_NFE2L2_Hepatic_fibrosis
# {    'NFE2L2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARGC1B -> biolink:regulates -> NFE2L2': 1}
#
# NCBIGene:133522 -> biolink:regulates -> NCBIGene:2321||infores:textminingkp
#
# NCBIGene:2321 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1B_FLT1_Hepatic_fibrosis
# {    'FLT1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARGC1B -> biolink:regulates -> FLT1': 1}
#
# NCBIGene:133522 -> biolink:regulates -> NCBIGene:405||infores:textminingkp
#
# NCBIGene:405 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1B_ARNT_Hepatic_fibrosis
# {    'ARNT -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARGC1B -> biolink:regulates -> ARNT': 1}
#
# NCBIGene:80205 -> biolink:interacts_with -> NCBIGene:183||infores:sri-reference-kg
#
# NCBIGene:183 -> biolink:contributes_to -> MONDO:0018840||infores:textminingkp
# CHD9_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'CHD9 -> biolink:interacts_with -> AGT': 1}
#
# NCBIGene:80205 -> biolink:interacts_with -> NCBIGene:183||infores:sri-reference-kg
#
# NCBIGene:183 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# CHD9_AGT_Hepatic_fibrosis
# {    'AGT -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CHD9 -> biolink:interacts_with -> AGT': 1}
#
# NCBIGene:80205 -> biolink:interacts_with -> NCBIGene:5244||infores:sri-reference-kg
#
# NCBIGene:5244 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# CHD9_ABCB4_Hepatic_fibrosis
# {    'ABCB4 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CHD9 -> biolink:interacts_with -> ABCB4': 1}
#
# NCBIGene:6772 -> biolink:interacts_with -> NCBIGene:10891||infores:sri-reference-kg
#
# NCBIGene:6772 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1A_STAT1_Hepatic_fibrosis
# {    'STAT1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'STAT1 -> biolink:interacts_with -> PPARGC1A': 1}
#
# NCBIGene:6696 -> biolink:regulates -> NCBIGene:10891||infores:textminingkp
#
# NCBIGene:6696 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1A_SPP1_Hepatic_fibrosis
# {    'SPP1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'SPP1 -> biolink:regulates -> PPARGC1A': 1}
#
# NCBIGene:213 -> biolink:regulates -> NCBIGene:10891||infores:textminingkp
#
# NCBIGene:213 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1A_ALB_Hepatic_fibrosis
# {    'ALB -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'ALB -> biolink:regulates -> PPARGC1A': 1}
#
# NCBIGene:2321 -> biolink:regulates -> NCBIGene:10891||infores:textminingkp
#
# NCBIGene:2321 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1A_FLT1_Hepatic_fibrosis
# {    'FLT1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'FLT1 -> biolink:regulates -> PPARGC1A': 1}
#
# NCBIGene:6347 -> biolink:regulates -> NCBIGene:10891||infores:textminingkp
#
# NCBIGene:6347 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1A_CCL2_Hepatic_fibrosis
# {    'CCL2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CCL2 -> biolink:regulates -> PPARGC1A': 1}
#
# NCBIGene:3569 -> biolink:regulates -> NCBIGene:10891||infores:textminingkp
#
# NCBIGene:3569 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1A_IL6_Hepatic_fibrosis
# {    'IL6 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'IL6 -> biolink:regulates -> PPARGC1A': 1}
#
# NCBIGene:7422 -> biolink:regulates -> NCBIGene:10891||infores:textminingkp
#
# NCBIGene:7422 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1A_VEGFA_Hepatic_fibrosis
# {    'VEGFA -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'VEGFA -> biolink:regulates -> PPARGC1A': 1}
#
# NCBIGene:4780 -> biolink:regulates -> NCBIGene:10891||infores:textminingkp
#
# NCBIGene:4780 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1A_NFE2L2_Hepatic_fibrosis
# {    'NFE2L2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'NFE2L2 -> biolink:regulates -> PPARGC1A': 1}
#
# NCBIGene:2200 -> biolink:regulates -> NCBIGene:10891||infores:textminingkp
#
# NCBIGene:2200 -> biolink:contributes_to -> MONDO:0018840||infores:textminingkp
# PPARGC1A_FBN1_isolated_congenital_hepatic_fibrosis
# {    'FBN1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'FBN1 -> biolink:regulates -> PPARGC1A': 1}
#
# NCBIGene:2200 -> biolink:regulates -> NCBIGene:10891||infores:textminingkp
#
# NCBIGene:2200 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1A_FBN1_Hepatic_fibrosis
# {    'FBN1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'FBN1 -> biolink:regulates -> PPARGC1A': 1}
#
# NCBIGene:10891 -> biolink:regulates -> NCBIGene:4313||infores:textminingkp
#
# NCBIGene:4313 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1A_MMP2_Hepatic_fibrosis
# {    'MMP2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARGC1A -> biolink:regulates -> MMP2': 1}
#
# NCBIGene:10891 -> biolink:regulates -> NCBIGene:405||infores:textminingkp
#
# NCBIGene:405 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1A_ARNT_Hepatic_fibrosis
# {    'ARNT -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARGC1A -> biolink:regulates -> ARNT': 1}
#
# NCBIGene:10891 -> biolink:regulates -> NCBIGene:6927||infores:textminingkp
#
# NCBIGene:6927 -> biolink:contributes_to -> MONDO:0018840||infores:textminingkp
# PPARGC1A_HNF1A_isolated_congenital_hepatic_fibrosis
# {    'HNF1A -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PPARGC1A -> biolink:regulates -> HNF1A': 1}
#
# NCBIGene:10891 -> biolink:regulates -> NCBIGene:183||infores:textminingkp
#
# NCBIGene:183 -> biolink:contributes_to -> MONDO:0018840||infores:textminingkp
# PPARGC1A_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PPARGC1A -> biolink:regulates -> AGT': 1}
#
# NCBIGene:10891 -> biolink:regulates -> NCBIGene:183||infores:textminingkp
#
# NCBIGene:183 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1A_AGT_Hepatic_fibrosis
# {    'AGT -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARGC1A -> biolink:regulates -> AGT': 1}
#
# NCBIGene:10891 -> biolink:regulates -> NCBIGene:5972||infores:textminingkp
#
# NCBIGene:5972 -> biolink:contributes_to -> MONDO:0018840||infores:textminingkp
# PPARGC1A_REN_isolated_congenital_hepatic_fibrosis
# {    'PPARGC1A -> biolink:regulates -> REN': 1,
#      'REN -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
#
# NCBIGene:10891 -> biolink:regulates -> NCBIGene:5972||infores:textminingkp
#
# NCBIGene:5972 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1A_REN_Hepatic_fibrosis
# {    'PPARGC1A -> biolink:regulates -> REN': 1,
#      'REN -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:10891 -> biolink:regulates -> NCBIGene:6696||infores:textminingkp
#
# NCBIGene:6696 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1A_SPP1_Hepatic_fibrosis
# {    'PPARGC1A -> biolink:regulates -> SPP1': 1,
#      'SPP1 -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:10891 -> biolink:regulates -> NCBIGene:4780||infores:textminingkp
#
# NCBIGene:4780 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1A_NFE2L2_Hepatic_fibrosis
# {    'NFE2L2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARGC1A -> biolink:regulates -> NFE2L2': 1}
#
# NCBIGene:10891 -> biolink:regulates -> NCBIGene:6347||infores:textminingkp
#
# NCBIGene:6347 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1A_CCL2_Hepatic_fibrosis
# {    'CCL2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARGC1A -> biolink:regulates -> CCL2': 1}
#
# NCBIGene:10891 -> biolink:regulates -> NCBIGene:7422||infores:textminingkp
#
# NCBIGene:7422 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1A_VEGFA_Hepatic_fibrosis
# {    'PPARGC1A -> biolink:regulates -> VEGFA': 1,
#      'VEGFA -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:10891 -> biolink:regulates -> NCBIGene:2321||infores:textminingkp
#
# NCBIGene:2321 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1A_FLT1_Hepatic_fibrosis
# {    'FLT1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARGC1A -> biolink:regulates -> FLT1': 1}
#
# NCBIGene:10891 -> biolink:regulates -> NCBIGene:3066||infores:lincs
#
# NCBIGene:3066 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARGC1A_HDAC2_Hepatic_fibrosis
# {    'HDAC2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARGC1A -> biolink:regulates -> HDAC2': 1}
#
# NCBIGene:3875 -> biolink:coexpressed_with -> UniProtKB:Q07869-1||infores:STRING
#
# NCBIGene:3875 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_KRT18_Hepatic_fibrosis
# {    'KRT18 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'KRT18 -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:1269 -> biolink:coexpressed_with -> UniProtKB:Q07869-1||infores:STRING
#
# NCBIGene:1269 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CNR2_Hepatic_fibrosis
# {    'CNR2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CNR2 -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:6347 -> biolink:coexpressed_with -> UniProtKB:Q07869-1||infores:STRING
#
# NCBIGene:6347 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CCL2_Hepatic_fibrosis
# {    'CCL2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CCL2 -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:183 -> biolink:coexpressed_with -> UniProtKB:Q07869-1||infores:STRING
#
# NCBIGene:183 -> biolink:contributes_to -> MONDO:0018840||infores:textminingkp
# peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
#
# NCBIGene:183 -> biolink:coexpressed_with -> UniProtKB:Q07869-1||infores:STRING
#
# NCBIGene:183 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_Hepatic_fibrosis
# {    'AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'AGT -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:866 -> biolink:coexpressed_with -> UniProtKB:Q07869-1||infores:STRING
#
# NCBIGene:866 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_SERPINA6_Hepatic_fibrosis
# {    'SERPINA6 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'SERPINA6 -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:1593 -> biolink:coexpressed_with -> UniProtKB:Q07869-1||infores:STRING
#
# NCBIGene:1593 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP27A1_Hepatic_fibrosis
# {    'CYP27A1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CYP27A1 -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:4015 -> biolink:coexpressed_with -> UniProtKB:Q07869-1||infores:STRING
#
# NCBIGene:4015 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_LOX_Hepatic_fibrosis
# {    'LOX -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'LOX -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:120227 -> biolink:coexpressed_with -> UniProtKB:Q07869-1||infores:STRING
#
# NCBIGene:120227 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP2R1_Hepatic_fibrosis
# {    'CYP2R1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CYP2R1 -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:2147 -> biolink:coexpressed_with -> UniProtKB:Q07869-1||infores:STRING
#
# NCBIGene:2147 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_F2_Hepatic_fibrosis
# {    'F2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'F2 -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:1356 -> biolink:coexpressed_with -> UniProtKB:Q07869-1||infores:STRING
#
# NCBIGene:1356 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CP_Hepatic_fibrosis
# {    'CP -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CP -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:3484 -> biolink:coexpressed_with -> UniProtKB:Q07869-1||infores:STRING
#
# NCBIGene:3484 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_IGFBP1_Hepatic_fibrosis
# {    'IGFBP1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'IGFBP1 -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# UniProtKB:Q07869-1 -> biolink:coexpressed_with -> NCBIGene:120227||infores:STRING
#
# NCBIGene:120227 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP2R1_Hepatic_fibrosis
# {    'CYP2R1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CYP2R1': 1}
#
# UniProtKB:Q07869-1 -> biolink:coexpressed_with -> NCBIGene:1269||infores:STRING
#
# NCBIGene:1269 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CNR2_Hepatic_fibrosis
# {    'CNR2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CNR2': 1}
#
# UniProtKB:Q07869-1 -> biolink:coexpressed_with -> NCBIGene:183||infores:STRING
#
# NCBIGene:183 -> biolink:contributes_to -> MONDO:0018840||infores:textminingkp
# peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> AGT': 1}
#
# UniProtKB:Q07869-1 -> biolink:coexpressed_with -> NCBIGene:183||infores:STRING
#
# NCBIGene:183 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_Hepatic_fibrosis
# {    'AGT -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> AGT': 1}
#
# UniProtKB:Q07869-1 -> biolink:coexpressed_with -> NCBIGene:6347||infores:STRING
#
# NCBIGene:6347 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CCL2_Hepatic_fibrosis
# {    'CCL2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CCL2': 1}
#
# UniProtKB:Q07869-1 -> biolink:coexpressed_with -> NCBIGene:1593||infores:STRING
#
# NCBIGene:1593 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP27A1_Hepatic_fibrosis
# {    'CYP27A1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CYP27A1': 1}
#
# UniProtKB:Q07869-1 -> biolink:coexpressed_with -> NCBIGene:4015||infores:STRING
#
# NCBIGene:4015 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_LOX_Hepatic_fibrosis
# {    'LOX -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> LOX': 1}
#
# UniProtKB:Q07869-1 -> biolink:coexpressed_with -> NCBIGene:1356||infores:STRING
#
# NCBIGene:1356 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CP_Hepatic_fibrosis
# {    'CP -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CP': 1}
#
# UniProtKB:Q07869-1 -> biolink:coexpressed_with -> NCBIGene:3875||infores:STRING
#
# NCBIGene:3875 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_KRT18_Hepatic_fibrosis
# {    'KRT18 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> KRT18': 1}
#
# UniProtKB:Q07869-1 -> biolink:coexpressed_with -> NCBIGene:2147||infores:STRING
#
# NCBIGene:2147 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_F2_Hepatic_fibrosis
# {    'F2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> F2': 1}
#
# UniProtKB:Q07869-1 -> biolink:coexpressed_with -> NCBIGene:3484||infores:STRING
#
# NCBIGene:3484 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_IGFBP1_Hepatic_fibrosis
# {    'IGFBP1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> IGFBP1': 1}
#
# UniProtKB:Q07869-1 -> biolink:coexpressed_with -> NCBIGene:866||infores:STRING
#
# NCBIGene:866 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_SERPINA6_Hepatic_fibrosis
# {    'SERPINA6 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> SERPINA6': 1}
#
# NCBIGene:6772 -> biolink:interacts_with -> NCBIGene:5465||infores:sri-reference-kg
#
# NCBIGene:6772 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_STAT1_Hepatic_fibrosis
# {    'STAT1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'STAT1 -> biolink:interacts_with -> PPARA': 1}
#
# NCBIGene:5465 -> biolink:interacts_with -> NCBIGene:183||infores:sri-reference-kg
#
# NCBIGene:183 -> biolink:contributes_to -> MONDO:0018840||infores:textminingkp
# PPARA_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PPARA -> biolink:interacts_with -> AGT': 1}
#
# NCBIGene:5465 -> biolink:interacts_with -> NCBIGene:183||infores:sri-reference-kg
#
# NCBIGene:183 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_AGT_Hepatic_fibrosis
# {    'AGT -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:interacts_with -> AGT': 1}
#
# NCBIGene:5465 -> biolink:interacts_with -> NCBIGene:5244||infores:sri-reference-kg
#
# NCBIGene:5244 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_ABCB4_Hepatic_fibrosis
# {    'ABCB4 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:interacts_with -> ABCB4': 1}
#
# NCBIGene:5465 -> biolink:interacts_with -> NCBIGene:2147||infores:sri-reference-kg
#
# NCBIGene:2147 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_F2_Hepatic_fibrosis
# {    'F2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:interacts_with -> F2': 1}
#
# NCBIGene:5465 -> biolink:contributes_to -> MONDO:0005154||infores:textminingkp
#
# MONDO:0018840 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver_disorder_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'isolated congenital hepatic fibrosis -> biolink:subclass_of -> liver disorder': 1}
#
# NCBIGene:5465 -> biolink:contributes_to -> MONDO:0005154||infores:textminingkp
#
# HP:0001395 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver_disorder_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'PPARA -> biolink:contributes_to -> liver disorder': 1}
#
# NCBIGene:5465 -> biolink:contributes_to -> MONDO:0005154||infores:textminingkp
#
# UMLS:C2827436 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver_disorder_Liver_Disease_Associated_with_Cystic_Fibrosis
# {    'Liver Disease Associated with Cystic Fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'PPARA -> biolink:contributes_to -> liver disorder': 1}
#
# NCBIGene:5465 -> biolink:contributes_to -> MONDO:0005154||infores:textminingkp
#
# MONDO:0100430 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver_disorder_fibrotic_liver_disease
# {    'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'fibrotic liver disease -> biolink:subclass_of -> liver disorder': 1}
#
# NCBIGene:5465 -> biolink:contributes_to -> MONDO:0005154||infores:textminingkp
#
# HP:0012852 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver_disorder_Hepatic_bridging_fibrosis
# {    'Hepatic bridging fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'PPARA -> biolink:contributes_to -> liver disorder': 1}
#
# NCBIGene:5465 -> biolink:contributes_to -> MONDO:0005154||infores:textminingkp
#
# HP:0001405 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver_disorder_Periportal_fibrosis
# {    'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'Periportal fibrosis -> biolink:subclass_of -> liver disorder': 1}
#
# NCBIGene:5465 -> biolink:contributes_to -> MONDO:0005155||infores:textminingkp
#
# MONDO:0018840 -> biolink:subclass_of -> MONDO:0005155||infores:sri-ontology
# PPARA_cirrhosis_of_liver_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:contributes_to -> cirrhosis of liver': 1,
#      'isolated congenital hepatic fibrosis -> biolink:subclass_of -> cirrhosis of liver': 1}
#
# NCBIGene:6696 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:6696 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_SPP1_Hepatic_fibrosis
# {    'SPP1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'SPP1 -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:5328 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:5328 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_PLAU_Hepatic_fibrosis
# {    'PLAU -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PLAU -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:3956 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:3956 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_LGALS1_Hepatic_fibrosis
# {    'LGALS1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'LGALS1 -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:4780 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:4780 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_NFE2L2_Hepatic_fibrosis
# {    'NFE2L2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'NFE2L2 -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:1269 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:1269 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_CNR2_Hepatic_fibrosis
# {    'CNR2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CNR2 -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:1499 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:1499 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_CTNNB1_Hepatic_fibrosis
# {    'CTNNB1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CTNNB1 -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:183 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:183 -> biolink:contributes_to -> MONDO:0018840||infores:textminingkp
# PPARA_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'AGT -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:183 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:183 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_AGT_Hepatic_fibrosis
# {    'AGT -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'AGT -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:4088 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:4088 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_SMAD3_Hepatic_fibrosis
# {    'SMAD3 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'SMAD3 -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:6347 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:6347 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_CCL2_Hepatic_fibrosis
# {    'CCL2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CCL2 -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:7040 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:7040 -> biolink:contributes_to -> MONDO:0018840||infores:textminingkp
# PPARA_TGFB1_isolated_congenital_hepatic_fibrosis
# {    'TGFB1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'TGFB1 -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:7040 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:7040 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_TGFB1_Hepatic_fibrosis
# {    'TGFB1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'TGFB1 -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:7422 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:7422 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_VEGFA_Hepatic_fibrosis
# {    'VEGFA -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'VEGFA -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:7057 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:7057 -> biolink:contributes_to -> MONDO:0018840||infores:textminingkp
# PPARA_THBS1_isolated_congenital_hepatic_fibrosis
# {    'THBS1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'THBS1 -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:7057 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:7057 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_THBS1_Hepatic_fibrosis
# {    'THBS1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'THBS1 -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:213 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:213 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_ALB_Hepatic_fibrosis
# {    'ALB -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'ALB -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:2149 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:2149 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_F2R_Hepatic_fibrosis
# {    'F2R -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'F2R -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:1356 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:1356 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_CP_Hepatic_fibrosis
# {    'CP -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CP -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:3569 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:3569 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_IL6_Hepatic_fibrosis
# {    'IL6 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'IL6 -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:4864 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:4864 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_NPC1_Hepatic_fibrosis
# {    'NPC1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'NPC1 -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:5314 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:5314 -> biolink:contributes_to -> MONDO:0018840||infores:textminingkp
# PPARA_PKHD1_isolated_congenital_hepatic_fibrosis
# {    'PKHD1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PKHD1 -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:5314 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:5314 -> biolink:genetic_association -> MONDO:0018840||infores:disgenet
# PPARA_PKHD1_isolated_congenital_hepatic_fibrosis
# {    'PKHD1 -> biolink:genetic_association -> isolated congenital hepatic fibrosis': 1,
#      'PKHD1 -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:408 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:408 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_ARRB1_Hepatic_fibrosis
# {    'ARRB1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'ARRB1 -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:4313 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:4313 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_MMP2_Hepatic_fibrosis
# {    'MMP2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'MMP2 -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:7046 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:7046 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_TGFBR1_Hepatic_fibrosis
# {    'TGFBR1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'TGFBR1 -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:1490 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:1490 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_CCN2_Hepatic_fibrosis
# {    'CCN2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CCN2 -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:3082 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:3082 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_HGF_Hepatic_fibrosis
# {    'HGF -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'HGF -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:5972 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:5972 -> biolink:contributes_to -> MONDO:0018840||infores:textminingkp
# PPARA_REN_isolated_congenital_hepatic_fibrosis
# {    'REN -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'REN -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:5972 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:5972 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_REN_Hepatic_fibrosis
# {    'REN -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'REN -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:405 -> biolink:regulates -> NCBIGene:5465||infores:textminingkp
#
# NCBIGene:405 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_ARNT_Hepatic_fibrosis
# {    'ARNT -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'ARNT -> biolink:regulates -> PPARA': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:1278||infores:textminingkp
#
# NCBIGene:1278 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_COL1A2_Hepatic_fibrosis
# {    'COL1A2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:regulates -> COL1A2': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:1499||infores:textminingkp
#
# NCBIGene:1499 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_CTNNB1_Hepatic_fibrosis
# {    'CTNNB1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:regulates -> CTNNB1': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:6347||infores:textminingkp
#
# NCBIGene:6347 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_CCL2_Hepatic_fibrosis
# {    'CCL2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:regulates -> CCL2': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:2147||infores:textminingkp
#
# NCBIGene:2147 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_F2_Hepatic_fibrosis
# {    'F2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:regulates -> F2': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:2321||infores:textminingkp
#
# NCBIGene:2321 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_FLT1_Hepatic_fibrosis
# {    'FLT1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:regulates -> FLT1': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:5244||infores:textminingkp
#
# NCBIGene:5244 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_ABCB4_Hepatic_fibrosis
# {    'ABCB4 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:regulates -> ABCB4': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:213||infores:textminingkp
#
# NCBIGene:213 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_ALB_Hepatic_fibrosis
# {    'ALB -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:regulates -> ALB': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:9104||infores:textminingkp
#
# NCBIGene:9104 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_RGN_Hepatic_fibrosis
# {    'PPARA -> biolink:regulates -> RGN': 1,
#      'RGN -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:6927||infores:textminingkp
#
# NCBIGene:6927 -> biolink:contributes_to -> MONDO:0018840||infores:textminingkp
# PPARA_HNF1A_isolated_congenital_hepatic_fibrosis
# {    'HNF1A -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PPARA -> biolink:regulates -> HNF1A': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:4780||infores:textminingkp
#
# NCBIGene:4780 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_NFE2L2_Hepatic_fibrosis
# {    'NFE2L2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:regulates -> NFE2L2': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:2247||infores:textminingkp
#
# NCBIGene:2247 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_FGF2_Hepatic_fibrosis
# {    'FGF2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:regulates -> FGF2': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:7431||infores:lincs
#
# NCBIGene:7431 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_VIM_Hepatic_fibrosis
# {    'PPARA -> biolink:regulates -> VIM': 1,
#      'VIM -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:6696||infores:textminingkp
#
# NCBIGene:6696 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_SPP1_Hepatic_fibrosis
# {    'PPARA -> biolink:regulates -> SPP1': 1,
#      'SPP1 -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:4313||infores:textminingkp
#
# NCBIGene:4313 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_MMP2_Hepatic_fibrosis
# {    'MMP2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:regulates -> MMP2': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:3082||infores:textminingkp
#
# NCBIGene:3082 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_HGF_Hepatic_fibrosis
# {    'HGF -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:regulates -> HGF': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:5972||infores:textminingkp
#
# NCBIGene:5972 -> biolink:contributes_to -> MONDO:0018840||infores:textminingkp
# PPARA_REN_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:regulates -> REN': 1,
#      'REN -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:5972||infores:textminingkp
#
# NCBIGene:5972 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_REN_Hepatic_fibrosis
# {    'PPARA -> biolink:regulates -> REN': 1,
#      'REN -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:4088||infores:textminingkp
#
# NCBIGene:4088 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_SMAD3_Hepatic_fibrosis
# {    'PPARA -> biolink:regulates -> SMAD3': 1,
#      'SMAD3 -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:183||infores:textminingkp
#
# NCBIGene:183 -> biolink:contributes_to -> MONDO:0018840||infores:textminingkp
# PPARA_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PPARA -> biolink:regulates -> AGT': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:183||infores:textminingkp
#
# NCBIGene:183 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_AGT_Hepatic_fibrosis
# {    'AGT -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:regulates -> AGT': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:1277||infores:textminingkp
#
# NCBIGene:1277 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_COL1A1_Hepatic_fibrosis
# {    'COL1A1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:regulates -> COL1A1': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:7057||infores:textminingkp
#
# NCBIGene:7057 -> biolink:contributes_to -> MONDO:0018840||infores:textminingkp
# PPARA_THBS1_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:regulates -> THBS1': 1,
#      'THBS1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:7057||infores:textminingkp
#
# NCBIGene:7057 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_THBS1_Hepatic_fibrosis
# {    'PPARA -> biolink:regulates -> THBS1': 1,
#      'THBS1 -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:3569||infores:textminingkp
#
# NCBIGene:3569 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_IL6_Hepatic_fibrosis
# {    'IL6 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:regulates -> IL6': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:7040||infores:textminingkp
#
# NCBIGene:7040 -> biolink:contributes_to -> MONDO:0018840||infores:textminingkp
# PPARA_TGFB1_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:regulates -> TGFB1': 1,
#      'TGFB1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:7040||infores:textminingkp
#
# NCBIGene:7040 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_TGFB1_Hepatic_fibrosis
# {    'PPARA -> biolink:regulates -> TGFB1': 1,
#      'TGFB1 -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:4763||infores:textminingkp
#
# NCBIGene:4763 -> biolink:contributes_to -> MONDO:0018840||infores:textminingkp
# PPARA_NF1_isolated_congenital_hepatic_fibrosis
# {    'NF1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PPARA -> biolink:regulates -> NF1': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:7046||infores:textminingkp
#
# NCBIGene:7046 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_TGFBR1_Hepatic_fibrosis
# {    'PPARA -> biolink:regulates -> TGFBR1': 1,
#      'TGFBR1 -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:5328||infores:textminingkp
#
# NCBIGene:5328 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_PLAU_Hepatic_fibrosis
# {    'PLAU -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:regulates -> PLAU': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:6696||infores:lincs
#
# NCBIGene:6696 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_SPP1_Hepatic_fibrosis
# {    'PPARA -> biolink:regulates -> SPP1': 1,
#      'SPP1 -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:1356||infores:textminingkp
#
# NCBIGene:1356 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_CP_Hepatic_fibrosis
# {    'CP -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:regulates -> CP': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:7422||infores:textminingkp
#
# NCBIGene:7422 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_VEGFA_Hepatic_fibrosis
# {    'PPARA -> biolink:regulates -> VEGFA': 1,
#      'VEGFA -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:6772||infores:textminingkp
#
# NCBIGene:6772 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_STAT1_Hepatic_fibrosis
# {    'PPARA -> biolink:regulates -> STAT1': 1,
#      'STAT1 -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:2149||infores:textminingkp
#
# NCBIGene:2149 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_F2R_Hepatic_fibrosis
# {    'F2R -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:regulates -> F2R': 1}
#
# NCBIGene:5465 -> biolink:regulates -> NCBIGene:1490||infores:textminingkp
#
# NCBIGene:1490 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_CCN2_Hepatic_fibrosis
# {    'CCN2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:regulates -> CCN2': 1}
#
# NCBIGene:5465 -> biolink:directly_physically_interacts_with -> NCBIGene:213||infores:intact
#
# NCBIGene:213 -> biolink:genetic_association -> HP:0001395||infores:disgenet
# PPARA_ALB_Hepatic_fibrosis
# {    'ALB -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:directly_physically_interacts_with -> ALB': 1}
#
# NCBIGene:5465 -> biolink:genetic_association -> MONDO:0005154||infores:diseases
#
# MONDO:0018840 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver_disorder_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'isolated congenital hepatic fibrosis -> biolink:subclass_of -> liver disorder': 1}
#
# NCBIGene:5465 -> biolink:genetic_association -> MONDO:0005154||infores:diseases
#
# HP:0001395 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver_disorder_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1}
#
# NCBIGene:5465 -> biolink:genetic_association -> MONDO:0005154||infores:diseases
#
# UMLS:C2827436 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver_disorder_Liver_Disease_Associated_with_Cystic_Fibrosis
# {    'Liver Disease Associated with Cystic Fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1}
#
# NCBIGene:5465 -> biolink:genetic_association -> MONDO:0005154||infores:diseases
#
# MONDO:0100430 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver_disorder_fibrotic_liver_disease
# {    'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'fibrotic liver disease -> biolink:subclass_of -> liver disorder': 1}
#
# NCBIGene:5465 -> biolink:genetic_association -> MONDO:0005154||infores:diseases
#
# HP:0012852 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver_disorder_Hepatic_bridging_fibrosis
# {    'Hepatic bridging fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1}
#
# NCBIGene:5465 -> biolink:genetic_association -> MONDO:0005154||infores:diseases
#
# HP:0001405 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver_disorder_Periportal_fibrosis
# {    'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'Periportal fibrosis -> biolink:subclass_of -> liver disorder': 1}
# (165, 6)

# %%
start_time = time.time()

# Initializing Cypher query and extracting results from ROBOKOPKG using Bolt protocol method
conn = Neo4jConnection(uri=robokopkg_bolt_url, user = user, pwd = pw)

nodes = ['n00','n01','n02']
relationships = ['r0','r1']

cols = []
for node in nodes:
    cols.append(node)
    cols.append(node+"_name")

results_df = pd.DataFrame(columns = cols)
results_dict_list = []

additional_input_node_ids = ['UniProtKB:Q07869-1', 'UniProtKB:Q3L8U1-2', 'UniProtKB:Q9UBK2-1']
additional_output_node_ids = ['HP:0001405', 'HP:0012852']

# cypher = f"""MATCH
# ({nodes[0]}:`biolink:GeneOrGeneProduct`)-[{relationships[0]}]-({nodes[1]}:`biolink:BiologicalEntity`)-[{relationships[1]}]-({nodes[2]}:`biolink:DiseaseOrPhenotypicFeature`)
# WHERE {nodes[0]}.id IN {input_node_id_list} AND {nodes[2]}.id IN {output_node_id_list}
# RETURN * LIMIT 100"""

cypher = f"""MATCH
({nodes[0]}:`biolink:GeneOrGeneProduct`)-[{relationships[0]}]-({nodes[1]}:`biolink:BiologicalEntity`)-[{relationships[1]}]-({nodes[2]}:`biolink:DiseaseOrPhenotypicFeature`)
WHERE {nodes[0]}.id IN {input_node_id_list+additional_input_node_ids} AND {nodes[2]}.id IN {output_node_id_list+additional_output_node_ids}
RETURN [startNode({relationships[0]}),[type({relationships[0]}),properties({relationships[0]})],endNode({relationships[0]})] as edge_1, 
[startNode({relationships[1]}),[type({relationships[1]}),properties({relationships[1]})],endNode({relationships[1]})] as edge_2, 
[{nodes[0]}.name, {nodes[1]}.name, {nodes[2]}.name] as node_names,
[{nodes[0]}.id, {nodes[1]}.id, {nodes[2]}.id] as node_ids LIMIT 300"""

record_list = conn.query(cypher)

i = 0
print(f"Number of records returned: {len(record_list)}")

results_df = pd.DataFrame(columns = cols)
results_dict_list = []

for record in record_list:
    string_out_list = []
    record_data = record.data()
    #only grab the edge information and skip the node names and IDs
    record_data_first2 = {k: record_data[k] for k in list(record_data)[:2]}
    for label, data in record_data_first2.items():
        string_out = f"{label} - {data[0]['name']} -> {data[1][0]} -> {data[2]['name']}||{data[1][1]}"
        string_out_ids = f"{label} - {data[0]['id']} -> {data[1][0]} -> {data[2]['id']}||{data[1][1]['biolink:primary_knowledge_source']}"
        print(string_out_ids)
        if string_out not in string_out_list:
            string_out_list.append(string_out)

    if len(record_list) > 0:
        combined_node_list = "_".join(list(record.data('node_names').values())[0])
        print(combined_node_list)

        string_out_list = [i.split('||', 1)[0] for i in string_out_list]

        string_out_dict = dict(Counter(string_out_list).items())
        pp.pprint(string_out_dict)

        with open(os.path.join(write_dir_cypher_robokopkg,combined_node_list+".txt"), 'a') as convert_file:
            convert_file.write(json.dumps(string_out_dict))

    record_data = record.data()
    #only grab the node labels and IDs
    record_data_last2 = {k: record_data[k] for k in list(record_data)[2:]}

    result_dict = {}
    for label, data in record_data_last2.items():
        # print(f"{label}: {data}")
        for j in range(len(nodes)):
            if "ids" in label:
                node_id = data[j]
                result_dict[nodes[j]] = node_id
            elif "names" in label:
                node_name = data[j]
                result_dict[nodes[j]+"_name"] = node_name
    # pp.pprint(result_dict)

    results_dict_list.append(result_dict)

results_df = pd.concat([results_df,pd.DataFrame.from_records(results_dict_list)])
print(results_df.shape)
display(results_df)
results_df.to_csv(Cypher_ROBOKOPKG_results_file)
conn.close()

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Number of records returned: 172
# edge_1 - NCBIGene:183 -> biolink:coexpressed_with -> UniProtKB:Q9UBK2-1||infores:string
# edge_2 - NCBIGene:183 -> biolink:contributes_to -> MONDO:0018840||infores:text-mining-provider-targeted
# peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human)_AGT_isolated congenital hepatic fibrosis
# {    'edge_1 - AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human)': 1,
#      'edge_2 - AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
# edge_1 - NCBIGene:183 -> biolink:coexpressed_with -> UniProtKB:Q9UBK2-1||infores:string
# edge_2 - NCBIGene:183 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human)_AGT_Hepatic fibrosis
# {    'edge_1 - AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human)': 1,
#      'edge_2 - AGT -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:7431 -> biolink:coexpressed_with -> UniProtKB:Q9UBK2-1||infores:string
# edge_2 - NCBIGene:7431 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human)_VIM_Hepatic fibrosis
# {    'edge_1 - VIM -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human)': 1,
#      'edge_2 - VIM -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:1593 -> biolink:coexpressed_with -> UniProtKB:Q9UBK2-1||infores:string
# edge_2 - NCBIGene:1593 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human)_CYP27A1_Hepatic fibrosis
# {    'edge_1 - CYP27A1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human)': 1,
#      'edge_2 - CYP27A1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - UniProtKB:Q9UBK2-1 -> biolink:coexpressed_with -> NCBIGene:1593||infores:string
# edge_2 - NCBIGene:1593 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human)_CYP27A1_Hepatic fibrosis
# {    'edge_1 - peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human) -> biolink:coexpressed_with -> CYP27A1': 1,
#      'edge_2 - CYP27A1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - UniProtKB:Q9UBK2-1 -> biolink:coexpressed_with -> NCBIGene:7431||infores:string
# edge_2 - NCBIGene:7431 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human)_VIM_Hepatic fibrosis
# {    'edge_1 - peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human) -> biolink:coexpressed_with -> VIM': 1,
#      'edge_2 - VIM -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - UniProtKB:Q9UBK2-1 -> biolink:coexpressed_with -> NCBIGene:183||infores:string
# edge_2 - NCBIGene:183 -> biolink:contributes_to -> MONDO:0018840||infores:text-mining-provider-targeted
# peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human)_AGT_isolated congenital hepatic fibrosis
# {    'edge_1 - peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human) -> biolink:coexpressed_with -> AGT': 1,
#      'edge_2 - AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
# edge_1 - UniProtKB:Q9UBK2-1 -> biolink:coexpressed_with -> NCBIGene:183||infores:string
# edge_2 - NCBIGene:183 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human)_AGT_Hepatic fibrosis
# {    'edge_1 - peroxisome proliferator-activated receptor gamma coactivator 1-alpha isoform h1 (human) -> biolink:coexpressed_with -> AGT': 1,
#      'edge_2 - AGT -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:1499 -> biolink:coexpressed_with -> UniProtKB:Q3L8U1-2||infores:string
# edge_2 - NCBIGene:1499 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# chromodomain-helicase-DNA-binding protein 9 isoform h2 (human)_CTNNB1_Hepatic fibrosis
# {    'edge_1 - CTNNB1 -> biolink:coexpressed_with -> chromodomain-helicase-DNA-binding protein 9 isoform h2 (human)': 1,
#      'edge_2 - CTNNB1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - UniProtKB:Q3L8U1-2 -> biolink:coexpressed_with -> NCBIGene:1499||infores:string
# edge_2 - NCBIGene:1499 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# chromodomain-helicase-DNA-binding protein 9 isoform h2 (human)_CTNNB1_Hepatic fibrosis
# {    'edge_1 - chromodomain-helicase-DNA-binding protein 9 isoform h2 (human) -> biolink:coexpressed_with -> CTNNB1': 1,
#      'edge_2 - CTNNB1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:6347 -> biolink:affects -> NCBIGene:133522||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:6347 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1B_CCL2_Hepatic fibrosis
# {    'edge_1 - CCL2 -> biolink:affects -> PPARGC1B': 1,
#      'edge_2 - CCL2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:213 -> biolink:affects -> NCBIGene:133522||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:213 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1B_ALB_Hepatic fibrosis
# {    'edge_1 - ALB -> biolink:affects -> PPARGC1B': 1,
#      'edge_2 - ALB -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:2321 -> biolink:affects -> NCBIGene:133522||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:2321 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1B_FLT1_Hepatic fibrosis
# {    'edge_1 - FLT1 -> biolink:affects -> PPARGC1B': 1,
#      'edge_2 - FLT1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:7422 -> biolink:affects -> NCBIGene:133522||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:7422 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1B_VEGFA_Hepatic fibrosis
# {    'edge_1 - VEGFA -> biolink:affects -> PPARGC1B': 1,
#      'edge_2 - VEGFA -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:3569 -> biolink:affects -> NCBIGene:133522||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:3569 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1B_IL6_Hepatic fibrosis
# {    'edge_1 - IL6 -> biolink:affects -> PPARGC1B': 1,
#      'edge_2 - IL6 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:4780 -> biolink:affects -> NCBIGene:133522||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:4780 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1B_NFE2L2_Hepatic fibrosis
# {    'edge_1 - NFE2L2 -> biolink:affects -> PPARGC1B': 1,
#      'edge_2 - NFE2L2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:6696 -> biolink:affects -> NCBIGene:133522||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:6696 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1B_SPP1_Hepatic fibrosis
# {    'edge_1 - SPP1 -> biolink:affects -> PPARGC1B': 1,
#      'edge_2 - SPP1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:133522 -> biolink:affects -> NCBIGene:6347||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:6347 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1B_CCL2_Hepatic fibrosis
# {    'edge_1 - PPARGC1B -> biolink:affects -> CCL2': 1,
#      'edge_2 - CCL2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:133522 -> biolink:affects -> NCBIGene:4780||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:4780 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1B_NFE2L2_Hepatic fibrosis
# {    'edge_1 - PPARGC1B -> biolink:affects -> NFE2L2': 1,
#      'edge_2 - NFE2L2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:133522 -> biolink:affects -> NCBIGene:405||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:405 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1B_ARNT_Hepatic fibrosis
# {    'edge_1 - PPARGC1B -> biolink:affects -> ARNT': 1,
#      'edge_2 - ARNT -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:133522 -> biolink:affects -> NCBIGene:7422||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:7422 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1B_VEGFA_Hepatic fibrosis
# {    'edge_1 - PPARGC1B -> biolink:affects -> VEGFA': 1,
#      'edge_2 - VEGFA -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:133522 -> biolink:affects -> NCBIGene:6696||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:6696 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1B_SPP1_Hepatic fibrosis
# {    'edge_1 - PPARGC1B -> biolink:affects -> SPP1': 1,
#      'edge_2 - SPP1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:133522 -> biolink:affects -> NCBIGene:183||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:183 -> biolink:contributes_to -> MONDO:0018840||infores:text-mining-provider-targeted
# PPARGC1B_AGT_isolated congenital hepatic fibrosis
# {    'edge_1 - PPARGC1B -> biolink:affects -> AGT': 1,
#      'edge_2 - AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
# edge_1 - NCBIGene:133522 -> biolink:affects -> NCBIGene:183||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:183 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1B_AGT_Hepatic fibrosis
# {    'edge_1 - PPARGC1B -> biolink:affects -> AGT': 1,
#      'edge_2 - AGT -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:133522 -> biolink:affects -> NCBIGene:2321||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:2321 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1B_FLT1_Hepatic fibrosis
# {    'edge_1 - PPARGC1B -> biolink:affects -> FLT1': 1,
#      'edge_2 - FLT1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:133522 -> biolink:affects -> NCBIGene:4313||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:4313 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1B_MMP2_Hepatic fibrosis
# {    'edge_1 - PPARGC1B -> biolink:affects -> MMP2': 1,
#      'edge_2 - MMP2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:6772 -> biolink:interacts_with -> NCBIGene:133522||infores:sri-reference-kg
# edge_2 - NCBIGene:6772 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1B_STAT1_Hepatic fibrosis
# {    'edge_1 - STAT1 -> biolink:interacts_with -> PPARGC1B': 1,
#      'edge_2 - STAT1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:133522 -> biolink:regulates -> NCBIGene:6696||infores:lincs
# edge_2 - NCBIGene:6696 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1B_SPP1_Hepatic fibrosis
# {    'edge_1 - PPARGC1B -> biolink:regulates -> SPP1': 1,
#      'edge_2 - SPP1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:80205 -> biolink:interacts_with -> NCBIGene:183||infores:sri-reference-kg
# edge_2 - NCBIGene:183 -> biolink:contributes_to -> MONDO:0018840||infores:text-mining-provider-targeted
# CHD9_AGT_isolated congenital hepatic fibrosis
# {    'edge_1 - CHD9 -> biolink:interacts_with -> AGT': 1,
#      'edge_2 - AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
# edge_1 - NCBIGene:80205 -> biolink:interacts_with -> NCBIGene:183||infores:sri-reference-kg
# edge_2 - NCBIGene:183 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# CHD9_AGT_Hepatic fibrosis
# {    'edge_1 - CHD9 -> biolink:interacts_with -> AGT': 1,
#      'edge_2 - AGT -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:80205 -> biolink:interacts_with -> NCBIGene:5244||infores:sri-reference-kg
# edge_2 - NCBIGene:5244 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# CHD9_ABCB4_Hepatic fibrosis
# {    'edge_1 - CHD9 -> biolink:interacts_with -> ABCB4': 1,
#      'edge_2 - ABCB4 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:213 -> biolink:affects -> NCBIGene:10891||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:213 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1A_ALB_Hepatic fibrosis
# {    'edge_1 - ALB -> biolink:affects -> PPARGC1A': 1,
#      'edge_2 - ALB -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:3569 -> biolink:affects -> NCBIGene:10891||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:3569 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1A_IL6_Hepatic fibrosis
# {    'edge_1 - IL6 -> biolink:affects -> PPARGC1A': 1,
#      'edge_2 - IL6 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:6347 -> biolink:affects -> NCBIGene:10891||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:6347 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1A_CCL2_Hepatic fibrosis
# {    'edge_1 - CCL2 -> biolink:affects -> PPARGC1A': 1,
#      'edge_2 - CCL2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:7422 -> biolink:affects -> NCBIGene:10891||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:7422 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1A_VEGFA_Hepatic fibrosis
# {    'edge_1 - VEGFA -> biolink:affects -> PPARGC1A': 1,
#      'edge_2 - VEGFA -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:6696 -> biolink:affects -> NCBIGene:10891||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:6696 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1A_SPP1_Hepatic fibrosis
# {    'edge_1 - SPP1 -> biolink:affects -> PPARGC1A': 1,
#      'edge_2 - SPP1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:2321 -> biolink:affects -> NCBIGene:10891||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:2321 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1A_FLT1_Hepatic fibrosis
# {    'edge_1 - FLT1 -> biolink:affects -> PPARGC1A': 1,
#      'edge_2 - FLT1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:2200 -> biolink:affects -> NCBIGene:10891||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:2200 -> biolink:contributes_to -> MONDO:0018840||infores:text-mining-provider-targeted
# PPARGC1A_FBN1_isolated congenital hepatic fibrosis
# {    'edge_1 - FBN1 -> biolink:affects -> PPARGC1A': 1,
#      'edge_2 - FBN1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
# edge_1 - NCBIGene:2200 -> biolink:affects -> NCBIGene:10891||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:2200 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1A_FBN1_Hepatic fibrosis
# {    'edge_1 - FBN1 -> biolink:affects -> PPARGC1A': 1,
#      'edge_2 - FBN1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:4780 -> biolink:affects -> NCBIGene:10891||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:4780 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1A_NFE2L2_Hepatic fibrosis
# {    'edge_1 - NFE2L2 -> biolink:affects -> PPARGC1A': 1,
#      'edge_2 - NFE2L2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:10891 -> biolink:affects -> NCBIGene:405||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:405 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1A_ARNT_Hepatic fibrosis
# {    'edge_1 - PPARGC1A -> biolink:affects -> ARNT': 1,
#      'edge_2 - ARNT -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:10891 -> biolink:affects -> NCBIGene:4313||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:4313 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1A_MMP2_Hepatic fibrosis
# {    'edge_1 - PPARGC1A -> biolink:affects -> MMP2': 1,
#      'edge_2 - MMP2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:10891 -> biolink:affects -> NCBIGene:183||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:183 -> biolink:contributes_to -> MONDO:0018840||infores:text-mining-provider-targeted
# PPARGC1A_AGT_isolated congenital hepatic fibrosis
# {    'edge_1 - PPARGC1A -> biolink:affects -> AGT': 1,
#      'edge_2 - AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
# edge_1 - NCBIGene:10891 -> biolink:affects -> NCBIGene:183||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:183 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1A_AGT_Hepatic fibrosis
# {    'edge_1 - PPARGC1A -> biolink:affects -> AGT': 1,
#      'edge_2 - AGT -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:10891 -> biolink:affects -> NCBIGene:6347||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:6347 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1A_CCL2_Hepatic fibrosis
# {    'edge_1 - PPARGC1A -> biolink:affects -> CCL2': 1,
#      'edge_2 - CCL2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:10891 -> biolink:affects -> NCBIGene:6696||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:6696 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1A_SPP1_Hepatic fibrosis
# {    'edge_1 - PPARGC1A -> biolink:affects -> SPP1': 1,
#      'edge_2 - SPP1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:10891 -> biolink:affects -> NCBIGene:2321||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:2321 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1A_FLT1_Hepatic fibrosis
# {    'edge_1 - PPARGC1A -> biolink:affects -> FLT1': 1,
#      'edge_2 - FLT1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:10891 -> biolink:affects -> NCBIGene:7422||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:7422 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1A_VEGFA_Hepatic fibrosis
# {    'edge_1 - PPARGC1A -> biolink:affects -> VEGFA': 1,
#      'edge_2 - VEGFA -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:10891 -> biolink:affects -> NCBIGene:4780||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:4780 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1A_NFE2L2_Hepatic fibrosis
# {    'edge_1 - PPARGC1A -> biolink:affects -> NFE2L2': 1,
#      'edge_2 - NFE2L2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:6772 -> biolink:interacts_with -> NCBIGene:10891||infores:sri-reference-kg
# edge_2 - NCBIGene:6772 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1A_STAT1_Hepatic fibrosis
# {    'edge_1 - STAT1 -> biolink:interacts_with -> PPARGC1A': 1,
#      'edge_2 - STAT1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:10891 -> biolink:regulates -> NCBIGene:3066||infores:lincs
# edge_2 - NCBIGene:3066 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARGC1A_HDAC2_Hepatic fibrosis
# {    'edge_1 - PPARGC1A -> biolink:regulates -> HDAC2': 1,
#      'edge_2 - HDAC2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:120227 -> biolink:coexpressed_with -> UniProtKB:Q07869-1||infores:string
# edge_2 - NCBIGene:120227 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor alpha isoform 1 (human)_CYP2R1_Hepatic fibrosis
# {    'edge_1 - CYP2R1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'edge_2 - CYP2R1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:1269 -> biolink:coexpressed_with -> UniProtKB:Q07869-1||infores:string
# edge_2 - NCBIGene:1269 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor alpha isoform 1 (human)_CNR2_Hepatic fibrosis
# {    'edge_1 - CNR2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'edge_2 - CNR2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:3484 -> biolink:coexpressed_with -> UniProtKB:Q07869-1||infores:string
# edge_2 - NCBIGene:3484 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor alpha isoform 1 (human)_IGFBP1_Hepatic fibrosis
# {    'edge_1 - IGFBP1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'edge_2 - IGFBP1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:1356 -> biolink:coexpressed_with -> UniProtKB:Q07869-1||infores:string
# edge_2 - NCBIGene:1356 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor alpha isoform 1 (human)_CP_Hepatic fibrosis
# {    'edge_1 - CP -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'edge_2 - CP -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:6347 -> biolink:coexpressed_with -> UniProtKB:Q07869-1||infores:string
# edge_2 - NCBIGene:6347 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor alpha isoform 1 (human)_CCL2_Hepatic fibrosis
# {    'edge_1 - CCL2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'edge_2 - CCL2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:3875 -> biolink:coexpressed_with -> UniProtKB:Q07869-1||infores:string
# edge_2 - NCBIGene:3875 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor alpha isoform 1 (human)_KRT18_Hepatic fibrosis
# {    'edge_1 - KRT18 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'edge_2 - KRT18 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:183 -> biolink:coexpressed_with -> UniProtKB:Q07869-1||infores:string
# edge_2 - NCBIGene:183 -> biolink:contributes_to -> MONDO:0018840||infores:text-mining-provider-targeted
# peroxisome proliferator-activated receptor alpha isoform 1 (human)_AGT_isolated congenital hepatic fibrosis
# {    'edge_1 - AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'edge_2 - AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
# edge_1 - NCBIGene:183 -> biolink:coexpressed_with -> UniProtKB:Q07869-1||infores:string
# edge_2 - NCBIGene:183 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor alpha isoform 1 (human)_AGT_Hepatic fibrosis
# {    'edge_1 - AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'edge_2 - AGT -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:4015 -> biolink:coexpressed_with -> UniProtKB:Q07869-1||infores:string
# edge_2 - NCBIGene:4015 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor alpha isoform 1 (human)_LOX_Hepatic fibrosis
# {    'edge_1 - LOX -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'edge_2 - LOX -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:2147 -> biolink:coexpressed_with -> UniProtKB:Q07869-1||infores:string
# edge_2 - NCBIGene:2147 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor alpha isoform 1 (human)_F2_Hepatic fibrosis
# {    'edge_1 - F2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'edge_2 - F2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:1593 -> biolink:coexpressed_with -> UniProtKB:Q07869-1||infores:string
# edge_2 - NCBIGene:1593 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor alpha isoform 1 (human)_CYP27A1_Hepatic fibrosis
# {    'edge_1 - CYP27A1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'edge_2 - CYP27A1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:866 -> biolink:coexpressed_with -> UniProtKB:Q07869-1||infores:string
# edge_2 - NCBIGene:866 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor alpha isoform 1 (human)_SERPINA6_Hepatic fibrosis
# {    'edge_1 - SERPINA6 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'edge_2 - SERPINA6 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - UniProtKB:Q07869-1 -> biolink:coexpressed_with -> NCBIGene:3875||infores:string
# edge_2 - NCBIGene:3875 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor alpha isoform 1 (human)_KRT18_Hepatic fibrosis
# {    'edge_1 - peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> KRT18': 1,
#      'edge_2 - KRT18 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - UniProtKB:Q07869-1 -> biolink:coexpressed_with -> NCBIGene:1593||infores:string
# edge_2 - NCBIGene:1593 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor alpha isoform 1 (human)_CYP27A1_Hepatic fibrosis
# {    'edge_1 - peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CYP27A1': 1,
#      'edge_2 - CYP27A1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - UniProtKB:Q07869-1 -> biolink:coexpressed_with -> NCBIGene:6347||infores:string
# edge_2 - NCBIGene:6347 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor alpha isoform 1 (human)_CCL2_Hepatic fibrosis
# {    'edge_1 - peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CCL2': 1,
#      'edge_2 - CCL2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - UniProtKB:Q07869-1 -> biolink:coexpressed_with -> NCBIGene:2147||infores:string
# edge_2 - NCBIGene:2147 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor alpha isoform 1 (human)_F2_Hepatic fibrosis
# {    'edge_1 - peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> F2': 1,
#      'edge_2 - F2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - UniProtKB:Q07869-1 -> biolink:coexpressed_with -> NCBIGene:3484||infores:string
# edge_2 - NCBIGene:3484 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor alpha isoform 1 (human)_IGFBP1_Hepatic fibrosis
# {    'edge_1 - peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> IGFBP1': 1,
#      'edge_2 - IGFBP1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - UniProtKB:Q07869-1 -> biolink:coexpressed_with -> NCBIGene:183||infores:string
# edge_2 - NCBIGene:183 -> biolink:contributes_to -> MONDO:0018840||infores:text-mining-provider-targeted
# peroxisome proliferator-activated receptor alpha isoform 1 (human)_AGT_isolated congenital hepatic fibrosis
# {    'edge_1 - peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> AGT': 1,
#      'edge_2 - AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
# edge_1 - UniProtKB:Q07869-1 -> biolink:coexpressed_with -> NCBIGene:183||infores:string
# edge_2 - NCBIGene:183 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor alpha isoform 1 (human)_AGT_Hepatic fibrosis
# {    'edge_1 - peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> AGT': 1,
#      'edge_2 - AGT -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - UniProtKB:Q07869-1 -> biolink:coexpressed_with -> NCBIGene:120227||infores:string
# edge_2 - NCBIGene:120227 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor alpha isoform 1 (human)_CYP2R1_Hepatic fibrosis
# {    'edge_1 - peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CYP2R1': 1,
#      'edge_2 - CYP2R1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - UniProtKB:Q07869-1 -> biolink:coexpressed_with -> NCBIGene:1356||infores:string
# edge_2 - NCBIGene:1356 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor alpha isoform 1 (human)_CP_Hepatic fibrosis
# {    'edge_1 - peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CP': 1,
#      'edge_2 - CP -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - UniProtKB:Q07869-1 -> biolink:coexpressed_with -> NCBIGene:1269||infores:string
# edge_2 - NCBIGene:1269 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor alpha isoform 1 (human)_CNR2_Hepatic fibrosis
# {    'edge_1 - peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CNR2': 1,
#      'edge_2 - CNR2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - UniProtKB:Q07869-1 -> biolink:coexpressed_with -> NCBIGene:4015||infores:string
# edge_2 - NCBIGene:4015 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor alpha isoform 1 (human)_LOX_Hepatic fibrosis
# {    'edge_1 - peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> LOX': 1,
#      'edge_2 - LOX -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - UniProtKB:Q07869-1 -> biolink:coexpressed_with -> NCBIGene:866||infores:string
# edge_2 - NCBIGene:866 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# peroxisome proliferator-activated receptor alpha isoform 1 (human)_SERPINA6_Hepatic fibrosis
# {    'edge_1 - peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> SERPINA6': 1,
#      'edge_2 - SERPINA6 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:5314 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:5314 -> biolink:affects -> MONDO:0018840||infores:text-mining-provider-targeted
# PPARA_PKHD1_isolated congenital hepatic fibrosis
# {    'edge_1 - PKHD1 -> biolink:affects -> PPARA': 1,
#      'edge_2 - PKHD1 -> biolink:affects -> isolated congenital hepatic fibrosis': 1}
# edge_1 - NCBIGene:5314 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:5314 -> biolink:contributes_to -> MONDO:0018840||infores:text-mining-provider-targeted
# PPARA_PKHD1_isolated congenital hepatic fibrosis
# {    'edge_1 - PKHD1 -> biolink:affects -> PPARA': 1,
#      'edge_2 - PKHD1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
# edge_1 - NCBIGene:5314 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:5314 -> biolink:genetically_associated_with -> MONDO:0018840||infores:disgenet
# PPARA_PKHD1_isolated congenital hepatic fibrosis
# {    'edge_1 - PKHD1 -> biolink:affects -> PPARA': 1,
#      'edge_2 - PKHD1 -> biolink:genetically_associated_with -> isolated congenital hepatic fibrosis': 1}
# edge_1 - NCBIGene:1490 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:1490 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_CCN2_Hepatic fibrosis
# {    'edge_1 - CCN2 -> biolink:affects -> PPARA': 1,
#      'edge_2 - CCN2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:1499 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:1499 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_CTNNB1_Hepatic fibrosis
# {    'edge_1 - CTNNB1 -> biolink:affects -> PPARA': 1,
#      'edge_2 - CTNNB1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:2149 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:2149 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_F2R_Hepatic fibrosis
# {    'edge_1 - F2R -> biolink:affects -> PPARA': 1,
#      'edge_2 - F2R -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:213 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:213 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_ALB_Hepatic fibrosis
# {    'edge_1 - ALB -> biolink:affects -> PPARA': 1,
#      'edge_2 - ALB -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:405 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:405 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_ARNT_Hepatic fibrosis
# {    'edge_1 - ARNT -> biolink:affects -> PPARA': 1,
#      'edge_2 - ARNT -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:1356 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:1356 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_CP_Hepatic fibrosis
# {    'edge_1 - CP -> biolink:affects -> PPARA': 1,
#      'edge_2 - CP -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:7057 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:7057 -> biolink:contributes_to -> MONDO:0018840||infores:text-mining-provider-targeted
# PPARA_THBS1_isolated congenital hepatic fibrosis
# {    'edge_1 - THBS1 -> biolink:affects -> PPARA': 1,
#      'edge_2 - THBS1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
# edge_1 - NCBIGene:7057 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:7057 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_THBS1_Hepatic fibrosis
# {    'edge_1 - THBS1 -> biolink:affects -> PPARA': 1,
#      'edge_2 - THBS1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:4313 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:4313 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_MMP2_Hepatic fibrosis
# {    'edge_1 - MMP2 -> biolink:affects -> PPARA': 1,
#      'edge_2 - MMP2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:7422 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:7422 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_VEGFA_Hepatic fibrosis
# {    'edge_1 - VEGFA -> biolink:affects -> PPARA': 1,
#      'edge_2 - VEGFA -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:7046 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:7046 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_TGFBR1_Hepatic fibrosis
# {    'edge_1 - TGFBR1 -> biolink:affects -> PPARA': 1,
#      'edge_2 - TGFBR1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:5972 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:5972 -> biolink:contributes_to -> MONDO:0018840||infores:text-mining-provider-targeted
# PPARA_REN_isolated congenital hepatic fibrosis
# {    'edge_1 - REN -> biolink:affects -> PPARA': 1,
#      'edge_2 - REN -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
# edge_1 - NCBIGene:5972 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:5972 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_REN_Hepatic fibrosis
# {    'edge_1 - REN -> biolink:affects -> PPARA': 1,
#      'edge_2 - REN -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:1269 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:1269 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_CNR2_Hepatic fibrosis
# {    'edge_1 - CNR2 -> biolink:affects -> PPARA': 1,
#      'edge_2 - CNR2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:4780 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:4780 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_NFE2L2_Hepatic fibrosis
# {    'edge_1 - NFE2L2 -> biolink:affects -> PPARA': 1,
#      'edge_2 - NFE2L2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:4864 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:4864 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_NPC1_Hepatic fibrosis
# {    'edge_1 - NPC1 -> biolink:affects -> PPARA': 1,
#      'edge_2 - NPC1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:7040 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:7040 -> biolink:contributes_to -> MONDO:0018840||infores:text-mining-provider-targeted
# PPARA_TGFB1_isolated congenital hepatic fibrosis
# {    'edge_1 - TGFB1 -> biolink:affects -> PPARA': 1,
#      'edge_2 - TGFB1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
# edge_1 - NCBIGene:7040 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:7040 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_TGFB1_Hepatic fibrosis
# {    'edge_1 - TGFB1 -> biolink:affects -> PPARA': 1,
#      'edge_2 - TGFB1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:5328 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:5328 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_PLAU_Hepatic fibrosis
# {    'edge_1 - PLAU -> biolink:affects -> PPARA': 1,
#      'edge_2 - PLAU -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:183 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:183 -> biolink:contributes_to -> MONDO:0018840||infores:text-mining-provider-targeted
# PPARA_AGT_isolated congenital hepatic fibrosis
# {    'edge_1 - AGT -> biolink:affects -> PPARA': 1,
#      'edge_2 - AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
# edge_1 - NCBIGene:183 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:183 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_AGT_Hepatic fibrosis
# {    'edge_1 - AGT -> biolink:affects -> PPARA': 1,
#      'edge_2 - AGT -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:6347 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:6347 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_CCL2_Hepatic fibrosis
# {    'edge_1 - CCL2 -> biolink:affects -> PPARA': 1,
#      'edge_2 - CCL2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:3956 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:3956 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_LGALS1_Hepatic fibrosis
# {    'edge_1 - LGALS1 -> biolink:affects -> PPARA': 1,
#      'edge_2 - LGALS1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:408 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:408 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_ARRB1_Hepatic fibrosis
# {    'edge_1 - ARRB1 -> biolink:affects -> PPARA': 1,
#      'edge_2 - ARRB1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:6696 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:6696 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_SPP1_Hepatic fibrosis
# {    'edge_1 - SPP1 -> biolink:affects -> PPARA': 1,
#      'edge_2 - SPP1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:3569 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:3569 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_IL6_Hepatic fibrosis
# {    'edge_1 - IL6 -> biolink:affects -> PPARA': 1,
#      'edge_2 - IL6 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:4088 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:4088 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_SMAD3_Hepatic fibrosis
# {    'edge_1 - SMAD3 -> biolink:affects -> PPARA': 1,
#      'edge_2 - SMAD3 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:3082 -> biolink:affects -> NCBIGene:5465||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:3082 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_HGF_Hepatic fibrosis
# {    'edge_1 - HGF -> biolink:affects -> PPARA': 1,
#      'edge_2 - HGF -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:5465 -> biolink:affects -> NCBIGene:3082||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:3082 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_HGF_Hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:affects -> HGF': 1,
#      'edge_2 - HGF -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:5465 -> biolink:affects -> NCBIGene:1499||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:1499 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_CTNNB1_Hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:affects -> CTNNB1': 1,
#      'edge_2 - CTNNB1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:5465 -> biolink:affects -> NCBIGene:7057||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:7057 -> biolink:contributes_to -> MONDO:0018840||infores:text-mining-provider-targeted
# PPARA_THBS1_isolated congenital hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:affects -> THBS1': 1,
#      'edge_2 - THBS1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
# edge_1 - NCBIGene:5465 -> biolink:affects -> NCBIGene:7057||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:7057 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_THBS1_Hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:affects -> THBS1': 1,
#      'edge_2 - THBS1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:5465 -> biolink:affects -> NCBIGene:2147||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:2147 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_F2_Hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:affects -> F2': 1,
#      'edge_2 - F2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:5465 -> biolink:affects -> NCBIGene:2321||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:2321 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_FLT1_Hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:affects -> FLT1': 1,
#      'edge_2 - FLT1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:5465 -> biolink:affects -> NCBIGene:4088||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:4088 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_SMAD3_Hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:affects -> SMAD3': 1,
#      'edge_2 - SMAD3 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:5465 -> biolink:affects -> NCBIGene:1490||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:1490 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_CCN2_Hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:affects -> CCN2': 1,
#      'edge_2 - CCN2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:5465 -> biolink:affects -> NCBIGene:6927||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:6927 -> biolink:contributes_to -> MONDO:0018840||infores:text-mining-provider-targeted
# PPARA_HNF1A_isolated congenital hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:affects -> HNF1A': 1,
#      'edge_2 - HNF1A -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
# edge_1 - NCBIGene:5465 -> biolink:affects -> NCBIGene:4780||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:4780 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_NFE2L2_Hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:affects -> NFE2L2': 1,
#      'edge_2 - NFE2L2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:5465 -> biolink:affects -> NCBIGene:1278||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:1278 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_COL1A2_Hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:affects -> COL1A2': 1,
#      'edge_2 - COL1A2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:5465 -> biolink:affects -> NCBIGene:213||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:213 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_ALB_Hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:affects -> ALB': 1,
#      'edge_2 - ALB -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:5465 -> biolink:affects -> NCBIGene:7046||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:7046 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_TGFBR1_Hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:affects -> TGFBR1': 1,
#      'edge_2 - TGFBR1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# ...
#      'edge_2 - ABCB4 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:5465 -> biolink:affects -> NCBIGene:4763||infores:text-mining-provider-targeted
# edge_2 - NCBIGene:4763 -> biolink:contributes_to -> MONDO:0018840||infores:text-mining-provider-targeted
# PPARA_NF1_isolated congenital hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:affects -> NF1': 1,
#      'edge_2 - NF1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
# edge_1 - NCBIGene:213 -> biolink:directly_physically_interacts_with -> NCBIGene:5465||infores:intact
# edge_2 - NCBIGene:213 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_ALB_Hepatic fibrosis
# {    'edge_1 - ALB -> biolink:directly_physically_interacts_with -> PPARA': 1,
#      'edge_2 - ALB -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:6772 -> biolink:interacts_with -> NCBIGene:5465||infores:sri-reference-kg
# edge_2 - NCBIGene:6772 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_STAT1_Hepatic fibrosis
# {    'edge_1 - STAT1 -> biolink:interacts_with -> PPARA': 1,
#      'edge_2 - STAT1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:5465 -> biolink:interacts_with -> NCBIGene:183||infores:sri-reference-kg
# edge_2 - NCBIGene:183 -> biolink:contributes_to -> MONDO:0018840||infores:text-mining-provider-targeted
# PPARA_AGT_isolated congenital hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:interacts_with -> AGT': 1,
#      'edge_2 - AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
# edge_1 - NCBIGene:5465 -> biolink:interacts_with -> NCBIGene:183||infores:sri-reference-kg
# edge_2 - NCBIGene:183 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_AGT_Hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:interacts_with -> AGT': 1,
#      'edge_2 - AGT -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:5465 -> biolink:interacts_with -> NCBIGene:5244||infores:sri-reference-kg
# edge_2 - NCBIGene:5244 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_ABCB4_Hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:interacts_with -> ABCB4': 1,
#      'edge_2 - ABCB4 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:5465 -> biolink:interacts_with -> NCBIGene:2147||infores:sri-reference-kg
# edge_2 - NCBIGene:2147 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_F2_Hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:interacts_with -> F2': 1,
#      'edge_2 - F2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:5465 -> biolink:contributes_to -> MONDO:0005154||infores:text-mining-provider-targeted
# edge_2 - MONDO:0018840 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver disorder_isolated congenital hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'edge_2 - isolated congenital hepatic fibrosis -> biolink:subclass_of -> liver disorder': 1}
# edge_1 - NCBIGene:5465 -> biolink:contributes_to -> MONDO:0005154||infores:text-mining-provider-targeted
# edge_2 - MONDO:0018840 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver disorder_isolated congenital hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'edge_2 - isolated congenital hepatic fibrosis -> biolink:subclass_of -> liver disorder': 1}
# edge_1 - NCBIGene:5465 -> biolink:contributes_to -> MONDO:0005154||infores:text-mining-provider-targeted
# edge_2 - HP:0001395 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver disorder_Hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'edge_2 - Hepatic fibrosis -> biolink:subclass_of -> liver disorder': 1}
# edge_1 - NCBIGene:5465 -> biolink:contributes_to -> MONDO:0005154||infores:text-mining-provider-targeted
# edge_2 - HP:0001395 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver disorder_Hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'edge_2 - Hepatic fibrosis -> biolink:subclass_of -> liver disorder': 1}
# edge_1 - NCBIGene:5465 -> biolink:contributes_to -> MONDO:0005154||infores:text-mining-provider-targeted
# edge_2 - UMLS:C2827436 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver disorder_Liver Disease Associated with Cystic Fibrosis
# {    'edge_1 - PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'edge_2 - Liver Disease Associated with Cystic Fibrosis -> biolink:subclass_of -> liver disorder': 1}
# edge_1 - NCBIGene:5465 -> biolink:contributes_to -> MONDO:0005154||infores:text-mining-provider-targeted
# edge_2 - UMLS:C2827436 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver disorder_Liver Disease Associated with Cystic Fibrosis
# {    'edge_1 - PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'edge_2 - Liver Disease Associated with Cystic Fibrosis -> biolink:subclass_of -> liver disorder': 1}
# edge_1 - NCBIGene:5465 -> biolink:contributes_to -> MONDO:0005154||infores:text-mining-provider-targeted
# edge_2 - MONDO:0100430 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver disorder_fibrotic liver disease
# {    'edge_1 - PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'edge_2 - fibrotic liver disease -> biolink:subclass_of -> liver disorder': 1}
# edge_1 - NCBIGene:5465 -> biolink:contributes_to -> MONDO:0005154||infores:text-mining-provider-targeted
# edge_2 - MONDO:0100430 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver disorder_fibrotic liver disease
# {    'edge_1 - PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'edge_2 - fibrotic liver disease -> biolink:subclass_of -> liver disorder': 1}
# edge_1 - NCBIGene:5465 -> biolink:contributes_to -> MONDO:0005154||infores:text-mining-provider-targeted
# edge_2 - HP:0012852 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver disorder_Hepatic bridging fibrosis
# {    'edge_1 - PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'edge_2 - Hepatic bridging fibrosis -> biolink:subclass_of -> liver disorder': 1}
# edge_1 - NCBIGene:5465 -> biolink:contributes_to -> MONDO:0005154||infores:text-mining-provider-targeted
# edge_2 - HP:0012852 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver disorder_Hepatic bridging fibrosis
# {    'edge_1 - PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'edge_2 - Hepatic bridging fibrosis -> biolink:subclass_of -> liver disorder': 1}
# edge_1 - NCBIGene:5465 -> biolink:contributes_to -> MONDO:0005154||infores:text-mining-provider-targeted
# edge_2 - HP:0001405 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver disorder_Periportal fibrosis
# {    'edge_1 - PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'edge_2 - Periportal fibrosis -> biolink:subclass_of -> liver disorder': 1}
# edge_1 - NCBIGene:5465 -> biolink:contributes_to -> MONDO:0005154||infores:text-mining-provider-targeted
# edge_2 - HP:0001405 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver disorder_Periportal fibrosis
# {    'edge_1 - PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'edge_2 - Periportal fibrosis -> biolink:subclass_of -> liver disorder': 1}
# edge_1 - NCBIGene:5465 -> biolink:contributes_to -> MONDO:0005155||infores:text-mining-provider-targeted
# edge_2 - MONDO:0018840 -> biolink:subclass_of -> MONDO:0005155||infores:sri-ontology
# PPARA_cirrhosis of liver_isolated congenital hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:contributes_to -> cirrhosis of liver': 1,
#      'edge_2 - isolated congenital hepatic fibrosis -> biolink:subclass_of -> cirrhosis of liver': 1}
# edge_1 - NCBIGene:5465 -> biolink:contributes_to -> MONDO:0005155||infores:text-mining-provider-targeted
# edge_2 - MONDO:0018840 -> biolink:subclass_of -> MONDO:0005155||infores:sri-ontology
# PPARA_cirrhosis of liver_isolated congenital hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:contributes_to -> cirrhosis of liver': 1,
#      'edge_2 - isolated congenital hepatic fibrosis -> biolink:subclass_of -> cirrhosis of liver': 1}
# edge_1 - NCBIGene:5465 -> biolink:regulates -> NCBIGene:7431||infores:lincs
# edge_2 - NCBIGene:7431 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_VIM_Hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:regulates -> VIM': 1,
#      'edge_2 - VIM -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:5465 -> biolink:regulates -> NCBIGene:6696||infores:lincs
# edge_2 - NCBIGene:6696 -> biolink:genetically_associated_with -> HP:0001395||infores:disgenet
# PPARA_SPP1_Hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:regulates -> SPP1': 1,
#      'edge_2 - SPP1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
# edge_1 - NCBIGene:5465 -> biolink:genetically_associated_with -> MONDO:0005154||infores:diseases
# edge_2 - MONDO:0018840 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver disorder_isolated congenital hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:genetically_associated_with -> liver disorder': 1,
#      'edge_2 - isolated congenital hepatic fibrosis -> biolink:subclass_of -> liver disorder': 1}
# edge_1 - NCBIGene:5465 -> biolink:genetically_associated_with -> MONDO:0005154||infores:diseases
# edge_2 - MONDO:0018840 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver disorder_isolated congenital hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:genetically_associated_with -> liver disorder': 1,
#      'edge_2 - isolated congenital hepatic fibrosis -> biolink:subclass_of -> liver disorder': 1}
# edge_1 - NCBIGene:5465 -> biolink:genetically_associated_with -> MONDO:0005154||infores:diseases
# edge_2 - HP:0001395 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver disorder_Hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:genetically_associated_with -> liver disorder': 1,
#      'edge_2 - Hepatic fibrosis -> biolink:subclass_of -> liver disorder': 1}
# edge_1 - NCBIGene:5465 -> biolink:genetically_associated_with -> MONDO:0005154||infores:diseases
# edge_2 - HP:0001395 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver disorder_Hepatic fibrosis
# {    'edge_1 - PPARA -> biolink:genetically_associated_with -> liver disorder': 1,
#      'edge_2 - Hepatic fibrosis -> biolink:subclass_of -> liver disorder': 1}
# edge_1 - NCBIGene:5465 -> biolink:genetically_associated_with -> MONDO:0005154||infores:diseases
# edge_2 - UMLS:C2827436 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver disorder_Liver Disease Associated with Cystic Fibrosis
# {    'edge_1 - PPARA -> biolink:genetically_associated_with -> liver disorder': 1,
#      'edge_2 - Liver Disease Associated with Cystic Fibrosis -> biolink:subclass_of -> liver disorder': 1}
# edge_1 - NCBIGene:5465 -> biolink:genetically_associated_with -> MONDO:0005154||infores:diseases
# edge_2 - UMLS:C2827436 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver disorder_Liver Disease Associated with Cystic Fibrosis
# {    'edge_1 - PPARA -> biolink:genetically_associated_with -> liver disorder': 1,
#      'edge_2 - Liver Disease Associated with Cystic Fibrosis -> biolink:subclass_of -> liver disorder': 1}
# edge_1 - NCBIGene:5465 -> biolink:genetically_associated_with -> MONDO:0005154||infores:diseases
# edge_2 - MONDO:0100430 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver disorder_fibrotic liver disease
# {    'edge_1 - PPARA -> biolink:genetically_associated_with -> liver disorder': 1,
#      'edge_2 - fibrotic liver disease -> biolink:subclass_of -> liver disorder': 1}
# edge_1 - NCBIGene:5465 -> biolink:genetically_associated_with -> MONDO:0005154||infores:diseases
# edge_2 - MONDO:0100430 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver disorder_fibrotic liver disease
# {    'edge_1 - PPARA -> biolink:genetically_associated_with -> liver disorder': 1,
#      'edge_2 - fibrotic liver disease -> biolink:subclass_of -> liver disorder': 1}
# edge_1 - NCBIGene:5465 -> biolink:genetically_associated_with -> MONDO:0005154||infores:diseases
# edge_2 - HP:0012852 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver disorder_Hepatic bridging fibrosis
# {    'edge_1 - PPARA -> biolink:genetically_associated_with -> liver disorder': 1,
#      'edge_2 - Hepatic bridging fibrosis -> biolink:subclass_of -> liver disorder': 1}
# edge_1 - NCBIGene:5465 -> biolink:genetically_associated_with -> MONDO:0005154||infores:diseases
# edge_2 - HP:0012852 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver disorder_Hepatic bridging fibrosis
# {    'edge_1 - PPARA -> biolink:genetically_associated_with -> liver disorder': 1,
#      'edge_2 - Hepatic bridging fibrosis -> biolink:subclass_of -> liver disorder': 1}
# edge_1 - NCBIGene:5465 -> biolink:genetically_associated_with -> MONDO:0005154||infores:diseases
# edge_2 - HP:0001405 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver disorder_Periportal fibrosis
# {    'edge_1 - PPARA -> biolink:genetically_associated_with -> liver disorder': 1,
#      'edge_2 - Periportal fibrosis -> biolink:subclass_of -> liver disorder': 1}
# edge_1 - NCBIGene:5465 -> biolink:genetically_associated_with -> MONDO:0005154||infores:diseases
# edge_2 - HP:0001405 -> biolink:subclass_of -> MONDO:0005154||infores:sri-ontology
# PPARA_liver disorder_Periportal fibrosis
# {    'edge_1 - PPARA -> biolink:genetically_associated_with -> liver disorder': 1,
#      'edge_2 - Periportal fibrosis -> biolink:subclass_of -> liver disorder': 1}
# (172, 6)
#                     n00                                           n00_name  \
# 0    UniProtKB:Q9UBK2-1  peroxisome proliferator-activated receptor gam...
# 1    UniProtKB:Q9UBK2-1  peroxisome proliferator-activated receptor gam...
# 2    UniProtKB:Q9UBK2-1  peroxisome proliferator-activated receptor gam...
# 3    UniProtKB:Q9UBK2-1  peroxisome proliferator-activated receptor gam...
# 4    UniProtKB:Q9UBK2-1  peroxisome proliferator-activated receptor gam...
# ..                  ...                                                ...
# 167       NCBIGene:5465                                              PPARA
# 168       NCBIGene:5465                                              PPARA
# 169       NCBIGene:5465                                              PPARA
# 170       NCBIGene:5465                                              PPARA
# 171       NCBIGene:5465                                              PPARA
#
#                n01        n01_name            n02  \
# 0     NCBIGene:183             AGT  MONDO:0018840
# 1     NCBIGene:183             AGT     HP:0001395
# 2    NCBIGene:7431             VIM     HP:0001395
# 3    NCBIGene:1593         CYP27A1     HP:0001395
# 4    NCBIGene:1593         CYP27A1     HP:0001395
# ..             ...             ...            ...
# 167  MONDO:0005154  liver disorder  MONDO:0100430
# 168  MONDO:0005154  liver disorder     HP:0012852
# 169  MONDO:0005154  liver disorder     HP:0012852
# 170  MONDO:0005154  liver disorder     HP:0001405
# 171  MONDO:0005154  liver disorder     HP:0001405
#
#                                  n02_name
# 0    isolated congenital hepatic fibrosis
# 1                        Hepatic fibrosis
# 2                        Hepatic fibrosis
# 3                        Hepatic fibrosis
# 4                        Hepatic fibrosis
# ..                                    ...
# 167                fibrotic liver disease
# 168             Hepatic bridging fibrosis
# 169             Hepatic bridging fibrosis
# 170                   Periportal fibrosis
# 171                   Periportal fibrosis
#
# [172 rows x 6 columns]
# --- 0.48143458366394043 seconds ---

# %% [markdown]
# # Summary comparisons

# %% [markdown]
# ## Initializing and defining summary compare functions

# %%
import pandas as pd
pd.options.display.max_colwidth = 100

def get_summary_stats(results_df):
    results_df['Freq'] = 1

    occur_n00=(results_df
      .groupby(
           results_df[["n00"]]
           .apply(lambda x: str(sorted(x)), axis=1)
           )
      .agg({"n00": "first", "n00_name": "first", "Freq": "sum"}).sort_values(['Freq'], ascending = False)
      .reset_index(drop=True)
    )
    occur_n02=(results_df
      .groupby(
           results_df[["n02"]]
           .apply(lambda x: str(sorted(x)), axis=1)
           )
      .agg({"n02": "first","n02_name": "first", "Freq": "sum"}).sort_values(['Freq'], ascending = False)
      .reset_index(drop=True)
    )
    
    # Counting pairwise results
    occur_pair=(results_df
      .groupby(
           results_df[["n00", "n02"]]
           .apply(lambda x: str(sorted(x)), axis=1)
           )
      .agg({"n00": "first", "n00_name": "first", "n02": "first", "n02_name": "first", "Freq": "sum"}).sort_values(['Freq'], ascending = False)
      .reset_index(drop=True)
    )

    print("\nFrequency of n00 IDs")
    display(occur_n00)
    print("\nFrequency of n02 IDs")
    display(occur_n02)
    print("\nFrequency of n00-n02 pair IDs")
    display(occur_pair)
    
    print("\nMost frequent pair")
    display(occur_pair.head(1))
    return(occur_pair.head(1))
    
def get_summary_stats_no_ids(results_df):
    results_df['Freq'] = 1

    occur_n00=(results_df
      .groupby(
           results_df[["n00_name"]]
           .apply(lambda x: str(sorted(x)), axis=1)
           )
      .agg({"n00_name": "first", "Freq": "sum"}).sort_values(['Freq'], ascending = False)
      .reset_index(drop=True)
    )
    occur_n02=(results_df
      .groupby(
           results_df[["n02_name"]]
           .apply(lambda x: str(sorted(x)), axis=1)
           )
      .agg({"n02_name": "first", "Freq": "sum"}).sort_values(['Freq'], ascending = False)
      .reset_index(drop=True)
    )
    
    # Counting pairwise results
    occur_pair=(results_df
      .groupby(
           results_df[["n00_name", "n02_name"]]
           .apply(lambda x: str(sorted(x)), axis=1)
           )
      .agg({"n00_name": "first", "n02_name": "first", "Freq": "sum"}).sort_values(['Freq'], ascending = False)
      .reset_index(drop=True)
    )

    print("\nFrequency of n00 labels")
    display(occur_n00)
    print("\nFrequency of n02 labels")
    display(occur_n02)
    print("\nFrequency of n00-n02 pair labels")
    display(occur_pair)
    
    print("\nMost frequent pair")
    display(occur_pair.head(1))
    return(occur_pair.head(1))
    
def compare_summary_stats(results_df1, results_df2, label1, label2):
    print(f"Summary stats for {label1}")
    most_frequent_pair1 = get_summary_stats(results_df1)
    most_frequent_pair1['label'] = label1
    print(f"\nSummary stats for {label2}")
    most_frequent_pair2 = get_summary_stats(results_df2)
    most_frequent_pair2['label'] = label2
    frames = [most_frequent_pair1,most_frequent_pair2]
    most_frequent_pairs = pd.concat(frames)
    display(most_frequent_pairs)
    
def compare_summary_stats_no_ids(results_df1, results_df2, label1, label2):
    print(f"Summary stats for {label1}")
    most_frequent_pair1 = get_summary_stats_no_ids(results_df1)
    most_frequent_pair1['label'] = label1
    print(f"\nSummary stats for {label2}")
    most_frequent_pair2 = get_summary_stats_no_ids(results_df2)
    most_frequent_pair2['label'] = label2
    frames = [most_frequent_pair1,most_frequent_pair2]
    most_frequent_pairs = pd.concat(frames)
    display(most_frequent_pairs)

# %%
results_df_Cypher_Automat = pd.read_csv(Cypher_Automat_results_file)
display(results_df_Cypher_Automat)
most_common_pair_test = get_summary_stats(results_df_Cypher_Automat)

# %% [markdown]
# ## TRAPI comparison results
# ARA vs TRAPI

# %%
results_df_ARA = pd.read_csv(ARA_results_file)
results_df_TRAPI = pd.read_csv(TRAPI_results_file)
compare_summary_stats(results_df_ARA,results_df_TRAPI,"ARA","TRAPI (automat)")

# %%
results_df_ARA = pd.read_csv(ARA_results_file)
results_df_Cypher_ROBOKOPKG = pd.read_csv(Cypher_ROBOKOPKG_results_file)
compare_summary_stats(results_df_ARA,results_df_Cypher_ROBOKOPKG,"ARA","Cypher (ROBOKOPKG)")

# %% [markdown]
# ## Cypher comparison results
# Automat vs ROBOKOPKG

# %%
results_df_Cypher_Automat = pd.read_csv(Cypher_Automat_results_file)
results_df_Cypher_ROBOKOPKG = pd.read_csv(Cypher_ROBOKOPKG_single_results_file)
compare_summary_stats(results_df_Cypher_Automat,results_df_Cypher_ROBOKOPKG,"Cypher (automat)","Cypher (ROBOKOPKG)")

# %% [markdown]
# ExEmPLAR vs ROBOKOPKG

# %%
results_df_Cypher_ROBOKOPKG = pd.read_csv(Cypher_ROBOKOPKG_results_file)
results_df_exemplar = pd.read_csv(exemplar_results_file)
compare_summary_stats_no_ids(results_df_exemplar,results_df_Cypher_ROBOKOPKG,"ExEmPLAR","Cypher (ROBOKOPKG)")

# %% [markdown]
# ## ARA vs Cypher (ROBOKOPKG)

# %%
results_df_ARA = pd.read_csv(ARA_results_file)
results_df_Cypher_ROBOKOPKG = pd.read_csv(Cypher_ROBOKOPKG_results_file)
compare_summary_stats(results_df_ARA,results_df_Cypher_ROBOKOPKG,"ARA","Cypher (ROBOKOPKG)")

# %% [markdown]
# ## Automat comparison results
# TRAPI vs Cypher

# %%
results_df_TRAPI = pd.read_csv(TRAPI_results_file)
results_df_Cypher_Automat = pd.read_csv(Cypher_Automat_results_file)
compare_summary_stats(results_df_TRAPI,results_df_Cypher_Automat,"TRAPI (automat)","Cypher (automat)")

# %% [markdown]
# ## Question Builder comparison
#
# Question builder with and without "BiologicalEntity" as the intermediate node

# %%
results_df_qbuilder_bio_entity = pd.read_csv(qbuilder_bio_entity_results_file)
results_df_qbuilder_blank = pd.read_csv(qbuilder_blank_results_file)
compare_summary_stats_no_ids(results_df_qbuilder_bio_entity,results_df_qbuilder_blank,"Question Builder (BiologicalEntity)","Question Builder")

# %% [markdown]
# # Comparison plots

# %%
# results_date = "2023-07-07_153233" # report out 2023-07-10, 2023-07-24
# results_date = "2023-08-03_112930" # report out 2023-08-07
# results_date = "2023-08-18_125007" # report out 2023-08-21 (with additional IDs)
results_date = "2023-08-18_133624" # report out 2023-08-21 (without additional IDs)

# Pathway results to load and write directory to specify (on David's work computer from previous run)
write_dir_cypher_automat = "output/compare/"+results_date+"/cypher/automat"
write_dir_cypher_robokopkg = "output/compare/"+results_date+"/cypher/robokopkg"
ARA_results_file = "output/compare/"+results_date+"/trapi/ara/results_ARA.csv"
TRAPI_results_file = "output/compare/"+results_date+"/trapi/automat/results_TRAPI.csv"
Cypher_ROBOKOPKG_results_file = "output/compare/"+results_date+"/cypher/robokopkg/results.csv"
Cypher_ROBOKOPKG_single_results_file = "output/compare/"+results_date+"/cypher/robokopkg_single/results.csv"
Cypher_Automat_results_file = "output/compare/"+results_date+"/cypher/automat/results.csv"
write_dir_compare = "output/compare/"+results_date+""
exemplar_results_file = "output/compare/"+results_date+"/exemplar_data.csv"
qbuilder_bio_entity_results_file = "output/compare/"+results_date+"/qbuilder_bio_entity_data.csv"
qbuilder_blank_results_file = "output/compare/"+results_date+"/qbuilder_blank_data.csv"
ARA_PPARA_Fibrosis_results_file = "output/compare/"+results_date+"/results_ARA_PPARA_Fibrosis.csv"

# %%
if Path.exists(Path((ARA_results_file))):
    results_df_ARA = pd.read_csv(ARA_results_file)
else:
    print("ARA not found")
if Path.exists(Path((TRAPI_results_file))):
    results_df_TRAPI = pd.read_csv(TRAPI_results_file)
else:
    print("TRAPI not found")
if Path.exists(Path((Cypher_Automat_results_file))):
    results_df_Cypher_Automat = pd.read_csv(Cypher_Automat_results_file)
else:
    print("Cypher (Automat) not found")
if Path.exists(Path((Cypher_ROBOKOPKG_results_file))):
    results_df_Cypher_ROBOKOPKG = pd.read_csv(Cypher_ROBOKOPKG_results_file)
else:
    print("Cypher (ROBOKOP) not found")
if Path.exists(Path((exemplar_results_file))):
    results_df_exemplar = pd.read_csv(exemplar_results_file)
else:
    print("ExEmPLAR not found")
if Path.exists(Path((qbuilder_bio_entity_results_file))):
    results_df_qbuilder_bio_entity = pd.read_csv(qbuilder_bio_entity_results_file)
else:
    print("Question Builder (Biological Entity) not found")
if Path.exists(Path((qbuilder_blank_results_file))):
    results_df_qbuilder_blank = pd.read_csv(qbuilder_blank_results_file)
else:
    print("Question Builder (blank middle) not found")
# if Path.exists(Path((ARA_PPARA_Fibrosis_results_file))):
#     results_df_ARA_PPARA_Fibrosis = pd.read_csv(ARA_PPARA_Fibrosis_results_file)

# %%
# library and defining compare_results() function for later demo use
import matplotlib.pyplot as plt
import sys
from matplotlib_venn import venn2

def convert_node_list_to_df(input_list):
    nodes = ['n00','n01','n02']
    results_df = pd.DataFrame(columns = nodes)
    
    dict_list = []
    for item_combined in input_list:
        item_list = item_combined.split("|")
        dict_to_add = {}
        for i in range(len(nodes)):
            dict_to_add[nodes[i]] = item_list[i]
        dict_list.append(dict_to_add)
        
    results_df = pd.concat([results_df,pd.DataFrame.from_records(dict_list)])
    display(results_df)

def compare_results(df1, df2, output_file_name, label1, label2):
    # This function takes the results of two dictionaries created by the TRAPI and Cypher query Jupyter notebooks and gets the following:
    #  -finds how many edges each set has in common, including having the same and different number of occurrences
    #  -finds edges exclusive to each set
    #  -plots a venn diagram representation of common edges and differences between sets
    #    -edges with the same predicate but different occurrences are treated as differences in the diagram
    # INPUT:
    #  -df1: dictionary with keys in the format of "node_label_1 -> predicate -> node_label_2" and corresponding values being occurrences within that set
    #  -df2: dictionary with keys in the format of "node_label_1 -> predicate -> node_label_2" and corresponding values being occurrences within that set
    #  -output_file_name: name of the file to write to with output results
    #  -label1/label2: Text and figure label for first and second input dictionaries, respectively
    # OUTPUT:
    #  -compare .txt file listing each of the following:
    #    -Common edges
    #    -Common edge predicates with different counts
    #    -Edges exclusive to the first input dictionary
    #    -Edges exclusive to the second input dictionary
    #  -Venn diagram showing number of common and different edges between the two input sets
    both_have_ids = False
    df1_has_ids = any(item in ['n00','n01','n02'] for item in df1.columns)
    df2_has_ids = any(item in ['n00','n01','n02'] for item in df2.columns)
    
    if df1_has_ids and df2_has_ids:
        both_have_ids = True
    
    if both_have_ids:
        col1 = df1.apply(lambda row: '|'.join([row['n00'],row['n01'],row['n02']]), axis=1)
        col2 = df2.apply(lambda row: '|'.join([row['n00'],row['n01'],row['n02']]), axis=1)
    else:
        col1 = df1.apply(lambda row: '|'.join([row['n00_name'],row['n01_name'],row['n02_name']]), axis=1)
        col2 = df2.apply(lambda row: '|'.join([row['n00_name'],row['n01_name'],row['n02_name']]), axis=1)

    pathways_in_common_list = list(set(col1) & set(col2))
    pathways_col1_list = list(set(col1) - set(col2))
    pathways_col2_list = list(set(col2) - set(col1))
    
    print("Node pathways in common:\n")
    convert_node_list_to_df(pathways_in_common_list)
    print(f"\nNode pathways in {label1} only:\n")
    convert_node_list_to_df(pathways_col1_list)
    print(f"\nNode pathways in {label2} only:\n")
    convert_node_list_to_df(pathways_col2_list)
    
    with open(output_file_name, "w") as f:
        f.write("Common pathways:\n")
        for pathway in pathways_in_common_list:
            f.write(pathway)
            f.write("\n")
        f.write(f"\n{label1} only:\n")
        for pathway in pathways_col1_list:
            f.write(pathway)
            f.write("\n")
        f.write(f"\n{label2} only:\n")
        for pathway in pathways_col2_list:
            f.write(pathway)
            f.write("\n")
    
    venn2(subsets = (len(pathways_col1_list), len(pathways_col2_list), len(pathways_in_common_list)), set_labels = (label1, label2))
    plt.savefig(output_file_name.replace(".txt","_venn.png"))
    plt.show()
    
    col3 = col1.value_counts()
    col4 = col2.value_counts()
        
    df_merge_input = pd.DataFrame([col3,col4]).T
    df_merge_input.columns = [label1,label2]
    df_merge_input[label1][df_merge_input[label1].isnull()] = 0
    df_merge_input[label2][df_merge_input[label2].isnull()] = 0
    df_merge_input_label1 = df_merge_input[(df_merge_input[label1] > 0) & (df_merge_input[label2] == 0)]
    df_merge_input_label2 = df_merge_input[(df_merge_input[label1] == 0) & (df_merge_input[label2] > 0)]
    df_merge_input_common = df_merge_input[(df_merge_input[label1] > 0) & (df_merge_input[label2] > 0)]
    df_merge_input_common['set_difference'] = df_merge_input_common[label2] - df_merge_input_common[label1]
    df_merge_input_diff = df_merge_input[(df_merge_input[label1] == 0) | (df_merge_input[label2] == 0)]
    df_merge_input_diff['set_difference'] = df_merge_input_diff[label2] - df_merge_input_diff[label1]
    print(f"Number of common pathways: {len(df_merge_input_common['set_difference'])}")
    print(f"Number pathways in {label1} alone: {len(df_merge_input_label1[label1])}")
    print(f"Number pathways in {label2} alone: {len(df_merge_input_label2[label2])}")
    # display(df_merge_input_common)
    display(df_merge_input_label1)
    display(df_merge_input_label2)

    y = df_merge_input_diff['set_difference']
    x = df_merge_input_diff.index.values.tolist()
    plt.figure()
    plt.barh(x,y)
    plt.gca().invert_yaxis()
    plt.xlabel(f'{label1} vs {label2}')
    max_set_difference = max(df_merge_input_diff['set_difference'])
    min_set_difference = min(df_merge_input_diff['set_difference'])
    plt.xlim([min(-3,min_set_difference),max(3,max_set_difference)])
    plt.savefig(output_file_name.replace(".txt","_diffplot.png"), bbox_inches="tight")

# %%
pd.set_option('max_colwidth', 100)

# %%
# ARA and Cypher (robokopkg) sets
output_file_name = os.path.join(write_dir_compare,"compare_ara_vs_cypher-robokopkg.txt")
compare_results(results_df_ARA,results_df_Cypher_ROBOKOPKG, output_file_name, "ARA", "Cypher (ROBOKOPKG)")
# Out:
# Node pathways in common:
#                    n00            n01            n02
# 0      NCBIGene:133522   NCBIGene:213     HP:0001395
# 1      NCBIGene:133522  NCBIGene:6347     HP:0001395
# 2   UniProtKB:Q9UBK2-1   NCBIGene:183     HP:0001395
# 3       NCBIGene:10891  NCBIGene:2200     HP:0001395
# 4       NCBIGene:80205   NCBIGene:183  MONDO:0018840
# ..                 ...            ...            ...
# 88       NCBIGene:5465  NCBIGene:4313     HP:0001395
# 89  UniProtKB:Q07869-1  NCBIGene:3875     HP:0001395
# 90       NCBIGene:5465  MONDO:0005154  MONDO:0018840
# 91     NCBIGene:133522   NCBIGene:405     HP:0001395
# 92  UniProtKB:Q07869-1   NCBIGene:866     HP:0001395
#
# [93 rows x 3 columns]
# Node pathways in ARA only:
#                n00            n01            n02
# 0  NCBIGene:133522  NCBIGene:5972     HP:0001395
# 1  NCBIGene:133522  NCBIGene:6927  MONDO:0018840
# 2    NCBIGene:5465  NCBIGene:9104     HP:0001395
# 3   NCBIGene:10891  NCBIGene:5972     HP:0001395
# 4  NCBIGene:133522  NCBIGene:5972  MONDO:0018840
# 5   NCBIGene:10891  NCBIGene:5972  MONDO:0018840
# 6   NCBIGene:10891  NCBIGene:6927  MONDO:0018840
# Node pathways in Cypher (ROBOKOPKG) only:
# Empty DataFrame
# Columns: [n00, n01, n02]
# Index: []
# Number of common pathways: 93
# Number pathways in ARA alone: 7
# Number pathways in Cypher (ROBOKOPKG) alone: 0
# C:\Users\dnwilliams\AppData\Local\Temp\ipykernel_4636\2799798396.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_merge_input_common['set_difference'] = df_merge_input_common[label2] - df_merge_input_common[label1]
# C:\Users\dnwilliams\AppData\Local\Temp\ipykernel_4636\2799798396.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_merge_input_diff['set_difference'] = df_merge_input_diff[label2] - df_merge_input_diff[label1]
#                                              ARA  Cypher (ROBOKOPKG)
# NCBIGene:133522|NCBIGene:6927|MONDO:0018840  2.0                 0.0
# NCBIGene:10891|NCBIGene:6927|MONDO:0018840   2.0                 0.0
# NCBIGene:133522|NCBIGene:5972|MONDO:0018840  2.0                 0.0
# NCBIGene:10891|NCBIGene:5972|MONDO:0018840   2.0                 0.0
# NCBIGene:5465|NCBIGene:9104|HP:0001395       2.0                 0.0
# NCBIGene:133522|NCBIGene:5972|HP:0001395     1.0                 0.0
# NCBIGene:10891|NCBIGene:5972|HP:0001395      1.0                 0.0
# Empty DataFrame
# Columns: [ARA, Cypher (ROBOKOPKG)]
# Index: []

# %%
# ARA and Cypher (automat) sets
output_file_name = os.path.join(write_dir_compare,"compare_ara_vs_cypher-automat.txt")
compare_results(results_df_ARA,results_df_Cypher_Automat, output_file_name, "ARA", "Cypher (Automat)")
# Out:
# Node pathways in common:
#                                                                    n00  \
# 0                                                                PPARA
# 1                                                                PPARA
# 2                                                             PPARGC1A
# 3   peroxisome proliferator-activated receptor alpha isoform 1 (human)
# 4                                                                PPARA
# ..                                                                 ...
# 95  peroxisome proliferator-activated receptor alpha isoform 1 (human)
# 96                                                               PPARA
# 97                                                            PPARGC1B
# 98                                                               PPARA
# 99                                                               PPARA
#
#        n01                                   n02
# 0     CCN2                      Hepatic fibrosis
# 1    VEGFA                      Hepatic fibrosis
# 2     MMP2                      Hepatic fibrosis
# 3   CYP2R1                      Hepatic fibrosis
# 4    PKHD1  isolated congenital hepatic fibrosis
# ..     ...                                   ...
# 95      CP                      Hepatic fibrosis
# 96     IL6                      Hepatic fibrosis
# 97   STAT1                      Hepatic fibrosis
# 98   THBS1  isolated congenital hepatic fibrosis
# 99     ALB                      Hepatic fibrosis
#
# [100 rows x 3 columns]
# Node pathways in ARA only:
# Empty DataFrame
# Columns: [n00, n01, n02]
# Index: []
# Node pathways in Cypher (Automat) only:
# Empty DataFrame
# Columns: [n00, n01, n02]
# Index: []
# Number of common pathways: 100
# Number pathways in ARA alone: 0
# Number pathways in Cypher (Automat) alone: 0
# Empty DataFrame
# Columns: [ARA, Cypher (Automat)]
# Index: []
# Empty DataFrame
# Columns: [ARA, Cypher (Automat)]
# Index: []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [25], line 3
#       1 # ARA and Cypher (automat) sets
#       2 output_file_name = os.path.join(write_dir_compare,"compare_ara_vs_cypher-automat.txt")
# ----> 3 compare_results(results_df_ARA,results_df_Cypher_Automat, output_file_name, "ARA", "Cypher (Automat)")
#
# Cell In [21], line 108, in compare_results(df1, df2, output_file_name, label1, label2)
#     106 plt.gca().invert_yaxis()
#     107 plt.xlabel(f'{label1} vs {label2}')
# --> 108 max_set_difference = max(df_merge_input_diff['set_difference'])
#     109 min_set_difference = min(df_merge_input_diff['set_difference'])
#     110 plt.xlim([min(-3,min_set_difference),max(3,max_set_difference)])
#
# ValueError: max() arg is an empty sequence

# %%
# ARA and TRAPI
output_file_name = os.path.join(write_dir_compare,"compare_ara_vs_trapi.txt")
compare_results(results_df_ARA,results_df_TRAPI, output_file_name, "ARA", "TRAPI")
# Out:
# Node pathways in common:
#                                                                    n00  \
# 0                                                                PPARA
# 1                                                                PPARA
# 2                                                             PPARGC1A
# 3   peroxisome proliferator-activated receptor alpha isoform 1 (human)
# 4                                                                PPARA
# ..                                                                 ...
# 95  peroxisome proliferator-activated receptor alpha isoform 1 (human)
# 96                                                               PPARA
# 97                                                            PPARGC1B
# 98                                                               PPARA
# 99                                                               PPARA
#
#        n01                                   n02
# 0     CCN2                      Hepatic fibrosis
# 1    VEGFA                      Hepatic fibrosis
# 2     MMP2                      Hepatic fibrosis
# 3   CYP2R1                      Hepatic fibrosis
# 4    PKHD1  isolated congenital hepatic fibrosis
# ..     ...                                   ...
# 95      CP                      Hepatic fibrosis
# 96     IL6                      Hepatic fibrosis
# 97   STAT1                      Hepatic fibrosis
# 98   THBS1  isolated congenital hepatic fibrosis
# 99     ALB                      Hepatic fibrosis
#
# [100 rows x 3 columns]
# Node pathways in ARA only:
# Empty DataFrame
# Columns: [n00, n01, n02]
# Index: []
# Node pathways in TRAPI only:
# Empty DataFrame
# Columns: [n00, n01, n02]
# Index: []
# Number of common pathways: 100
# Number pathways in ARA alone: 0
# Number pathways in TRAPI alone: 0
# Empty DataFrame
# Columns: [ARA, TRAPI]
# Index: []
# Empty DataFrame
# Columns: [ARA, TRAPI]
# Index: []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [26], line 3
#       1 # ARA and TRAPI
#       2 output_file_name = os.path.join(write_dir_compare,"compare_ara_vs_trapi.txt")
# ----> 3 compare_results(results_df_ARA,results_df_TRAPI, output_file_name, "ARA", "TRAPI")
#
# Cell In [21], line 108, in compare_results(df1, df2, output_file_name, label1, label2)
#     106 plt.gca().invert_yaxis()
#     107 plt.xlabel(f'{label1} vs {label2}')
# --> 108 max_set_difference = max(df_merge_input_diff['set_difference'])
#     109 min_set_difference = min(df_merge_input_diff['set_difference'])
#     110 plt.xlim([min(-3,min_set_difference),max(3,max_set_difference)])
#
# ValueError: max() arg is an empty sequence

# %%
# Cypher (automat) and Cypher (robokopkg) sets
output_file_name = os.path.join(write_dir_compare,"compare_cypher-automat_vs_cypher-robokopkg.txt")
compare_results(results_df_Cypher_Automat,results_df_Cypher_ROBOKOPKG, output_file_name, "Cypher (Automat)", "Cypher (ROBOKOPKG)")
# Out:
# Node pathways in common:
#                                                                    n00  \
# 0                                                                PPARA
# 1                                                                PPARA
# 2                                                             PPARGC1A
# 3   peroxisome proliferator-activated receptor alpha isoform 1 (human)
# 4                                                                PPARA
# ..                                                                 ...
# 88  peroxisome proliferator-activated receptor alpha isoform 1 (human)
# 89                                                               PPARA
# 90                                                            PPARGC1B
# 91                                                               PPARA
# 92                                                               PPARA
#
#        n01                                   n02
# 0     CCN2                      Hepatic fibrosis
# 1    VEGFA                      Hepatic fibrosis
# 2     MMP2                      Hepatic fibrosis
# 3   CYP2R1                      Hepatic fibrosis
# 4    PKHD1  isolated congenital hepatic fibrosis
# ..     ...                                   ...
# 88      CP                      Hepatic fibrosis
# 89     IL6                      Hepatic fibrosis
# 90   STAT1                      Hepatic fibrosis
# 91   THBS1  isolated congenital hepatic fibrosis
# 92     ALB                      Hepatic fibrosis
#
# [93 rows x 3 columns]
# Node pathways in Cypher (Automat) only:
#         n00    n01                                   n02
# 0  PPARGC1B  HNF1A  isolated congenital hepatic fibrosis
# 1  PPARGC1A  HNF1A  isolated congenital hepatic fibrosis
# 2  PPARGC1A    REN  isolated congenital hepatic fibrosis
# 3  PPARGC1B    REN  isolated congenital hepatic fibrosis
# 4  PPARGC1A    REN                      Hepatic fibrosis
# 5     PPARA    RGN                      Hepatic fibrosis
# 6  PPARGC1B    REN                      Hepatic fibrosis
# Node pathways in Cypher (ROBOKOPKG) only:
# Empty DataFrame
# Columns: [n00, n01, n02]
# Index: []
# Number of common pathways: 93
# Number pathways in Cypher (Automat) alone: 7
# Number pathways in Cypher (ROBOKOPKG) alone: 0
# C:\Users\dnwilliams\AppData\Local\Temp\ipykernel_4636\1460531569.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_merge_input_common['set_difference'] = df_merge_input_common[label2] - df_merge_input_common[label1]
# C:\Users\dnwilliams\AppData\Local\Temp\ipykernel_4636\1460531569.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_merge_input_diff['set_difference'] = df_merge_input_diff[label2] - df_merge_input_diff[label1]
#                                                      Cypher (Automat)  \
# PPARA|RGN|Hepatic fibrosis                                        1.0
# PPARGC1B|HNF1A|isolated congenital hepatic fibrosis               1.0
# PPARGC1A|REN|Hepatic fibrosis                                     1.0
# PPARGC1A|REN|isolated congenital hepatic fibrosis                 1.0
# PPARGC1A|HNF1A|isolated congenital hepatic fibrosis               1.0
# PPARGC1B|REN|isolated congenital hepatic fibrosis                 1.0
# PPARGC1B|REN|Hepatic fibrosis                                     1.0
#
#                                                      Cypher (ROBOKOPKG)
# PPARA|RGN|Hepatic fibrosis                                          0.0
# PPARGC1B|HNF1A|isolated congenital hepatic fibrosis                 0.0
# PPARGC1A|REN|Hepatic fibrosis                                       0.0
# PPARGC1A|REN|isolated congenital hepatic fibrosis                   0.0
# PPARGC1A|HNF1A|isolated congenital hepatic fibrosis                 0.0
# PPARGC1B|REN|isolated congenital hepatic fibrosis                   0.0
# PPARGC1B|REN|Hepatic fibrosis                                       0.0
# Empty DataFrame
# Columns: [Cypher (Automat), Cypher (ROBOKOPKG)]
# Index: []

# %%
# ExEmPLAR and Cypher (robokopkg) sets
results_df_exemplar_names = results_df_exemplar[[c for c in results_df_exemplar.columns if "_name" in c]]
output_file_name = os.path.join(write_dir_compare,"compare_exemplar_vs_cypher-robokopkg.txt")
compare_results(results_df_exemplar_names,results_df_Cypher_ROBOKOPKG, output_file_name, "ExEmPLAR", "Cypher (ROBOKOPKG)")

# %%
# ExEmPLAR and Cypher (automat) sets
results_df_exemplar_names = results_df_exemplar[[c for c in results_df_exemplar.columns if "_name" in c]]
output_file_name = os.path.join(write_dir_compare,"compare_exemplar_vs_cypher-automat.txt")
compare_results(results_df_exemplar_names,results_df_Cypher_Automat, output_file_name, "ExEmPLAR", "Cypher (Automat)")

# %%
# ARA and Question Builder (Biological Entity) sets
output_file_name = os.path.join(write_dir_compare,"compare_ARA_vs_qbuilder_bio_entity.txt")
compare_results(results_df_ARA,results_df_qbuilder_bio_entity, output_file_name, "ARA", "Question-Builder (Biological Entity)")

# %%
# ARA (PPARA-Hepatic Fibrosis) and Question Builder (Biological Entity) sets
output_file_name = os.path.join(write_dir_compare,"compare_ARA_PPARA_Fibrosis_vs_qbuilder_bio_entity.txt")
compare_results(results_df_ARA_PPARA_Fibrosis,results_df_qbuilder_bio_entity, output_file_name, "ARA (PPARA-Hepatic Fibrosis)", "Question-Builder (Biological Entity)")

# %%
# ARA and Question Builder (Blank intermediate) sets
output_file_name = os.path.join(write_dir_compare,"compare_ARA_vs_qbuilder_blank.txt")
compare_results(results_df_ARA,results_df_qbuilder_blank, output_file_name, "ARA", "Question-Builder (Blank intermediate)")

# %%
# Cypher ROBOKOPKG comparison (for loop vs single line)
output_file_name = os.path.join(write_dir_compare,"compare_robokopkg_cypher_single_vs_for_loop.txt")
compare_results(results_df_Cypher_ROBOKOPKG,results_df_Cypher_ROBOKOPKG_single, output_file_name, "For Loop", "Single query")
