# %%
# Parameter inputs
aragorn_submit_url = "https://aragorn-u24.apps.renci.org/robokop/query"
input_search_string = 'ppara'
output_search_string = 'liver fibrosis'

# Initializing directory to write
from datetime import datetime
from pathlib import Path

now = datetime.now()
dt_string = now.strftime("%Y-%m-%d_%H%M%S")
write_dir = Path("output/TRAPI",str(dt_string))
write_dir.mkdir(parents=True, exist_ok=True)

# %%
import requests
import json
import pprint
pp = pprint.PrettyPrinter(indent=5)

# %% [markdown]
# This notebook provides a deeper dive into the TRAPI options for querying the ROBOKOP KG using the ARA functionality. It assumes you are familiar with the concepts covered in `HelloRobokop.ipynb`.  This follows the same format and process as in `HelloRobokop_TRAPI.ipynb` except using the API based upon Automomous Relay Agent (ARA) methodology developed as part of the NIH Biomedical Data Translator to query the ROBOKOP knowledgegraph, which returns a score for each result.
#
# TRAPI Documentation: https://github.com/NCATSTranslator/ReasonerAPI
#
# Most TRAPI documents contain a `message` key.  Within that `message` are a `query_graph` denoting the user query,
# a `knowledge_graph` consisting of the union of all nodes and edges that match the `query_graph` pattern, and a list of `results` that bind `query_graph` elements to `knowledge_graph` elements.
#
# The following message contains only a `query_graph`.  This query graph consists of 3 nodes connected together in a line.   Two of the nodes (`n00` and `n02`) have specified identifiers, while the middle node of the line does not.  Rather the middle node has a list of `categories` that are acceptable.
#
# For a researcher who is starting from a `name` who wants to use TRAPI, they can use the Name Resolver tool to get the identifers for the nodes.  This is illustrated in the `HelloRobokop_TRAPI_multiple_IDs.ipynb` notebook.
#
# This query asks "Find me a Biological Process or Activity, or a Gene, or a Pathway that is related to both `PUBCHEM.COMPOUND:644073` (Buprenorphine) and `HP:0001337` (Tremor).

# %%
results = requests.post(f'https://name-resolution-sri.renci.org/lookup?string={input_search_string}&offset=0&limit=10')
results_json = results.json()
#print(json.dumps(results_json,indent=4))
input_node_id_list = list(results_json.keys())
print(input_node_id_list)
# Out:
# ['UniProtKB:P37230', 'UniProtKB:Q07869', 'UniProtKB:Q95N78', 'PR:000013056', 'UniProtKB:P23204', 'NCBIGene:19013', 'NCBIGene:25747', 'NCBIGene:5465', 'NCBIGene:557714', 'NCBIGene:30755']

# %%
results = requests.post(f'https://name-resolution-sri.renci.org/lookup?string={output_search_string}&offset=0&limit=10')
results_json = results.json()
#print(json.dumps(results_json,indent=4))
output_node_id_list = list(results_json.keys())
print(output_node_id_list)
# Out:
# ['HP:0001395', 'UMLS:C4227681', 'UMLS:C4034373', 'UMLS:C5189427', 'UMLS:C0544816', 'MONDO:0100430', 'MONDO:0018840', 'UMLS:C1397317', 'UMLS:C4068302', 'UMLS:C4481250']

# %%
query={
    "message": {
      "query_graph": {
        "edges": {
          "e00": {
            "subject": "n00",
              "object": "n01",
          "predicates":["biolink:related_to"]
          },
          "e01": {
            "subject": "n01",
              "object": "n02",
          "predicates":["biolink:related_to"]
          }
        },
        "nodes": {
          "n00": {
            "ids": input_node_id_list, #['NCBIGene:5465'], #
            "categories": ["biolink:GeneOrGeneProduct"]
          },
          "n01": {
              "categories": ["biolink:BiologicalEntity"]
          },
          "n02": {
            "ids": output_node_id_list, #["HP:0001395"],
            "categories": ["biolink:DiseaseOrPhenotypicFeature"]
          }
        }
      }
    }
  }

# %% [markdown]
# This query can be sent directly to the ROBOKOP KG hosted in the Automat system like this:

# %%
response = requests.post(aragorn_submit_url,json=query)
print(response.status_code)
number_pathway_results = len(response.json()['message']['results'])
print(len(response.json()['message']['results']))
# Out:
# 200
# 136

# %% [markdown]
# The response in JSON form is a python dictionary with three main keys, the `message`, `log_level`, and `workflow`.  The `message` property contains the `query_graph`, `knowledge_graph`, and `results` from the query.

# %%
print(response.json().keys())
print(response.json()['message'].keys())

query_out = response.json()['message']['query_graph']
kg = response.json()['message']['knowledge_graph']
results = response.json()['message']['results']
# Out:
# dict_keys(['message', 'logs', 'status', 'pid'])
# dict_keys(['query_graph', 'knowledge_graph', 'results'])

# %% [markdown]
# The original, submitted query graph with additional fields is returned with the `message` property in the `query_graph` property.
#
# The code below shows the changes between the submitted query graph and the results query graph. The results includes additional attributes such as `knowledge_type`, `attribute_constraints`, and `qualifier_constraints`.  These attributes can be explicitly defined when submitting to automat such that further filtering can be done.  Because nothing was specified for these attributes in the submitted query graph, their values in the returned query graph are blank.

# %%
edges = ["e00", "e01"]
nodes = ["n00", "n01", "n02"]

#print(nodes)
#print(edges)
#pp.pprint(query)
#pp.pprint(query_out)
#pp.pprint(results)
#pp.pprint(kg.keys())
#next(iter( kg['nodes'].items() ))
#next(iter( kg['edges'].items() ))
#pp.pprint(results[0])

# %% [markdown]
# The `results` property contains pathways resulting from the query message. Each pathway is organized into edge_bindings and node bindings and contains results for the edges and nodes specified in the query message.  Results are defined using the node and edge identifiers. The attributes for those nodes and edges (including the names) are available via the `knowledge_graph` component of the `message` section of the response.

# %% [markdown]
# The code below writes out nodes from our `results`, but NOT the edges connecting the nodes.

# %%
import pandas as pd
import os

cols = []
for node in sorted(results[0]['node_bindings'].keys()):
    cols.append(node)
    cols.append(node + '_name')
results_df = pd.DataFrame(columns = cols)

results_list = []
for result in results:
    result_dict = {}
    for node in sorted(result['node_bindings'].keys()):
        node_id = result['node_bindings'][node][0]['id']
        result_dict[node] = node_id
        result_dict[node + '_name'] = kg['nodes'][node_id]['name']

    results_list.append(pd.DataFrame([result_dict]))
results_df = pd.concat(results_list)
display(results_df)
results_df.to_csv(os.path.join(write_dir,'results_TRAPI.csv'), index=False)

combined_node_list = ["_".join([row[1].replace(" ", "_"), row[3].replace(" ", "_"), row[5].replace(" ", "_")]) for row in results_df[cols].to_numpy()]
pp.pprint(combined_node_list)
# Out:
#                    n00                                           n00_name  \
# 0        NCBIGene:5465                                              PPARA
# 0        NCBIGene:5465                                              PPARA
# 0        NCBIGene:5465                                              PPARA
# 0        NCBIGene:5465                                              PPARA
# 0        NCBIGene:5465                                              PPARA
# ..                 ...                                                ...
# 0   UniProtKB:Q07869-1  peroxisome proliferator-activated receptor alp...
# 0   UniProtKB:Q07869-1  peroxisome proliferator-activated receptor alp...
# 0   UniProtKB:Q07869-1  peroxisome proliferator-activated receptor alp...
# 0   UniProtKB:Q07869-1  peroxisome proliferator-activated receptor alp...
# 0   UniProtKB:Q07869-1  peroxisome proliferator-activated receptor alp...
#
#               n01  n01_name         n02          n02_name
# 0   NCBIGene:4088     SMAD3  HP:0001395  Hepatic fibrosis
# 0   NCBIGene:4088     SMAD3  HP:0001395  Hepatic fibrosis
# 0   NCBIGene:7040     TGFB1  HP:0001395  Hepatic fibrosis
# 0   NCBIGene:7040     TGFB1  HP:0001395  Hepatic fibrosis
# 0   NCBIGene:6347      CCL2  HP:0001395  Hepatic fibrosis
# ..            ...       ...         ...               ...
# 0   NCBIGene:3484    IGFBP1  HP:0001395  Hepatic fibrosis
# 0   NCBIGene:1269      CNR2  HP:0001395  Hepatic fibrosis
# 0   NCBIGene:1269      CNR2  HP:0001395  Hepatic fibrosis
# 0    NCBIGene:866  SERPINA6  HP:0001395  Hepatic fibrosis
# 0    NCBIGene:866  SERPINA6  HP:0001395  Hepatic fibrosis
#
# [136 rows x 6 columns]
# [    'PPARA_SMAD3_Hepatic_fibrosis',
#      'PPARA_SMAD3_Hepatic_fibrosis',
#      'PPARA_TGFB1_Hepatic_fibrosis',
#      'PPARA_TGFB1_Hepatic_fibrosis',
#      'PPARA_CCL2_Hepatic_fibrosis',
#      'PPARA_CCL2_Hepatic_fibrosis',
#      'PPARA_ALB_Hepatic_fibrosis',
#      'PPARA_ALB_Hepatic_fibrosis',
#      'PPARA_HGF_Hepatic_fibrosis',
#      'PPARA_HGF_Hepatic_fibrosis',
#      'PPARA_liver_disorder_Hepatic_fibrosis',
#      'PPARA_liver_disorder_Hepatic_fibrosis',
#      'PPARA_MMP2_Hepatic_fibrosis',
#      'PPARA_MMP2_Hepatic_fibrosis',
#      'PPARA_IL6_Hepatic_fibrosis',
#      'PPARA_IL6_Hepatic_fibrosis',
#      'PPARA_liver_disorder_isolated_congenital_hepatic_fibrosis',
#      'PPARA_liver_disorder_isolated_congenital_hepatic_fibrosis',
#      'PPARA_liver_disorder_isolated_congenital_hepatic_fibrosis',
#      'PPARA_liver_disorder_isolated_congenital_hepatic_fibrosis',
#      'PPARA_CCN2_Hepatic_fibrosis',
#      'PPARA_CCN2_Hepatic_fibrosis',
#      'PPARA_F2_Hepatic_fibrosis',
#      'PPARA_F2_Hepatic_fibrosis',
#      'PPARA_liver_disorder_Periportal_fibrosis',
#      'PPARA_liver_disorder_Periportal_fibrosis',
#      'PPARA_STAT1_Hepatic_fibrosis',
#      'PPARA_STAT1_Hepatic_fibrosis',
#      'PPARA_NFE2L2_Hepatic_fibrosis',
#      'PPARA_NFE2L2_Hepatic_fibrosis',
#      'PPARA_cirrhosis_of_liver_isolated_congenital_hepatic_fibrosis',
#      'PPARA_cirrhosis_of_liver_isolated_congenital_hepatic_fibrosis',
#      'PPARA_cirrhosis_of_liver_isolated_congenital_hepatic_fibrosis',
#      'PPARA_cirrhosis_of_liver_isolated_congenital_hepatic_fibrosis',
#      'PPARA_CP_Hepatic_fibrosis',
#      'PPARA_CP_Hepatic_fibrosis',
#      'PPARA_REN_Hepatic_fibrosis',
#      'PPARA_REN_Hepatic_fibrosis',
#      'PPARA_COL1A1_Hepatic_fibrosis',
#      'PPARA_COL1A1_Hepatic_fibrosis',
#      'PPARA_SPP1_Hepatic_fibrosis',
#      'PPARA_SPP1_Hepatic_fibrosis',
#      'PPARA_VEGFA_Hepatic_fibrosis',
#      'PPARA_VEGFA_Hepatic_fibrosis',
#      'PPARA_AGT_Hepatic_fibrosis',
#      'PPARA_AGT_Hepatic_fibrosis',
#      'PPARA_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARA_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARA_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARA_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARA_TGFB1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_TGFB1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_TGFB1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_TGFB1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_TGFBR1_Hepatic_fibrosis',
#      'PPARA_TGFBR1_Hepatic_fibrosis',
#      'PPARA_CTNNB1_Hepatic_fibrosis',
#      'PPARA_CTNNB1_Hepatic_fibrosis',
#      'PPARA_THBS1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_THBS1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_THBS1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_THBS1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_REN_isolated_congenital_hepatic_fibrosis',
#      'PPARA_REN_isolated_congenital_hepatic_fibrosis',
#      'PPARA_REN_isolated_congenital_hepatic_fibrosis',
#      'PPARA_REN_isolated_congenital_hepatic_fibrosis',
#      'PPARA_PKHD1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_PKHD1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_PKHD1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_PKHD1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_THBS1_Hepatic_fibrosis',
#      'PPARA_THBS1_Hepatic_fibrosis',
#      'PPARA_ABCB4_Hepatic_fibrosis',
#      'PPARA_ABCB4_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CCL2_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CCL2_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_F2_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_F2_Hepatic_fibrosis',
#      'PPARA_COL1A2_Hepatic_fibrosis',
#      'PPARA_COL1A2_Hepatic_fibrosis',
#      'PPARA_PLAU_Hepatic_fibrosis',
#      'PPARA_PLAU_Hepatic_fibrosis',
#      'PPARA_F2R_Hepatic_fibrosis',
#      'PPARA_F2R_Hepatic_fibrosis',
#      'PPARA_ARRB1_Hepatic_fibrosis',
#      'PPARA_ARRB1_Hepatic_fibrosis',
#      'PPARA_FLT1_Hepatic_fibrosis',
#      'PPARA_FLT1_Hepatic_fibrosis',
#      'PPARA_FGF2_Hepatic_fibrosis',
#      'PPARA_FGF2_Hepatic_fibrosis',
#      'PPARA_ARNT_Hepatic_fibrosis',
#      'PPARA_ARNT_Hepatic_fibrosis',
#      'PPARA_LGALS1_Hepatic_fibrosis',
#      'PPARA_LGALS1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CP_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CP_Hepatic_fibrosis',
#      'PPARA_NPC1_Hepatic_fibrosis',
#      'PPARA_NPC1_Hepatic_fibrosis',
#      'PPARA_CNR2_Hepatic_fibrosis',
#      'PPARA_CNR2_Hepatic_fibrosis',
#      'PPARA_RGN_Hepatic_fibrosis',
#      'PPARA_RGN_Hepatic_fibrosis',
#      'PPARA_HNF1A_isolated_congenital_hepatic_fibrosis',
#      'PPARA_HNF1A_isolated_congenital_hepatic_fibrosis',
#      'PPARA_HNF1A_isolated_congenital_hepatic_fibrosis',
#      'PPARA_HNF1A_isolated_congenital_hepatic_fibrosis',
#      'PPARA_NF1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_NF1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_NF1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_NF1_isolated_congenital_hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_isolated_congenital_hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_isolated_congenital_hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_isolated_congenital_hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARA_VIM_Hepatic_fibrosis',
#      'PPARA_VIM_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_LOX_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_LOX_Hepatic_fibrosis',
#      'PPARA_liver_disorder_Hepatic_bridging_fibrosis',
#      'PPARA_liver_disorder_Hepatic_bridging_fibrosis',
#      'PPARA_liver_disorder_fibrotic_liver_disease',
#      'PPARA_liver_disorder_fibrotic_liver_disease',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP27A1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP27A1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP2R1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP2R1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_KRT18_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_KRT18_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_IGFBP1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_IGFBP1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CNR2_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CNR2_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_SERPINA6_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_SERPINA6_Hepatic_fibrosis']

# %% [markdown]
# The edge IDs are then retrieved from the `results` and used to find the corresponding `predicate` label in the `knowledge_graph`. Two nodes can have more than one edge connecting them because each edge represents a distinct type of association derived from a single data source. Because of this, the number of rows in this report may differ from the set of results above. For an answer with three nodes such as this one, there will be at least one edge between nodes 1 and 2 as well as nodes 2 and 3. The direction of the edge connecting two nodes can differ as well, such as for "Buprenorphine" and "CYP2D6" below. Sometimes a single association type will be derived from multiple data sources. In the code below, we print a single edge for each association type and include the count of the number of data sources where that association was found. The following writes out all unique edges for each of the results in the format of `subject` -> `predicate` -> `object` and exports the information into a single file per `result`.

# %%
from collections import Counter
import json
import pprint
pp = pprint.PrettyPrinter(indent=5)

for i in range(number_pathway_results):
    print(f"Pathway result: {combined_node_list[i]}")
    edge_bindings = results[i]['edge_bindings']

    edge_ids = []
    for edge_name, edge_list in edge_bindings.items():
        edge_ids.append({edge_name: [x['id'] for x in edge_list]})

    string_out_list = []
    for edge_dict in edge_ids:
        for edge_name, edge_list in edge_dict.items():
            for edge_id in edge_list:
                subject_id = kg['edges'][edge_id]['subject']
                subject = kg['nodes'][subject_id]['name']
                predicate = kg['edges'][edge_id]['predicate']
                object_id = kg['edges'][edge_id]['object']
                object = kg['nodes'][object_id]['name']
                string_out = f"{subject} -> {predicate} -> {object}"
                string_out_list.append(string_out)
    string_out_dict = dict(Counter(string_out_list).items())
    pp.pprint(string_out_dict)
    print("")
    
    with open(os.path.join(write_dir,combined_node_list[i]+".txt"), 'w') as convert_file:
        convert_file.write(json.dumps(string_out_dict))
# Out:
# Pathway result: PPARA_SMAD3_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> SMAD3': 1,
#      'PPARA -> biolink:regulates -> SMAD3': 1,
#      'SMAD3 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'SMAD3 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'SMAD3 -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_SMAD3_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> SMAD3': 1,
#      'PPARA -> biolink:regulates -> SMAD3': 1,
#      'SMAD3 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'SMAD3 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'SMAD3 -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_TGFB1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> TGFB1': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> TGFB1': 1,
#      'PPARA -> biolink:regulates -> TGFB1': 1,
#      'TGFB1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'TGFB1 -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_TGFB1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> TGFB1': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> TGFB1': 1,
#      'PPARA -> biolink:regulates -> TGFB1': 1,
#      'TGFB1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'TGFB1 -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_CCL2_Hepatic_fibrosis
# {    'CCL2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CCL2 -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CCL2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> CCL2': 1,
#      'PPARA -> biolink:regulates -> CCL2': 1}
#
# Pathway result: PPARA_CCL2_Hepatic_fibrosis
# {    'CCL2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CCL2 -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CCL2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> CCL2': 1,
#      'PPARA -> biolink:regulates -> CCL2': 1}
#
# Pathway result: PPARA_ALB_Hepatic_fibrosis
# {    'ALB -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'ALB -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'ALB -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> ALB': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:directly_physically_interacts_with -> ALB': 1,
#      'PPARA -> biolink:regulates -> ALB': 1}
#
# Pathway result: PPARA_ALB_Hepatic_fibrosis
# {    'ALB -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'ALB -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'ALB -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> ALB': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:directly_physically_interacts_with -> ALB': 1,
#      'PPARA -> biolink:regulates -> ALB': 1}
#
# Pathway result: PPARA_HGF_Hepatic_fibrosis
# {    'HGF -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'HGF -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'HGF -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> HGF': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> HGF': 1}
#
# Pathway result: PPARA_HGF_Hepatic_fibrosis
# {    'HGF -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'HGF -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'HGF -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> HGF': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> HGF': 1}
#
# Pathway result: PPARA_liver_disorder_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> liver disorder': 1,
#      'Hepatic fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_liver_disorder_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> liver disorder': 1,
#      'Hepatic fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_MMP2_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> MMP2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'MMP2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'MMP2 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'MMP2 -> biolink:regulates -> PPARA': 1,
#      'PPARA -> biolink:regulates -> MMP2': 1}
#
# Pathway result: PPARA_MMP2_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> MMP2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'MMP2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'MMP2 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'MMP2 -> biolink:regulates -> PPARA': 1,
#      'PPARA -> biolink:regulates -> MMP2': 1}
#
# Pathway result: PPARA_IL6_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> IL6': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'IL6 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'IL6 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'IL6 -> biolink:regulates -> PPARA': 1,
#      'PPARA -> biolink:regulates -> IL6': 1}
#
# Pathway result: PPARA_IL6_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> IL6': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'IL6 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'IL6 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'IL6 -> biolink:regulates -> PPARA': 1,
#      'PPARA -> biolink:regulates -> IL6': 1}
#
# Pathway result: PPARA_liver_disorder_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> isolated congenital hepatic fibrosis': 1}
#
# Pathway result: PPARA_liver_disorder_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> isolated congenital hepatic fibrosis': 1}
#
# Pathway result: PPARA_liver_disorder_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> isolated congenital hepatic fibrosis': 1}
#
# Pathway result: PPARA_liver_disorder_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> isolated congenital hepatic fibrosis': 1}
#
# Pathway result: PPARA_CCN2_Hepatic_fibrosis
# {    'CCN2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CCN2 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'CCN2 -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CCN2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> CCN2': 1}
#
# Pathway result: PPARA_CCN2_Hepatic_fibrosis
# {    'CCN2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CCN2 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'CCN2 -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CCN2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> CCN2': 1}
#
# Pathway result: PPARA_F2_Hepatic_fibrosis
# {    'F2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'F2 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> F2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:interacts_with -> F2': 1,
#      'PPARA -> biolink:regulates -> F2': 1}
#
# Pathway result: PPARA_F2_Hepatic_fibrosis
# {    'F2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'F2 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> F2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:interacts_with -> F2': 1,
#      'PPARA -> biolink:regulates -> F2': 1}
#
# Pathway result: PPARA_liver_disorder_Periportal_fibrosis
# {    'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'Periportal fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Periportal fibrosis -> biolink:occurs_together_in_literature_with -> liver disorder': 1,
#      'Periportal fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_liver_disorder_Periportal_fibrosis
# {    'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'Periportal fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Periportal fibrosis -> biolink:occurs_together_in_literature_with -> liver disorder': 1,
#      'Periportal fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_STAT1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> STAT1': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> STAT1': 1,
#      'PPARA -> biolink:regulates -> STAT1': 1,
#      'STAT1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'STAT1 -> biolink:interacts_with -> PPARA': 1}
#
# Pathway result: PPARA_STAT1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> STAT1': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> STAT1': 1,
#      'PPARA -> biolink:regulates -> STAT1': 1,
#      'STAT1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'STAT1 -> biolink:interacts_with -> PPARA': 1}
#
# Pathway result: PPARA_NFE2L2_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> NFE2L2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'NFE2L2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'NFE2L2 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'NFE2L2 -> biolink:regulates -> PPARA': 1,
#      'PPARA -> biolink:regulates -> NFE2L2': 1}
#
# Pathway result: PPARA_NFE2L2_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> NFE2L2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'NFE2L2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'NFE2L2 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'NFE2L2 -> biolink:regulates -> PPARA': 1,
#      'PPARA -> biolink:regulates -> NFE2L2': 1}
#
# Pathway result: PPARA_cirrhosis_of_liver_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:contributes_to -> cirrhosis of liver': 1,
#      'cirrhosis of liver -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'cirrhosis of liver -> biolink:occurs_together_in_literature_with -> isolated congenital hepatic fibrosis': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:subclass_of -> cirrhosis of liver': 1}
#
# Pathway result: PPARA_cirrhosis_of_liver_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:contributes_to -> cirrhosis of liver': 1,
#      'cirrhosis of liver -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'cirrhosis of liver -> biolink:occurs_together_in_literature_with -> isolated congenital hepatic fibrosis': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:subclass_of -> cirrhosis of liver': 1}
#
# Pathway result: PPARA_cirrhosis_of_liver_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:contributes_to -> cirrhosis of liver': 1,
#      'cirrhosis of liver -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'cirrhosis of liver -> biolink:occurs_together_in_literature_with -> isolated congenital hepatic fibrosis': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:subclass_of -> cirrhosis of liver': 1}
#
# Pathway result: PPARA_cirrhosis_of_liver_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:contributes_to -> cirrhosis of liver': 1,
#      'cirrhosis of liver -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'cirrhosis of liver -> biolink:occurs_together_in_literature_with -> isolated congenital hepatic fibrosis': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:subclass_of -> cirrhosis of liver': 1}
#
# Pathway result: PPARA_CP_Hepatic_fibrosis
# {    'CP -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CP -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'CP -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CP': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> CP': 1}
#
# Pathway result: PPARA_CP_Hepatic_fibrosis
# {    'CP -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CP -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'CP -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CP': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> CP': 1}
#
# Pathway result: PPARA_REN_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> REN': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> REN': 1,
#      'PPARA -> biolink:regulates -> REN': 1,
#      'REN -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'REN -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_REN_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> REN': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> REN': 1,
#      'PPARA -> biolink:regulates -> REN': 1,
#      'REN -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'REN -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_COL1A1_Hepatic_fibrosis
# {    'COL1A1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'COL1A1 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> COL1A1': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> COL1A1': 1}
#
# Pathway result: PPARA_COL1A1_Hepatic_fibrosis
# {    'COL1A1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'COL1A1 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> COL1A1': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> COL1A1': 1}
#
# Pathway result: PPARA_SPP1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> SPP1': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> SPP1': 1,
#      'PPARA -> biolink:regulates -> SPP1': 2,
#      'SPP1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'SPP1 -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_SPP1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> SPP1': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> SPP1': 1,
#      'PPARA -> biolink:regulates -> SPP1': 2,
#      'SPP1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'SPP1 -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_VEGFA_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> VEGFA': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> VEGFA': 1,
#      'PPARA -> biolink:regulates -> VEGFA': 1,
#      'VEGFA -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'VEGFA -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_VEGFA_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> VEGFA': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> VEGFA': 1,
#      'PPARA -> biolink:regulates -> VEGFA': 1,
#      'VEGFA -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'VEGFA -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_AGT_Hepatic_fibrosis
# {    'AGT -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'AGT -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'AGT -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:interacts_with -> AGT': 1,
#      'PPARA -> biolink:regulates -> AGT': 1}
#
# Pathway result: PPARA_AGT_Hepatic_fibrosis
# {    'AGT -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'AGT -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'AGT -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:interacts_with -> AGT': 1,
#      'PPARA -> biolink:regulates -> AGT': 1}
#
# Pathway result: PPARA_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'AGT -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'AGT -> biolink:regulates -> PPARA': 1,
#      'PPARA -> biolink:interacts_with -> AGT': 1,
#      'PPARA -> biolink:regulates -> AGT': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'AGT -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'AGT -> biolink:regulates -> PPARA': 1,
#      'PPARA -> biolink:interacts_with -> AGT': 1,
#      'PPARA -> biolink:regulates -> AGT': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'AGT -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'AGT -> biolink:regulates -> PPARA': 1,
#      'PPARA -> biolink:interacts_with -> AGT': 1,
#      'PPARA -> biolink:regulates -> AGT': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'AGT -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'AGT -> biolink:regulates -> PPARA': 1,
#      'PPARA -> biolink:interacts_with -> AGT': 1,
#      'PPARA -> biolink:regulates -> AGT': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_TGFB1_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:occurs_together_in_literature_with -> TGFB1': 1,
#      'PPARA -> biolink:regulates -> TGFB1': 1,
#      'TGFB1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'TGFB1 -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> TGFB1': 1}
#
# Pathway result: PPARA_TGFB1_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:occurs_together_in_literature_with -> TGFB1': 1,
#      'PPARA -> biolink:regulates -> TGFB1': 1,
#      'TGFB1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'TGFB1 -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> TGFB1': 1}
#
# Pathway result: PPARA_TGFB1_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:occurs_together_in_literature_with -> TGFB1': 1,
#      'PPARA -> biolink:regulates -> TGFB1': 1,
#      'TGFB1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'TGFB1 -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> TGFB1': 1}
#
# Pathway result: PPARA_TGFB1_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:occurs_together_in_literature_with -> TGFB1': 1,
#      'PPARA -> biolink:regulates -> TGFB1': 1,
#      'TGFB1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'TGFB1 -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> TGFB1': 1}
#
# Pathway result: PPARA_TGFBR1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> TGFBR1': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> TGFBR1': 1,
#      'PPARA -> biolink:regulates -> TGFBR1': 1,
#      'TGFBR1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'TGFBR1 -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_TGFBR1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> TGFBR1': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> TGFBR1': 1,
#      'PPARA -> biolink:regulates -> TGFBR1': 1,
#      'TGFBR1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'TGFBR1 -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_CTNNB1_Hepatic_fibrosis
# {    'CTNNB1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CTNNB1 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'CTNNB1 -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CTNNB1': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> CTNNB1': 1}
#
# Pathway result: PPARA_CTNNB1_Hepatic_fibrosis
# {    'CTNNB1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CTNNB1 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'CTNNB1 -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CTNNB1': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> CTNNB1': 1}
#
# Pathway result: PPARA_THBS1_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:occurs_together_in_literature_with -> THBS1': 1,
#      'PPARA -> biolink:regulates -> THBS1': 1,
#      'THBS1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'THBS1 -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> THBS1': 1}
#
# Pathway result: PPARA_THBS1_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:occurs_together_in_literature_with -> THBS1': 1,
#      'PPARA -> biolink:regulates -> THBS1': 1,
#      'THBS1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'THBS1 -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> THBS1': 1}
#
# Pathway result: PPARA_THBS1_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:occurs_together_in_literature_with -> THBS1': 1,
#      'PPARA -> biolink:regulates -> THBS1': 1,
#      'THBS1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'THBS1 -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> THBS1': 1}
#
# Pathway result: PPARA_THBS1_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:occurs_together_in_literature_with -> THBS1': 1,
#      'PPARA -> biolink:regulates -> THBS1': 1,
#      'THBS1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'THBS1 -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> THBS1': 1}
#
# Pathway result: PPARA_REN_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:occurs_together_in_literature_with -> REN': 1,
#      'PPARA -> biolink:regulates -> REN': 1,
#      'REN -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'REN -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> REN': 1}
#
# Pathway result: PPARA_REN_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:occurs_together_in_literature_with -> REN': 1,
#      'PPARA -> biolink:regulates -> REN': 1,
#      'REN -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'REN -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> REN': 1}
#
# Pathway result: PPARA_REN_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:occurs_together_in_literature_with -> REN': 1,
#      'PPARA -> biolink:regulates -> REN': 1,
#      'REN -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'REN -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> REN': 1}
#
# Pathway result: PPARA_REN_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:occurs_together_in_literature_with -> REN': 1,
#      'PPARA -> biolink:regulates -> REN': 1,
#      'REN -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'REN -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> REN': 1}
#
# Pathway result: PPARA_PKHD1_isolated_congenital_hepatic_fibrosis
# {    'PKHD1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PKHD1 -> biolink:genetic_association -> isolated congenital hepatic fibrosis': 1,
#      'PKHD1 -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PKHD1': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_PKHD1_isolated_congenital_hepatic_fibrosis
# {    'PKHD1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PKHD1 -> biolink:genetic_association -> isolated congenital hepatic fibrosis': 1,
#      'PKHD1 -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PKHD1': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_PKHD1_isolated_congenital_hepatic_fibrosis
# {    'PKHD1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PKHD1 -> biolink:genetic_association -> isolated congenital hepatic fibrosis': 1,
#      'PKHD1 -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PKHD1': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_PKHD1_isolated_congenital_hepatic_fibrosis
# {    'PKHD1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PKHD1 -> biolink:genetic_association -> isolated congenital hepatic fibrosis': 1,
#      'PKHD1 -> biolink:regulates -> PPARA': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PKHD1': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_THBS1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> THBS1': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> THBS1': 1,
#      'PPARA -> biolink:regulates -> THBS1': 1,
#      'THBS1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'THBS1 -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_THBS1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> THBS1': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> THBS1': 1,
#      'PPARA -> biolink:regulates -> THBS1': 1,
#      'THBS1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'THBS1 -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_ABCB4_Hepatic_fibrosis
# {    'ABCB4 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'ABCB4 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> ABCB4': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:interacts_with -> ABCB4': 1,
#      'PPARA -> biolink:regulates -> ABCB4': 1}
#
# Pathway result: PPARA_ABCB4_Hepatic_fibrosis
# {    'ABCB4 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'ABCB4 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> ABCB4': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:interacts_with -> ABCB4': 1,
#      'PPARA -> biolink:regulates -> ABCB4': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CCL2_Hepatic_fibrosis
# {    'CCL2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CCL2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CCL2': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CCL2': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CCL2_Hepatic_fibrosis
# {    'CCL2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CCL2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CCL2': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CCL2': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_F2_Hepatic_fibrosis
# {    'F2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'F2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> F2': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> F2': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_F2_Hepatic_fibrosis
# {    'F2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'F2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> F2': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> F2': 1}
#
# Pathway result: PPARA_COL1A2_Hepatic_fibrosis
# {    'COL1A2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'COL1A2 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> COL1A2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> COL1A2': 1}
#
# Pathway result: PPARA_COL1A2_Hepatic_fibrosis
# {    'COL1A2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'COL1A2 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> COL1A2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> COL1A2': 1}
#
# Pathway result: PPARA_PLAU_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PLAU': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PLAU -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PLAU -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PLAU -> biolink:regulates -> PPARA': 1,
#      'PPARA -> biolink:regulates -> PLAU': 1}
#
# Pathway result: PPARA_PLAU_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PLAU': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PLAU -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'PLAU -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PLAU -> biolink:regulates -> PPARA': 1,
#      'PPARA -> biolink:regulates -> PLAU': 1}
#
# Pathway result: PPARA_F2R_Hepatic_fibrosis
# {    'F2R -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'F2R -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> F2R': 1}
#
# Pathway result: PPARA_F2R_Hepatic_fibrosis
# {    'F2R -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'F2R -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> F2R': 1}
#
# Pathway result: PPARA_ARRB1_Hepatic_fibrosis
# {    'ARRB1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'ARRB1 -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> ARRB1': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_ARRB1_Hepatic_fibrosis
# {    'ARRB1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'ARRB1 -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> ARRB1': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_FLT1_Hepatic_fibrosis
# {    'FLT1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'FLT1 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> FLT1': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> FLT1': 1}
#
# Pathway result: PPARA_FLT1_Hepatic_fibrosis
# {    'FLT1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'FLT1 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> FLT1': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> FLT1': 1}
#
# Pathway result: PPARA_FGF2_Hepatic_fibrosis
# {    'FGF2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'FGF2 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> FGF2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> FGF2': 1}
#
# Pathway result: PPARA_FGF2_Hepatic_fibrosis
# {    'FGF2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'FGF2 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> FGF2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> FGF2': 1}
#
# Pathway result: PPARA_ARNT_Hepatic_fibrosis
# {    'ARNT -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'ARNT -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'ARNT -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> ARNT': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_ARNT_Hepatic_fibrosis
# {    'ARNT -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'ARNT -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'ARNT -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> ARNT': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_LGALS1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> LGALS1': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'LGALS1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'LGALS1 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'LGALS1 -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_LGALS1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> LGALS1': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'LGALS1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'LGALS1 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'LGALS1 -> biolink:regulates -> PPARA': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CP_Hepatic_fibrosis
# {    'CP -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CP -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CP': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CP': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CP_Hepatic_fibrosis
# {    'CP -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CP -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CP': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CP': 1}
#
# Pathway result: PPARA_NPC1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> NPC1': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'NPC1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'NPC1 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'NPC1 -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_NPC1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> NPC1': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'NPC1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'NPC1 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'NPC1 -> biolink:regulates -> PPARA': 1}
#
# Pathway result: PPARA_CNR2_Hepatic_fibrosis
# {    'CNR2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CNR2 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'CNR2 -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CNR2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_CNR2_Hepatic_fibrosis
# {    'CNR2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'CNR2 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'CNR2 -> biolink:regulates -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CNR2': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_RGN_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> RGN': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> RGN': 1,
#      'PPARA -> biolink:regulates -> RGN': 1,
#      'RGN -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# Pathway result: PPARA_RGN_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> RGN': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> RGN': 1,
#      'PPARA -> biolink:regulates -> RGN': 1,
#      'RGN -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# Pathway result: PPARA_HNF1A_isolated_congenital_hepatic_fibrosis
# {    'HNF1A -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> HNF1A': 1,
#      'PPARA -> biolink:regulates -> HNF1A': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_HNF1A_isolated_congenital_hepatic_fibrosis
# {    'HNF1A -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> HNF1A': 1,
#      'PPARA -> biolink:regulates -> HNF1A': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_HNF1A_isolated_congenital_hepatic_fibrosis
# {    'HNF1A -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> HNF1A': 1,
#      'PPARA -> biolink:regulates -> HNF1A': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_HNF1A_isolated_congenital_hepatic_fibrosis
# {    'HNF1A -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> HNF1A': 1,
#      'PPARA -> biolink:regulates -> HNF1A': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_NF1_isolated_congenital_hepatic_fibrosis
# {    'NF1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'NF1 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> NF1': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> NF1': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_NF1_isolated_congenital_hepatic_fibrosis
# {    'NF1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'NF1 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> NF1': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> NF1': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_NF1_isolated_congenital_hepatic_fibrosis
# {    'NF1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'NF1 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> NF1': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> NF1': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_NF1_isolated_congenital_hepatic_fibrosis
# {    'NF1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'NF1 -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'PPARA -> biolink:regulates -> NF1': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> NF1': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> AGT': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> AGT': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> AGT': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'isolated congenital hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> AGT': 1}
#
# Pathway result: PPARA_VIM_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> VIM': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> VIM': 1,
#      'PPARA -> biolink:regulates -> VIM': 1,
#      'VIM -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# Pathway result: PPARA_VIM_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> PPARA': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> VIM': 1,
#      'PPARA -> biolink:occurs_together_in_literature_with -> VIM': 1,
#      'PPARA -> biolink:regulates -> VIM': 1,
#      'VIM -> biolink:genetic_association -> Hepatic fibrosis': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_LOX_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> LOX': 1,
#      'LOX -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'LOX -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> LOX': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_LOX_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> LOX': 1,
#      'LOX -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'LOX -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> LOX': 1}
#
# Pathway result: PPARA_liver_disorder_Hepatic_bridging_fibrosis
# {    'Hepatic bridging fibrosis -> biolink:occurs_together_in_literature_with -> liver disorder': 1,
#      'Hepatic bridging fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_liver_disorder_Hepatic_bridging_fibrosis
# {    'Hepatic bridging fibrosis -> biolink:occurs_together_in_literature_with -> liver disorder': 1,
#      'Hepatic bridging fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_liver_disorder_fibrotic_liver_disease
# {    'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'fibrotic liver disease -> biolink:subclass_of -> liver disorder': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: PPARA_liver_disorder_fibrotic_liver_disease
# {    'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetic_association -> liver disorder': 1,
#      'fibrotic liver disease -> biolink:subclass_of -> liver disorder': 1,
#      'liver disorder -> biolink:occurs_together_in_literature_with -> PPARA': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_Hepatic_fibrosis
# {    'AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'AGT -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> AGT': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_AGT_Hepatic_fibrosis
# {    'AGT -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'AGT -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> AGT': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> AGT': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP27A1_Hepatic_fibrosis
# {    'CYP27A1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CYP27A1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CYP27A1': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CYP27A1': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP27A1_Hepatic_fibrosis
# {    'CYP27A1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CYP27A1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CYP27A1': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CYP27A1': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP2R1_Hepatic_fibrosis
# {    'CYP2R1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CYP2R1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CYP2R1': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CYP2R1': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP2R1_Hepatic_fibrosis
# {    'CYP2R1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CYP2R1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CYP2R1': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CYP2R1': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_KRT18_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> KRT18': 1,
#      'KRT18 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'KRT18 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> KRT18': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_KRT18_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> KRT18': 1,
#      'KRT18 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'KRT18 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> KRT18': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_IGFBP1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> IGFBP1': 1,
#      'IGFBP1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'IGFBP1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> IGFBP1': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_IGFBP1_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> IGFBP1': 1,
#      'IGFBP1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'IGFBP1 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> IGFBP1': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CNR2_Hepatic_fibrosis
# {    'CNR2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CNR2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CNR2': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CNR2': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CNR2_Hepatic_fibrosis
# {    'CNR2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CNR2 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'Hepatic fibrosis -> biolink:occurs_together_in_literature_with -> CNR2': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CNR2': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_SERPINA6_Hepatic_fibrosis
# {    'SERPINA6 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'SERPINA6 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> SERPINA6': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_SERPINA6_Hepatic_fibrosis
# {    'SERPINA6 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'SERPINA6 -> biolink:genetic_association -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> SERPINA6': 1}

# %% [markdown]
# We see that the connection between Buprenorphine and CYP2D6 consists of two edge types `biolink:affects` and `biolink:directly_physically_interacts_with`. The `biolink:affects` relationship is bidirectional with one edge starting with Buprenorphine (`Buprenorphine -> biolink:affects -> CYP2D6`) and one starting with CYP2D6 (`CYP2D6 -> biolink:affects -> Buprenorphine`). These three edges are repeated for all results that include Buprenorphine and CYP2D6 as the first two nodes. Those results differ in the type of tremor found for the third node. There are three edges connecting Buprenorphine and OPRM1 (`biolink:affects`, `biolink:directly_physically_interacts_with`, `biolink:related_to`). Of note, the `biolink:affects` was identified in 4 different knowledge sources as indicated by the count reported after the colon.

# %%
pp.pprint(results[0].keys())
pp.pprint(results[0]['node_bindings'].keys())
pp.pprint(results[0]['edge_bindings'].keys())
pp.pprint(results[0]['score'])
#pp.pprint(kg['edges'])
# Out:
# dict_keys(['node_bindings', 'edge_bindings', 'score'])
# dict_keys(['n02', 'n01', 'n00'])
# dict_keys(['e00', 'e01', 's7', 's67', 's68'])
# 0.4262633578538942

# %%
aragorn_result_summaries = []
for r in results:
    rs = f"Score={round(r['score'], 3)}: "
    j = 0
    while j < len(nodes):
        node_id = r['node_bindings'][nodes[j]][0]['id']
        node_name = kg['nodes'][node_id]['name']
        rs = rs + f"{node_name} ({node_id})"
        if j < len(edges):
            edge_id = r['edge_bindings'][edges[j]][0]['id']
            edge_name = kg['edges'][edge_id]['predicate']
            rs = rs + f"--{edge_name}-->"
        j = j + 1
    aragorn_result_summaries.append(rs)

# %%
for rs in aragorn_result_summaries:
    print(rs)
# Out:
# Score=0.426: PPARA (NCBIGene:5465)--biolink:regulates-->SMAD3 (NCBIGene:4088)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.426: PPARA (NCBIGene:5465)--biolink:regulates-->SMAD3 (NCBIGene:4088)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.422: PPARA (NCBIGene:5465)--biolink:regulates-->TGFB1 (NCBIGene:7040)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.422: PPARA (NCBIGene:5465)--biolink:regulates-->TGFB1 (NCBIGene:7040)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.415: PPARA (NCBIGene:5465)--biolink:regulates-->CCL2 (NCBIGene:6347)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.415: PPARA (NCBIGene:5465)--biolink:regulates-->CCL2 (NCBIGene:6347)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.406: PPARA (NCBIGene:5465)--biolink:directly_physically_interacts_with-->ALB (NCBIGene:213)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.406: PPARA (NCBIGene:5465)--biolink:directly_physically_interacts_with-->ALB (NCBIGene:213)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.395: PPARA (NCBIGene:5465)--biolink:regulates-->HGF (NCBIGene:3082)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.395: PPARA (NCBIGene:5465)--biolink:regulates-->HGF (NCBIGene:3082)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.383: PPARA (NCBIGene:5465)--biolink:contributes_to-->liver disorder (MONDO:0005154)--biolink:subclass_of-->Hepatic fibrosis (HP:0001395)
# Score=0.383: PPARA (NCBIGene:5465)--biolink:contributes_to-->liver disorder (MONDO:0005154)--biolink:subclass_of-->Hepatic fibrosis (HP:0001395)
# Score=0.36: PPARA (NCBIGene:5465)--biolink:regulates-->MMP2 (NCBIGene:4313)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.36: PPARA (NCBIGene:5465)--biolink:regulates-->MMP2 (NCBIGene:4313)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.355: PPARA (NCBIGene:5465)--biolink:regulates-->IL6 (NCBIGene:3569)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.355: PPARA (NCBIGene:5465)--biolink:regulates-->IL6 (NCBIGene:3569)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.326: PPARA (NCBIGene:5465)--biolink:contributes_to-->liver disorder (MONDO:0005154)--biolink:subclass_of-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.326: PPARA (NCBIGene:5465)--biolink:contributes_to-->liver disorder (MONDO:0005154)--biolink:subclass_of-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.326: PPARA (NCBIGene:5465)--biolink:contributes_to-->liver disorder (MONDO:0005154)--biolink:subclass_of-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.326: PPARA (NCBIGene:5465)--biolink:contributes_to-->liver disorder (MONDO:0005154)--biolink:subclass_of-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.319: PPARA (NCBIGene:5465)--biolink:regulates-->CCN2 (NCBIGene:1490)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.319: PPARA (NCBIGene:5465)--biolink:regulates-->CCN2 (NCBIGene:1490)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.314: PPARA (NCBIGene:5465)--biolink:regulates-->F2 (NCBIGene:2147)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.314: PPARA (NCBIGene:5465)--biolink:regulates-->F2 (NCBIGene:2147)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.314: PPARA (NCBIGene:5465)--biolink:contributes_to-->liver disorder (MONDO:0005154)--biolink:subclass_of-->Periportal fibrosis (HP:0001405)
# Score=0.314: PPARA (NCBIGene:5465)--biolink:contributes_to-->liver disorder (MONDO:0005154)--biolink:subclass_of-->Periportal fibrosis (HP:0001405)
# Score=0.308: PPARA (NCBIGene:5465)--biolink:regulates-->STAT1 (NCBIGene:6772)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.308: PPARA (NCBIGene:5465)--biolink:regulates-->STAT1 (NCBIGene:6772)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.303: PPARA (NCBIGene:5465)--biolink:regulates-->NFE2L2 (NCBIGene:4780)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.303: PPARA (NCBIGene:5465)--biolink:regulates-->NFE2L2 (NCBIGene:4780)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.295: PPARA (NCBIGene:5465)--biolink:contributes_to-->cirrhosis of liver (MONDO:0005155)--biolink:subclass_of-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.295: PPARA (NCBIGene:5465)--biolink:contributes_to-->cirrhosis of liver (MONDO:0005155)--biolink:subclass_of-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.295: PPARA (NCBIGene:5465)--biolink:contributes_to-->cirrhosis of liver (MONDO:0005155)--biolink:subclass_of-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.295: PPARA (NCBIGene:5465)--biolink:contributes_to-->cirrhosis of liver (MONDO:0005155)--biolink:subclass_of-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.256: PPARA (NCBIGene:5465)--biolink:regulates-->CP (NCBIGene:1356)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.256: PPARA (NCBIGene:5465)--biolink:regulates-->CP (NCBIGene:1356)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.246: PPARA (NCBIGene:5465)--biolink:regulates-->REN (NCBIGene:5972)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.246: PPARA (NCBIGene:5465)--biolink:regulates-->REN (NCBIGene:5972)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.239: PPARA (NCBIGene:5465)--biolink:regulates-->COL1A1 (NCBIGene:1277)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.239: PPARA (NCBIGene:5465)--biolink:regulates-->COL1A1 (NCBIGene:1277)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.239: PPARA (NCBIGene:5465)--biolink:regulates-->SPP1 (NCBIGene:6696)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.239: PPARA (NCBIGene:5465)--biolink:regulates-->SPP1 (NCBIGene:6696)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.236: PPARA (NCBIGene:5465)--biolink:regulates-->VEGFA (NCBIGene:7422)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.236: PPARA (NCBIGene:5465)--biolink:regulates-->VEGFA (NCBIGene:7422)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.235: PPARA (NCBIGene:5465)--biolink:regulates-->AGT (NCBIGene:183)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.235: PPARA (NCBIGene:5465)--biolink:regulates-->AGT (NCBIGene:183)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.231: PPARA (NCBIGene:5465)--biolink:regulates-->AGT (NCBIGene:183)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.231: PPARA (NCBIGene:5465)--biolink:regulates-->AGT (NCBIGene:183)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.231: PPARA (NCBIGene:5465)--biolink:regulates-->AGT (NCBIGene:183)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.231: PPARA (NCBIGene:5465)--biolink:regulates-->AGT (NCBIGene:183)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.222: PPARA (NCBIGene:5465)--biolink:regulates-->TGFB1 (NCBIGene:7040)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.222: PPARA (NCBIGene:5465)--biolink:regulates-->TGFB1 (NCBIGene:7040)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.222: PPARA (NCBIGene:5465)--biolink:regulates-->TGFB1 (NCBIGene:7040)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.222: PPARA (NCBIGene:5465)--biolink:regulates-->TGFB1 (NCBIGene:7040)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.22: PPARA (NCBIGene:5465)--biolink:regulates-->TGFBR1 (NCBIGene:7046)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.22: PPARA (NCBIGene:5465)--biolink:regulates-->TGFBR1 (NCBIGene:7046)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.22: PPARA (NCBIGene:5465)--biolink:regulates-->CTNNB1 (NCBIGene:1499)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.22: PPARA (NCBIGene:5465)--biolink:regulates-->CTNNB1 (NCBIGene:1499)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.216: PPARA (NCBIGene:5465)--biolink:regulates-->THBS1 (NCBIGene:7057)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.216: PPARA (NCBIGene:5465)--biolink:regulates-->THBS1 (NCBIGene:7057)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.216: PPARA (NCBIGene:5465)--biolink:regulates-->THBS1 (NCBIGene:7057)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.216: PPARA (NCBIGene:5465)--biolink:regulates-->THBS1 (NCBIGene:7057)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.211: PPARA (NCBIGene:5465)--biolink:regulates-->REN (NCBIGene:5972)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.211: PPARA (NCBIGene:5465)--biolink:regulates-->REN (NCBIGene:5972)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.211: PPARA (NCBIGene:5465)--biolink:regulates-->REN (NCBIGene:5972)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.211: PPARA (NCBIGene:5465)--biolink:regulates-->REN (NCBIGene:5972)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.204: PPARA (NCBIGene:5465)--biolink:regulates-->PKHD1 (NCBIGene:5314)--biolink:genetic_association-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.204: PPARA (NCBIGene:5465)--biolink:regulates-->PKHD1 (NCBIGene:5314)--biolink:genetic_association-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.204: PPARA (NCBIGene:5465)--biolink:regulates-->PKHD1 (NCBIGene:5314)--biolink:genetic_association-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.204: PPARA (NCBIGene:5465)--biolink:regulates-->PKHD1 (NCBIGene:5314)--biolink:genetic_association-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.198: PPARA (NCBIGene:5465)--biolink:regulates-->THBS1 (NCBIGene:7057)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.198: PPARA (NCBIGene:5465)--biolink:regulates-->THBS1 (NCBIGene:7057)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.192: PPARA (NCBIGene:5465)--biolink:interacts_with-->ABCB4 (NCBIGene:5244)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.192: PPARA (NCBIGene:5465)--biolink:interacts_with-->ABCB4 (NCBIGene:5244)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.191: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->CCL2 (NCBIGene:6347)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.191: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->CCL2 (NCBIGene:6347)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.191: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->F2 (NCBIGene:2147)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.191: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->F2 (NCBIGene:2147)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.182: PPARA (NCBIGene:5465)--biolink:regulates-->COL1A2 (NCBIGene:1278)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.182: PPARA (NCBIGene:5465)--biolink:regulates-->COL1A2 (NCBIGene:1278)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.176: PPARA (NCBIGene:5465)--biolink:regulates-->PLAU (NCBIGene:5328)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.176: PPARA (NCBIGene:5465)--biolink:regulates-->PLAU (NCBIGene:5328)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.172: PPARA (NCBIGene:5465)--biolink:regulates-->F2R (NCBIGene:2149)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.172: PPARA (NCBIGene:5465)--biolink:regulates-->F2R (NCBIGene:2149)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.171: PPARA (NCBIGene:5465)--biolink:regulates-->ARRB1 (NCBIGene:408)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.171: PPARA (NCBIGene:5465)--biolink:regulates-->ARRB1 (NCBIGene:408)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.166: PPARA (NCBIGene:5465)--biolink:regulates-->FLT1 (NCBIGene:2321)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.166: PPARA (NCBIGene:5465)--biolink:regulates-->FLT1 (NCBIGene:2321)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.165: PPARA (NCBIGene:5465)--biolink:regulates-->FGF2 (NCBIGene:2247)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.165: PPARA (NCBIGene:5465)--biolink:regulates-->FGF2 (NCBIGene:2247)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.161: PPARA (NCBIGene:5465)--biolink:regulates-->ARNT (NCBIGene:405)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.161: PPARA (NCBIGene:5465)--biolink:regulates-->ARNT (NCBIGene:405)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.159: PPARA (NCBIGene:5465)--biolink:regulates-->LGALS1 (NCBIGene:3956)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.159: PPARA (NCBIGene:5465)--biolink:regulates-->LGALS1 (NCBIGene:3956)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.154: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->CP (NCBIGene:1356)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.154: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->CP (NCBIGene:1356)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.153: PPARA (NCBIGene:5465)--biolink:regulates-->NPC1 (NCBIGene:4864)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.153: PPARA (NCBIGene:5465)--biolink:regulates-->NPC1 (NCBIGene:4864)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.147: PPARA (NCBIGene:5465)--biolink:regulates-->CNR2 (NCBIGene:1269)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.147: PPARA (NCBIGene:5465)--biolink:regulates-->CNR2 (NCBIGene:1269)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.146: PPARA (NCBIGene:5465)--biolink:regulates-->RGN (NCBIGene:9104)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.146: PPARA (NCBIGene:5465)--biolink:regulates-->RGN (NCBIGene:9104)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.146: PPARA (NCBIGene:5465)--biolink:regulates-->HNF1A (NCBIGene:6927)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.146: PPARA (NCBIGene:5465)--biolink:regulates-->HNF1A (NCBIGene:6927)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.146: PPARA (NCBIGene:5465)--biolink:regulates-->HNF1A (NCBIGene:6927)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.146: PPARA (NCBIGene:5465)--biolink:regulates-->HNF1A (NCBIGene:6927)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.144: PPARA (NCBIGene:5465)--biolink:regulates-->NF1 (NCBIGene:4763)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.144: PPARA (NCBIGene:5465)--biolink:regulates-->NF1 (NCBIGene:4763)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.144: PPARA (NCBIGene:5465)--biolink:regulates-->NF1 (NCBIGene:4763)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.144: PPARA (NCBIGene:5465)--biolink:regulates-->NF1 (NCBIGene:4763)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.142: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->AGT (NCBIGene:183)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.142: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->AGT (NCBIGene:183)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.142: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->AGT (NCBIGene:183)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.142: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->AGT (NCBIGene:183)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.141: PPARA (NCBIGene:5465)--biolink:regulates-->VIM (NCBIGene:7431)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.141: PPARA (NCBIGene:5465)--biolink:regulates-->VIM (NCBIGene:7431)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.134: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->LOX (NCBIGene:4015)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.134: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->LOX (NCBIGene:4015)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.125: PPARA (NCBIGene:5465)--biolink:contributes_to-->liver disorder (MONDO:0005154)--biolink:subclass_of-->Hepatic bridging fibrosis (HP:0012852)
# Score=0.125: PPARA (NCBIGene:5465)--biolink:contributes_to-->liver disorder (MONDO:0005154)--biolink:subclass_of-->Hepatic bridging fibrosis (HP:0012852)
# Score=0.123: PPARA (NCBIGene:5465)--biolink:contributes_to-->liver disorder (MONDO:0005154)--biolink:subclass_of-->fibrotic liver disease (MONDO:0100430)
# Score=0.123: PPARA (NCBIGene:5465)--biolink:contributes_to-->liver disorder (MONDO:0005154)--biolink:subclass_of-->fibrotic liver disease (MONDO:0100430)
# Score=0.123: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->AGT (NCBIGene:183)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.123: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->AGT (NCBIGene:183)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.118: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->CYP27A1 (NCBIGene:1593)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.118: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->CYP27A1 (NCBIGene:1593)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.115: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->CYP2R1 (NCBIGene:120227)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.115: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->CYP2R1 (NCBIGene:120227)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.113: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->KRT18 (NCBIGene:3875)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.113: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->KRT18 (NCBIGene:3875)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.106: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->IGFBP1 (NCBIGene:3484)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.106: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->IGFBP1 (NCBIGene:3484)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.105: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->CNR2 (NCBIGene:1269)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.105: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->CNR2 (NCBIGene:1269)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.099: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->SERPINA6 (NCBIGene:866)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)
# Score=0.099: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->SERPINA6 (NCBIGene:866)--biolink:genetic_association-->Hepatic fibrosis (HP:0001395)

# %% [markdown]
# The following assumes that the node names will sort in the correct order, which is the case with the default naming conventions. This exports the results showing the nodes and the score assigned to each result.

# %%
cols = []
for node in sorted(results[0]['node_bindings'].keys()):
    cols.append(node)
    cols.append(node + '_name')
results_df = pd.DataFrame(columns = cols)

results_dict_list = []
for result in results:
    result_dict = {}
    for node in result['node_bindings'].keys():
        node_id = result['node_bindings'][node][0]['id']
        result_dict[node] = node_id
        result_dict[node + '_name'] = kg['nodes'][node_id]['name']
    result_dict['score'] = result['score']
    #print(result_dict)

    results_dict_list.append(result_dict)
    # results_df = results_df.append(result_dict, ignore_index=True)
results_df = pd.concat([results_df,pd.DataFrame.from_records(results_dict_list)])
print(results_df.shape)
results_df.to_csv(os.path.join(write_dir,'results_TRAPI_aragorn.csv'))
# Out:
# (136, 7)
