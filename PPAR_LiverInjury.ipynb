# %%
# Parameter inputs
aragorn_submit_url = "https://robokop-ara.apps.renci.org/robokop/query"
input_search_string = 'ppara'
output_search_string = 'liver fibrosis'

# Initializing directory to write
from datetime import datetime
from pathlib import Path

now = datetime.now()
dt_string = now.strftime("%Y-%m-%d_%H%M%S")
write_dir = Path("output/TRAPI",str(dt_string))
write_dir.mkdir(parents=True, exist_ok=True)

# %%
import requests
import json
import pprint
import pandas as pd
import os
pp = pprint.PrettyPrinter(indent=5)

# %% [markdown]
# This notebook serves as the starting point for an investigation into the relationship between PPAR$\alpha$ and Liver Fibrosis by using the APIs available in ROBOKOP.
#
# Users unfamiliar with these APIs and want an introduction to these APIs should look into the RoboDocumentation repo on GitHub: https://github.com/RobokopU24/RoboDocumentation.

# %% [markdown]
# Two lists of CURIES are generated by using the Name Resolver tool, where the submissions are strings "ppara" and "liver fibrosis".

# %%
results = requests.post(f'https://name-resolution-sri.renci.org/lookup?string={input_search_string}&offset=0&limit=10')
results_json = results.json()
# print(json.dumps(results_json,indent=4))

input_node_id_list = []
for result in results_json:
    if result["curie"] not in input_node_id_list:
        input_node_id_list.append(result["curie"])
print(input_node_id_list)
# Out:
# ['NCBIGene:5465', 'NCBIGene:19013', 'NCBIGene:25747', 'NCBIGene:281992', 'NCBIGene:374120', 'NCBIGene:397239', 'NCBIGene:403654', 'NCBIGene:443457', 'NCBIGene:458910', 'NCBIGene:613250']

# %%
results = requests.post(f'https://name-resolution-sri.renci.org/lookup?string={output_search_string}&offset=0&limit=10')
results_json = results.json()
# print(json.dumps(results_json,indent=4))

output_node_id_list = []
for result in results_json:
    if result["curie"] not in output_node_id_list:
        output_node_id_list.append(result["curie"])
print(output_node_id_list)
# Out:
# ['UBERON:0002107', 'UMLS:C1397317', 'UMLS:C1954436', 'HP:0001395', 'UMLS:C4034373', 'UMLS:C4227681', 'UMLS:C5548946', 'UMLS:C4695228', 'UMLS:C4695229', 'UMLS:C5189427']

# %% [markdown]
# A simple three node, two hop pathway is constructed using these lists of CURIES.

# %%
query={
    "message": {
      "query_graph": {
        "edges": {
          "e00": {
            "subject": "n00",
              "object": "n01",
          "predicates":["biolink:related_to"]
          },
          "e01": {
            "subject": "n01",
              "object": "n02",
          "predicates":["biolink:related_to"]
          }
        },
        "nodes": {
          "n00": {
            "ids": input_node_id_list, #['NCBIGene:5465'], #
            "categories": ["biolink:GeneOrGeneProduct"]
          },
          "n01": {
              "categories": ["biolink:BiologicalEntity"]
          },
          "n02": {
            "ids": output_node_id_list, #["HP:0001395"],
            "categories": ["biolink:DiseaseOrPhenotypicFeature"]
          }
        }
      }
    }
  }

# %% [markdown]
# The query is sent to Aragorn to get scores for the pathways.

# %%
response = requests.post(aragorn_submit_url,json=query)
print(response.status_code)
number_pathway_results = len(response.json()['message']['results'])
print(len(response.json()['message']['results']))
# Out:
# 200
# 56

# %% [markdown]
# The TRAPI response can be written to a JSON file like below.

# %%
json_object = json.dumps(results_json, indent=4)
 
# Writing TRAPI response_ara to JSON file
with open(Path(write_dir,"trapi_query_response_ara.json"), "w") as outfile:
    outfile.write(json_object)

# %% [markdown]
# The response in JSON form is a python dictionary with three main keys, the `message`, `log_level`, and `workflow`.  The `message` property contains the `query_graph`, `knowledge_graph`, and `results` from the query.

# %%
print(response.json().keys())
print(response.json()['message'].keys())

query_out = response.json()['message']['query_graph']
kg = response.json()['message']['knowledge_graph']
results = response.json()['message']['results']

edges = ["e00", "e01"]
nodes = ["n00", "n01", "n02"]
# Out:
# dict_keys(['message', 'logs', 'status', 'pid'])
# dict_keys(['query_graph', 'knowledge_graph', 'results'])

# %% [markdown]
# The `results` property contains pathways resulting from the query message. Each pathway is organized into edge_bindings and node bindings and contains results for the edges and nodes specified in the query message.  Results are defined using the node and edge identifiers. The attributes for those nodes and edges (including the names) are available via the `knowledge_graph` component of the `message` section of the response.

# %% [markdown]
# The code below writes out nodes from our `results`, but NOT the edges connecting the nodes.  This includes the scores provided by Aragorn.

# %%
aragorn_result_summaries = []
for r in results:
    rs = f"Score={round(r['analyses'][0]['score'], 3)}: "
    j = 0
    while j < len(nodes):
        node_id = r['node_bindings'][nodes[j]][0]['id']
        node_name = kg['nodes'][node_id]['name']
        rs = rs + f"{node_name} ({node_id})"
        if j < len(edges):
            edge_id = r['analyses'][0]['edge_bindings'][edges[j]][0]['id']
            edge_name = kg['edges'][edge_id]['predicate']
            rs = rs + f"--{edge_name}-->"
        j = j + 1
    aragorn_result_summaries.append(rs)

# %%
for rs in aragorn_result_summaries:
    print(rs)
# Out:
# Score=0.679: PPARA (NCBIGene:5465)--biolink:affects-->PKHD1 (NCBIGene:5314)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.495: PPARA (NCBIGene:5465)--biolink:affects-->THBS1 (NCBIGene:7057)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.495: PPARA (NCBIGene:5465)--biolink:interacts_with-->AGT (NCBIGene:183)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.476: PPARA (NCBIGene:5465)--biolink:contributes_to-->cirrhosis of liver (MONDO:0005155)--biolink:subclass_of-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.473: PPARA (NCBIGene:5465)--biolink:affects-->TGFB1 (NCBIGene:7040)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.448: PPARA (NCBIGene:5465)--biolink:contributes_to-->liver disorder (MONDO:0005154)--biolink:subclass_of-->Hepatic bridging fibrosis (HP:0012852)
# Score=0.448: PPARA (NCBIGene:5465)--biolink:contributes_to-->liver disorder (MONDO:0005154)--biolink:subclass_of-->Hepatic fibrosis (HP:0001395)
# Score=0.448: PPARA (NCBIGene:5465)--biolink:contributes_to-->liver disorder (MONDO:0005154)--biolink:subclass_of-->Periportal fibrosis (HP:0001405)
# Score=0.448: PPARA (NCBIGene:5465)--biolink:contributes_to-->liver disorder (MONDO:0005154)--biolink:subclass_of-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.415: PPARA (NCBIGene:5465)--biolink:affects-->REN (NCBIGene:5972)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.279: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->TGFB1 (NCBIGene:7040)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.275: PPARA (NCBIGene:5465)--biolink:affects-->ALB (NCBIGene:213)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.273: PPARA (NCBIGene:5465)--biolink:affects-->NF1 (NCBIGene:4763)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.273: PPARA (NCBIGene:5465)--biolink:affects-->HNF1A (NCBIGene:6927)--biolink:contributes_to-->isolated congenital hepatic fibrosis (MONDO:0018840)
# Score=0.273: PPARA (NCBIGene:5465)--biolink:affects-->THBS1 (NCBIGene:7057)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.273: PPARA (NCBIGene:5465)--biolink:interacts_with-->AGT (NCBIGene:183)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.268: PPARA (NCBIGene:5465)--biolink:affects-->SMAD3 (NCBIGene:4088)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.265: PPARA (NCBIGene:5465)--biolink:affects-->CCL2 (NCBIGene:6347)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.263: PPARA (NCBIGene:5465)--biolink:affects-->SPP1 (NCBIGene:6696)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.262: PPARA (NCBIGene:5465)--biolink:affects-->CCN2 (NCBIGene:1490)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.262: PPARA (NCBIGene:5465)--biolink:affects-->MMP2 (NCBIGene:4313)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.261: PPARA (NCBIGene:5465)--biolink:affects-->LGALS1 (NCBIGene:3956)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.261: PPARA (NCBIGene:5465)--biolink:affects-->HGF (NCBIGene:3082)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.261: PPARA (NCBIGene:5465)--biolink:affects-->NFE2L2 (NCBIGene:4780)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.261: PPARA (NCBIGene:5465)--biolink:affects-->TGFB1 (NCBIGene:7040)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.254: PPARA (NCBIGene:5465)--biolink:affects-->CTNNB1 (NCBIGene:1499)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.248: PPARA (NCBIGene:5465)--biolink:affects-->STAT1 (NCBIGene:6772)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.247: PPARA (NCBIGene:5465)--biolink:affects-->IL6 (NCBIGene:3569)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.241: PPARA (NCBIGene:5465)--biolink:affects-->ARNT (NCBIGene:405)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.241: PPARA (NCBIGene:5465)--biolink:affects-->ARRB1 (NCBIGene:408)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.241: PPARA (NCBIGene:5465)--biolink:affects-->F2R (NCBIGene:2149)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.236: PPARA (NCBIGene:5465)--biolink:affects-->FLT1 (NCBIGene:2321)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.229: PPARA (NCBIGene:5465)--biolink:affects-->VEGFA (NCBIGene:7422)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.229: PPARA (NCBIGene:5465)--biolink:affects-->REN (NCBIGene:5972)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.218: PPARA (NCBIGene:5465)--biolink:affects-->F2 (NCBIGene:2147)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.208: PPARA (NCBIGene:5465)--biolink:affects-->CNR2 (NCBIGene:1269)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.208: PPARA (NCBIGene:5465)--biolink:affects-->TGFBR1 (NCBIGene:7046)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.208: PPARA (NCBIGene:5465)--biolink:affects-->NPC1 (NCBIGene:4864)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.208: PPARA (NCBIGene:5465)--biolink:affects-->PLAU (NCBIGene:5328)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.208: PPARA (NCBIGene:5465)--biolink:affects-->CP (NCBIGene:1356)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.188: PPARA (NCBIGene:5465)--biolink:interacts_with-->ABCB4 (NCBIGene:5244)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.154: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->CYP27A1 (NCBIGene:1593)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.154: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->DHCR7 (NCBIGene:1717)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.154: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->CTNNB1 (NCBIGene:1499)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.154: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->CYBA (NCBIGene:1535)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.154: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->VIM (NCBIGene:7431)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.154: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->CP (NCBIGene:1356)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.154: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->CYP2R1 (NCBIGene:120227)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.154: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->IL6 (NCBIGene:3569)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.154: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->CNR2 (NCBIGene:1269)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.154: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->TGFB1 (NCBIGene:7040)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.154: peroxisome proliferator-activated receptor alpha isoform 1 (human) (UniProtKB:Q07869-1)--biolink:coexpressed_with-->CCL2 (NCBIGene:6347)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.151: PPARA (NCBIGene:5465)--biolink:affects-->COL1A2 (NCBIGene:1278)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.151: PPARA (NCBIGene:5465)--biolink:affects-->FGF2 (NCBIGene:2247)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.151: PPARA (NCBIGene:5465)--biolink:affects-->COL1A1 (NCBIGene:1277)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)
# Score=0.083: PPARA (NCBIGene:5465)--biolink:regulates-->VIM (NCBIGene:7431)--biolink:genetically_associated_with-->Hepatic fibrosis (HP:0001395)

# %% [markdown]
# The following assumes that the node names will sort in the correct order, which is the case with the default naming conventions. This exports the results showing the nodes and the score assigned to each result.

# %%
cols = []
for node in sorted(results[0]['node_bindings'].keys()):
    cols.append(node)
    cols.append(node + '_name')
results_df = pd.DataFrame(columns = cols)

results_dict_list = []
for result in results:
    result_dict = {}
    for node in result['node_bindings'].keys():
        node_id = result['node_bindings'][node][0]['id']
        result_dict[node] = node_id
        result_dict[node + '_name'] = kg['nodes'][node_id]['name']
    result_dict['score'] = result['analyses'][0]['score']
    #print(result_dict)

    results_dict_list.append(result_dict)
results_df = pd.concat([results_df,pd.DataFrame.from_records(results_dict_list)])
print(results_df.shape)
results_df.to_csv(os.path.join(write_dir,'results_TRAPI_aragorn.csv'))
# Out:
# (56, 7)

# %% [markdown]
# In the code below, we print a single edge for each association type and include the count of the number of data sources where that association was found. The following writes out all unique edges for each of the results in the format of `subject` -> `predicate` -> `object` and exports the information into a single file per `result`.

# %%
cols = []
for node in sorted(results[0]['node_bindings'].keys()):
    cols.append(node)
    cols.append(node + '_name')
results_df = pd.DataFrame(columns = cols)

results_list = []
for result in results:
    result_dict = {}
    for node in sorted(result['node_bindings'].keys()):
        node_id = result['node_bindings'][node][0]['id']
        result_dict[node] = node_id
        result_dict[node + '_name'] = kg['nodes'][node_id]['name']

    results_list.append(pd.DataFrame([result_dict]))
results_df = pd.concat(results_list)
# display(results_df)
# results_df.to_csv(os.path.join(write_dir,'results_TRAPI.csv'), index=False)

combined_node_list = ["_".join([row[1].replace(" ", "_"), row[3].replace(" ", "_"), row[5].replace(" ", "_")]) for row in results_df[cols].to_numpy()]
pp.pprint(combined_node_list)
# Out:
# [    'PPARA_PKHD1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_THBS1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_AGT_isolated_congenital_hepatic_fibrosis',
#      'PPARA_cirrhosis_of_liver_isolated_congenital_hepatic_fibrosis',
#      'PPARA_TGFB1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_liver_disorder_Hepatic_bridging_fibrosis',
#      'PPARA_liver_disorder_Hepatic_fibrosis',
#      'PPARA_liver_disorder_Periportal_fibrosis',
#      'PPARA_liver_disorder_isolated_congenital_hepatic_fibrosis',
#      'PPARA_REN_isolated_congenital_hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_TGFB1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_ALB_Hepatic_fibrosis',
#      'PPARA_NF1_isolated_congenital_hepatic_fibrosis',
#      'PPARA_HNF1A_isolated_congenital_hepatic_fibrosis',
#      'PPARA_THBS1_Hepatic_fibrosis',
#      'PPARA_AGT_Hepatic_fibrosis',
#      'PPARA_SMAD3_Hepatic_fibrosis',
#      'PPARA_CCL2_Hepatic_fibrosis',
#      'PPARA_SPP1_Hepatic_fibrosis',
#      'PPARA_CCN2_Hepatic_fibrosis',
#      'PPARA_MMP2_Hepatic_fibrosis',
#      'PPARA_LGALS1_Hepatic_fibrosis',
#      'PPARA_HGF_Hepatic_fibrosis',
#      'PPARA_NFE2L2_Hepatic_fibrosis',
#      'PPARA_TGFB1_Hepatic_fibrosis',
#      'PPARA_CTNNB1_Hepatic_fibrosis',
#      'PPARA_STAT1_Hepatic_fibrosis',
#      'PPARA_IL6_Hepatic_fibrosis',
#      'PPARA_ARNT_Hepatic_fibrosis',
#      'PPARA_ARRB1_Hepatic_fibrosis',
#      'PPARA_F2R_Hepatic_fibrosis',
#      'PPARA_FLT1_Hepatic_fibrosis',
#      'PPARA_VEGFA_Hepatic_fibrosis',
#      'PPARA_REN_Hepatic_fibrosis',
#      'PPARA_F2_Hepatic_fibrosis',
#      'PPARA_CNR2_Hepatic_fibrosis',
#      'PPARA_TGFBR1_Hepatic_fibrosis',
#      'PPARA_NPC1_Hepatic_fibrosis',
#      'PPARA_PLAU_Hepatic_fibrosis',
#      'PPARA_CP_Hepatic_fibrosis',
#      'PPARA_ABCB4_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP27A1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_DHCR7_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CTNNB1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYBA_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_VIM_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CP_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP2R1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_IL6_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CNR2_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_TGFB1_Hepatic_fibrosis',
#      'peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CCL2_Hepatic_fibrosis',
#      'PPARA_COL1A2_Hepatic_fibrosis',
#      'PPARA_FGF2_Hepatic_fibrosis',
#      'PPARA_COL1A1_Hepatic_fibrosis',
#      'PPARA_VIM_Hepatic_fibrosis']

# %%
from collections import Counter
import json
import pprint
pp = pprint.PrettyPrinter(indent=5)

for i in range(number_pathway_results):
    print(f"Pathway result: {combined_node_list[i]}")
    edge_bindings = results[i]['analyses'][0]['edge_bindings']

    edge_ids = []
    for edge_name, edge_list in edge_bindings.items():
        edge_ids.append({edge_name: [x['id'] for x in edge_list]})

    string_out_list = []
    for edge_dict in edge_ids:
        for edge_name, edge_list in edge_dict.items():
            for edge_id in edge_list:
                subject_id = kg['edges'][edge_id]['subject']
                subject = kg['nodes'][subject_id]['name']
                predicate = kg['edges'][edge_id]['predicate']
                object_id = kg['edges'][edge_id]['object']
                object = kg['nodes'][object_id]['name']
                string_out = f"{subject} -> {predicate} -> {object}"
                string_out_list.append(string_out)
    string_out_dict = dict(Counter(string_out_list).items())
    pp.pprint(string_out_dict)
    print("")
    
    with open(os.path.join(write_dir,combined_node_list[i]+".txt"), 'w') as convert_file:
        convert_file.write(json.dumps(string_out_dict))
# Out:
# Pathway result: PPARA_PKHD1_isolated_congenital_hepatic_fibrosis
# {    'PKHD1 -> biolink:affects -> PPARA': 1,
#      'PKHD1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PKHD1 -> biolink:genetically_associated_with -> isolated congenital hepatic fibrosis': 1}
#
# Pathway result: PPARA_THBS1_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:affects -> THBS1': 1,
#      'THBS1 -> biolink:affects -> PPARA': 1,
#      'THBS1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
#
# Pathway result: PPARA_AGT_isolated_congenital_hepatic_fibrosis
# {    'AGT -> biolink:affects -> PPARA': 1,
#      'AGT -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PPARA -> biolink:affects -> AGT': 1,
#      'PPARA -> biolink:interacts_with -> AGT': 1}
#
# Pathway result: PPARA_cirrhosis_of_liver_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:contributes_to -> cirrhosis of liver': 1,
#      'isolated congenital hepatic fibrosis -> biolink:subclass_of -> cirrhosis of liver': 1}
#
# Pathway result: PPARA_TGFB1_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:affects -> TGFB1': 1,
#      'TGFB1 -> biolink:affects -> PPARA': 1,
#      'TGFB1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
#
# Pathway result: PPARA_liver_disorder_Hepatic_bridging_fibrosis
# {    'Hepatic bridging fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetically_associated_with -> liver disorder': 1}
#
# Pathway result: PPARA_liver_disorder_Hepatic_fibrosis
# {    'Hepatic fibrosis -> biolink:subclass_of -> liver disorder': 1,
#      'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetically_associated_with -> liver disorder': 1}
#
# Pathway result: PPARA_liver_disorder_Periportal_fibrosis
# {    'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetically_associated_with -> liver disorder': 1,
#      'Periportal fibrosis -> biolink:subclass_of -> liver disorder': 1}
#
# Pathway result: PPARA_liver_disorder_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:contributes_to -> liver disorder': 1,
#      'PPARA -> biolink:genetically_associated_with -> liver disorder': 1,
#      'isolated congenital hepatic fibrosis -> biolink:subclass_of -> liver disorder': 1}
#
# Pathway result: PPARA_REN_isolated_congenital_hepatic_fibrosis
# {    'PPARA -> biolink:affects -> REN': 1,
#      'REN -> biolink:affects -> PPARA': 1,
#      'REN -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_TGFB1_isolated_congenital_hepatic_fibrosis
# {    'TGFB1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'TGFB1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> TGFB1': 1}
#
# Pathway result: PPARA_ALB_Hepatic_fibrosis
# {    'ALB -> biolink:affects -> PPARA': 1,
#      'ALB -> biolink:directly_physically_interacts_with -> PPARA': 1,
#      'ALB -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:affects -> ALB': 1}
#
# Pathway result: PPARA_NF1_isolated_congenital_hepatic_fibrosis
# {    'NF1 -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PPARA -> biolink:affects -> NF1': 1}
#
# Pathway result: PPARA_HNF1A_isolated_congenital_hepatic_fibrosis
# {    'HNF1A -> biolink:contributes_to -> isolated congenital hepatic fibrosis': 1,
#      'PPARA -> biolink:affects -> HNF1A': 1}
#
# Pathway result: PPARA_THBS1_Hepatic_fibrosis
# {    'PPARA -> biolink:affects -> THBS1': 1,
#      'THBS1 -> biolink:affects -> PPARA': 1,
#      'THBS1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
#
# Pathway result: PPARA_AGT_Hepatic_fibrosis
# {    'AGT -> biolink:affects -> PPARA': 1,
#      'AGT -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:affects -> AGT': 1,
#      'PPARA -> biolink:interacts_with -> AGT': 1}
#
# Pathway result: PPARA_SMAD3_Hepatic_fibrosis
# {    'PPARA -> biolink:affects -> SMAD3': 1,
#      'SMAD3 -> biolink:affects -> PPARA': 1,
#      'SMAD3 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
#
# Pathway result: PPARA_CCL2_Hepatic_fibrosis
# {    'CCL2 -> biolink:affects -> PPARA': 1,
#      'CCL2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:affects -> CCL2': 1}
#
# Pathway result: PPARA_SPP1_Hepatic_fibrosis
# {    'PPARA -> biolink:affects -> SPP1': 1,
#      'PPARA -> biolink:regulates -> SPP1': 1,
#      'SPP1 -> biolink:affects -> PPARA': 1,
#      'SPP1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
#
# Pathway result: PPARA_CCN2_Hepatic_fibrosis
# {    'CCN2 -> biolink:affects -> PPARA': 1,
#      'CCN2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:affects -> CCN2': 1}
#
# Pathway result: PPARA_MMP2_Hepatic_fibrosis
# {    'MMP2 -> biolink:affects -> PPARA': 1,
#      'MMP2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:affects -> MMP2': 1}
#
# Pathway result: PPARA_LGALS1_Hepatic_fibrosis
# {    'LGALS1 -> biolink:affects -> PPARA': 1,
#      'LGALS1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
#
# Pathway result: PPARA_HGF_Hepatic_fibrosis
# {    'HGF -> biolink:affects -> PPARA': 1,
#      'HGF -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:affects -> HGF': 1}
#
# Pathway result: PPARA_NFE2L2_Hepatic_fibrosis
# {    'NFE2L2 -> biolink:affects -> PPARA': 1,
#      'NFE2L2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:affects -> NFE2L2': 1}
#
# Pathway result: PPARA_TGFB1_Hepatic_fibrosis
# {    'PPARA -> biolink:affects -> TGFB1': 1,
#      'TGFB1 -> biolink:affects -> PPARA': 1,
#      'TGFB1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
#
# Pathway result: PPARA_CTNNB1_Hepatic_fibrosis
# {    'CTNNB1 -> biolink:affects -> PPARA': 1,
#      'CTNNB1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:affects -> CTNNB1': 1}
#
# Pathway result: PPARA_STAT1_Hepatic_fibrosis
# {    'PPARA -> biolink:affects -> STAT1': 1,
#      'STAT1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'STAT1 -> biolink:interacts_with -> PPARA': 1}
#
# Pathway result: PPARA_IL6_Hepatic_fibrosis
# {    'IL6 -> biolink:affects -> PPARA': 1,
#      'IL6 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:affects -> IL6': 1}
#
# Pathway result: PPARA_ARNT_Hepatic_fibrosis
# {    'ARNT -> biolink:affects -> PPARA': 1,
#      'ARNT -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
#
# Pathway result: PPARA_ARRB1_Hepatic_fibrosis
# {    'ARRB1 -> biolink:affects -> PPARA': 1,
#      'ARRB1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
#
# Pathway result: PPARA_F2R_Hepatic_fibrosis
# {    'F2R -> biolink:affects -> PPARA': 1,
#      'F2R -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:affects -> F2R': 1}
#
# Pathway result: PPARA_FLT1_Hepatic_fibrosis
# {    'FLT1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:affects -> FLT1': 1}
#
# Pathway result: PPARA_VEGFA_Hepatic_fibrosis
# {    'PPARA -> biolink:affects -> VEGFA': 1,
#      'VEGFA -> biolink:affects -> PPARA': 1,
#      'VEGFA -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
#
# Pathway result: PPARA_REN_Hepatic_fibrosis
# {    'PPARA -> biolink:affects -> REN': 1,
#      'REN -> biolink:affects -> PPARA': 1,
#      'REN -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
#
# Pathway result: PPARA_F2_Hepatic_fibrosis
# {    'F2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:affects -> F2': 1,
#      'PPARA -> biolink:interacts_with -> F2': 1}
#
# Pathway result: PPARA_CNR2_Hepatic_fibrosis
# {    'CNR2 -> biolink:affects -> PPARA': 1,
#      'CNR2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
#
# Pathway result: PPARA_TGFBR1_Hepatic_fibrosis
# {    'PPARA -> biolink:affects -> TGFBR1': 1,
#      'TGFBR1 -> biolink:affects -> PPARA': 1,
#      'TGFBR1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
#
# Pathway result: PPARA_NPC1_Hepatic_fibrosis
# {    'NPC1 -> biolink:affects -> PPARA': 1,
#      'NPC1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
#
# Pathway result: PPARA_PLAU_Hepatic_fibrosis
# {    'PLAU -> biolink:affects -> PPARA': 1,
#      'PLAU -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:affects -> PLAU': 1}
#
# Pathway result: PPARA_CP_Hepatic_fibrosis
# {    'CP -> biolink:affects -> PPARA': 1,
#      'CP -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:affects -> CP': 1}
#
# Pathway result: PPARA_ABCB4_Hepatic_fibrosis
# {    'ABCB4 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:affects -> ABCB4': 1,
#      'PPARA -> biolink:interacts_with -> ABCB4': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP27A1_Hepatic_fibrosis
# {    'CYP27A1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CYP27A1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CYP27A1': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_DHCR7_Hepatic_fibrosis
# {    'DHCR7 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'DHCR7 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> DHCR7': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CTNNB1_Hepatic_fibrosis
# {    'CTNNB1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CTNNB1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CTNNB1': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYBA_Hepatic_fibrosis
# {    'CYBA -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CYBA -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CYBA': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_VIM_Hepatic_fibrosis
# {    'VIM -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'VIM -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> VIM': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CP_Hepatic_fibrosis
# {    'CP -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CP -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CP': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CYP2R1_Hepatic_fibrosis
# {    'CYP2R1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CYP2R1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CYP2R1': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_IL6_Hepatic_fibrosis
# {    'IL6 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'IL6 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> IL6': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CNR2_Hepatic_fibrosis
# {    'CNR2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CNR2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CNR2': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_TGFB1_Hepatic_fibrosis
# {    'TGFB1 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'TGFB1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> TGFB1': 1}
#
# Pathway result: peroxisome_proliferator-activated_receptor_alpha_isoform_1_(human)_CCL2_Hepatic_fibrosis
# {    'CCL2 -> biolink:coexpressed_with -> peroxisome proliferator-activated receptor alpha isoform 1 (human)': 1,
#      'CCL2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'peroxisome proliferator-activated receptor alpha isoform 1 (human) -> biolink:coexpressed_with -> CCL2': 1}
#
# Pathway result: PPARA_COL1A2_Hepatic_fibrosis
# {    'COL1A2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:affects -> COL1A2': 1}
#
# Pathway result: PPARA_FGF2_Hepatic_fibrosis
# {    'FGF2 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:affects -> FGF2': 1}
#
# Pathway result: PPARA_COL1A1_Hepatic_fibrosis
# {    'COL1A1 -> biolink:genetically_associated_with -> Hepatic fibrosis': 1,
#      'PPARA -> biolink:affects -> COL1A1': 1}
#
# Pathway result: PPARA_VIM_Hepatic_fibrosis
# {    'PPARA -> biolink:regulates -> VIM': 1,
#      'VIM -> biolink:genetically_associated_with -> Hepatic fibrosis': 1}
