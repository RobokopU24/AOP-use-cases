# %%
import requests
import json

# %% [markdown]
# TRAPI Documentation: https://github.com/NCATSTranslator/ReasonerAPI
#
# Most TRAPI documents contain a `message` key.  Within that `message` are a `query_graph` denoting the user query,
# a `knowledge_graph` consisting of the union of all nodes and edges that match the `query_graph` pattern, and a list of `results` that bind `query_graph` elements to `knowledge_graph` elements.
#
# The following message contains only a `query_graph`.  This query graph consists of 3 nodes connected together in a line.   Two of the nodes (`n00` and `n02`) have specified identifiers, while the middle node of the line does not.  Rather the middle node has a list of `categories` that are acceptable.
#
# For a researcher who is starting from a `name` who wants to use TRAPI, they can use the Node Resolver tool to get a list of identifers for the nodes.  For example, finding IDs for `Buprenorphine` is below.

# %%
search_string = 'ppara'
results = requests.post(f'https://name-resolution-sri.renci.org/lookup?string={search_string}&offset=0&limit=10')
results_json = results.json()
#print(json.dumps(results_json,indent=4))

# %%
input_node_id_list = list(results_json.keys())
print(input_node_id_list)
# Out:
# ['UniProtKB:P37230', 'UniProtKB:Q07869', 'UniProtKB:Q95N78', 'PR:000013056', 'UniProtKB:P23204', 'NCBIGene:19013', 'NCBIGene:25747', 'NCBIGene:5465', 'NCBIGene:557714', 'NCBIGene:30755']

# %% [markdown]
# For confirmation of the labels for each of these IDs, the Node Normalizer tool can be used to show contents.

# %%
nn_query = {
  "curies": input_node_id_list,
  "conflate": True
}
results = requests.post('https://nodenormalization-sri.renci.org/get_normalized_nodes',json=nn_query)

# %%
print(json.dumps(results.json(),indent=4))
# Out:
# {
#     "UniProtKB:P37230": {
#         "id": {
#             "identifier": "NCBIGene:25747",
#             "label": "Ppara"
#         },
#         "equivalent_identifiers": [
#             {
#                 "identifier": "NCBIGene:25747",
#                 "label": "Ppara"
#             },
#             {
#                 "identifier": "ENSEMBL:ENSRNOG00000021463"
#             },
#             {
#                 "identifier": "RGD:3369",
#                 "label": "Ppara"
#             },
#             {
#                 "identifier": "UniProtKB:P37230",
#                 "label": "PPARA_RAT Peroxisome proliferator-activated receptor alpha (sprot)"
#             },
#             {
#                 "identifier": "PR:P37230",
#                 "label": "peroxisome proliferator-activated receptor alpha (rat)"
#             },
#             {
#                 "identifier": "ENSEMBL:ENSRNOP00000038651"
#             }
#         ],
#         "type": [
#             "biolink:Gene",
#             "biolink:GeneOrGeneProduct",
#             "biolink:GenomicEntity",
#             "biolink:ChemicalEntityOrGeneOrGeneProduct",
#             "biolink:PhysicalEssence",
#             "biolink:OntologyClass",
#             "biolink:BiologicalEntity",
#             "biolink:NamedThing",
#             "biolink:Entity",
#             "biolink:PhysicalEssenceOrOccurrent",
#             "biolink:ThingWithTaxon",
#             "biolink:MacromolecularMachineMixin",
#             "biolink:Protein",
#             "biolink:GeneProductMixin",
#             "biolink:Polypeptide",
#             "biolink:ChemicalEntityOrProteinOrPolypeptide"
#         ],
#         "information_content": 94.9
#     },
#     "UniProtKB:Q07869": {
#         "id": {
#             "identifier": "NCBIGene:5465",
#             "label": "PPARA"
#         },
#         "equivalent_identifiers": [
#             {
#                 "identifier": "NCBIGene:5465",
#                 "label": "PPARA"
#             },
#             {
#                 "identifier": "ENSEMBL:ENSG00000186951"
#             },
#             {
#                 "identifier": "HGNC:9232",
#                 "label": "PPARA"
#             },
#             {
#                 "identifier": "OMIM:170998"
#             },
#             {
#                 "identifier": "UMLS:C1418776",
#                 "label": "PPARA gene"
#             },
#             {
#                 "identifier": "UniProtKB:F1D8S4",
#                 "label": "F1D8S4_HUMAN Peroxisome proliferator-activated receptor alpha (trembl)"
#             },
#             {
#                 "identifier": "UniProtKB:Q07869",
#                 "label": "PPARA_HUMAN Peroxisome proliferator-activated receptor alpha (sprot)"
#             },
#             {
#                 "identifier": "PR:Q07869",
#                 "label": "peroxisome proliferator-activated receptor alpha (human)"
#             },
#             {
#                 "identifier": "UMLS:C4551616",
#                 "label": "Peroxisome Proliferator-Activated Receptor Alpha, human"
#             }
#         ],
#         "type": [
#             "biolink:Gene",
#             "biolink:GeneOrGeneProduct",
#             "biolink:GenomicEntity",
#             "biolink:ChemicalEntityOrGeneOrGeneProduct",
#             "biolink:PhysicalEssence",
#             "biolink:OntologyClass",
#             "biolink:BiologicalEntity",
#             "biolink:NamedThing",
#             "biolink:Entity",
#             "biolink:PhysicalEssenceOrOccurrent",
#             "biolink:ThingWithTaxon",
#             "biolink:MacromolecularMachineMixin",
#             "biolink:Protein",
#             "biolink:GeneProductMixin",
#             "biolink:Polypeptide",
#             "biolink:ChemicalEntityOrProteinOrPolypeptide"
#         ],
#         "information_content": 91.9
#     },
#     "UniProtKB:Q95N78": {
#         "id": {
#             "identifier": "NCBIGene:403654",
#             "label": "PPARA"
#         },
#         "equivalent_identifiers": [
#             {
#                 "identifier": "NCBIGene:403654",
#                 "label": "PPARA"
#             },
#             {
#                 "identifier": "ENSEMBL:ENSCAFG00845010405"
#             },
#             {
#                 "identifier": "UniProtKB:Q95N78",
#                 "label": "PPARA_CANLF Peroxisome proliferator-activated receptor alpha (sprot)"
#             },
#             {
#                 "identifier": "PR:Q95N78",
#                 "label": "peroxisome proliferator-activated receptor alpha (dog)"
#             }
#         ],
#         "type": [
#             "biolink:Gene",
#             "biolink:GeneOrGeneProduct",
#             "biolink:GenomicEntity",
#             "biolink:ChemicalEntityOrGeneOrGeneProduct",
#             "biolink:PhysicalEssence",
#             "biolink:OntologyClass",
#             "biolink:BiologicalEntity",
#             "biolink:NamedThing",
#             "biolink:Entity",
#             "biolink:PhysicalEssenceOrOccurrent",
#             "biolink:ThingWithTaxon",
#             "biolink:MacromolecularMachineMixin",
#             "biolink:Protein",
#             "biolink:GeneProductMixin",
#             "biolink:Polypeptide",
#             "biolink:ChemicalEntityOrProteinOrPolypeptide"
#         ],
#         "information_content": 100.0
#     },
#     "PR:000013056": {
#         "id": {
#             "identifier": "PR:000013056",
#             "label": "peroxisome proliferator-activated receptor alpha"
#         },
#         "equivalent_identifiers": [
#             {
#                 "identifier": "PR:000013056",
#                 "label": "peroxisome proliferator-activated receptor alpha"
#             }
#         ],
#         "type": [
#             "biolink:Protein",
#             "biolink:GeneProductMixin",
#             "biolink:ThingWithTaxon",
#             "biolink:Polypeptide",
#             "biolink:ChemicalEntityOrGeneOrGeneProduct",
#             "biolink:ChemicalEntityOrProteinOrPolypeptide",
#             "biolink:BiologicalEntity",
#             "biolink:NamedThing",
#             "biolink:Entity",
#             "biolink:GeneOrGeneProduct",
#             "biolink:MacromolecularMachineMixin"
#         ],
#         "information_content": 83.1
#     },
#     "UniProtKB:P23204": {
#         "id": {
#             "identifier": "NCBIGene:19013",
#             "label": "Ppara"
#         },
#         "equivalent_identifiers": [
#             {
#                 "identifier": "NCBIGene:19013",
#                 "label": "Ppara"
#             },
#             {
#                 "identifier": "ENSEMBL:ENSMUSG00000022383",
#                 "label": "Ppara (Mmus)"
#             },
#             {
#                 "identifier": "MGI:104740",
#                 "label": "Ppara"
#             },
#             {
#                 "identifier": "UniProtKB:P23204",
#                 "label": "PPARA_MOUSE Peroxisome proliferator-activated receptor alpha (sprot)"
#             },
#             {
#                 "identifier": "PR:P23204",
#                 "label": "peroxisome proliferator-activated receptor alpha (mouse)"
#             },
#             {
#                 "identifier": "ENSEMBL:ENSMUSP00000059719"
#             },
#             {
#                 "identifier": "ENSEMBL:ENSMUSP00000105049"
#             },
#             {
#                 "identifier": "ENSEMBL:ENSMUSP00000105050"
#             },
#             {
#                 "identifier": "UniProtKB:Q542P9",
#                 "label": "Q542P9_MOUSE Peroxisome proliferator-activated receptor alpha (trembl)"
#             }
#         ],
#         "type": [
#             "biolink:Gene",
#             "biolink:GeneOrGeneProduct",
#             "biolink:GenomicEntity",
#             "biolink:ChemicalEntityOrGeneOrGeneProduct",
#             "biolink:PhysicalEssence",
#             "biolink:OntologyClass",
#             "biolink:BiologicalEntity",
#             "biolink:NamedThing",
#             "biolink:Entity",
#             "biolink:PhysicalEssenceOrOccurrent",
#             "biolink:ThingWithTaxon",
#             "biolink:MacromolecularMachineMixin",
#             "biolink:Protein",
#             "biolink:GeneProductMixin",
#             "biolink:Polypeptide",
#             "biolink:ChemicalEntityOrProteinOrPolypeptide"
#         ],
#         "information_content": 94.9
#     },
#     "NCBIGene:19013": {
#         "id": {
#             "identifier": "NCBIGene:19013",
#             "label": "Ppara"
#         },
#         "equivalent_identifiers": [
#             {
#                 "identifier": "NCBIGene:19013",
#                 "label": "Ppara"
#             },
#             {
#                 "identifier": "ENSEMBL:ENSMUSG00000022383",
#                 "label": "Ppara (Mmus)"
#             },
#             {
#                 "identifier": "MGI:104740",
#                 "label": "Ppara"
#             },
#             {
#                 "identifier": "UniProtKB:P23204",
#                 "label": "PPARA_MOUSE Peroxisome proliferator-activated receptor alpha (sprot)"
#             },
#             {
#                 "identifier": "PR:P23204",
#                 "label": "peroxisome proliferator-activated receptor alpha (mouse)"
#             },
#             {
#                 "identifier": "ENSEMBL:ENSMUSP00000059719"
#             },
#             {
#                 "identifier": "ENSEMBL:ENSMUSP00000105049"
#             },
#             {
#                 "identifier": "ENSEMBL:ENSMUSP00000105050"
#             },
#             {
#                 "identifier": "UniProtKB:Q542P9",
#                 "label": "Q542P9_MOUSE Peroxisome proliferator-activated receptor alpha (trembl)"
#             }
#         ],
#         "type": [
#             "biolink:Gene",
#             "biolink:GeneOrGeneProduct",
#             "biolink:GenomicEntity",
#             "biolink:ChemicalEntityOrGeneOrGeneProduct",
#             "biolink:PhysicalEssence",
#             "biolink:OntologyClass",
#             "biolink:BiologicalEntity",
#             "biolink:NamedThing",
#             "biolink:Entity",
#             "biolink:PhysicalEssenceOrOccurrent",
#             "biolink:ThingWithTaxon",
#             "biolink:MacromolecularMachineMixin",
#             "biolink:Protein",
#             "biolink:GeneProductMixin",
#             "biolink:Polypeptide",
#             "biolink:ChemicalEntityOrProteinOrPolypeptide"
#         ],
#         "information_content": 100.0
#     },
#     "NCBIGene:25747": {
#         "id": {
#             "identifier": "NCBIGene:25747",
#             "label": "Ppara"
#         },
#         "equivalent_identifiers": [
#             {
#                 "identifier": "NCBIGene:25747",
#                 "label": "Ppara"
#             },
#             {
#                 "identifier": "ENSEMBL:ENSRNOG00000021463"
#             },
#             {
#                 "identifier": "RGD:3369",
#                 "label": "Ppara"
#             },
#             {
#                 "identifier": "UniProtKB:P37230",
#                 "label": "PPARA_RAT Peroxisome proliferator-activated receptor alpha (sprot)"
#             },
#             {
#                 "identifier": "PR:P37230",
#                 "label": "peroxisome proliferator-activated receptor alpha (rat)"
#             },
#             {
#                 "identifier": "ENSEMBL:ENSRNOP00000038651"
#             }
#         ],
#         "type": [
#             "biolink:Gene",
#             "biolink:GeneOrGeneProduct",
#             "biolink:GenomicEntity",
#             "biolink:ChemicalEntityOrGeneOrGeneProduct",
#             "biolink:PhysicalEssence",
#             "biolink:OntologyClass",
#             "biolink:BiologicalEntity",
#             "biolink:NamedThing",
#             "biolink:Entity",
#             "biolink:PhysicalEssenceOrOccurrent",
#             "biolink:ThingWithTaxon",
#             "biolink:MacromolecularMachineMixin",
#             "biolink:Protein",
#             "biolink:GeneProductMixin",
#             "biolink:Polypeptide",
#             "biolink:ChemicalEntityOrProteinOrPolypeptide"
#         ],
#         "information_content": 100.0
#     },
#     "NCBIGene:5465": {
#         "id": {
#             "identifier": "NCBIGene:5465",
#             "label": "PPARA"
#         },
#         "equivalent_identifiers": [
#             {
#                 "identifier": "NCBIGene:5465",
#                 "label": "PPARA"
#             },
#             {
#                 "identifier": "ENSEMBL:ENSG00000186951"
#             },
#             {
#                 "identifier": "HGNC:9232",
#                 "label": "PPARA"
#             },
#             {
#                 "identifier": "OMIM:170998"
#             },
#             {
#                 "identifier": "UMLS:C1418776",
#                 "label": "PPARA gene"
#             },
#             {
#                 "identifier": "UniProtKB:F1D8S4",
#                 "label": "F1D8S4_HUMAN Peroxisome proliferator-activated receptor alpha (trembl)"
#             },
#             {
#                 "identifier": "UniProtKB:Q07869",
#                 "label": "PPARA_HUMAN Peroxisome proliferator-activated receptor alpha (sprot)"
#             },
#             {
#                 "identifier": "PR:Q07869",
#                 "label": "peroxisome proliferator-activated receptor alpha (human)"
#             },
#             {
#                 "identifier": "UMLS:C4551616",
#                 "label": "Peroxisome Proliferator-Activated Receptor Alpha, human"
#             }
#         ],
#         "type": [
#             "biolink:Gene",
#             "biolink:GeneOrGeneProduct",
#             "biolink:GenomicEntity",
#             "biolink:ChemicalEntityOrGeneOrGeneProduct",
#             "biolink:PhysicalEssence",
#             "biolink:OntologyClass",
#             "biolink:BiologicalEntity",
#             "biolink:NamedThing",
#             "biolink:Entity",
#             "biolink:PhysicalEssenceOrOccurrent",
#             "biolink:ThingWithTaxon",
#             "biolink:MacromolecularMachineMixin",
#             "biolink:Protein",
#             "biolink:GeneProductMixin",
#             "biolink:Polypeptide",
#             "biolink:ChemicalEntityOrProteinOrPolypeptide"
#         ],
#         "information_content": 100.0
#     },
#     "NCBIGene:557714": {
#         "id": {
#             "identifier": "NCBIGene:557714",
#             "label": "pparab"
#         },
#         "equivalent_identifiers": [
#             {
#                 "identifier": "NCBIGene:557714",
#                 "label": "pparab"
#             },
#             {
#                 "identifier": "ENSEMBL:ENSDARG00000054323"
#             },
#             {
#                 "identifier": "ZFIN:ZDB-GENE-990415-211",
#                 "label": "pparab"
#             },
#             {
#                 "identifier": "UniProtKB:A0A8M3AW97",
#                 "label": "A0A8M3AW97_DANRE Peroxisome proliferator-activated receptor alpha (trembl)"
#             },
#             {
#                 "identifier": "UniProtKB:A6XMH7",
#                 "label": "A6XMH7_DANRE Peroxisome proliferator-activated receptor alpha (trembl)"
#             },
#             {
#                 "identifier": "UniProtKB:K7DY57",
#                 "label": "K7DY57_DANRE Peroxisome proliferator-activated receptor alpha (trembl)"
#             },
#             {
#                 "identifier": "ENSEMBL:ENSDARP00000126384"
#             },
#             {
#                 "identifier": "ENSEMBL:ENSDARP00000126384.1"
#             },
#             {
#                 "identifier": "ENSEMBL:ENSDARP00000156861"
#             },
#             {
#                 "identifier": "ENSEMBL:ENSDARP00000156861.1"
#             }
#         ],
#         "type": [
#             "biolink:Gene",
#             "biolink:GeneOrGeneProduct",
#             "biolink:GenomicEntity",
#             "biolink:ChemicalEntityOrGeneOrGeneProduct",
#             "biolink:PhysicalEssence",
#             "biolink:OntologyClass",
#             "biolink:BiologicalEntity",
#             "biolink:NamedThing",
#             "biolink:Entity",
#             "biolink:PhysicalEssenceOrOccurrent",
#             "biolink:ThingWithTaxon",
#             "biolink:MacromolecularMachineMixin",
#             "biolink:Protein",
#             "biolink:GeneProductMixin",
#             "biolink:Polypeptide",
#             "biolink:ChemicalEntityOrProteinOrPolypeptide"
#         ]
#     },
#     "NCBIGene:30755": {
#         "id": {
#             "identifier": "NCBIGene:30755",
#             "label": "ppara2"
#         },
#         "equivalent_identifiers": [
#             {
#                 "identifier": "NCBIGene:30755",
#                 "label": "ppara2"
#             },
#             {
#                 "identifier": "ZFIN:ZDB-GENE-000112-40",
#                 "label": "ppara2"
#             }
#         ],
#         "type": [
#             "biolink:Gene",
#             "biolink:GeneOrGeneProduct",
#             "biolink:GenomicEntity",
#             "biolink:ChemicalEntityOrGeneOrGeneProduct",
#             "biolink:PhysicalEssence",
#             "biolink:OntologyClass",
#             "biolink:BiologicalEntity",
#             "biolink:NamedThing",
#             "biolink:Entity",
#             "biolink:PhysicalEssenceOrOccurrent",
#             "biolink:ThingWithTaxon",
#             "biolink:MacromolecularMachineMixin"
#         ]
#     }
# }

# %% [markdown]
# Now to find the IDs associated with our disease

# %%
search_string = 'liver fibrosis'
results = requests.post(f'https://name-resolution-sri.renci.org/lookup?string={search_string}&offset=0&limit=10')
results_json = results.json()

# %%
output_node_id_list = list(results_json.keys())
print(output_node_id_list)
# Out:
# ['HP:0001395', 'UMLS:C4227681', 'UMLS:C4034373', 'UMLS:C5189427', 'UMLS:C0544816', 'MONDO:0100430', 'MONDO:0018840', 'UMLS:C1397317', 'UMLS:C4068302', 'UMLS:C4481250']

# %%
nn_query = {
  "curies": output_node_id_list,
  "conflate": True
}
results = requests.post('https://nodenormalization-sri.renci.org/get_normalized_nodes',json=nn_query)
print(json.dumps(results.json(),indent=4))
# Out:
# {
#     "HP:0001395": {
#         "id": {
#             "identifier": "HP:0001395",
#             "label": "Hepatic fibrosis"
#         },
#         "equivalent_identifiers": [
#             {
#                 "identifier": "HP:0001395",
#                 "label": "Hepatic fibrosis"
#             },
#             {
#                 "identifier": "NCIT:C168581",
#                 "label": "Liver Fibrosis"
#             },
#             {
#                 "identifier": "UMLS:C0239946",
#                 "label": "Fibrosis, Liver"
#             },
#             {
#                 "identifier": "MEDDRA:10016648"
#             },
#             {
#                 "identifier": "MEDDRA:10019668"
#             },
#             {
#                 "identifier": "SNOMEDCT:62484002"
#             }
#         ],
#         "type": [
#             "biolink:PhenotypicFeature",
#             "biolink:DiseaseOrPhenotypicFeature",
#             "biolink:ThingWithTaxon",
#             "biolink:BiologicalEntity",
#             "biolink:NamedThing",
#             "biolink:Entity"
#         ],
#         "information_content": 89.8
#     },
#     "UMLS:C4227681": {
#         "id": {
#             "identifier": "UMLS:C4227681",
#             "label": "Liver fibrosis, mild"
#         },
#         "equivalent_identifiers": [
#             {
#                 "identifier": "UMLS:C4227681",
#                 "label": "Liver fibrosis, mild"
#             }
#         ],
#         "type": [
#             "biolink:PhenotypicFeature",
#             "biolink:DiseaseOrPhenotypicFeature",
#             "biolink:ThingWithTaxon",
#             "biolink:BiologicalEntity",
#             "biolink:NamedThing",
#             "biolink:Entity"
#         ]
#     },
#     "UMLS:C4034373": {
#         "id": {
#             "identifier": "UMLS:C4034373",
#             "label": "liver fibrosis score"
#         },
#         "equivalent_identifiers": [
#             {
#                 "identifier": "UMLS:C4034373",
#                 "label": "liver fibrosis score"
#             }
#         ],
#         "type": [
#             "biolink:Procedure",
#             "biolink:ActivityAndBehavior",
#             "biolink:NamedThing",
#             "biolink:Entity",
#             "biolink:Occurrent",
#             "biolink:PhysicalEssenceOrOccurrent"
#         ]
#     },
#     "UMLS:C5189427": {
#         "id": {
#             "identifier": "UMLS:C5189427",
#             "label": "liver fibrosis stage"
#         },
#         "equivalent_identifiers": [
#             {
#                 "identifier": "UMLS:C5189427",
#                 "label": "liver fibrosis stage"
#             }
#         ],
#         "type": [
#             "biolink:Procedure",
#             "biolink:ActivityAndBehavior",
#             "biolink:NamedThing",
#             "biolink:Entity",
#             "biolink:Occurrent",
#             "biolink:PhysicalEssenceOrOccurrent"
#         ]
#     },
#     "UMLS:C0544816": {
#         "id": {
#             "identifier": "UMLS:C0544816",
#             "label": "Septal fibrosis of liver"
#         },
#         "equivalent_identifiers": [
#             {
#                 "identifier": "UMLS:C0544816",
#                 "label": "Septal fibrosis of liver"
#             },
#             {
#                 "identifier": "SNOMEDCT:123607009"
#             }
#         ],
#         "type": [
#             "biolink:Disease",
#             "biolink:DiseaseOrPhenotypicFeature",
#             "biolink:ThingWithTaxon",
#             "biolink:BiologicalEntity",
#             "biolink:NamedThing",
#             "biolink:Entity"
#         ]
#     },
#     "MONDO:0100430": {
#         "id": {
#             "identifier": "MONDO:0100430",
#             "label": "fibrotic liver disease"
#         },
#         "equivalent_identifiers": [
#             {
#                 "identifier": "MONDO:0100430",
#                 "label": "fibrotic liver disease"
#             }
#         ],
#         "type": [
#             "biolink:Disease",
#             "biolink:DiseaseOrPhenotypicFeature",
#             "biolink:ThingWithTaxon",
#             "biolink:BiologicalEntity",
#             "biolink:NamedThing",
#             "biolink:Entity"
#         ]
#     },
#     "MONDO:0018840": {
#         "id": {
#             "identifier": "MONDO:0018840",
#             "label": "isolated congenital hepatic fibrosis"
#         },
#         "equivalent_identifiers": [
#             {
#                 "identifier": "MONDO:0018840",
#                 "label": "isolated congenital hepatic fibrosis"
#             },
#             {
#                 "identifier": "ORPHANET:485426"
#             },
#             {
#                 "identifier": "UMLS:C0009714",
#                 "label": "Hepatic Fibrosis, Congenital"
#             },
#             {
#                 "identifier": "MESH:C562378",
#                 "label": "Hepatic Fibrosis, Congenital"
#             },
#             {
#                 "identifier": "MEDDRA:10056533"
#             },
#             {
#                 "identifier": "NCIT:C97071",
#                 "label": "Congenital Hepatic Fibrosis"
#             },
#             {
#                 "identifier": "SNOMEDCT:79607001"
#             },
#             {
#                 "identifier": "HP:0002612",
#                 "label": "Congenital hepatic fibrosis"
#             }
#         ],
#         "type": [
#             "biolink:Disease",
#             "biolink:DiseaseOrPhenotypicFeature",
#             "biolink:ThingWithTaxon",
#             "biolink:BiologicalEntity",
#             "biolink:NamedThing",
#             "biolink:Entity"
#         ],
#         "information_content": 100.0
#     },
#     "UMLS:C1397317": {
#         "id": {
#             "identifier": "UMLS:C1397317",
#             "label": "Fibrosis of liver caused by alcohol"
#         },
#         "equivalent_identifiers": [
#             {
#                 "identifier": "UMLS:C1397317",
#                 "label": "Fibrosis of liver caused by alcohol"
#             },
#             {
#                 "identifier": "SNOMEDCT:721710005"
#             }
#         ],
#         "type": [
#             "biolink:Disease",
#             "biolink:DiseaseOrPhenotypicFeature",
#             "biolink:ThingWithTaxon",
#             "biolink:BiologicalEntity",
#             "biolink:NamedThing",
#             "biolink:Entity"
#         ]
#     },
#     "UMLS:C4068302": {
#         "id": {
#             "identifier": "UMLS:C4068302",
#             "label": "Liver fibrosis score panel"
#         },
#         "equivalent_identifiers": [
#             {
#                 "identifier": "UMLS:C4068302",
#                 "label": "Liver fibrosis score panel"
#             }
#         ],
#         "type": [
#             "biolink:Procedure",
#             "biolink:ActivityAndBehavior",
#             "biolink:NamedThing",
#             "biolink:Entity",
#             "biolink:Occurrent",
#             "biolink:PhysicalEssenceOrOccurrent"
#         ]
#     },
#     "UMLS:C4481250": {
#         "id": {
#             "identifier": "UMLS:C4481250",
#             "label": "biopsy liver portal fibrosis"
#         },
#         "equivalent_identifiers": [
#             {
#                 "identifier": "UMLS:C4481250",
#                 "label": "biopsy liver portal fibrosis"
#             }
#         ],
#         "type": [
#             "biolink:PhenotypicFeature",
#             "biolink:DiseaseOrPhenotypicFeature",
#             "biolink:ThingWithTaxon",
#             "biolink:BiologicalEntity",
#             "biolink:NamedThing",
#             "biolink:Entity"
#         ]
#     }
# }

# %% [markdown]
# This query asks "Find me a Biological Process or Activity, or a Gene, or a Pathway that is related to both `HP:0001337` (Tremor) and the list of IDs above found searching the Name Resolver with `Buprenorphine`.

# %%
query={
    "message": {
      "query_graph": {
        "edges": {
          "e00": {
            "subject": "n00",
              "object": "n01",
          "predicates":["biolink:related_to"]
          },
          "e01": {
            "subject": "n01",
              "object": "n02",
          "predicates":["biolink:related_to"]
          }
        },
        "nodes": {
          "n00": {
            "ids": input_node_id_list,
            "categories": ["biolink:BiologicalEntity"]
          },
          "n01": {
              #"categories": ["biolink:BiologicalEntity"]
              "categories": ["biolink:BiologicalProcessOrActivity","biolink:Gene","biolink:Pathway"]
          },
          "n02": {
            "ids": output_node_id_list, #["HP:0001395"],
            #  "categories": ["biolink:BiologicalEntity"]
            "categories": ["biolink:DiseaseOrPhenotypicFeature"]
          }

        }
      }
    }
  }

# %% [markdown]
# This query can be sent to various components of Translator as needed.  It can be sent directly to the ROBOKOP database like this:

# %%
robokop_submit_url = "https://automat.renci.org/robokopkg/1.3/query"
response = requests.post(robokop_submit_url,json=query)

# %%
print(response.status_code)
# Out:
# 200

# %%
print(len(response.json()['message']['results']))
# Out:
# 36

# %%
import pprint
pp = pprint.PrettyPrinter(indent=5)

# %% [markdown]
# The response in JSON form is a python dictionary with three main keys, the `message`, `log_level`, and `workflow`.  The `message` component contains the `query_graph`, `knowledge_graph`, and `results` from the query.

# %%
print(response.json().keys())
print(response.json()['message'].keys())
# Out:
# dict_keys(['message', 'log_level', 'workflow'])
# dict_keys(['query_graph', 'knowledge_graph', 'results'])

# %% [markdown]
# The `results` component contains pathways resulting from the query message. Each pathway is organized into edge_bindings and node bindings and contains results for the edges and nodes specified in the query message.  Results are represented in identifier form, which can be found in the `knowledge_graph` component of the `message` section of the response.

# %%
pp.pprint(response.json()['message']['results'][0])
# Out:
# {    'edge_bindings': {    'e00': [    {'attributes': None, 'id': '77699818'},
#                                        {'attributes': None, 'id': '65555672'}],
#                            'e01': [{'attributes': None, 'id': '90073165'}]},
#      'node_bindings': {    'n00': [    {    'attributes': None,
#                                             'id': 'UniProtKB:Q07869-1',
#                                             'qnode_id': 'NCBIGene:5465',
#                                             'query_id': None}],
#                            'n01': [    {    'attributes': None,
#                                             'id': 'NCBIGene:6347',
#                                             'query_id': None}],
#                            'n02': [    {    'attributes': None,
#                                             'id': 'HP:0001395',
#                                             'qnode_id': 'HP:0001395',
#                                             'query_id': None}]},
#      'score': None}

# %% [markdown]
# The `knowledge_graph` contains information about each of the Nodes and Edges found in `results`.  An example of a Node and an Edge are shown below.

# %%
pp.pprint(response.json()['message']['knowledge_graph'].keys())
# Out:
# {    'edges': {    '103813207': {    'attributes': [    {    'attribute_source': 'infores:automat-robokop',
#                                                              'attribute_type_id': 'biolink:aggregator_knowledge_source',
#                                                              'attributes': None,
#                                                              'description': None,
#                                                              'original_attribute_name': 'biolink:aggregator_knowledge_source',
#                                                              'value': [    'infores:automat-robokop',
#                                                                            'infores:sri-reference-kg'],
#                                                              'value_type_id': 'biolink:InformationResource',
#                                                              'value_url': None},
#                                                         {    'attribute_source': 'infores:automat-robokop',
#                                                              'attribute_type_id': 'biolink:primary_knowledge_source',
#                                                              'attributes': None,
#                                                              'description': None,
#                                                              'original_attribute_name': 'biolink:primary_knowledge_source',
#                                                              'value': 'infores:biolink',
#                                                              'value_type_id': 'biolink:InformationResource',
#                                                              'value_url': None}],
#                                      'object': 'NCBIGene:5244',
#                                      'predicate': 'biolink:interacts_with',
#                                      'qualifiers': None,
#                                      'subject': 'NCBIGene:5465'},
#                    '104558425': {    'attributes': [    {    'attribute_source': 'infores:automat-robokop',
#                                                              'attribute_type_id': 'biolink:aggregator_knowledge_source',
#                                                              'attributes': None,
#                                                              'description': None,
#                                                              'original_attribute_name': 'biolink:aggregator_knowledge_source',
#                                                              'value': [    'infores:automat-robokop',
#                                                                            'infores:pharos'],
#                                                              'value_type_id': 'biolink:InformationResource',
#                                                              'value_url': None},
#                                                         {    'attribute_source': 'infores:automat-robokop',
#                                                              'attribute_type_id': 'biolink:primary_knowledge_source',
#                                                              'attributes': None,
#                                                              'description': None,
#                                                              'original_attribute_name': 'biolink:primary_knowledge_source',
#                                                              'value': 'DisGeNET',
#                                                              'value_type_id': 'biolink:InformationResource',
#                                                              'value_url': None}],
#                                      'object': 'HP:0001395',
#                                      'predicate': 'biolink:genetic_association',
#                                      'qualifiers': None,
#                                      'subject': 'NCBIGene:3484'},
#                    '10563763': {    'attributes': [    {    'attribute_source': 'infores:automat-robokop',
#                                                             'attribute_type_id': 'biolink:aggregator_knowledge_source',
#                                                             'attributes': None,
#                                                             'description': None,
#                                                             'original_attribute_name': 'biolink:aggregator_knowledge_source',
#                                                             'value': [    'infores:automat-robokop',
#                                                                           'infores:pharos'],
#                                                             'value_type_id': 'biolink:InformationResource',
#                                                             'value_url': None},
#                                                        {    'attribute_source': 'infores:automat-robokop',
#                                                             'attribute_type_id': 'biolink:primary_knowledge_source',
#                                                             'attributes': None,
#                                                             'description': None,
#                                                             'original_attribute_name': 'biolink:primary_knowledge_source',
#                                                             'value': 'DisGeNET',
#                                                             'value_type_id': 'biolink:InformationResource',
#                                                             'value_url': None}],
#                                     'object': 'HP:0001395',
#                                     'predicate': 'biolink:genetic_association',
#                                     'qualifiers': None,
#                                     'subject': 'NCBIGene:1269'},
#                    '107697294': {    'attributes': [    {    'attribute_source': 'infores:automat-robokop',
#                                                              'attribute_type_id': 'biolink:aggregator_knowledge_source',
#                                                              'attributes': None,
#                                                              'description': None,
#                                                              'original_attribute_name': 'biolink:aggregator_knowledge_source',
#                                                              'value': [    'infores:automat-robokop'],
#                                                              'value_type_id': 'biolink:InformationResource',
#                                                              'value_url': None},
#                                                         {    'attribute_source': 'infores:automat-robokop',
#                                                              'attribute_type_id': 'biolink:primary_knowledge_source',
#                                                              'attributes': None,
#                                                              'description': None,
#                                                              'original_attribute_name': 'biolink:primary_knowledge_source',
#                                                              'value': 'infores:STRING',
#                                                              'value_type_id': 'biolink:InformationResource',
#                                                              'value_url': None}],
#                                      'object': 'UniProtKB:Q07869-1',
#                                      'predicate': 'biolink:coexpressed_with',
#                                      'qualifiers': None,
#                                      'subject': 'NCBIGene:1269'},
#                    '110120221': {    'attributes': [    {    'attribute_source': 'infores:automat-robokop',
#                                                              'attribute_type_id': 'biolink:aggregator_knowledge_source',
#                                                              'attributes': None,
#                                                              'description': None,
#                                                              'original_attribute_name': 'biolink:aggregator_knowledge_source',
#                                                              'value': [    'infores:automat-robokop',
#                                                                            'infores:sri-reference-kg'],
#                                                              'value_type_id': 'biolink:InformationResource',
#                                                              'value_url': None},
#                                                         {    'attribute_source': 'infores:automat-robokop',
#                                                              'attribute_type_id': 'biolink:primary_knowledge_source',
#                                                              'attributes': None,
#                                                              'description': None,
#                                                              'original_attribute_name': 'biolink:primary_knowledge_source',
#                                                              'value': 'infores:biolink',
#                                                              'value_type_id': 'biolink:InformationResource',
#                                                              'value_url': None}],
#                                      'object': 'NCBIGene:5465',
#                                      'predicate': 'biolink:interacts_with',
#                                      'qualifiers': None,
#                                      'subject': 'NCBIGene:6772'},
#                    '112023883': {    'attributes': [    {    'attribute_source': 'infores:automat-robokop',
#                                                              'attribute_type_id': 'biolink:aggregator_knowledge_source',
#                                                              'attributes': None,
#                                                              'description': None,
#                                                              'original_attribute_name': 'biolink:aggregator_knowledge_source',
#                                                              'value': [    'infores:automat-robokop',
#                                                                            'infores:sri-reference-kg'],
#                                                              'value_type_id': 'biolink:InformationResource',
#                                                              'value_url': None},
#                                                         {    'attribute_source': 'infores:automat-robokop',
#                                                              'attribute_type_id': 'biolink:primary_knowledge_source',
#                                                              'attributes': None,
#                                                              'description': None,
#                                                              'original_attribute_name': 'biolink:primary_knowledge_source',
#                                                              'value': 'infores:biolink',
#                                                              'value_type_id': 'biolink:InformationResource',
#                                                              'value_url': None}],
#                                      'object': 'NCBIGene:2147',
#                                      'predicate': 'biolink:interacts_with',
#                                      'qualifiers': None,
#                                      'subject': 'NCBIGene:5465'},
#                    '112899352': {    'attributes': [    {    'attribute_source': 'infores:automat-robokop',
#                                                              'attribute_type_id': 'biolink:aggregator_knowledge_source',
#                                                              'attributes': None,
#                                                              'description': None,
#                                                              'original_attribute_name': 'biolink:aggregator_knowledge_source',
#                                                              'value': [    'infores:automat-robokop'],
#                                                              'value_type_id': 'biolink:InformationResource',
#                                                              'value_url': None},
#                                                         {    'attribute_source': 'infores:automat-robokop',
#                                                              'attribute_type_id': 'biolink:primary_knowledge_source',
#                                                              'attributes': None,
#                                                              'description': None,
#                                                              'original_attribute_name': 'biolink:primary_knowledge_source',
#                                                              'value': 'infores:STRING',
#                                                              'value_type_id': 'biolink:InformationResource',
#                                                              'value_url': None}],
#                                      'object': 'NCBIGene:120227',
#                                      'predicate': 'biolink:coexpressed_with',
#                                      'qualifiers': None,
#                                      'subject': 'UniProtKB:Q07869-1'},
#                    '114718535': {    'attributes': [    {    'attribute_source': 'infores:automat-robokop',
#                                                              'attribute_type_id': 'biolink:aggregator_knowledge_source',
#                                                              'attributes': None,
#                                                              'description': None,
#                                                              'original_attribute_name': 'biolink:aggregator_knowledge_source',
#                                                              'value': [    'infores:automat-robokop',
#                                                                            'infores:pharos'],
#                                                              'value_type_id': 'biolink:InformationResource',
#                                                              'value_url': None},
#                                                         {    'attribute_source': 'infores:automat-robokop',
#                                                              'attribute_type_id': 'biolink:primary_knowledge_source',
#                                                              'attributes': None,
#                                                              'description': None,
#                                                              'original_attribute_name': 'biolink:primary_knowledge_source',
#                                                              'value': 'DisGeNET',
#                                                              'value_type_id': 'biolink:InformationResource',
#                                                              'value_url': None}],
#                                      'object': 'HP:0001395',
#                                      'predicate': 'biolink:genetic_association',
#                                      'qualifiers': None,
#                                      'subject': 'NCBIGene:6696'},
#                    '117760752': {    'attributes': [    {    'attribute_source': 'infores:automat-robokop',
#                                                              'attribute_type_id': 'biolink:aggregator_knowledge_source',
#                                                              'attributes': None,
#                                                              'description': None,
#                                                              'original_attribute_name': 'biolink:aggregator_knowledge_source',
#                                                              'value': [    'infores:automat-robokop',
#                                                                            'infores:pharos'],
#                                                              'value_type_id': 'biolink:InformationResource',
#                                                              'value_url': None},
#                                                         {    'attribute_source': 'infores:automat-robokop',
#                                                              'attribute_type_id': 'biolink:primary_knowledge_source',
#                                                              'attributes': None,
#                                                              'description': None,
#                                                              'original_attribute_name': 'biolink:primary_knowledge_source',
#                                                              'value': 'DisGeNET',
#                                                              'value_type_id': 'biolink:InformationResource',
#                                                              'value_url': None}],
#                                      'object': 'HP:0001395',
#                                      'predicate': 'biolink:genetic_association',
#                                      'qualifiers': None,
#                                      'subject': 'NCBIGene:213'},
#                    '117801464': {    'attributes': [    {    'attribute_source': 'infores:automat-robokop',
#                                                              'attribute_type_id': 'biolink:aggregator_knowledge_source',
#                                                              'attributes': None,
#                                                              'description': None,
#                                                              'original_attribute_name': 'biolink:aggregator_knowledge_source',
#                                                              'value': [    'infores:automat-robokop'],
#                                                              'value_type_id': 'biolink:InformationResource',
#                                                              'value_url': None},
#                                                         {    'attribute_source': 'infores:automat-robokop',
#                                                              'attribute_type_id': 'biolink:primary_knowledge_source',
#                                                              'attributes': None,
#                                                              'description': None,
#                                                              'original_attribute_name': 'biolink:primary_knowledge_source',
#                                                              'value': 'infores:STRING',
#                                                              'value_type_id': 'biolink:InformationResource',
#                                                              'value_url': None}],
#                                      'object': 'UniProtKB:Q07869-1',
#                                      'predicate': 'biolink:coexpressed_with',
#                                      'qualifiers': None,
#                                      'subject': 'NCBIGene:3875'},
#                    '122392360': {    'attributes': [    {    'attribute_source': 'infores:automat-robokop',
#                                                              'attribute_type_id': 'biolink:aggregator_knowledge_source',
#                                                              'attributes': None,
#                                                              'description': None,
#                                                              'original_attribute_name': 'biolink:aggregator_knowledge_source',
#                                                              'value': [    'infores:automat-robokop',
#                                                                            'infores:pharos'],
#                                                              'value_type_id': 'biolink:InformationResource',
#                                                              'value_url': None},
#                                                         {    'attribute_source': 'infores:automat-robokop',
#                                                              'attribute_type_id': 'biolink:primary_knowledge_source',
#                                                              'attributes': None,
#                                                              'description': None,
#                                                              'original_attribute_name': 'biolink:primary_knowledge_source',
#                                                              'value': 'DisGeNET',
#                                                              'value_type_id': 'biolink:InformationResource',
#                                                              'value_url': None}],
#                                      'object': 'HP:0001395',
#                                      'predicate': 'biolink:genetic_association',
#                                      'qualifiers': None,
#                                      'subject': 'NCBIGene:1593'},
#                    '125795180': {    'attributes': [    {    'attribute_source': 'infores:automat-robokop',
#                                                              'attribute_type_id': 'biolink:aggregator_knowledge_source',
#                                                              'attributes': None,
#                                                              'description': None,
#                                                              'original_attribute_name': 'biolink:aggregator_knowledge_source',
#                                                              'value': [    'infores:automat-robokop',
#                                                                            'infores:pharos'],
#                                                              'value_type_id': 'biolink:InformationResource',
#                                                              'value_url': None},
#                                                         {    'attribute_source': 'infores:automat-robokop',
#                                                              'attribute_type_id': 'biolink:primary_knowledge_source',
#                                                              'attributes': None,
#                                                              'description': None,
#                                                              'original_attribute_name': 'biolink:primary_knowledge_source',
#                                                              'value': 'DisGeNET',
#                                                              'value_type_id': 'biolink:InformationResource',
#                                                              'value_url': None}],
#                                      'object': 'HP:0001395',
#                                      'predicate': 'biolink:genetic_association',
#                                      'qualifiers': None,
#                                      'subject': 'NCBIGene:6772'},
#                    '125931491': {    'attributes': [    {    'attribute_source': 'infores:automat-robokop',
#                                                              'attribute_type_id': 'biolink:aggregator_knowledge_source',
#                                                              'attributes': None,
#                                                              'description': None,
#                                                              'original_attribute_name': 'biolink:aggregator_knowledge_source',
#                                                              'value': [    'infores:automat-robokop',
#                                                                            'infores:pharos'],
#                                                              'value_type_id': 'biolink:InformationResource',
#                                                              'value_url': None},
#                                                         {    'attribute_source': 'infores:automat-robokop',
#                                                              'attribute_type_id': 'biolink:primary_knowledge_source',
#                                                              'attributes': None,
#                                                              'description': None,
#                                                              'original_attribute_name': 'biolink:primary_knowledge_source',
#                                                              'value': 'DisGeNET',
#                                                              'value_type_id': 'biolink:InformationResource',
#                                                              'value_url': None}],
#                                      'object': 'HP:0001395',
#                                      'predicate': 'biolink:genetic_association',
#                                      'qualifiers': None,
#                                      'subject': 'NCBIGene:2147'},
#                    '13704030': {    'attributes': [    {    'attribute_source': 'infores:automat-robokop',
#                                                             'attribute_type_id': 'biolink:aggregator_knowledge_source',
#                                                             'attributes': None,
#                                                             'description': None,
#                                                             'original_attribute_name': 'biolink:aggregator_knowledge_source',
#                                                             'value': [    'infores:automat-robokop'],
#                                                             'value_type_id': 'biolink:InformationResource',
#                                                             'value_url': None},
#                                                        {    'attribute_source': 'infores:automat-robokop',
#                                                             'attribute_type_id': 'biolink:primary_knowledge_source',
#                                                             'attributes': None,
#                                                             'description': None,
#                                                             'original_attribute_name': 'biolink:primary_knowledge_source',
#                                                             'value': 'infores:STRING',
#                                                             'value_type_id': 'biolink:InformationResource',
#                                                             'value_url': None}],
#                                     'object': 'UniProtKB:Q07869-1',
#                                     'predicate': 'biolink:coexpressed_with',
#                                     'qualifiers': None,
#                                     'subject': 'NCBIGene:3484'},
#                    '16738860': {    'attributes': [    {    'attribute_source': 'infores:automat-robokop',
#                                                             'attribute_type_id': 'biolink:aggregator_knowledge_source',
#                                                             'attributes': None,
#                                                             'description': None,
#                                                             'original_attribute_name': 'biolink:aggregator_knowledge_source',
#                                                             'value': [    'infores:automat-robokop'],
#                                                             'value_type_id': 'biolink:InformationResource',
#                                                             'value_url': None},
#                                                        {    'attribute_source': 'infores:automat-robokop',
#                                                             'attribute_type_id': 'biolink:primary_knowledge_source',
#                                                             'attributes': None,
#                                                             'description': None,
#                                                             'original_attribute_name': 'biolink:primary_knowledge_source',
#                                                             'value': 'infores:STRING',
#                                                             'value_type_id': 'biolink:InformationResource',
#                                                             'value_url': None}],
#                                     'object': 'UniProtKB:Q07869-1',
#                                     'predicate': 'biolink:coexpressed_with',
#                                     'qualifiers': None,
#                                     'subject': 'NCBIGene:1356'},
#                    '17412017': {    'attributes': [    {    'attribute_source': 'infores:automat-robokop',
#                                                             'attribute_type_id': 'biolink:aggregator_knowledge_source',
#                                                             'attributes': None,
#                                                             'description': None,
#                                                             'original_attribute_name': 'biolink:aggregator_knowledge_source',
#                                                             'value': [    'infores:automat-robokop'],
#                                                             'value_type_id': 'biolink:InformationResource',
#                                                             'value_url': None},
#                                                        {    'attribute_source': 'infores:automat-robokop',
#                                                             'attribute_type_id': 'biolink:primary_knowledge_source',
#                                                             'attributes': None,
#                                                             'description': None,
#                                                             'original_attribute_name': 'biolink:primary_knowledge_source',
#                                                             'value': 'infores:STRING',
#                                                             'value_type_id': 'biolink:InformationResource',
#                                                             'value_url': None}],
#                                     'object': 'UniProtKB:Q07869-1',
#                                     'predicate': 'biolink:coexpressed_with',
#                                     'qualifiers': None,
#                                     'subject': 'NCBIGene:2147'},
#                    '18195447': {    'attributes': [    {    'attribute_source': 'infores:automat-robokop',
#                                                             'attribute_type_id': 'biolink:aggregator_knowledge_source',
#                                                             'attributes': None,
#                                                             'description': None,
#                                                             'original_attribute_name': 'biolink:aggregator_knowledge_source',
#                                                             'value': [    'infores:automat-robokop',
#                                                                           'infores:pharos'],
#                                                             'value_type_id': 'biolink:InformationResource',
#                                                             'value_url': None},
#                                                        {    'attribute_source': 'infores:automat-robokop',
#                                                             'attribute_type_id': 'biolink:primary_knowledge_source',
#                                                             'attributes': None,
#                                                             'description': None,
#                                                             'original_attribute_name': 'biolink:primary_knowledge_source',
#                                                             'value': 'DisGeNET',
#                                                             'value_type_id': 'biolink:InformationResource',
#                                                             'value_url': None}],
#                                     'object': 'HP:0001395',
#                                     'predicate': 'biolink:genetic_association',
#                                     'qualifiers': None,
#                                     'subject': 'NCBIGene:120227'},
#                    '19535631': {    'attributes': [    {    'attribute_source': 'infores:automat-robokop',
#                                                             'attribute_type_id': 'biolink:aggregator_knowledge_source',
#                                                             'attributes': None,
#                                                             'description': None,
#                                                             'original_attribute_name': 'biolink:aggregator_knowledge_source',
#                                                             'value': [    'infores:automat-robokop'],
#                                                             'value_type_id': 'biolink:InformationResource',
#                                                             'value_url': None},
#                                                        {    'attribute_source': None,
#                                                             'attribute_type_id': 'biolink:Attribute',
#                                                             'attributes': None,
#                                                             'description': None,
#                                                             'original_attribute_name': 'detection_method',
#                                                             'value': 'MI:1356|MI:0398|MI:0397',
#                                                             'value_type_id': 'EDAM:data_0006',
#                                                             'value_url': None},
#                                                        {    'attribute_source': 'infores:automat-robokop',
#                                                             'attribute_type_id': 'biolink:primary_knowledge_source',
#                                                             'attributes': None,
#                                                             'description': None,
#                                                             'original_attribute_name': 'biolink:primary_knowledge_source',
#                                                             'value': 'infores:intact',
#                                                             'value_type_id': 'biolink:InformationResource',
#                                                             'value_url': None},
#                                                        {    'attribute_source': None,
#                                                             'attribute_type_id': 'biolink:publications',
#                                                             'attributes': None,
#                                                             'description': None,
#                                                             'original_attribute_name': 'publications',
#                                                             'value': [    'PMID:32814053'],
#                                                             'value_type_id': 'EDAM:data_0006',
#                                                             'value_url': None}],
#                                     'object': 'NCBIGene:213',
#                                     'predicate': 'biolink:directly_physically_interacts_with',
#                                     'qualifiers': None,
#                                     'subject': 'NCBIGene:5465'},
#                    '20299346': {    'attributes': [    {    'attribute_source': 'infores:automat-robokop',
#                                                             'attribute_type_id': 'biolink:aggregator_knowledge_source',
#                                                             'attributes': None,
#                                                             'description': None,
#                                                             'original_attribute_name': 'biolink:aggregator_knowledge_source',
#                                                             'value': [    'infores:automat-robokop'],
#                                                             'value_type_id': 'biolink:InformationResource',
#                                                             'value_url': None},
#                                                        {    'attribute_source': 'infores:automat-robokop',
#                                                             'attribute_type_id': 'biolink:primary_knowledge_source',
#                                                             'attributes': None,
#                                                             'description': None,
#                                                             'original_attribute_name': 'biolink:primary_knowledge_source',
#                                                             'value': 'infores:STRING',
#                                                             'value_type_id': 'biolink:InformationResource',
#                                                             'value_url': None}],
#                                     'object': 'UniProtKB:Q07869-1',
#                                     'predicate': 'biolink:coexpressed_with',
#                                     'qualifiers': None,
#                                     'subject': 'NCBIGene:120227'},
#                    '21466662': {    'attributes': [    {    'attribute_source': 'infores:automat-robokop',
#                                                             'attribute_type_id': 'biolink:aggregator_knowledge_source',
#                                                             'attributes': None,
#                                                             'description': None,
#                                                             'original_attribute_name': 'biolink:aggregator_knowledge_source',
#                                                             'value': [    'infores:automat-robokop',
#                                                                           'infores:pharos'],
#                                                             'value_type_id': 'biolink:InformationResource',
#                                                             'value_url': None},
#                                                        {    'attribute_source': 'infores:automat-robokop',
#                                                             'attribute_type_id': 'biolink:primary_knowledge_source',
#                                                             'attributes': None,
#                                                             'description': None,
#                                                             'original_attribute_name': 'biolink:primary_knowledge_source',
#                                                             'value': 'DisGeNET',
#                                                             'value_type_id': 'biolink:InformationResource',
#                                                             'value_url': None}],
#                                     'object': 'HP:0001395',
#                                     'predicate': 'biolink:genetic_association',
#                                     'qualifiers': None,
#                                     'subject': 'NCBIGene:1356'},
#                    '21748134': {    'attributes': [    {    'attribute_source': 'infores:automat-robokop',
#                                                             'attribute_type_id': 'biolink:aggregator_knowledge_source',
#                                                             'attributes': None,
#                                                             'description': None,
#                                                             'original_attribute_name': 'biolink:aggregator_knowledge_source',
#                                                             'value': [    'infores:automat-robokop',
#                                                                           'infores:pharos'],
#                                                             'value_type_id': 'biolink:InformationResource',
#                                                             'value_url': None},
#                                                        {    'attribute_source': 'infores:automat-robokop',
#                                                             'attribute_type_id': 'biolink:primary_knowledge_source',
#                                                             'attributes': None,
#                                                             'description': None,
#                                                             'original_attribute_name': 'biolink:primary_knowledge_source',
#                                                             'value': 'DisGeNET',
#                                                             'value_type_id': 'biolink:InformationResource',
#                                                             'value_url': None}],
#                                     'object': 'HP:0001395',
#                                     'predicate': 'biolink:genetic_association',
#                                     'qualifiers': None,
#                                     'subject': 'NCBIGene:3875'},
#                    '22101363': {    'attributes': [    {    'attribute_source': 'infores:automat-robokop',
#                                                             'attribute_type_id': 'biolink:aggregator_knowledge_source',
#                                                             'attributes': None,
#                                                             'description': None,
#                                                             'original_attribute_name': 'biolink:aggregator_knowledge_source',
#                                                             'value': [    'infores:automat-robokop'],
#                                                             'value_type_id': 'biolink:InformationResource',
#                                                             'value_url': None},
#                                                        {    'attribute_source': 'infores:automat-robokop',
#                                                             'attribute_type_id': 'biolink:primary_knowledge_source',
#                                                             'attributes': None,
#                                                             'description': None,
#                                                             'original_attribute_name': 'biolink:primary_knowledge_source',
#                                                             'value': 'infores:STRING',
#                                                             'value_type_id': 'biolink:InformationResource',
#                                                             'value_url': None}],
#                                     'object': 'NCBIGene:3484',
#                                     'predicate': 'biolink:coexpressed_with',
#                                     'qualifiers': None,
#                                     'subject': 'UniProtKB:Q07869-1'},
#                    '2285184': {    'attributes': [    {    'attribute_source': 'infores:automat-robokop',
#                                                            'attribute_type_id': 'biolink:aggregator_knowledge_source',
#                                                            'attributes': None,
#                                                            'description': None,
#                                                            'original_attribute_name': 'biolink:aggregator_knowledge_source',
#                                                            'value': [    'infores:automat-robokop',
#                                                                          'infores:pharos'],
#                                                            'value_type_id': 'biolink:InformationResource',
#                                                            'value_url': None},
#                                                       {    'attribute_source': 'infores:automat-robokop',
#                                                            'attribute_type_id': 'biolink:primary_knowledge_source',
#                                                            'attributes': None,
#                                                            'description': None,
#                                                            'original_attribute_name': 'biolink:primary_knowledge_source',
#                                                            'value': 'DisGeNET',
#                                                            'value_type_id': 'biolink:InformationResource',
#                                                            'value_url': None}],
#                                    'object': 'HP:0001395',
#                                    'predicate': 'biolink:genetic_association',
#                                    'qualifiers': None,
#                                    'subject': 'NCBIGene:183'},
#                    '29215890': {    'attributes': [    {    'attribute_source': 'infores:automat-robokop',
#                                                             'attribute_type_id': 'biolink:aggregator_knowledge_source',
#                                                             'attributes': None,
#                                                             'description': None,
#                                                             'original_attribute_name': 'biolink:aggregator_knowledge_source',
#                                                             'value': [    'infores:automat-robokop',
#                                                                           'infores:pharos'],
#                                                             'value_type_id': 'biolink:InformationResource',
#                                                             'value_url': None},
#                                                        {    'attribute_source': 'infores:automat-robokop',
#                                                             'attribute_type_id': 'biolink:primary_knowledge_source',
#                                                             'attributes': None,
#                                                             'description': None,
#                                                             'original_attribute_name': 'biolink:primary_knowledge_source',
#                                                             'value': 'DisGeNET',
#                                                             'value_type_id': 'biolink:InformationResource',
#                                                             'value_url': None}],
#                                     'object': 'HP:0001395',
#                                     'predicate': 'biolink:genetic_association',
#                                     'qualifiers': None,
#                                     'subject': 'NCBIGene:4015'},
#                    '29240951': {    'attributes': [    {    'attribute_source': 'infores:automat-robokop',
#                                                             'attribute_type_id': 'biolink:aggregator_knowledge_source',
#                                                             'attributes': None,
#                                                             'description': None,
#                                                             'original_attribute_name': 'biolink:aggregator_knowledge_source',
# ...
#                                                                  'value_type_id': 'EDAM:data_0006',
#                                                                  'value_url': None},
#                                                             {    'attribute_source': None,
#                                                                  'attribute_type_id': 'biolink:symbol',
#                                                                  'attributes': None,
#                                                                  'description': None,
#                                                                  'original_attribute_name': 'symbol',
#                                                                  'value': 'VIM',
#                                                                  'value_type_id': 'EDAM:data_0006',
#                                                                  'value_url': None},
#                                                             {    'attribute_source': None,
#                                                                  'attribute_type_id': 'biolink:Attribute',
#                                                                  'attributes': None,
#                                                                  'description': None,
#                                                                  'original_attribute_name': 'NCBITaxon',
#                                                                  'value': '10090',
#                                                                  'value_type_id': 'EDAM:data_0006',
#                                                                  'value_url': None},
#                                                             {    'attribute_source': None,
#                                                                  'attribute_type_id': 'biolink:Attribute',
#                                                                  'attributes': None,
#                                                                  'description': None,
#                                                                  'original_attribute_name': 'taxon',
#                                                                  'value': 'NCBITaxon9606',
#                                                                  'value_type_id': 'EDAM:data_0006',
#                                                                  'value_url': None},
#                                                             {    'attribute_source': None,
#                                                                  'attribute_type_id': 'biolink:Attribute',
#                                                                  'attributes': None,
#                                                                  'description': None,
#                                                                  'original_attribute_name': 'location',
#                                                                  'value': '10p13',
#                                                                  'value_type_id': 'EDAM:data_0006',
#                                                                  'value_url': None}],
#                                          'categories': [    'biolink:GeneOrGeneProduct',
#                                                             'biolink:MacromolecularMachineMixin',
#                                                             'biolink:GeneProductMixin',
#                                                             'biolink:GenomicEntity',
#                                                             'biolink:Entity',
#                                                             'biolink:BiologicalEntity',
#                                                             'biolink:NamedThing',
#                                                             'biolink:OntologyClass',
#                                                             'biolink:ChemicalEntityOrProteinOrPolypeptide',
#                                                             'biolink:ChemicalEntityOrGeneOrGeneProduct',
#                                                             'biolink:PhysicalEssence',
#                                                             'biolink:Gene',
#                                                             'biolink:PhysicalEssenceOrOccurrent',
#                                                             'biolink:ThingWithTaxon',
#                                                             'biolink:Protein',
#                                                             'biolink:Polypeptide'],
#                                          'name': 'VIM'},
#                    'NCBIGene:866': {    'attributes': [    {    'attribute_source': None,
#                                                                 'attribute_type_id': 'biolink:Attribute',
#                                                                 'attributes': None,
#                                                                 'description': None,
#                                                                 'original_attribute_name': 'locus_group',
#                                                                 'value': 'protein-coding '
#                                                                          'gene',
#                                                                 'value_type_id': 'EDAM:data_0006',
#                                                                 'value_url': None},
#                                                            {    'attribute_source': None,
#                                                                 'attribute_type_id': 'biolink:Attribute',
#                                                                 'attributes': None,
#                                                                 'description': None,
#                                                                 'original_attribute_name': 'information_content',
#                                                                 'value': 100.0,
#                                                                 'value_type_id': 'EDAM:data_0006',
#                                                                 'value_url': None},
#                                                            {    'attribute_source': None,
#                                                                 'attribute_type_id': 'biolink:Attribute',
#                                                                 'attributes': None,
#                                                                 'description': None,
#                                                                 'original_attribute_name': 'location',
#                                                                 'value': '14q32.13',
#                                                                 'value_type_id': 'EDAM:data_0006',
#                                                                 'value_url': None},
#                                                            {    'attribute_source': None,
#                                                                 'attribute_type_id': 'biolink:Attribute',
#                                                                 'attributes': None,
#                                                                 'description': None,
#                                                                 'original_attribute_name': 'NCBITaxon',
#                                                                 'value': '10090',
#                                                                 'value_type_id': 'EDAM:data_0006',
#                                                                 'value_url': None},
#                                                            {    'attribute_source': None,
#                                                                 'attribute_type_id': 'biolink:same_as',
#                                                                 'attributes': None,
#                                                                 'description': None,
#                                                                 'original_attribute_name': 'equivalent_identifiers',
#                                                                 'value': [    'UniProtKB:A0A2Z4LCH4',
#                                                                               'HGNC:1540',
#                                                                               'ENSEMBL:ENSP00000342850',
#                                                                               'UMLS:C1413150',
#                                                                               'UniProtKB:P08185',
#                                                                               'PR:P08185',
#                                                                               'ENSEMBL:ENSP00000484501.1',
#                                                                               'OMIM:122500',
#                                                                               'ENSEMBL:ENSP00000342850.3',
#                                                                               'NCBIGene:866',
#                                                                               'ENSEMBL:ENSP00000484501',
#                                                                               'ENSEMBL:ENSG00000170099'],
#                                                                 'value_type_id': 'metatype:uriorcurie',
#                                                                 'value_url': None},
#                                                            {    'attribute_source': None,
#                                                                 'attribute_type_id': 'biolink:Attribute',
#                                                                 'attributes': None,
#                                                                 'description': None,
#                                                                 'original_attribute_name': 'taxon',
#                                                                 'value': 'NCBITaxon9606',
#                                                                 'value_type_id': 'EDAM:data_0006',
#                                                                 'value_url': None},
#                                                            {    'attribute_source': None,
#                                                                 'attribute_type_id': 'biolink:symbol',
#                                                                 'attributes': None,
#                                                                 'description': None,
#                                                                 'original_attribute_name': 'symbol',
#                                                                 'value': 'SERPINA6',
#                                                                 'value_type_id': 'EDAM:data_0006',
#                                                                 'value_url': None}],
#                                         'categories': [    'biolink:GeneOrGeneProduct',
#                                                            'biolink:MacromolecularMachineMixin',
#                                                            'biolink:GeneProductMixin',
#                                                            'biolink:GenomicEntity',
#                                                            'biolink:Entity',
#                                                            'biolink:BiologicalEntity',
#                                                            'biolink:NamedThing',
#                                                            'biolink:OntologyClass',
#                                                            'biolink:ChemicalEntityOrProteinOrPolypeptide',
#                                                            'biolink:ChemicalEntityOrGeneOrGeneProduct',
#                                                            'biolink:PhysicalEssence',
#                                                            'biolink:Gene',
#                                                            'biolink:PhysicalEssenceOrOccurrent',
#                                                            'biolink:ThingWithTaxon',
#                                                            'biolink:Protein',
#                                                            'biolink:Polypeptide'],
#                                         'name': 'SERPINA6'},
#                    'UniProtKB:Q07869-1': {    'attributes': [    {    'attribute_source': None,
#                                                                       'attribute_type_id': 'biolink:same_as',
#                                                                       'attributes': None,
#                                                                       'description': None,
#                                                                       'original_attribute_name': 'equivalent_identifiers',
#                                                                       'value': [    'UniProtKB:Q07869-1',
#                                                                                     'ENSEMBL:ENSP00000385523.1',
#                                                                                     'ENSEMBL:ENSP00000385246',
#                                                                                     'ENSEMBL:ENSP00000385246.1',
#                                                                                     'PR:Q07869-1',
#                                                                                     'ENSEMBL:ENSP00000385523'],
#                                                                       'value_type_id': 'metatype:uriorcurie',
#                                                                       'value_url': None},
#                                                                  {    'attribute_source': None,
#                                                                       'attribute_type_id': 'biolink:Attribute',
#                                                                       'attributes': None,
#                                                                       'description': None,
#                                                                       'original_attribute_name': 'information_content',
#                                                                       'value': 100.0,
#                                                                       'value_type_id': 'EDAM:data_0006',
#                                                                       'value_url': None}],
#                                               'categories': [    'biolink:GeneOrGeneProduct',
#                                                                  'biolink:MacromolecularMachineMixin',
#                                                                  'biolink:GeneProductMixin',
#                                                                  'biolink:Entity',
#                                                                  'biolink:BiologicalEntity',
#                                                                  'biolink:NamedThing',
#                                                                  'biolink:ChemicalEntityOrGeneOrGeneProduct',
#                                                                  'biolink:ChemicalEntityOrProteinOrPolypeptide',
#                                                                  'biolink:ThingWithTaxon',
#                                                                  'biolink:Protein',
#                                                                  'biolink:Polypeptide'],
#                                               'name': 'peroxisome '
#                                                       'proliferator-activated '
#                                                       'receptor alpha isoform '
#                                                       '1 (human)'}}}

# %% [markdown]
# Information returned for the each Node includes the concept ID (key), biolink categories, the name/label, attributes, the value type, and others.  Note that each entry under the `nodes` level is itemized in dictionary format and not lists.  The content for one Node is shown below.

# %%
#response.json()['message']['knowledge_graph']['nodes'].keys()
next(iter( response.json()['message']['knowledge_graph']['nodes'].items() ))
# Out:
# ('HP:0001395',
#  {'categories': ['biolink:PhenotypicFeature',
#    'biolink:DiseaseOrPhenotypicFeature',
#    'biolink:Entity',
#    'biolink:BiologicalEntity',
#    'biolink:NamedThing',
#    'biolink:ThingWithTaxon'],
#   'name': 'Hepatic fibrosis',
#   'attributes': [{'attribute_type_id': 'biolink:Attribute',
#     'value': 89.8,
#     'value_type_id': 'EDAM:data_0006',
#     'original_attribute_name': 'information_content',
#     'value_url': None,
#     'attribute_source': None,
#     'description': None,
#     'attributes': None},
#    {'attribute_type_id': 'biolink:same_as',
#     'value': ['NCIT:C168581',
#      'MEDDRA:10016648',
#      'HP:0001395',
#      'SNOMEDCT:62484002',
#      'UMLS:C0239946',
#      'MEDDRA:10019668'],
#     'value_type_id': 'metatype:uriorcurie',
#     'original_attribute_name': 'equivalent_identifiers',
#     'value_url': None,
#     'attribute_source': None,
#     'description': None,
#     'attributes': None}]})

# %% [markdown]
# Information returned for the each Edge includes the edge ID (key), the subject's concept ID, the object's concept ID, the edge's predicate, any qualifiers, and attributes.  Note that each entry under the `edges` level is itemized in dictionary format and not lists.  The content for one Edge is shown below.

# %%
next(iter( response.json()['message']['knowledge_graph']['edges'].items() ))
# Out:
# ('29300493',
#  {'subject': 'NCBIGene:5465',
#   'object': 'NCBIGene:6696',
#   'predicate': 'biolink:regulates',
#   'qualifiers': None,
#   'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#     'value': ['infores:hetio', 'infores:automat-robokop'],
#     'value_type_id': 'biolink:InformationResource',
#     'original_attribute_name': 'biolink:aggregator_knowledge_source',
#     'value_url': None,
#     'attribute_source': 'infores:automat-robokop',
#     'description': None,
#     'attributes': None},
#    {'attribute_type_id': 'biolink:primary_knowledge_source',
#     'value': 'infores:lincs',
#     'value_type_id': 'biolink:InformationResource',
#     'original_attribute_name': 'biolink:primary_knowledge_source',
#     'value_url': None,
#     'attribute_source': 'infores:automat-robokop',
#     'description': None,
#     'attributes': None}]})

# %% [markdown]
# Since the edge and node contents are returned as CURIES (Compact URIs) instead of labels, a sample workflow was written to show how to use the above edge information and the Node Normalizer tool to convert results into a human readble form.  This workflow does the following steps:
# - combine edge_binding IDs and convert edge IDs to labels for each result
# - use output from the `knowledge_graph` to convert node IDs to labels
# - write the output dictionary as a CSV

# %%
edges = response.json()['message']['results'][0]['edge_bindings'].keys()
nodes = response.json()['message']['results'][0]['node_bindings'].keys()
edges_nodes = sorted(edges|nodes)

edges_nodes_keys = [s for s in edges_nodes if not s.startswith('s')]
print(edges_nodes_keys)

# Initializing a base dictionary containing edge and node IDs from message results
base_dict = {}
for key in edges_nodes_keys:
    base_dict[key] = {}
print(base_dict)
# Out:
# ['e00', 'e01', 'n00', 'n01', 'n02']
# {'e00': {}, 'e01': {}, 'n00': {}, 'n01': {}, 'n02': {}}

# %%
# Illustrating the structure of each pathway result from the message component
pp.pprint(response.json()['message']['results'][0])
# Out:
# {    'edge_bindings': {    'e00': [    {'attributes': None, 'id': '77699818'},
#                                        {'attributes': None, 'id': '65555672'}],
#                            'e01': [{'attributes': None, 'id': '90073165'}]},
#      'node_bindings': {    'n00': [    {    'attributes': None,
#                                             'id': 'UniProtKB:Q07869-1',
#                                             'qnode_id': 'NCBIGene:5465',
#                                             'query_id': None}],
#                            'n01': [    {    'attributes': None,
#                                             'id': 'NCBIGene:6347',
#                                             'query_id': None}],
#                            'n02': [    {    'attributes': None,
#                                             'id': 'HP:0001395',
#                                             'qnode_id': 'HP:0001395',
#                                             'query_id': None}]},
#      'score': None}

# %%
# - populate base_dict with entries from response.json()['message']['results']
i = 0
for entry in response.json()['message']['results']:
    for edge_id in edges:
        base_dict[edge_id][i] = entry['edge_bindings'][edge_id][0]['id']
    for node_id in nodes:
        base_dict[node_id][i] = entry['node_bindings'][node_id][0]['id']
    i = i + 1
        
pp.pprint(base_dict)
# Out:
# {    'e00': {    0: '77699818',
#                  1: '103813207',
#                  2: '32256396',
#                  3: '57629658',
#                  4: '20299346',
#                  5: '17412017',
#                  6: '20299346',
#                  7: '73429394',
#                  8: '29300493',
#                  9: '112023883',
#                  10: '19535631',
#                  11: '40673173',
#                  12: '103813207',
#                  13: '107697294',
#                  14: '110120221',
#                  15: '13704030',
#                  16: '13704030',
#                  17: '29300493',
#                  18: '45775086',
#                  19: '40673173',
#                  20: '57629658',
#                  21: '3445204',
#                  22: '73429394',
#                  23: '32256396',
#                  24: '17412017',
#                  25: '86622785',
#                  26: '107697294',
#                  27: '60874778',
#                  28: '86622785',
#                  29: '110120221',
#                  30: '112023883',
#                  31: '3445204',
#                  32: '19535631',
#                  33: '77699818',
#                  34: '45775086',
#                  35: '60874778'},
#      'e01': {    0: '90073165',
#                  1: '29240951',
#                  2: '29215890',
#                  3: '122392360',
#                  4: '18195447',
#                  5: '125931491',
#                  6: '18195447',
#                  7: '36344874',
#                  8: '114718535',
#                  9: '125931491',
#                  10: '117760752',
#                  11: '21748134',
#                  12: '29240951',
#                  13: '10563763',
#                  14: '125795180',
#                  15: '104558425',
#                  16: '104558425',
#                  17: '114718535',
#                  18: '21466662',
#                  19: '21748134',
#                  20: '122392360',
#                  21: '58868056',
#                  22: '36344874',
#                  23: '29215890',
#                  24: '125931491',
#                  25: '2285184',
#                  26: '10563763',
#                  27: '2285184',
#                  28: '2285184',
#                  29: '125795180',
#                  30: '125931491',
#                  31: '58868056',
#                  32: '117760752',
#                  33: '90073165',
#                  34: '21466662',
#                  35: '2285184'},
#      'n00': {    0: 'UniProtKB:Q07869-1',
#                  1: 'NCBIGene:5465',
#                  2: 'UniProtKB:Q07869-1',
#                  3: 'UniProtKB:Q07869-1',
#                  4: 'UniProtKB:Q07869-1',
#                  5: 'UniProtKB:Q07869-1',
#                  6: 'UniProtKB:Q07869-1',
#                  7: 'NCBIGene:5465',
#                  8: 'NCBIGene:5465',
#                  9: 'NCBIGene:5465',
#                  10: 'NCBIGene:5465',
#                  11: 'UniProtKB:Q07869-1',
#                  12: 'NCBIGene:5465',
#                  13: 'UniProtKB:Q07869-1',
#                  14: 'NCBIGene:5465',
#                  15: 'UniProtKB:Q07869-1',
#                  16: 'UniProtKB:Q07869-1',
#                  17: 'NCBIGene:5465',
#                  18: 'UniProtKB:Q07869-1',
#                  19: 'UniProtKB:Q07869-1',
#                  20: 'UniProtKB:Q07869-1',
#                  21: 'UniProtKB:Q07869-1',
#                  22: 'NCBIGene:5465',
#                  23: 'UniProtKB:Q07869-1',
#                  24: 'UniProtKB:Q07869-1',
#                  25: 'UniProtKB:Q07869-1',
#                  26: 'UniProtKB:Q07869-1',
#                  27: 'NCBIGene:5465',
#                  28: 'UniProtKB:Q07869-1',
#                  29: 'NCBIGene:5465',
#                  30: 'NCBIGene:5465',
#                  31: 'UniProtKB:Q07869-1',
#                  32: 'NCBIGene:5465',
#                  33: 'UniProtKB:Q07869-1',
#                  34: 'UniProtKB:Q07869-1',
#                  35: 'NCBIGene:5465'},
#      'n01': {    0: 'NCBIGene:6347',
#                  1: 'NCBIGene:5244',
#                  2: 'NCBIGene:4015',
#                  3: 'NCBIGene:1593',
#                  4: 'NCBIGene:120227',
#                  5: 'NCBIGene:2147',
#                  6: 'NCBIGene:120227',
#                  7: 'NCBIGene:7431',
#                  8: 'NCBIGene:6696',
#                  9: 'NCBIGene:2147',
#                  10: 'NCBIGene:213',
#                  11: 'NCBIGene:3875',
#                  12: 'NCBIGene:5244',
#                  13: 'NCBIGene:1269',
#                  14: 'NCBIGene:6772',
#                  15: 'NCBIGene:3484',
#                  16: 'NCBIGene:3484',
#                  17: 'NCBIGene:6696',
#                  18: 'NCBIGene:1356',
#                  19: 'NCBIGene:3875',
#                  20: 'NCBIGene:1593',
#                  21: 'NCBIGene:866',
#                  22: 'NCBIGene:7431',
#                  23: 'NCBIGene:4015',
#                  24: 'NCBIGene:2147',
#                  25: 'NCBIGene:183',
#                  26: 'NCBIGene:1269',
#                  27: 'NCBIGene:183',
#                  28: 'NCBIGene:183',
#                  29: 'NCBIGene:6772',
#                  30: 'NCBIGene:2147',
#                  31: 'NCBIGene:866',
#                  32: 'NCBIGene:213',
#                  33: 'NCBIGene:6347',
#                  34: 'NCBIGene:1356',
#                  35: 'NCBIGene:183'},
#      'n02': {    0: 'HP:0001395',
#                  1: 'HP:0001395',
#                  2: 'HP:0001395',
#                  3: 'HP:0001395',
#                  4: 'HP:0001395',
#                  5: 'HP:0001395',
#                  6: 'HP:0001395',
#                  7: 'HP:0001395',
#                  8: 'HP:0001395',
#                  9: 'HP:0001395',
#                  10: 'HP:0001395',
#                  11: 'HP:0001395',
#                  12: 'HP:0001395',
#                  13: 'HP:0001395',
#                  14: 'HP:0001395',
#                  15: 'HP:0001395',
#                  16: 'HP:0001395',
#                  17: 'HP:0001395',
#                  18: 'HP:0001395',
#                  19: 'HP:0001395',
#                  20: 'HP:0001395',
#                  21: 'HP:0001395',
#                  22: 'HP:0001395',
#                  23: 'HP:0001395',
#                  24: 'HP:0001395',
#                  25: 'HP:0001395',
#                  26: 'HP:0001395',
#                  27: 'HP:0001395',
#                  28: 'HP:0001395',
#                  29: 'HP:0001395',
#                  30: 'HP:0001395',
#                  31: 'HP:0001395',
#                  32: 'HP:0001395',
#                  33: 'HP:0001395',
#                  34: 'HP:0001395',
#                  35: 'HP:0001395'}}

# %%
import copy
output_dict = copy.deepcopy(base_dict)
edge_list = [x for x in output_dict.keys() if 'e' in x]
#print(edge_list)

# - convert and combine edge_binding IDs for each result
for edge_id in edge_list:
    for edge_index, edge_number in output_dict[edge_id].items():
        # Getting the predicate/label using the edge_binding ID from the knowledge graph
        output_dict[edge_id][edge_index] = response.json()['message']['knowledge_graph']['edges'][edge_number]['predicate']

pp.pprint(output_dict)
# Out:
# {    'e00': {    0: 'biolink:coexpressed_with',
#                  1: 'biolink:interacts_with',
#                  2: 'biolink:coexpressed_with',
#                  3: 'biolink:coexpressed_with',
#                  4: 'biolink:coexpressed_with',
#                  5: 'biolink:coexpressed_with',
#                  6: 'biolink:coexpressed_with',
#                  7: 'biolink:regulates',
#                  8: 'biolink:regulates',
#                  9: 'biolink:interacts_with',
#                  10: 'biolink:directly_physically_interacts_with',
#                  11: 'biolink:coexpressed_with',
#                  12: 'biolink:interacts_with',
#                  13: 'biolink:coexpressed_with',
#                  14: 'biolink:interacts_with',
#                  15: 'biolink:coexpressed_with',
#                  16: 'biolink:coexpressed_with',
#                  17: 'biolink:regulates',
#                  18: 'biolink:coexpressed_with',
#                  19: 'biolink:coexpressed_with',
#                  20: 'biolink:coexpressed_with',
#                  21: 'biolink:coexpressed_with',
#                  22: 'biolink:regulates',
#                  23: 'biolink:coexpressed_with',
#                  24: 'biolink:coexpressed_with',
#                  25: 'biolink:coexpressed_with',
#                  26: 'biolink:coexpressed_with',
#                  27: 'biolink:interacts_with',
#                  28: 'biolink:coexpressed_with',
#                  29: 'biolink:interacts_with',
#                  30: 'biolink:interacts_with',
#                  31: 'biolink:coexpressed_with',
#                  32: 'biolink:directly_physically_interacts_with',
#                  33: 'biolink:coexpressed_with',
#                  34: 'biolink:coexpressed_with',
#                  35: 'biolink:interacts_with'},
#      'e01': {    0: 'biolink:genetic_association',
#                  1: 'biolink:genetic_association',
#                  2: 'biolink:genetic_association',
#                  3: 'biolink:genetic_association',
#                  4: 'biolink:genetic_association',
#                  5: 'biolink:genetic_association',
#                  6: 'biolink:genetic_association',
#                  7: 'biolink:genetic_association',
#                  8: 'biolink:genetic_association',
#                  9: 'biolink:genetic_association',
#                  10: 'biolink:genetic_association',
#                  11: 'biolink:genetic_association',
#                  12: 'biolink:genetic_association',
#                  13: 'biolink:genetic_association',
#                  14: 'biolink:genetic_association',
#                  15: 'biolink:genetic_association',
#                  16: 'biolink:genetic_association',
#                  17: 'biolink:genetic_association',
#                  18: 'biolink:genetic_association',
#                  19: 'biolink:genetic_association',
#                  20: 'biolink:genetic_association',
#                  21: 'biolink:genetic_association',
#                  22: 'biolink:genetic_association',
#                  23: 'biolink:genetic_association',
#                  24: 'biolink:genetic_association',
#                  25: 'biolink:genetic_association',
#                  26: 'biolink:genetic_association',
#                  27: 'biolink:genetic_association',
#                  28: 'biolink:genetic_association',
#                  29: 'biolink:genetic_association',
#                  30: 'biolink:genetic_association',
#                  31: 'biolink:genetic_association',
#                  32: 'biolink:genetic_association',
#                  33: 'biolink:genetic_association',
#                  34: 'biolink:genetic_association',
#                  35: 'biolink:genetic_association'},
#      'n00': {    0: 'UniProtKB:Q07869-1',
#                  1: 'NCBIGene:5465',
#                  2: 'UniProtKB:Q07869-1',
#                  3: 'UniProtKB:Q07869-1',
#                  4: 'UniProtKB:Q07869-1',
#                  5: 'UniProtKB:Q07869-1',
#                  6: 'UniProtKB:Q07869-1',
#                  7: 'NCBIGene:5465',
#                  8: 'NCBIGene:5465',
#                  9: 'NCBIGene:5465',
#                  10: 'NCBIGene:5465',
#                  11: 'UniProtKB:Q07869-1',
#                  12: 'NCBIGene:5465',
#                  13: 'UniProtKB:Q07869-1',
#                  14: 'NCBIGene:5465',
#                  15: 'UniProtKB:Q07869-1',
#                  16: 'UniProtKB:Q07869-1',
#                  17: 'NCBIGene:5465',
#                  18: 'UniProtKB:Q07869-1',
#                  19: 'UniProtKB:Q07869-1',
#                  20: 'UniProtKB:Q07869-1',
#                  21: 'UniProtKB:Q07869-1',
#                  22: 'NCBIGene:5465',
#                  23: 'UniProtKB:Q07869-1',
#                  24: 'UniProtKB:Q07869-1',
#                  25: 'UniProtKB:Q07869-1',
#                  26: 'UniProtKB:Q07869-1',
#                  27: 'NCBIGene:5465',
#                  28: 'UniProtKB:Q07869-1',
#                  29: 'NCBIGene:5465',
#                  30: 'NCBIGene:5465',
#                  31: 'UniProtKB:Q07869-1',
#                  32: 'NCBIGene:5465',
#                  33: 'UniProtKB:Q07869-1',
#                  34: 'UniProtKB:Q07869-1',
#                  35: 'NCBIGene:5465'},
#      'n01': {    0: 'NCBIGene:6347',
#                  1: 'NCBIGene:5244',
#                  2: 'NCBIGene:4015',
#                  3: 'NCBIGene:1593',
#                  4: 'NCBIGene:120227',
#                  5: 'NCBIGene:2147',
#                  6: 'NCBIGene:120227',
#                  7: 'NCBIGene:7431',
#                  8: 'NCBIGene:6696',
#                  9: 'NCBIGene:2147',
#                  10: 'NCBIGene:213',
#                  11: 'NCBIGene:3875',
#                  12: 'NCBIGene:5244',
#                  13: 'NCBIGene:1269',
#                  14: 'NCBIGene:6772',
#                  15: 'NCBIGene:3484',
#                  16: 'NCBIGene:3484',
#                  17: 'NCBIGene:6696',
#                  18: 'NCBIGene:1356',
#                  19: 'NCBIGene:3875',
#                  20: 'NCBIGene:1593',
#                  21: 'NCBIGene:866',
#                  22: 'NCBIGene:7431',
#                  23: 'NCBIGene:4015',
#                  24: 'NCBIGene:2147',
#                  25: 'NCBIGene:183',
#                  26: 'NCBIGene:1269',
#                  27: 'NCBIGene:183',
#                  28: 'NCBIGene:183',
#                  29: 'NCBIGene:6772',
#                  30: 'NCBIGene:2147',
#                  31: 'NCBIGene:866',
#                  32: 'NCBIGene:213',
#                  33: 'NCBIGene:6347',
#                  34: 'NCBIGene:1356',
#                  35: 'NCBIGene:183'},
#      'n02': {    0: 'HP:0001395',
#                  1: 'HP:0001395',
#                  2: 'HP:0001395',
#                  3: 'HP:0001395',
#                  4: 'HP:0001395',
#                  5: 'HP:0001395',
#                  6: 'HP:0001395',
#                  7: 'HP:0001395',
#                  8: 'HP:0001395',
#                  9: 'HP:0001395',
#                  10: 'HP:0001395',
#                  11: 'HP:0001395',
#                  12: 'HP:0001395',
#                  13: 'HP:0001395',
#                  14: 'HP:0001395',
#                  15: 'HP:0001395',
#                  16: 'HP:0001395',
#                  17: 'HP:0001395',
#                  18: 'HP:0001395',
#                  19: 'HP:0001395',
#                  20: 'HP:0001395',
#                  21: 'HP:0001395',
#                  22: 'HP:0001395',
#                  23: 'HP:0001395',
#                  24: 'HP:0001395',
#                  25: 'HP:0001395',
#                  26: 'HP:0001395',
#                  27: 'HP:0001395',
#                  28: 'HP:0001395',
#                  29: 'HP:0001395',
#                  30: 'HP:0001395',
#                  31: 'HP:0001395',
#                  32: 'HP:0001395',
#                  33: 'HP:0001395',
#                  34: 'HP:0001395',
#                  35: 'HP:0001395'}}

# %%
node_list = [x for x in output_dict.keys() if 'n' in x]

for node_id in node_list:
    for node_index, node_value in output_dict[node_id].items():
        # Getting the 'name' label using the node ID from the knowledge graph
        output_dict[node_id][node_index] = response.json()['message']['knowledge_graph']['nodes'][node_value]['name']
        
pp.pprint(output_dict)
# Out:
# {    'e00': {    0: 'biolink:coexpressed_with',
#                  1: 'biolink:interacts_with',
#                  2: 'biolink:coexpressed_with',
#                  3: 'biolink:coexpressed_with',
#                  4: 'biolink:coexpressed_with',
#                  5: 'biolink:coexpressed_with',
#                  6: 'biolink:coexpressed_with',
#                  7: 'biolink:regulates',
#                  8: 'biolink:regulates',
#                  9: 'biolink:interacts_with',
#                  10: 'biolink:directly_physically_interacts_with',
#                  11: 'biolink:coexpressed_with',
#                  12: 'biolink:interacts_with',
#                  13: 'biolink:coexpressed_with',
#                  14: 'biolink:interacts_with',
#                  15: 'biolink:coexpressed_with',
#                  16: 'biolink:coexpressed_with',
#                  17: 'biolink:regulates',
#                  18: 'biolink:coexpressed_with',
#                  19: 'biolink:coexpressed_with',
#                  20: 'biolink:coexpressed_with',
#                  21: 'biolink:coexpressed_with',
#                  22: 'biolink:regulates',
#                  23: 'biolink:coexpressed_with',
#                  24: 'biolink:coexpressed_with',
#                  25: 'biolink:coexpressed_with',
#                  26: 'biolink:coexpressed_with',
#                  27: 'biolink:interacts_with',
#                  28: 'biolink:coexpressed_with',
#                  29: 'biolink:interacts_with',
#                  30: 'biolink:interacts_with',
#                  31: 'biolink:coexpressed_with',
#                  32: 'biolink:directly_physically_interacts_with',
#                  33: 'biolink:coexpressed_with',
#                  34: 'biolink:coexpressed_with',
#                  35: 'biolink:interacts_with'},
#      'e01': {    0: 'biolink:genetic_association',
#                  1: 'biolink:genetic_association',
#                  2: 'biolink:genetic_association',
#                  3: 'biolink:genetic_association',
#                  4: 'biolink:genetic_association',
#                  5: 'biolink:genetic_association',
#                  6: 'biolink:genetic_association',
#                  7: 'biolink:genetic_association',
#                  8: 'biolink:genetic_association',
#                  9: 'biolink:genetic_association',
#                  10: 'biolink:genetic_association',
#                  11: 'biolink:genetic_association',
#                  12: 'biolink:genetic_association',
#                  13: 'biolink:genetic_association',
#                  14: 'biolink:genetic_association',
#                  15: 'biolink:genetic_association',
#                  16: 'biolink:genetic_association',
#                  17: 'biolink:genetic_association',
#                  18: 'biolink:genetic_association',
#                  19: 'biolink:genetic_association',
#                  20: 'biolink:genetic_association',
#                  21: 'biolink:genetic_association',
#                  22: 'biolink:genetic_association',
#                  23: 'biolink:genetic_association',
#                  24: 'biolink:genetic_association',
#                  25: 'biolink:genetic_association',
#                  26: 'biolink:genetic_association',
#                  27: 'biolink:genetic_association',
#                  28: 'biolink:genetic_association',
#                  29: 'biolink:genetic_association',
#                  30: 'biolink:genetic_association',
#                  31: 'biolink:genetic_association',
#                  32: 'biolink:genetic_association',
#                  33: 'biolink:genetic_association',
#                  34: 'biolink:genetic_association',
#                  35: 'biolink:genetic_association'},
#      'n00': {    0: 'peroxisome proliferator-activated receptor alpha isoform '
#                     '1 (human)',
#                  1: 'PPARA',
#                  2: 'peroxisome proliferator-activated receptor alpha isoform '
#                     '1 (human)',
#                  3: 'peroxisome proliferator-activated receptor alpha isoform '
#                     '1 (human)',
#                  4: 'peroxisome proliferator-activated receptor alpha isoform '
#                     '1 (human)',
#                  5: 'peroxisome proliferator-activated receptor alpha isoform '
#                     '1 (human)',
#                  6: 'peroxisome proliferator-activated receptor alpha isoform '
#                     '1 (human)',
#                  7: 'PPARA',
#                  8: 'PPARA',
#                  9: 'PPARA',
#                  10: 'PPARA',
#                  11: 'peroxisome proliferator-activated receptor alpha isoform '
#                      '1 (human)',
#                  12: 'PPARA',
#                  13: 'peroxisome proliferator-activated receptor alpha isoform '
#                      '1 (human)',
#                  14: 'PPARA',
#                  15: 'peroxisome proliferator-activated receptor alpha isoform '
#                      '1 (human)',
#                  16: 'peroxisome proliferator-activated receptor alpha isoform '
#                      '1 (human)',
#                  17: 'PPARA',
#                  18: 'peroxisome proliferator-activated receptor alpha isoform '
#                      '1 (human)',
#                  19: 'peroxisome proliferator-activated receptor alpha isoform '
#                      '1 (human)',
#                  20: 'peroxisome proliferator-activated receptor alpha isoform '
#                      '1 (human)',
#                  21: 'peroxisome proliferator-activated receptor alpha isoform '
#                      '1 (human)',
#                  22: 'PPARA',
#                  23: 'peroxisome proliferator-activated receptor alpha isoform '
#                      '1 (human)',
#                  24: 'peroxisome proliferator-activated receptor alpha isoform '
#                      '1 (human)',
#                  25: 'peroxisome proliferator-activated receptor alpha isoform '
#                      '1 (human)',
#                  26: 'peroxisome proliferator-activated receptor alpha isoform '
#                      '1 (human)',
#                  27: 'PPARA',
#                  28: 'peroxisome proliferator-activated receptor alpha isoform '
#                      '1 (human)',
#                  29: 'PPARA',
#                  30: 'PPARA',
#                  31: 'peroxisome proliferator-activated receptor alpha isoform '
#                      '1 (human)',
#                  32: 'PPARA',
#                  33: 'peroxisome proliferator-activated receptor alpha isoform '
#                      '1 (human)',
#                  34: 'peroxisome proliferator-activated receptor alpha isoform '
#                      '1 (human)',
#                  35: 'PPARA'},
#      'n01': {    0: 'CCL2',
#                  1: 'ABCB4',
#                  2: 'LOX',
#                  3: 'CYP27A1',
#                  4: 'CYP2R1',
#                  5: 'F2',
#                  6: 'CYP2R1',
#                  7: 'VIM',
#                  8: 'SPP1',
#                  9: 'F2',
#                  10: 'ALB',
#                  11: 'KRT18',
#                  12: 'ABCB4',
#                  13: 'CNR2',
#                  14: 'STAT1',
#                  15: 'IGFBP1',
#                  16: 'IGFBP1',
#                  17: 'SPP1',
#                  18: 'CP',
#                  19: 'KRT18',
#                  20: 'CYP27A1',
#                  21: 'SERPINA6',
#                  22: 'VIM',
#                  23: 'LOX',
#                  24: 'F2',
#                  25: 'AGT',
#                  26: 'CNR2',
#                  27: 'AGT',
#                  28: 'AGT',
#                  29: 'STAT1',
#                  30: 'F2',
#                  31: 'SERPINA6',
#                  32: 'ALB',
#                  33: 'CCL2',
#                  34: 'CP',
#                  35: 'AGT'},
#      'n02': {    0: 'Hepatic fibrosis',
#                  1: 'Hepatic fibrosis',
#                  2: 'Hepatic fibrosis',
#                  3: 'Hepatic fibrosis',
#                  4: 'Hepatic fibrosis',
#                  5: 'Hepatic fibrosis',
#                  6: 'Hepatic fibrosis',
#                  7: 'Hepatic fibrosis',
#                  8: 'Hepatic fibrosis',
#                  9: 'Hepatic fibrosis',
#                  10: 'Hepatic fibrosis',
#                  11: 'Hepatic fibrosis',
#                  12: 'Hepatic fibrosis',
#                  13: 'Hepatic fibrosis',
#                  14: 'Hepatic fibrosis',
#                  15: 'Hepatic fibrosis',
#                  16: 'Hepatic fibrosis',
#                  17: 'Hepatic fibrosis',
#                  18: 'Hepatic fibrosis',
#                  19: 'Hepatic fibrosis',
#                  20: 'Hepatic fibrosis',
#                  21: 'Hepatic fibrosis',
#                  22: 'Hepatic fibrosis',
#                  23: 'Hepatic fibrosis',
#                  24: 'Hepatic fibrosis',
#                  25: 'Hepatic fibrosis',
#                  26: 'Hepatic fibrosis',
#                  27: 'Hepatic fibrosis',
#                  28: 'Hepatic fibrosis',
#                  29: 'Hepatic fibrosis',
#                  30: 'Hepatic fibrosis',
#                  31: 'Hepatic fibrosis',
#                  32: 'Hepatic fibrosis',
#                  33: 'Hepatic fibrosis',
#                  34: 'Hepatic fibrosis',
#                  35: 'Hepatic fibrosis'}}

# %%
import pandas as pd
import os

if os.path.exists('output'):
    if not os.path.isdir:
        raise Exception('output is not a directory')
else:
    os.makedirs('output')
# Convert JSON String to CSV File
# Read json from String
json_str = json.dumps(output_dict, indent=4)
df = pd.read_json(json_str)
df.to_csv('output/results_TRAPI_automat_multiple_ids.csv')

# %% [markdown]
# The results above are just database matches, there are no scores or other additions.  You can instead send the TRAPI to the robokop application using Aragorn (rather than just to the graph)

# %%
ara_robokop_submit_url = "https://aragorn.renci.org/robokop/query"
response = requests.post(ara_robokop_submit_url,json=query)

# %%
response.status_code
# Out:
# 500

# %%
len(response_ara.json()['message']['results'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [58], line 1
# ----> 1 len(response_ara.json()['message']['results'])
#
# NameError: name 'response_ara' is not defined

# %%
pp.pprint(response_ara.json()['message']['results'])

# %%
for result in response.json()['message']['results']:
    print(result['score'])
